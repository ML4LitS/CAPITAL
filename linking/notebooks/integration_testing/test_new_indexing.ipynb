# %%
knowledge_base_path = '/home/stirunag/work/github/source_data/knowledge_base/'

disease_path = knowledge_base_path+'umls-2022AB-full/'

# %%
import csv
import gzip
from tqdm import tqdm

resources = [
    'HL7V2.5', 'ICD10AM', 'ICD10AMAE', 'LCH', 'MTHICPC2ICD10AE', 'MTHMST',
    'NCI_RENI', 'SNM', 'SNMI', 'SNOMEDCT_VET', 'FMA', 'GO', 'ICD10', 'ICD10AE',
    'ICD10CM', 'ICD9CM', 'LNC', 'MDR', 'MEDLINEPLUS', 'MSH', 'MTH', 'MTHICD9',
    'NCI', 'NCI_BRIDG', 'NCI_CDISC', 'NCI_CTCAE', 'NCI_CTEP-SDC', 'NCI_FDA',
    'NCI_NCI-GLOSS', 'NDFRT', 'OMIM', 'SNOMEDCT_US', 'WHO'
]

def modify_term(term):
    replacements = [
        '-- ',
        ' (physical finding)', ' (diagnosis)', ' (disorder)', ' (procedure)', ' (finding)',
        ' (symptom)', ' (history)', ' (treatment)', ' (manifestation)', ' [Disease/Finding]',
        ' (morphologic abnormality)', ' (etiology)', ' (observable entity)', ' (event)',
        ' (situation)', ' (___ degrees)', ' (in some patients)', ' (___ cm)', ' (___ mm)',
        ' (#___)', ' (rare)', ' (___ degree.)', ' (including anastomotic)', ' (navigational concept)',
        ' (___cm)', ' (1 patient)', ' (qualifier value)', ' (lab test)', ' (unintentional)',
        ' (tophi)', ' (NOS)', ' (___ msec)', ' (RENI)', ' (less common)', ' [as symptom]', ' (s)'
    ]
    for replacement in replacements:
        term = term.replace(replacement, '')
    term = term.replace('-', ' ')
    return term.lower()

def is_required_category(category):
    required_categories = ["T020", "T190", "T049", "T019", "T047", "T050", "T033", "T037", "T048", "T191", "T046", "T184"]
    return category in required_categories

def extract_terms_and_ids_from_umls(input_files, mrsty_file):
    """
    Extract terms and IDs from the provided UMLS into a dictionary.

    Args:
        input_files (list): List of paths to the UMLS files.
        mrsty_file (str): Path to the MRSTY file.

    Returns:
        dict: Dictionary where keys are terms and values are IDs.
    """

    term_to_id = {}

    print("Processing terms from UMLS..")

    # Read each row in MRSTY file and check for the required category
    interested_ids = set()
    with gzip.open(mrsty_file, 'rt') as file:
        reader = csv.reader(file, delimiter='|')
        for row in reader:
            if is_required_category(row[1]):
                interested_ids.add(row[0])

    # Read each row in input_files
    for filename in input_files:
        with gzip.open(filename, 'rt') as file:
            reader = csv.reader(file, delimiter='|')
            for row in tqdm(reader, desc=f"Processing {filename}"):
                if len(row) > 16:  # Ensure there are enough columns in the row
                    if (row and len(row[14]) > 3 and row[1] == "ENG" and row[16] != "0" and
                            row[11] in resources and row[0] in interested_ids):
                        term = modify_term(row[14])
                        term_to_id[term] = row[0]

    return term_to_id

# %%
input_files = [disease_path + 'MRCONSO.RRF.aa.gz', disease_path + 'MRCONSO.RRF.ab.gz']
mrsty_file = disease_path + "MRSTY.RRF.gz"

term_id_dict = extract_terms_and_ids_from_umls(input_files, mrsty_file)
# Out:
# Processing terms from UMLS..
# Processing /home/stirunag/work/github/source_data/knowledge_base/umls-2022AB-full/MRCONSO.RRF.aa.gz: 8607058it [00:18, 475007.92it/s]
# Processing /home/stirunag/work/github/source_data/knowledge_base/umls-2022AB-full/MRCONSO.RRF.ab.gz: 8154375it [00:19, 424103.21it/s]

# %%
term_id_dict
# Out:
# {'abdomen, acute': 'C0000727',
#  'abdomens, acute': 'C0000727',
#  'acute abdomen': 'C0000727',
#  'acute abdomens': 'C0000727',
#  'acute abdomen, nos': 'C0000727',
#  'abdomen   acute': 'C0000727',
#  'syndrome abdominal acute': 'C0000727',
#  'abdominal syndrome acute': 'C0000727',
#  'acute abdominal pain syndrome': 'C0000727',
#  'acute abdominal pain syndrome, nos': 'C0000727',
#  '[d]acute abdomen': 'C0000727',
#  '[d]acute abdomen (context dependent category)': 'C0000727',
#  'surgical abdomen': 'C0000727',
#  'abdominal cramps': 'C0000729',
#  'abdominal cramp': 'C0000729',
#  'cramp abdominal': 'C0000729',
#  'cramp, abdominal': 'C0000729',
#  'cramps, abdominal': 'C0000729',
#  'abdominal crampy pains': 'C0000729',
#  'griping abdominal': 'C0000729',
#  '[d]abdominal cramps': 'C0000729',
#  'griping abdomen': 'C0000729',
#  '[d]abdominal cramps (context dependent category)': 'C0000729',
#  'abdomen distended': 'C0000731',
#  'distended abdomen': 'C0000731',
#  'abdominal distention': 'C0000731',
#  'abdominal distension': 'C0000731',
#  'swollen abdomen': 'C0000731',
#  'swelling of abdomen': 'C0000731',
#  'swelling abdomen': 'C0000731',
#  'swelling of the abdomen': 'C0000731',
#  'abdominal bloating': 'C1291077',
#  'abdominal swelling': 'C0000731',
#  'abdominal swelling, nos': 'C0000731',
#  '[d]abdominal swelling': 'C0000731',
#  'swelling abd': 'C0000731',
#  'abdomen distention': 'C0000731',
#  '[d]abdominal swelling (context dependent category)': 'C0000731',
#  'abdominal mass': 'C0000734',
#  'abdominal mass, nos': 'C0000734',
#  'abdominal mass nos': 'C0000734',
#  'abdominal lump': 'C0000734',
#  'abdominal lump, nos': 'C0000734',
#  '[d]abdominal lump': 'C0000734',
#  '[d]abdominal mass': 'C0000734',
#  'mass in abdomen': 'C0000734',
#  'abdominal mass [ambiguous]': 'C0000734',
#  '[d]abdominal lump (context dependent category)': 'C0000734',
#  '[d]abdominal mass (context dependent category)': 'C0000734',
#  'abdominal neoplasms': 'C0000735',
#  'abdominal neoplasm': 'C0000735',
#  'neoplasm, abdominal': 'C0000735',
#  'neoplasms, abdominal': 'C0000735',
#  'abdominal neoplasm nos': 'C0000735',
#  'neoplasm of abdomen': 'C0000735',
#  'tumor of abdomen': 'C0000735',
#  'tumour of abdomen': 'C0000735',
#  'abdominal tumor': 'C0000735',
#  'abdominal tumour': 'C0000735',
#  'abdominal neopl': 'C0000735',
#  'abdominal pain': 'C0000737',
#  'abdominal pains': 'C0000737',
#  'pain, abdominal': 'C0000737',
#  'pains, abdominal': 'C0000737',
#  'abdominal pain nos': 'C0000737',
#  'pain abdominal': 'C0000737',
#  'abdominal pain, unspecified site': 'C0000737',
#  '[d]abdominal pain': 'C0000737',
#  '[d]abdominal pain nos': 'C0000737',
#  'ap   abdominal pain': 'C0000737',
#  'abd. pain': 'C0000737',
#  'abdo pain': 'C0000737',
#  'pain abdo': 'C0000737',
#  'gut pain': 'C0000737',
#  '[d]abdominal pain nos (context dependent category)': 'C0000737',
#  '[d]abdominal pain (context dependent category)': 'C0000737',
#  'abdmnal pain unspcf site': 'C0000737',
#  'bellyache': 'C0000737',
#  'unspecified abdominal pain': 'C0000737',
#  'abetalipoproteinemia': 'C0000744',
#  'abetalipoproteinaemia': 'C0000744',
#  'bassen kornzweig disease': 'C0000744',
#  'bassen kornzweig syndrome': 'C0000744',
#  'congenital betalipoprotein deficiency syndrome': 'C0000744',
#  'acanthocytosis': 'C0687751',
#  'acanthocytoses': 'C0000744',
#  'abl   abetalipoproteinemia': 'C0000744',
#  'abl   abetalipoproteinaemia': 'C0000744',
#  'betalipoprotein deficiency disease': 'C0000744',
#  'betalipoprotein deficiency diseases': 'C0000744',
#  'deficiency disease, betalipoprotein': 'C0000744',
#  'deficiency diseases, betalipoprotein': 'C0000744',
#  'disease, betalipoprotein deficiency': 'C0000744',
#  'diseases, betalipoprotein deficiency': 'C0000744',
#  'microsomal triglyceride transfer protein deficiency disease': 'C0000744',
#  'homozygous familial hypobetalipoproteinemia': 'C0000744',
#  'homozygous familial hypobetalipoproteinaemia': 'C0000744',
#  'abetalipoproteinemia [ambiguous]': 'C0000744',
#  'microsomal triglyceride transfer protein deficiency': 'C0000744',
#  'mtp deficiency': 'C0000744',
#  'bassen kornzweig dis': 'C0000744',
#  'microsomal triglyceride transfer protein defic dis': 'C0000744',
#  'microsomal triglyceride transfer protein defic': 'C0000744',
#  'congenital abnormal fusion': 'C0000754',
#  'abnormal fusion, congenital': 'C0000754',
#  'congenital abnormal fusions': 'C0000754',
#  'congenital abnormal fusion, nos': 'C0000754',
#  'congenital failure of segmentation': 'C0000754',
#  'congenital failure of segmentation, nos': 'C0000754',
#  'fused structure': 'C0000754',
#  'congenital failure of cleavage': 'C0000754',
#  'congenital failure of cleavage, nos': 'C0000754',
#  'congenitally fused structure': 'C0000754',
#  'congenitally fused structure, nos': 'C0000754',
#  '201 congenital abnormal fusions': 'C0000754',
#  'abnormal position on right side of body': 'C0000762',
#  'excessive body weight gain': 'C0000765',
#  'body weight gain, excessive': 'C0000765',
#  'excessive weight gain': 'C0000765',
#  'excessive body weight gain [ambiguous]': 'C0000765',
#  'excessive weight': 'C0000765',
#  'x ray abnormal': 'C0000766',
#  'abnormal x ray': 'C0000766',
#  'x ray nos abnormal': 'C0000766',
#  'reflexes abnormal nec': 'C0000767',
#  'congenital abnormality': 'C0000768',
#  'abnormalities, congenital': 'C0000768',
#  'abnormality, congenital': 'C0000768',
#  'congenital abnormalities': 'C0000768',
#  'congenital abnormality, nos': 'C0000768',
#  'congenital abnormality nos': 'C0000768',
#  'abnormalities': 'C0000768',
#  'birth defects': 'C0220810',
#  'birth defect': 'C1737329',
#  'defect, birth': 'C0000768',
#  'congenital anomaly': 'C0000768',
#  'congenital anomaly nos': 'C0000768',
#  'anomaly congenital': 'C0000768',
#  'congenital anomalies': 'C0000768',
#  'congenital anomaly, nos': 'C0000768',
#  'congenital defects': 'C0220810',
#  'congenital defect': 'C0000768',
#  'defect, congenital': 'C0000768',
#  'defects, congenital': 'C0000768',
#  'congenital defect, nos': 'C0000768',
#  'congenital malformation': 'C1705254',
#  'congenital malformation, nos': 'C0000768',
#  'developmental anomaly, nos': 'C0000768',
#  'developmental anomaly': 'C0000768',
#  'developmental defect, nos': 'C0000768',
#  'developmental defect': 'C0000768',
#  'developmental malformation, nos': 'C0000768',
#  'developmental malformation': 'C0000768',
#  'developmental malformations': 'C0000768',
#  'dysgenesis, nos': 'C0000768',
#  'dysgenesis': 'C0000768',
#  'malformation, nos': 'C0000768',
#  'malformation': 'C0000768',
#  'abnormal development, nos': 'C0000768',
#  'abnormal development': 'C0000768',
#  'anomalous formation, nos': 'C0000768',
#  'anomalous formation': 'C0000768',
#  'anomaly anomaly congen': 'C0000768',
#  'congenital anomaly, unspecified': 'C0000768',
#  'fetal developmental abnormality': 'C0000768',
#  'foetal developmental abnormality': 'C0242354',
#  'congenital malformation, unspecified': 'C0000768',
#  'fetal malformation': 'C5243499',
#  'foetal malformation': 'C0000768',
#  'developmental abnormality': 'C0000768',
#  'cm   congenital malformation': 'C0000768',
#  'section 2 congenital anomalies': 'C0000768',
#  'congenital deformity': 'C1705254',
#  'congenital deformity, nos': 'C0000768',
#  'congenital deformity nos': 'C0000768',
#  'deformities': 'C0000768',
#  'deformity': 'C0302142',
#  'developmental disturbance': 'C0000768',
#  'congenital anatomic abnormality': 'C0000768',
#  'congenital anatomical abnormality': 'C0000768',
#  'congen defects': 'C0000768',
#  'defects congen': 'C0000768',
#  'congen abnorm': 'C0000768',
#  'abnorm congen': 'C0000768',
#  'congenital anomaly or birth defect': 'C0000768',
#  'abnormalities of size and form of teeth': 'C0000770',
#  'tooth size and form abnormality': 'C0000770',
#  'abnormal tooth size/form': 'C0000770',
#  'abnormalities, drug induced': 'C0000771',
#  'abnormality, drug induced': 'C0000771',
#  'drug induced abnormalities': 'C0000771',
#  'drug induced abnormality': 'C0000771',
#  'drug ind abnorm': 'C0000771',
#  'abnorm drug ind': 'C0000771',
#  'multiple congenital anomalies': 'C1302790',
#  'multiple congenital anomalies nos': 'C0000772',
#  'multiple congenital anomalies, nos': 'C0000772',
#  'anomalies congenital multiple': 'C0000772',
#  'anomaly congenital multiple': 'C0000772',
#  'congenital anomaly, multiple nos': 'C0000772',
#  'abnormalities, multiple': 'C0000772',
#  'multiple abnormalities': 'C0000772',
#  'malformations multiple': 'C0000772',
#  'multiple anomalies, nos': 'C0000772',
#  'multiple congenital abnormalities': 'C0000772',
#  'multiple congenital malformations': 'C1302790',
#  'multiple congenital deformities nos': 'C0000772',
#  'congenital deformity, multiple nos': 'C0000772',
#  'multiple abnorm': 'C0000772',
#  'abnorm multiple': 'C0000772',
#  'abnormalities, radiation induced': 'C0000773',
#  'abnormality, radiation induced': 'C0000773',
#  'radiation induced abnormalities': 'C1527225',
#  'radiation induced abnormality': 'C1527225',
#  'rad ind abnorm': 'C0000773',
#  'abnorm rad ind': 'C0000773',
#  'abnormality of secretion of gastrin': 'C0000774',
#  'abnormality of gastrin secretion': 'C0000774',
#  'gastrin secretion abnormality nos': 'C0000774',
#  'abnorm secretion gastrin': 'C0000774',
#  'gastrin secretion disorder': 'C0000774',
#  'gastrin secretion disorder nos': 'C0000774',
#  'abnormal secretion of gastrin': 'C0000774',
#  'spontaneous abortion': 'C4552766',
#  'abortion, spontaneous': 'C0000786',
#  'abortions, spontaneous': 'C0000786',
#  'spontaneous abortions': 'C0000786',
#  'spontaneous abortion, nos': 'C4552766',
#  'spontaneous abortion nos': 'C0000786',
#  'abortion spontaneous': 'C0000786',
#  'abortion spontaneous nos': 'C0000786',
#  'abortions spontaneous': 'C0000786',
#  'abortion   spontaneous': 'C0000786',
#  'abortions.spontaneous': 'C0000786',
#  'miscarriage': 'C4552766',
#  'miscarriage, nos': 'C4552766',
#  'unspecified spontaneous abortion nos': 'C0000786',
#  'spontaneous abortion unspecified': 'C0000786',
#  'spontaneous abortion, fetus': 'C0000786',
#  'previous abortion': 'C0000790',
#  'abortion, previous': 'C0000790',
#  'abortions, previous': 'C0000790',
#  'previous abortions': 'C0000790',
#  'abortion history': 'C0000790',
#  'abortion histories': 'C0000790',
#  'histories, abortion': 'C0000790',
#  'history, abortion': 'C0000790',
#  'history of abortion': 'C0000790',
#  'history of   abortion nos': 'C0000790',
#  'history of   abortion': 'C0000790',
#  'h/o: abortion': 'C0000790',
#  'h/o: abortion nos': 'C0000790',
#  'h/o: termination': 'C0000790',
#  'history of pregnancy with abortive outcome': 'C0000790',
#  'history of   abortion nos (context dependent category)': 'C0000790',
#  'history of   abortion (context dependent category)': 'C0000790',
#  'history of   termination (context dependent category)': 'C0000790',
#  'history of fetal loss': 'C0000790',
#  'history of   foetal loss': 'C0000790',
#  'history of foetal loss': 'C0000790',
#  'history of   fetal loss': 'C0000790',
#  'abortion hist': 'C0000790',
#  'abortion, criminal': 'C0000804',
#  'abortions, criminal': 'C0000804',
#  'criminal abortion': 'C0000804',
#  'criminal abortions': 'C0000804',
#  'abortion, illegal': 'C0000804',
#  'abortions, illegal': 'C0000804',
#  'illegal abortion': 'C0000804',
#  'illegal abortions': 'C0000804',
#  'illegally induced abortion': 'C0000804',
#  'illegally induced abortion nos': 'C0000804',
#  'abortion induced illegally': 'C0000804',
#  'unspecified illegal abortion nos': 'C0000804',
#  'illegal abortion unspecified': 'C0000804',
#  'illegal termination of pregnancy': 'C0000804',
#  'abortion, habitual': 'C0000809',
#  'habitual abortion': 'C0000809',
#  'habitual abortions': 'C0000809',
#  'habitual aborter': 'C0000809',
#  'habitual aborter nos': 'C0000809',
#  'habitual aborter   unspecified': 'C0000809',
#  'abortion, recurrent': 'C0000809',
#  'recurrent abortion': 'C0000809',
#  'recurrent abortions': 'C0000809',
#  'miscarriage, recurrent': 'C3280670',
#  'recurrent miscarriage': 'C0000809',
#  'recurrent miscarriages': 'C0000809',
#  'recurrent aborter': 'C0000809',
#  'aborter   recurrent': 'C0000809',
#  'recurrent early pregnancy loss': 'C0000809',
#  'incomplete spontaneous abortion': 'C0000810',
#  'incomplete spontaneous abortion nos': 'C0000810',
#  'abortion spontaneous incomplete nos': 'C0000810',
#  'abortion spontaneous incomplete': 'C0000810',
#  'abortion, incomplete': 'C0812470',
#  'abortions, incomplete': 'C0000810',
#  'incomplete abortion': 'C0812470',
#  'incomplete abortions': 'C0000810',
#  'incomplete miscarriage': 'C0812470',
#  'retained products after spontaneous abortion': 'C0000810',
#  'retained products after miscarriage': 'C0000810',
#  'retained tissue after pregnancy loss': 'C0000810',
#  'retained products of conception following spontaneous termination of pregnancy': 'C0000810',
#  'spontaneous abortion: [incomplete nos] or [retained products]': 'C0000810',
#  'missed abortion': 'C0000814',
#  'abortion, missed': 'C0000814',
#  'abortions, missed': 'C0000814',
#  'missed abortions': 'C0000814',
#  'abortion missed': 'C0000814',
#  'foetal death before 22 weeks with retention of dead foetus': 'C0701847',
#  'ma   missed abortion': 'C0000814',
#  'missed miscarriage': 'C0000814',
#  'silent miscarriage': 'C0000814',
#  'abortion, septic': 'C0000817',
#  'abortions, septic': 'C0000817',
#  'septic abortion': 'C0000817',
#  'septic abortions': 'C0000817',
#  'unspecified abortion with sepsis': 'C0000817',
#  'abortion infective': 'C0000817',
#  'infective abortion': 'C0000817',
#  'abortion infected': 'C0000817',
#  'infected abortion': 'C0000817',
#  'abortion with sepsis': 'C0000817',
#  'threatened abortion': 'C0000821',
#  'abortion, threatened': 'C0000821',
#  'threatened abortions': 'C0000821',
#  'abortion threatened': 'C0000821',
#  'threatened abortion, nos': 'C0000821',
#  'threatened abortion nos': 'C0000821',
#  'threatened abortion (antepartum)': 'C0000821',
#  'threatened abortion, antepartum': 'C0000821',
#  'threatened abortion, antepartum condition or complication': 'C0000821',
#  'threatened miscarriage': 'C0000821',
#  'miscarriage, threatened': 'C0000821',
#  'threatened miscarriages': 'C0000821',
#  'threatened abortion unspecified': 'C0000821',
#  'threaten abort antepart': 'C0000821',
#  'abortion, tubal': 'C0000822',
#  'abortions, tubal': 'C0000822',
#  'tubal abortion': 'C0000822',
#  'tubal abortions': 'C0000822',
#  'miscarriage of tubal ectopic pregnancy': 'C0000822',
#  'abortion, veterinary': 'C0000823',
#  'abortions, veterinary': 'C0000823',
#  'veterinary abortion': 'C0000823',
#  'veterinary abortions': 'C0000823',
#  'vet abortion': 'C0000823',
#  'abortion vet': 'C0000823',
#  'abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection': 'C0000827',
#  'abrasion nec': 'C0000827',
#  'abruptio placentae': 'C0000832',
#  'abruptio placentae nos': 'C0000832',
#  'abruptio placenta': 'C0000832',
#  'couvelaire placenta': 'C0000832',
#  'premature placental separation': 'C0000832',
#  'premature separation of placenta': 'C0000832',
#  'prematurely separated placenta': 'C0000832',
#  'premature separation of placenta, unspecified as to episode of care': 'C0000832',
#  'ablatio placentae': 'C0000832',
#  'placental separation': 'C0000832',
#  'premature detachment of normally implanted placenta': 'C0000832',
#  'premature detachment of placenta': 'C0000832',
#  'placental abruption': 'C0000832',
#  'placental abruption nos': 'C0000832',
#  'placental abruptions': 'C0000832',
#  'abruption, placental': 'C0000832',
#  'abruptions, placental': 'C0000832',
#  'accidental haemorrhage': 'C0000832',
#  'accidental hemorrhage': 'C0000832',
#  'premature placental detachment': 'C0000832',
#  'premature separation of placenta [abruptio placentae]': 'C0000832',
#  'placental abruption unspecified': 'C0000832',
#  'accidental antepartum haemorrhage': 'C0000832',
#  'accidental antepartum hemorrhage': 'C0000832',
#  'premature separation of placenta, unspecified': 'C0000832',
#  'abruptio placentae syndrome': 'C0000832',
#  'couvelaire syndrome': 'C0000832',
#  'premature separation of placenta, unsp, unsp trimester': 'C0000832',
#  'premature separation of placenta, unspecified as to episode of care or not applicable': 'C0000832',
#  'detachment of placenta': 'C0000832',
#  'premature separation of normally implanted placenta': 'C0000832',
#  'placental abruption [ambiguous]': 'C0000832',
#  'prem separ placen unspec': 'C0000832',
#  'premature separation of placenta, unspecified, unspecified trimester': 'C0000832',
#  'abscess': 'C0000833',
#  'abscesses': 'C0000833',
#  'abscess nos': 'C0000833',
#  'abscess morphology': 'C0000833',
#  'agenesis': 'C0332907',
#  'posterior tibial pulse absent': 'C0000848',
#  'child abuse nec': 'C0000865',
#  'academic problem': 'C0000873',
#  'academic problems nos': 'C0000873',
#  'acanthamoeba keratitis': 'C0000880',
#  'acanthamoeba keratitides': 'C0000880',
#  'keratitides, acanthamoeba': 'C0000880',
#  'keratitis, acanthamoeba': 'C0000880',
#  'acanthameba keratitis': 'C0000880',
#  'acantholysis': 'C0000887',
#  'acantholyses': 'C0000887',
#  'acanthosis nigricans': 'C0000889',
#  'nigricans, acanthosis': 'C0000889',
#  'keratosis nigricans': 'C0000889',
#  'an   acanthosis nigricans': 'C0000889',
#  'acanthosis nigrican': 'C0000889',
#  'nigrican, acanthosis': 'C0000889',
#  'accident caused by caustic and corrosive substances': 'C0000908',
#  'accid caustic substance': 'C0000908',
#  'accident caused by excessive heat due to weather conditions': 'C0000909',
#  'excessive heat: weather': 'C0000909',
#  'accident due to changes in air pressure due to diving': 'C0000914',
#  'air press change: diving': 'C0000914',
#  'accident caused by lightning': 'C0000915',
#  'accident due to lightning': 'C0000915',
#  'acc due to lightning': 'C0000915',
#  'accidents due to residence or prolonged visit at high altitude': 'C0000916',
#  'accident due to residence or prolonged visit at high altitude': 'C0000916',
#  'accidents due to residence or prolonged visit at high altitude nos': 'C0000916',
#  'high altitude residence': 'C0417648',
#  'accidental falls': 'C0000921',
#  'accidental fall': 'C0000921',
#  'fall, accidental': 'C0000921',
#  'falls, accidental': 'C0000921',
#  'accidental falls nos': 'C0000921',
#  'fall   accidental': 'C0000921',
#  'accidental fall nos': 'C0000921',
#  'falls': 'C0085639',
#  'falling': 'C0085639',
#  'falls (accidents)': 'C0000921',
#  'accidental mechanical suffocation by unspecified means': 'C0000922',
#  'suffocation nos': 'C0004044',
#  'accidental poisoning from other fish': 'C0000923',
#  'acc poison fish nec': 'C0000923',
#  'incised wound': 'C0000925',
#  'incised wound, nos': 'C0000925',
#  'wound, incised': 'C0000925',
#  'incised wound   morphology': 'C0000925',
#  'cut wound': 'C0000925',
#  'accidents due to excessive heat of unspecified origin': 'C0000926',
#  'excessive heat nos': 'C0000926',
#  'traffic accidents': 'C0000932',
#  'accident, traffic': 'C0000932',
#  'accidents, traffic': 'C0000932',
#  'traffic accident': 'C0000932',
#  'achlorhydria': 'C0001075',
#  'achylia gastrica': 'C0001075',
#  'absent gastric acidity': 'C0001075',
#  'gastric acidity, absent': 'C0001075',
#  'achlorhydria, gastric': 'C0001075',
#  'gastric anacidity': 'C0001075',
#  'anacidity, gastric': 'C0001075',
#  'achondrogenesis': 'C0001079',
#  'achondrogenesis, nos': 'C0001079',
#  'achondrogenesis syndrome': 'C0001079',
#  'achondroplasia': 'C0001080',
#  'achondroplasias': 'C0001080',
#  'chondrodystrophia fetalis': 'C0001080',
#  'congenital osteosclerosis': 'C0001080',
#  'achondroplastic dwarfism': 'C2930793',
#  'achondroplastic dwarf': 'C0001080',
#  'dwarf, achondroplastic': 'C0001080',
#  'physiologic dwarfism': 'C0013336',
#  'achondroplastic physique': 'C0001080',
#  'chondrodystrophia foetalis': 'C0001080',
#  'achondroplasia syndrome': 'C0001080',
#  'chondrodystrophy syndrome': 'C0001080',
#  'osteosclerosis congenita': 'C0001080',
#  'chondrodystrophia': 'C0001080',
#  'achromia parasitica': 'C0001083',
#  'acid base imbalance': 'C0001118',
#  'acid base imbalances': 'C0001118',
#  'imbalance, acid base': 'C0001118',
#  'imbalances, acid base': 'C0001118',
#  'acidosis': 'C0001122',
#  'acidoses': 'C0001122',
#  'acidosis, nos': 'C0001122',
#  'acidosis nos': 'C0001122',
#  'acidosis, unspecified': 'C0001122',
#  'acidosis, lactic': 'C0001125',
#  'lactic acidosis': 'C0001125',
#  'acidosis lactic': 'C0001125',
#  'lactic acidosis nos': 'C0001125',
#  'renal tubular acidosis': 'C0001126',
#  'acidosis, renal tubular': 'C0001126',
#  'renal acidosis tubular': 'C0001126',
#  'renal tubular acidosis, nos': 'C0001126',
#  'renal tubular acidosis nos': 'C0001126',
#  'acidosis renal tubular': 'C0001126',
#  'rta, nos': 'C0001126',
#  'rta   renal tubular acidosis': 'C0001126',
#  'acidosis, respiratory': 'C0001127',
#  'acidoses, respiratory': 'C0001127',
#  'respiratory acidoses': 'C0001127',
#  'respiratory acidosis': 'C0001127',
#  'acidosis respiratory': 'C0001127',
#  'respiratory acidosis, nos': 'C0001127',
#  'respiratory acidosis nos': 'C0001127',
#  'acidosis, hypercapneic': 'C0001127',
#  'hypercapnic acidosis': 'C0001127',
#  'acinetobacter infections': 'C0001139',
#  'acinetobacter infection': 'C0001139',
#  'infection, acinetobacter': 'C0001139',
#  'infections, acinetobacter': 'C0001139',
#  'mimae infections': 'C0001139',
#  'infection, mimae': 'C0001139',
#  'infections, mimae': 'C0001139',
#  'mimae infection': 'C0001139',
#  'infection caused by acinetobacter': 'C0001139',
#  'mimae infect': 'C0001139',
#  'infect mimae': 'C0001139',
#  'acinetobacter infect': 'C0001139',
#  'infect acinetobacter': 'C0001139',
#  'acladiosis': 'C0001142',
#  'dermatomycosis by acladium castellani': 'C0001142',
#  'acne vulgaris': 'C0702166',
#  'acne, vulgaris': 'C0001144',
#  'vulgaris   acne': 'C0001144',
#  'acne': 'C0702166',
#  'common acne': 'C0702166',
#  'acne keloid': 'C0001145',
#  'acne keloids': 'C0001145',
#  'keloid, acne': 'C0001145',
#  'keloids, acne': 'C0001145',
#  'folliculitis cheloidalis': 'C0001145',
#  'folliculitis keloidalis': 'C0001145',
#  'keloidal acne': 'C0001145',
#  'acne, keloidal': 'C0001145',
#  'keloidal acnes': 'C0001145',
#  'acne keloidalis': 'C0001145',
#  'dermatitis papillaris capilliti': 'C0001145',
#  'folliculitis keloidalis nuchae': 'C0001145',
#  'keloidalis nuchae, folliculitis': 'C0001145',
#  'nuchae, folliculitis keloidalis': 'C0001145',
#  'sycosis nuchae': 'C0001145',
#  'acne cheloidalis': 'C0001145',
#  'nuchal keloid acne': 'C0001145',
#  'acne, nuchal keloid': 'C0001145',
#  'acnes, nuchal keloid': 'C0001145',
#  'keloid acne, nuchal': 'C0001145',
#  'keloid acnes, nuchal': 'C0001145',
#  'nuchal keloid acnes': 'C0001145',
#  'lichen keloidalis nuchae': 'C0001145',
#  'keloidalis nuchae, lichen': 'C0001145',
#  'nuchae, lichen keloidalis': 'C0001145',
#  'dermatitis papillaris capillitii': 'C0001145',
#  'capillitii, dermatitis papillaris': 'C0001145',
#  'capillitius, dermatitis papillaris': 'C0001145',
#  'dermatitis papillaris capillitius': 'C0001145',
#  'papillaris capillitii, dermatitis': 'C0001145',
#  'papillaris capillitius, dermatitis': 'C0001145',
#  'keloidal folliculitis': 'C0001145',
#  'acne keloidalis nuchae': 'C0001145',
#  'vestibulocochlear nerve diseases': 'C0001163',
#  'vestibulocochlear nerve disease': 'C0001163',
#  'disorder of acoustic nerve': 'C0001163',
#  'disorders of acoustic nerve': 'C0001163',
#  'disorders of the acoustic nerve': 'C0001163',
#  'disorder of acoustic nerve, nos': 'C0001163',
#  'acoustic nerve disorder nos': 'C0001163',
#  'acoustic nerve disorders': 'C0750885',
#  'acoustic nerve disorder': 'C0750885',
#  'disorder of eighth nerve': 'C0001163',
#  'disorder of eighth nerve, nos': 'C0001163',
#  'disorder of the vestibulocochlear nerve': 'C0001163',
#  'disorder of the vestibulocochlear nerve, nos': 'C0001163',
#  'disorder of vestibulocochlear nerve': 'C0001163',
#  'vestibulocochlear nerve disorder': 'C0001163',
#  'acoustic nerve disorder, nos (see also section x)': 'C0001163',
#  'auditory nerve disease or syndrome': 'C0001163',
#  'eighth cranial nerve disease or syndrome': 'C0001163',
#  'eight cranial nerve disorder': 'C0001163',
#  'disorder of cranial nerve 8': 'C0001163',
#  'disorder of eighth cranial nerve': 'C0001163',
#  'a 959 disorders of the acoustic nerve': 'C0001163',
#  'disorder of acoustovestibular nerve': 'C0001163',
#  'disorder of auditory nerve': 'C0001163',
#  'auditory nerve disorders': 'C0001163',
#  'auditory nerve disorder': 'C0001163',
#  'viiith cranial nerve disorders': 'C0001163',
#  'eighth cranial nerve diseases': 'C0001163',
#  'cranial nerve viii diseases': 'C0001163',
#  'cranial nerve viii disorders': 'C0001163',
#  'disorder of acoustic or eighth nerve': 'C0001163',
#  'eighth cranial nerve dis': 'C0001163',
#  'vestibulocochlear nerve dis': 'C0001163',
#  'cranial nerve viii dis': 'C0001163',
#  'complete obstruction': 'C0001168',
#  'acquired atresia': 'C0001168',
#  'occlusion': 'C0028778',
#  'obturation': 'C0001168',
#  'acquired coagulation factor deficiency': 'C0001169',
#  'acquired coagulation factor deficiency, nos': 'C0001169',
#  'acquired coagulation factor deficiency nos': 'C0001169',
#  'acquired clotting factor deficiency': 'C0001169',
#  'acq coagul factor defic': 'C0001169',
#  'acquired deformities of auricle or pinna': 'C0001170',
#  'acq deform auricle/pinna': 'C0001170',
#  'acquired deformity of chest and rib': 'C0001171',
#  'acquired chest and rib deformity': 'C0001171',
#  'acquired chest or rib deformity nos': 'C0001171',
#  'acq chest deformity': 'C0001171',
#  'acquired obstruction of pylorus': 'C0001173',
#  'gastric outlet obstruction': 'C0162651',
#  'acquired pyloric obstruction': 'C0001173',
#  'adult pyloric stenosis': 'C0001173',
#  'gastric outflow obstruction': 'C0162651',
#  'acquired immunodeficiency syndrome': 'C0001175',
#  'acquired immunodeficiency syndromes': 'C0001175',
#  'immunodeficiency syndrome, acquired': 'C0001175',
#  'immunodeficiency syndromes, acquired': 'C0001175',
#  'syndrome, acquired immunodeficiency': 'C0001175',
#  'syndromes, acquired immunodeficiency': 'C0001175',
#  'acquired immunodeficiency syndrome, nos': 'C0001175',
#  'acquired immunodeficiency syndrome nos': 'C0001175',
#  'aids': 'C0001175',
#  'aids, nos': 'C0001175',
#  'acquired immune deficiency syndr': 'C0001175',
#  'acquired immune deficiency syndrome': 'C0001175',
#  'acquired immune deficiency syndrome, nos': 'C0001175',
#  'immunologic deficiency syndrome, acquired': 'C0001175',
#  'aids   acquired immunodeficiency syndrome': 'C0001175',
#  'acquired human immunodeficiency virus infection syndrome nos': 'C0001175',
#  'immunodeficiency due to human immunodeficiency virus infection': 'C0001175',
#  'acquired immune deficiency syndrome (aids)': 'C0001175',
#  'acquired immune deficiency syndrome [aids]': 'C0001175',
#  'autoimmune deficiency syndrome': 'C0001175',
#  'acquired immunodeficiency syndrome, unspecified': 'C0001175',
#  'hiv/aids': 'C0001175',
#  'acquired immune defic. synd.': 'C0001175',
#  'acquired immune defic. syndr.': 'C0001175',
#  'acquired immune deficiency': 'C0001175',
#  'acquired immuno deficiency syndrome': 'C0001175',
#  'acquired immuno deficiency syndromes': 'C0001175',
#  'immuno deficiency syndrome, acquired': 'C0001175',
#  'immuno deficiency syndromes, acquired': 'C0001175',
#  'syndrome, acquired immuno deficiency': 'C0001175',
#  'syndromes, acquired immuno deficiency': 'C0001175',
#  'acquired immune defic syndrome': 'C0001175',
#  'acquired immuno defic syndrome': 'C0001175',
#  'immunol defic syndrome acquired': 'C0001175',
#  'immunodefic syndrome acquired': 'C0001175',
#  'acquired immunodefic syndrome': 'C0001175',
#  'apert syndrome': 'C0001193',
#  "apert's syndrome": 'C0001193',
#  'syndrome, apert': 'C0001193',
#  'acrocephalosyndactyly syndrome, type i': 'C0001193',
#  'acrocephalosyndactyly, type i': 'C1510455',
#  'acrocephalosyndactyly type i': 'C0001193',
#  'type i acrocephalosyndactyly': 'C0001193',
#  'acrocephalosyndactylies, type i': 'C0001193',
#  'type i acrocephalosyndactylies': 'C0001193',
#  'acrocephalosyndactyly (apert)': 'C0001193',
#  'acrocephalosyndactyly [apert]': 'C0001193',
#  'acs1': 'C0001193',
#  'acs i': 'C0001193',
#  'syndactylic oxycephaly': 'C0001193',
#  'syndactylic oxycephalies': 'C0001193',
#  'acrocephalosyndactyly, type 1': 'C0001193',
#  'acrocephalosyndactylies, type 1': 'C0001193',
#  'acrodermatitis': 'C0263372',
#  'acrodermatitides': 'C0001197',
#  'acrodermatitis, nos': 'C0001197',
#  'acrodynia': 'C0001198',
#  'acrodynia due to mercury': 'C0001198',
#  'erythredema polyneuropathy': 'C0001198',
#  'feer disease': 'C4553710',
#  "feer's disease": 'C0001198',
#  'pink disease': 'C4553710',
#  'disease pink': 'C0001198',
#  'swift disease': 'C4553710',
#  "swift's disease": 'C0001198',
#  'swifts disease': 'C0001198',
#  'acrodynia due to mercury poisoning': 'C0001198',
#  'acrodynia caused by mercury': 'C0001198',
#  'acrodynia caused by mercury poisoning': 'C0001198',
#  'acrodynic erythema': 'C0001198',
#  'erythema, acrodynic': 'C0001198',
#  'chronic childhood mercurialism': 'C0001198',
#  'childhood mercurialism, chronic': 'C0001198',
#  'mercurialism, chronic childhood': 'C0001198',
#  'childhood mercurialisms, chronic': 'C0001198',
#  'chronic childhood mercurialisms': 'C0001198',
#  "bilderbeck's disease": 'C0001198',
#  'swift feer disease': 'C4553710',
#  "selter's disease": 'C0001198',
#  'feers disease': 'C0001198',
#  'erythroedema polyneuropathy': 'C0001198',
#  'feer dis': 'C0001198',
#  'feers dis': 'C0001198',
#  'swift dis': 'C0001198',
#  'swifts dis': 'C0001198',
#  'pink dis': 'C0001198',
#  'acrokeratosis': 'C0001202',
#  'acromegaly': 'C0001206',
#  'acromegalia': 'C0001206',
#  'eosinophilic adenoma syndrome': 'C0001206',
#  "marie's syndrome": 'C0001206',
#  'anterior pituitary adenoma syndrome': 'C0001206',
#  'marie disease': 'C0001206',
#  'growth hormone hypersecretion syndrome': 'C0001206',
#  'sth hypersecretion syndrome': 'C0001206',
#  'inappropriate gh secretion syndrome (acromegaly)': 'C0001206',
#  'inappropriate growth hormone secretion syndrome (acromegaly)': 'C0001206',
#  'somatotropin hypersecretion syndrome (acromegaly)': 'C0001206',
#  'hypersecretion syndrome, somatotropin (acromegaly)': 'C0001206',
#  'hypersecretion syndromes, somatotropin (acromegaly)': 'C0001206',
#  'somatotropin hypersecretion syndromes (acromegaly)': 'C0001206',
#  'syndrome, somatotropin hypersecretion (acromegaly)': 'C0001206',
#  'syndromes, somatotropin hypersecretion (acromegaly)': 'C0001206',
#  'inappropriate growth hormone secret syndrome acromegaly': 'C0001206',
#  'inappropriate gh secret syndrome acromegaly': 'C0001206',
#  'somatotropin hypersecret syndrome acromegaly': 'C0001206',
#  'hypersomatotropic gigantism': 'C0001207',
#  'launois syndrome': 'C0001207',
#  "launois' syndrome": 'C0001207',
#  'acromegalic gigantism': 'C0001207',
#  'acth syndrome, ectopic': 'C0001231',
#  'acth syndromes, ectopic': 'C0001231',
#  'ectopic acth syndrome': 'C0001231',
#  'ectopic acth syndromes': 'C0001231',
#  'syndrome, ectopic acth': 'C0001231',
#  'syndromes, ectopic acth': 'C0001231',
#  'hypercortisolism due to nonpituitary tumor': 'C0001231',
#  'hypercortisolism due to nonpituitary tumour': 'C0001231',
#  "ectopic acth secretion causing cushing's syndrome": 'C0001231',
#  'ectopic acth secretion': 'C0001231',
#  'ectopic adrenocorticotropic hormone secretion': 'C0001231',
#  'ectopic corticotropin syndrome': 'C0001231',
#  'ectopic corticotrophin syndrome': 'C0001231',
#  'ectopic acth secretion syndrome': 'C0001231',
#  'actinobacillosis': 'C0001247',
#  'actinobacilloses': 'C0001247',
#  'actinobacillosis, nos': 'C0001247',
#  'actinobacillus infections': 'C0001249',
#  'actinobacillus infection': 'C0001249',
#  'infection, actinobacillus': 'C0001249',
#  'infections, actinobacillus': 'C0001249',
#  'actinobacillus infection, nos': 'C0001249',
#  'e 11c actinobacillus infections': 'C0001249',
#  'actinobacillus infect': 'C0001249',
#  'infect actinobacillus': 'C0001249',
#  'actinomycetales infections': 'C0001255',
#  'actinomycetales infection': 'C0001255',
#  'infection, actinomycetales': 'C0001255',
#  'infections, actinomycetales': 'C0001255',
#  'actinomycete infections': 'C0001255',
#  'actinomycete infection': 'C0001255',
#  'infection, actinomycete': 'C0001255',
#  'infections, actinomycete': 'C0001255',
#  'infection caused by actinomycetales': 'C0001255',
#  'actinomycetales infect': 'C0001255',
#  'infect actinomycetales': 'C0001255',
#  'actinomycete infect': 'C0001255',
#  'infect actinomycete': 'C0001255',
#  'actinomycosis': 'C0001261',
#  'actinomycoses': 'C0001261',
#  'actinomycosis, nos': 'C0001261',
#  'actinomycosis nos': 'C0001261',
#  'actinomyces infections': 'C0001261',
#  'actinomyces infection': 'C0001261',
#  'infection, actinomyces': 'C0001261',
#  'infections, actinomyces': 'C0001261',
#  'actinomycotic infection of unspecified site': 'C0001261',
#  'actinomycotic infection': 'C0001261',
#  'actinomycotic infections': 'C0001261',
#  'actinomycotic infection, nos': 'C0001261',
#  'actinomycosis unspecified site nos': 'C0001261',
#  'actinomycosis unspecified site': 'C0001261',
#  'actinomycosis, unspecified': 'C0001261',
#  '[x]actinomycosis, unspecified': 'C0001261',
#  'e 110 actinomycotic infections': 'C0001261',
#  'actinomycotic infectious disorders': 'C0001261',
#  'infect actinomyces': 'C0001261',
#  'actinomyces infect': 'C0001261',
#  'abdominal actinomycosis': 'C0001263',
#  'actinomycosis, abdominal': 'C0001263',
#  'ray fungus disease of the intestines': 'C0001263',
#  'actinomycotic abdominal infection': 'C0001263',
#  'abdominal actinomycotic infection': 'C0001263',
#  'cervicofacial actinomycosis': 'C0001264',
#  'actinomycosis, cervicofacial': 'C0001264',
#  'cervicofacial actinomycotic infection': 'C0001264',
#  'lumpy jaw': 'C1264617',
#  'cervico facial actinomycosis': 'C0001264',
#  'cervicofac actinomycosis': 'C0001264',
#  'actinomycotic infection of other specified sites': 'C0001265',
#  'actinomycosis nec': 'C0001265',
#  'acute abscess': 'C0001304',
#  'acute adenoviral follicular conjunctivitis': 'C0001305',
#  'acute alcoholic liver disease': 'C0001306',
#  'acute alcoholic hepatitis': 'C0001306',
#  'ac alcoholic hepatitis': 'C0001306',
#  'acute and subacute liver necrosis': 'C0001308',
#  'acute and subacute liver necrosis nos': 'C0001308',
#  'acute and subacute necrosis of liver': 'C0001308',
#  'acute necrosis of liver': 'C0001364',
#  'acute/subac. necrosis of liver': 'C0001308',
#  'acute atopic conjunctivitis': 'C0001309',
#  'critical allergic conjunctivitis syndrome': 'C0001309',
#  "angelucci's syndrome": 'C0001309',
#  'acute allergic conjunctivitis': 'C0001309',
#  'ac atopic conjunctivitis': 'C0001309',
#  'acute bronchiolitis': 'C0001311',
#  'acute bronchiolitis, nos': 'C0001311',
#  'acute bronchiolitis nos': 'C0001311',
#  'bronchiolitis (acute)': 'C0001311',
#  'capillary pneumonia': 'C0001311',
#  'acute capillary bronchiolitis': 'C0001311',
#  'acute bronchiolitis, unspecified': 'C0001311',
#  'acute disease': 'C0001314',
#  'acute diseases': 'C0001314',
#  'disease, acute': 'C0001314',
#  'diseases, acute': 'C0001314',
#  'acute disease, nos': 'C0001314',
#  'acute dis': 'C0001314',
#  'acute erythremia and erythroleukemia': 'C0001317',
#  'acute erythraemia and erythroleukaemia': 'C0001317',
#  'acute laryngitis': 'C0001327',
#  'acute laryngitis nos': 'C0001327',
#  'laryngitis (acute) nos': 'C0001327',
#  'laryngitis (acute)': 'C0001327',
#  'laryngitis acute nos': 'C0001327',
#  'herpetic acute necrotizing encephalitis': 'C0001338',
#  'acute necrotizing encephalitis, herpetic': 'C0001338',
#  'herpetic acute necrotising encephalitis': 'C0001338',
#  'herpetic acute necrotizing enceph': 'C0001338',
#  'acute necrotizing enceph herpetic': 'C0001338',
#  'pancreatitis, acute': 'C0001339',
#  'acute pancreatitis': 'C0001339',
#  'pancreatitis acute': 'C0001339',
#  'acute pancreatitis nos': 'C0001339',
#  'acute pancreatitides': 'C0001339',
#  'pancreatitides, acute': 'C0001339',
#  'pancreatitis (& [acute nos])': 'C0001339',
#  'acute pancreatitis, unspecified': 'C0001339',
#  'acute pancreatitis unspecified': 'C0001339',
#  'ap   acute pancreatitis': 'C0001339',
#  'acute pancreatitis [ambiguous]': 'C0001339',
#  'acute periodontitis': 'C0001342',
#  'acute periodontitis nos': 'C0001342',
#  'acute pericementitis': 'C0001342',
#  'aggressive and acute periodontitis': 'C0001342',
#  'aggressive periodontitis': 'C0031106',
#  'acute pharyngitis': 'C0001344',
#  'acute pharyngitis, nos': 'C0001344',
#  'acute pharyngitis nos': 'C0001344',
#  'pharyngitis (acute) nos': 'C0001344',
#  'pharyngitis   acute': 'C0001344',
#  'acute pharyngitis, unspecified': 'C0001344',
#  'acute pharyngitis [ambiguous]': 'C0001344',
#  'acute phase reaction': 'C0001349',
#  'reaction, acute phase': 'C0001349',
#  'acute phase state': 'C0001349',
#  'state, acute phase': 'C0001349',
#  'response, acute phase': 'C0001349',
#  'acute phase response': 'C0001349',
#  'acute phase responses': 'C0001349',
#  'phase response, acute': 'C0001349',
#  'acute renal failure with other specified pathological lesion in kidney': 'C0001355',
#  'acute thyroiditis': 'C0001360',
#  'acute thyroiditis nos': 'C0001360',
#  'thyroiditis acute': 'C0001360',
#  'acute tonsillitis': 'C0001361',
#  'acute tonsillitis nos': 'C0001361',
#  'tonsillitis (acute) nos': 'C0001361',
#  'tonsillitis acute nos': 'C0001361',
#  'acute tonsillitis, nos': 'C0001361',
#  'tonsillitis (& acute)': 'C0001361',
#  'infective tonsillitis': 'C0001361',
#  'tonsillitis, infective': 'C0001361',
#  'acute tonsillitis, unspecified': 'C0001361',
#  'acute vascular insufficiency of intestine': 'C0001363',
#  'acute vascular insufficiency of intestine, nos': 'C0001363',
#  'acute mesenteric ischemia': 'C0001363',
#  'acute mesenteric ischaemia': 'C0001363',
#  'acute intestinal vascular insufficiency': 'C0001363',
#  'acute intestinal vascular insufficiency nos': 'C0001363',
#  'acute intestinal ischemia': 'C0001363',
#  'acute intestinal ischaemia': 'C0001363',
#  'acute intestinal ischemic syndrome': 'C0001363',
#  'acute intestinal ischemic syndrome, nos': 'C0001363',
#  'acute intestinal ischaemic syndrome, nos': 'C0001363',
#  'acute intestinal ischaemic syndrome': 'C0001363',
#  'ami   acute mesenteric ischemia': 'C0001363',
#  'ami   acute mesenteric ischaemia': 'C0001363',
#  'ac vasc insuff intestine': 'C0001363',
#  'massive hepatic necrosis': 'C0001364',
#  'hepatic necrosis, massive': 'C0001364',
#  'acute yellow atrophy': 'C0001364',
#  'atrophy, acute yellow': 'C0001364',
#  'acute yellow atrophies': 'C0001364',
#  'yellow atrophy, acute': 'C0001364',
#  'acute yellow atrophy of liver': 'C0001364',
#  'acute yellow liver atrophy': 'C0001364',
#  'atrophy acute yellow liver': 'C0001364',
#  'massive necrosis of liver': 'C0001364',
#  'acute hepatic necrosis': 'C0001364',
#  'acute necrosis of liver nos': 'C0001364',
#  'acute hepatic necrosis [ambiguous]': 'C0001364',
#  'acute ill defined cerebrovascular disease': 'C0001365',
#  'acute ill defined cerebrovascular disease, nos': 'C0001365',
#  'acute, but ill defined, cerebrovascular disease': 'C0001365',
#  'adams stokes syndrome': 'C0001396',
#  'stokes adams syndrome': 'C0001396',
#  'syndrome, adams stokes': 'C0001396',
#  'syndrome, stokes adams': 'C0001396',
#  'adam stokes syndrome': 'C0001396',
#  'syndrome adams stokes': 'C0001396',
#  'syndrome stokes adams': 'C0001396',
#  "morgagni adam's stokes syndrome": 'C0001396',
#  'morgagni adams stokes syndrome': 'C0001396',
#  'stokes adams morgagni syndrome': 'C0001396',
#  'stokes adams attacks': 'C0001396',
#  'adam stokes attacks': 'C0001396',
#  'attacks, adam stokes': 'C0001396',
#  'attacks, stokes adams': 'C0001396',
#  'adams stokes attack': 'C0001396',
#  'stokes adams attack': 'C0001396',
#  "morgagni's disease": 'C0001396',
#  "spens' syndrome": 'C0001396',
#  'stokes adams: [syndrome] or [attack]': 'C0001396',
#  'addison disease': 'C0001403',
#  "addison's disease": 'C0001403',
#  'addisons disease': 'C0001403',
#  'disease, addison': 'C0001403',
#  "addison's disease, nos": 'C0001403',
#  "disease addison's": 'C0001403',
#  "addison's disease nos": 'C0001403',
#  'adrenal insufficiency (addison disease)': 'C0001403',
#  'primary adrenal deficiency': 'C0001403',
#  'primary adrenal insufficiency': 'C3887896',
#  'adrenal insufficiency, primary': 'C0001403',
#  'primary adrenocortical insufficiency': 'C0001403',
#  'insufficiencies, primary adrenocortical': 'C0001403',
#  'insufficiency, primary adrenocortical': 'C0001403',
#  'primary adrenocortical insufficiencies': 'C0001403',
#  'adrenocortical insufficiencies, primary': 'C0001403',
#  'adrenocortical insufficiency, primary': 'C0001403',
#  'primary hypoadrenalism': 'C0001403',
#  'hypoadrenalism, primary': 'C0001403',
#  'chronic primary adrenal insufficiency': 'C0001403',
#  "addison's disease [ambiguous]": 'C0001403',
#  'hypoadrenalisms, primary': 'C0001403',
#  'addison dis': 'C0001403',
#  'addisons dis': 'C0001403',
#  'primary adrenocortical failure': 'C0001403',
#  'hypocortisolism': 'C1833054',
#  'adenitis': 'C0024205',
#  'adenitides': 'C0001416',
#  'adenitis, nos': 'C0024205',
#  '[d]adenitis nos': 'C0001416',
#  'adenocarcinoma': 'C0001418',
#  'adenocarcinomas': 'C0001418',
#  'adenocarcinoma nos': 'C0001418',
#  'adenocarcinoma, nos': 'C0001418',
#  '[m]adenocarcinoma nos': 'C0001418',
#  '[m]adenocarcinomas': 'C0001418',
#  'adenoma, malignant': 'C0001418',
#  'adenomas, malignant': 'C0001418',
#  'malignant adenoma': 'C0001418',
#  'malignant adenomas': 'C0001418',
#  'carcinoma in adenoma': 'C0001418',
#  'adenocarcinoma, no subtype': 'C0001418',
#  'papillary adenocarcinoma': 'C0001420',
#  'adenocarcinoma, papillary': 'C0001420',
#  'adenocarcinomas, papillary': 'C0001420',
#  'papillary adenocarcinomas': 'C0001420',
#  'papillary adenocarcinoma, nos': 'C0001420',
#  'papillary adenocarcinoma nos': 'C0001420',
#  '[m]papillary adenocarcinoma nos': 'C0001420',
#  'adenofibroma': 'C0001422',
#  'adenofibromas': 'C0001422',
#  'adenofibroma, nos': 'C0001422',
#  'adenofibroma nos': 'C0001422',
#  'benign adenofibroma': 'C0001422',
#  '[m]adenofibroma nos': 'C0001422',
#  'adenofibroma, no international classification of diseases for oncology subtype': 'C0001422',
#  'adenofibroma, no icd o subtype': 'C0001422',
#  'adenoiditis': 'C0001427',
#  'adenoiditis, nos': 'C0001427',
#  'adenolymphoma': 'C0001429',
#  'adenolymphomas': 'C0001429',
#  'cystadenoma lymphomatosum, papillary': 'C0001429',
#  'papillary cystadenoma lymphomatosum': 'C0001429',
#  'warthin tumor': 'C0001429',
#  "warthin's tumor": 'C0001429',
#  'tumor, warthin': 'C0001429',
#  "warthin's tumour": 'C0001429',
#  'salivary gland warthin tumor': 'C0001429',
#  'adenoma': 'C0001430',
#  'adenomas': 'C0001430',
#  'adenoma, nos': 'C0001430',
#  'adenoma nos': 'C0001430',
#  '[m]adenoma nos': 'C0001430',
#  '[m]adenomas': 'C0001430',
#  'benign adenoma': 'C0001430',
#  'adenoma benign': 'C0001430',
#  'adenoma benign nos': 'C0001430',
#  'benign adenomatous neoplasm': 'C0001430',
#  ...}

# %%
import pickle
import numpy as np
import spacy
import faiss
from tqdm import tqdm
import warnings
import gc
from rapidfuzz import process, fuzz
from sklearn.metrics.pairwise import cosine_similarity
from scispacy.abbreviation import AbbreviationDetector

warnings.simplefilter("ignore")

# Function to create quantized Faiss index
def create_quantized_index(embeddings_np, d):
    nlist = 1000
    m = 30
    quantizer = faiss.IndexFlatL2(d)
    index = faiss.IndexIVFPQ(quantizer, d, nlist, m, 8)
    index.train(embeddings_np)
    return index

# Function to calculate mean vector from the model's vocabulary
def calculate_mean_vector(model):
    vectors = [word.vector for word in model.vocab if word.has_vector]
    if vectors:
        mean_vector = np.mean(vectors, axis=0)
        return mean_vector
    else:
        return np.zeros((300,))

# Function to get average embeddings for terms in batches using the user's model, with mean vector fallback
def get_average_embeddings_batched(terms, model, mean_vector):
    docs = list(model.pipe(terms))
    embeddings = []
    for doc in docs:
        valid_vectors = [token.vector for token in doc if token.has_vector and token.vector.shape[0] == 300]
        if len(valid_vectors) == 0:
            embeddings.append(mean_vector)
        else:
            average_embedding = np.mean(valid_vectors, axis=0)
            embeddings.append(average_embedding)
    return embeddings

# Preprocessing and indexing function to create Faiss index and save necessary data
def preprocess_and_index(term_id_dict, output_pickle_filename, output_list, faiss_index_filename, model_path, batch_size=10000):
    # Load your custom embedding model
    nlp_model = spacy.load(model_path)
    mean_vector = calculate_mean_vector(nlp_model)

    embeddings = []
    indexed_terms = []

    terms = list(term_id_dict.keys())
    ids = list(term_id_dict.values())

    for idx in tqdm(range(0, len(terms), batch_size), desc="Generating Embeddings"):
        term_batch = terms[idx: idx + batch_size]
        id_batch = ids[idx: idx + batch_size]

        batch_embeddings = get_average_embeddings_batched(term_batch, nlp_model, mean_vector)

        for term, term_id, embedding in zip(term_batch, id_batch, batch_embeddings):
            norm = np.linalg.norm(embedding)
            if norm == 0:
                print(f"Term '{term}' with ID '{term_id}' has a zero vector.")
            normalized_embedding = embedding if norm == 0 else embedding / norm
            embeddings.append(normalized_embedding)
            indexed_terms.append(term)
        gc.collect()

    d = 300
    embeddings_np = np.array(embeddings).astype('float32')
    index = create_quantized_index(embeddings_np, d)
    index.add(embeddings_np)
    del embeddings, embeddings_np
    gc.collect()

    print("Saving quantized faiss index...")
    faiss.write_index(index, faiss_index_filename)

    print("Saving term to ID mapping and indexed terms...")
    with open(output_pickle_filename, "wb") as outfile:
        pickle.dump({"term_to_id": term_id_dict, "indexed_terms": indexed_terms}, outfile)

    print("Writing terms to a txt file...")
    with open(output_list, "w") as txt_file:
        for term in term_id_dict.keys():
            txt_file.write(term + "\n")

# Function to load Faiss index and mappings
def load_faiss_and_mappings(faiss_index_filename, pickle_filename):
    index = faiss.read_index(faiss_index_filename)
    with open(pickle_filename, "rb") as infile:
        data = pickle.load(infile)
    return index, data["term_to_id"], data["indexed_terms"]

# Functions for exact, fuzzy, and embedding-based matching
def get_exact_match(term, term_dict):
    return term_dict.get(term)

def get_fuzzy_match(term, term_dict, threshold=70):
    result = process.extractOne(term, term_dict.keys(), scorer=fuzz.ratio)
    if result:
        match, score, _ = result
        if score >= threshold:
            return term_dict[match]
    return None

def get_embedding_match(term, index, indexed_terms, term_dict, model, threshold=0.7):
    term_vector = model(term).vector.reshape(1, -1).astype('float32')
    faiss.normalize_L2(term_vector)
    _, I = index.search(term_vector, 1)
    if I[0][0] != -1:
        matched_term = indexed_terms[I[0][0]]
        similarity = cosine_similarity(term_vector, model(matched_term).vector.reshape(1, -1))[0][0]
        if similarity >= threshold:
            # Ensure that the matched term exists in term_dict
            return term_dict.get(matched_term, "No Match")
    return None

def expand_abbreviations(term, model):
    abbreviation_detector = AbbreviationDetector(model)
    model.add_pipe(abbreviation_detector, last=True)
    doc = model(term)
    expanded_term = []
    for token in doc:
        if token._.long_form:
            expanded_term.append(token._.long_form)
        else:
            expanded_term.append(token.text)
    return " ".join(expanded_term)

def map_terms(entities, term_dict, index, indexed_terms, model, scispacy_model):
    """Map new entities using exact, fuzzy, and embedding matches, with abbreviation fallback."""
    mapped_entities = {}
    for entity in entities:
        # Step 1: Initial matching
        match = get_exact_match(entity, term_dict)
        if not match:
            match = get_fuzzy_match(entity, term_dict)
        if not match:
            match = get_embedding_match(entity, index, indexed_terms, term_dict, model)

        # Step 2: Abbreviation Expansion and Retry if no match
        if not match:
            expanded_entity = expand_abbreviations(entity, scispacy_model)
            if expanded_entity != entity:  # Only retry if abbreviation expanded
                match = get_exact_match(expanded_entity, term_dict)
                if not match:
                    match = get_fuzzy_match(expanded_entity, term_dict)
                if not match:
                    match = get_embedding_match(expanded_entity, index, indexed_terms, term_dict, model)

        mapped_entities[entity] = match if match else "No Match"
    return mapped_entities

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_md-0.5.4.tar.gz

# %%
# Step 1: Preprocess and Index
spacy_path =   "/home/stirunag/work/github/CAPITAL/normalisation/en_floret_model" # "en_core_sci_md"en_core_sci_
preprocess_and_index(term_id_dict, "term_mapping.pkl", "indexed_terms.txt", "faiss_index.idx", spacy_path)
# Out:
# Generating Embeddings: 100%|████████████████████████████████████████████████████████████████| 82/82 [04:23<00:00,  3.21s/it]
# Saving quantized faiss index...
# Saving term to ID mapping and indexed terms...
# Writing terms to a txt file...

# %%
# Step 3: Perform Mappings
new_entities = ['abdominal lump, nos', 'abdominal tumor', 'unknown term', 'T2DM', "asthma", "acute bronchitis"]
nlp_model = spacy.load(spacy_path) # spacy.load("en_core_sci_lg")  # Correctly load the SciSpaCy model
scispacy_model = spacy.load("en_core_sci_md")  # SciSpaCy model for abbreviation expansion

# %%
mapped_entities = map_terms(new_entities, term_dict, index, indexed_terms, nlp_model, scispacy_model)
mapped_entities
# Out:
# {'abdominal lump, nos': 'C0000734',
#  'abdominal tumor': 'C0000735',
#  'unknown term': 'C3846629',
#  'T2DM': 'C0362046',
#  'asthma': 'C0004096',
#  'acute bronchitis': 'C0149514'}

# %%
cui = "C0149514"
# Reverse the dictionary to find terms by their CUI
id_to_term = {v: k for k, v in term_id_dict.items()}
term = id_to_term.get(cui, "Unknown CUI")
print(f"The term associated with '{cui}' is: {term}")
# Out:
# The term associated with 'C0149514' is: acute chest infections

# %%
import random

# Original term2dict dictionary for reference
term2dict = {
    'abdominal lump, nos': 'C0000734',
    '[d]abdominal lump': 'C0000734',
    '[d]abdominal mass': 'C0000734',
    'mass in abdomen': 'C0000734',
    'abdominal mass [ambiguous]': 'C0000734',
    '[d]abdominal lump (context dependent category)': 'C0000734',
    '[d]abdominal mass (context dependent category)': 'C0000734',
    'abdominal neoplasms': 'C0000735',
    'abdominal neoplasm': 'C0000735',
    'neoplasm, abdominal': 'C0000735',
}

# Function to create a modified version of a term
def modify_term(term):
    words = term.split()
    
    # Choose a random modification: replace a word, jumble, or introduce a typo
    modification_type = random.choice(['replace', 'jumble', 'typo'])
    
    if modification_type == 'replace' and len(words) > 1:
        # Replace a word with a similar word or synonym
        synonyms = {
            'abdominal': 'belly',
            'mass': 'lump',
            'neoplasms': 'tumors',
            'neoplasm': 'tumor',
            'lump': 'swelling',
            'mass': 'growth',
        }
        word_to_replace = random.choice(words)
        if word_to_replace in synonyms:
            replacement = synonyms[word_to_replace]
            words[words.index(word_to_replace)] = replacement
    
    elif modification_type == 'jumble' and len(words) > 1:
        # Randomly shuffle the words
        random.shuffle(words)
    
    elif modification_type == 'typo':
        # Introduce a small typo in a random word
        word_to_modify = random.choice(words)
        if len(word_to_modify) > 1:
            index = random.randint(0, len(word_to_modify) - 1)
            typo_word = list(word_to_modify)
            typo_word[index] = random.choice('abcdefghijklmnopqrstuvwxyz')
            words[words.index(word_to_modify)] = ''.join(typo_word)
    
    return ' '.join(words)

# Create a test set by modifying the terms in the dictionary
test_set = {}
for term, term_id in term2dict.items():
    modified_term = modify_term(term)
    test_set[modified_term] = term_id

print("Generated Test Set:")
for original, modified in zip(term2dict.keys(), test_set.keys()):
    print(f"Original: {original} --> Modified: {modified}")
# Out:
# Generated Test Set:
# Original: abdominal lump, nos --> Modified: abdominal lump, nos
# Original: [d]abdominal lump --> Modified: lump [d]abdominal
# Original: [d]abdominal mass --> Modified: [d]abdominal mass
# Original: mass in abdomen --> Modified: abdomen mass in
# Original: abdominal mass [ambiguous] --> Modified: abdominal mass [ambiguzus]
# Original: [d]abdominal lump (context dependent category) --> Modified: [d]abdominal lump (context dependent catelory)
# Original: [d]abdominal mass (context dependent category) --> Modified: mass dependent [d]abdominal (context category)
# Original: abdominal neoplasms --> Modified: abdominal tumors
# Original: abdominal neoplasm --> Modified: neoplasm abdominal
# Original: neoplasm, abdominal --> Modified: neoplasm, abdominal

# %%
# Use the generated test set as input to evaluate performance
test_terms = list(test_set.keys())
mapped_results = map_terms(test_terms, term2dict, index, indexed_terms, nlp_model, scispacy_model)

# Compare the mapped results with the correct IDs from the test set
correct_mappings = 0
total_mappings = len(test_terms)

print("\nMapping Performance:")
for test_term, original_id in test_set.items():
    predicted_id = mapped_results[test_term]
    if predicted_id == original_id:
        correct_mappings += 1
        result = "Correct"
    else:
        result = "Incorrect"
    print(f"Test Term: {test_term} | Predicted ID: {predicted_id} | Expected ID: {original_id} | {result}")

accuracy = correct_mappings / total_mappings * 100
print(f"\nAccuracy: {accuracy:.2f}%")
# Out:
# Mapping Performance:
# Test Term: abdominal lump, nos | Predicted ID: C0000734 | Expected ID: C0000734 | Correct
# Test Term: lump [d]abdominal | Predicted ID: C0000734 | Expected ID: C0000734 | Correct
# Test Term: [d]abdominal mass | Predicted ID: C0000734 | Expected ID: C0000734 | Correct
# Test Term: abdomen mass in | Predicted ID: C0000734 | Expected ID: C0000734 | Correct
# Test Term: abdominal mass [ambiguzus] | Predicted ID: C0000734 | Expected ID: C0000734 | Correct
# Test Term: [d]abdominal lump (context dependent catelory) | Predicted ID: C0000734 | Expected ID: C0000734 | Correct
# Test Term: mass dependent [d]abdominal (context category) | Predicted ID: C0000734 | Expected ID: C0000734 | Correct
# Test Term: abdominal tumors | Predicted ID: C0000734 | Expected ID: C0000735 | Incorrect
# Test Term: neoplasm abdominal | Predicted ID: C0000735 | Expected ID: C0000735 | Correct
# Test Term: neoplasm, abdominal | Predicted ID: C0000735 | Expected ID: C0000735 | Correct
#
# Accuracy: 90.00%

# %%
import csv
import gzip
from tqdm import tqdm

resources = [
    'HL7V2.5', 'ICD10AM', 'ICD10AMAE', 'LCH', 'MTHICPC2ICD10AE', 'MTHMST',
    'NCI_RENI', 'SNM', 'SNMI', 'SNOMEDCT_VET', 'FMA', 'GO', 'ICD10', 'ICD10AE',
    'ICD10CM', 'ICD9CM', 'LNC', 'MDR', 'MEDLINEPLUS', 'MSH', 'MTH', 'MTHICD9',
    'NCI', 'NCI_BRIDG', 'NCI_CDISC', 'NCI_CTCAE', 'NCI_CTEP-SDC', 'NCI_FDA',
    'NCI_NCI-GLOSS', 'NDFRT', 'OMIM', 'SNOMEDCT_US', 'WHO'
]

def modify_term(term):
    replacements = [
        '-- ', ' (physical finding)', ' (diagnosis)', ' (disorder)', ' (procedure)', ' (finding)',
        ' (symptom)', ' (history)', ' (treatment)', ' (manifestation)', ' [Disease/Finding]',
        ' (morphologic abnormality)', ' (etiology)', ' (observable entity)', ' (event)',
        ' (situation)', ' (___ degrees)', ' (in some patients)', ' (___ cm)', ' (___ mm)',
        ' (#___)', ' (rare)', ' (___ degree.)', ' (including anastomotic)', ' (navigational concept)',
        ' (___cm)', ' (1 patient)', ' (qualifier value)', ' (lab test)', ' (unintentional)',
        ' (tophi)', ' (NOS)', ' (___ msec)', ' (RENI)', ' (less common)', ' [as symptom]', ' (s)'
    ]
    for replacement in replacements:
        term = term.replace(replacement, '')
    term = term.replace('-', ' ')
    return term.lower()

def is_required_category(category):
    required_categories = ["T020", "T190", "T049", "T019", "T047", "T050", "T033", "T037", "T048", "T191", "T046", "T184"]
    return category in required_categories

def extract_terms_and_ids_from_umls(input_files, mrsty_file):
    """
    Extract terms and IDs from the provided UMLS into a dictionary.

    Args:
        input_files (list): List of paths to the UMLS files.
        mrsty_file (str): Path to the MRSTY file.

    Returns:
        dict: Dictionary where keys are terms and values are IDs.
    """

    term_to_id = {}
    abbreviation_to_longform = {}

    print("Processing terms from UMLS..")

    # Read each row in MRSTY file and check for the required category
    interested_ids = set()
    with gzip.open(mrsty_file, 'rt') as file:
        reader = csv.reader(file, delimiter='|')
        for row in reader:
            if is_required_category(row[1]):
                interested_ids.add(row[0])

    # Read each row in input_files
    for filename in input_files:
        with gzip.open(filename, 'rt') as file:
            reader = csv.reader(file, delimiter='|')
            for row in tqdm(reader, desc=f"Processing {filename}"):
                if len(row) > 16:
                    # Check for English terms, preferred terms (PT) and abbreviations (AB)
                    cui = row[0]
                    term = modify_term(row[14])
                    term_type = row[12]
                    if row[1] == "ENG" and row[16] != "0" and row[11] in resources and cui in interested_ids:
                        # Store preferred terms as long forms
                        if term_type == "PT":
                            term_to_id[term] = cui
                        # Store abbreviations and link them to their long forms using the same CUI
                        elif term_type == "AB" and cui in term_to_id:
                            abbreviation_to_longform[term] = term_to_id[cui]

    # Combine term_to_id with abbreviations
    term_to_id.update(abbreviation_to_longform)
    return term_to_id, abbreviation_to_longform

# %%
knowledge_base_path = '/home/stirunag/work/github/source_data/knowledge_base/'

disease_path = knowledge_base_path+'umls-2022AB-full/'

# %%
input_files = [disease_path + 'MRCONSO.RRF.aa.gz', disease_path + 'MRCONSO.RRF.ab.gz']
mrsty_file = disease_path + "MRSTY.RRF.gz"

term_id_dict, abbr_dict = extract_terms_and_ids_from_umls(input_files, mrsty_file)
# Out:
# Processing terms from UMLS..
# Processing /home/stirunag/work/github/source_data/knowledge_base/umls-2022AB-full/MRCONSO.RRF.aa.gz: 8607058it [00:43, 198039.56it/s]
# Processing /home/stirunag/work/github/source_data/knowledge_base/umls-2022AB-full/MRCONSO.RRF.ab.gz: 8154375it [00:44, 183224.64it/s]

# %%
term_id_dict
# Out:
# {'acute abdomen, nos': 'C0000727',
#  'acute abdomen': 'C0000727',
#  'abdominal cramp': 'C0000729',
#  'abdominal cramps': 'C0000729',
#  'abdominal distention': 'C0000731',
#  'abdominal distension': 'C0000731',
#  'swollen abdomen': 'C0000731',
#  'abdomen distention': 'C0000731',
#  'abdominal mass': 'C0000734',
#  'abdominal mass, nos': 'C0000734',
#  'abdominal neoplasms': 'C0000735',
#  'abdominal neoplasm': 'C0000735',
#  'neoplasm of abdomen': 'C0000735',
#  'abdominal pain': 'C0000737',
#  'abdominal pain, unspecified site': 'C0000737',
#  'unspecified abdominal pain': 'C0000737',
#  'abetalipoproteinemia': 'C0000744',
#  'abetalipoproteinaemia': 'C0000744',
#  'congenital abnormal fusion': 'C0000754',
#  'abnormal fusion, congenital': 'C0000754',
#  'congenital abnormal fusion, nos': 'C0000754',
#  'excessive body weight gain': 'C0000765',
#  'body weight gain, excessive': 'C0000765',
#  'excessive weight gain': 'C0000765',
#  'x ray abnormal': 'C0000766',
#  'abnormal x ray': 'C0000766',
#  'congenital abnormality': 'C0000768',
#  'abnormalities': 'C0000768',
#  'congenital anomaly': 'C0000768',
#  'congenital anomaly nos': 'C0000768',
#  'congenital malformation': 'C0000768',
#  'developmental anomaly, nos': 'C0000768',
#  'developmental malformation': 'C0000768',
#  'congenital anomaly, unspecified': 'C0000768',
#  'congenital malformation, unspecified': 'C0000768',
#  'foetal malformation': 'C0000768',
#  'congenital deformity': 'C0000768',
#  'abnormalities of size and form of teeth': 'C0000770',
#  'multiple congenital anomalies, nos': 'C0000772',
#  'multiple congenital anomalies': 'C0000772',
#  'malformations multiple': 'C0000772',
#  'multiple congenital abnormalities': 'C0000772',
#  'abnormality of secretion of gastrin': 'C0000774',
#  'gastrin secretion disorder': 'C0000774',
#  'abnormal secretion of gastrin': 'C0000774',
#  'abortion, spontaneous': 'C0000786',
#  'spontaneous abortion': 'C0000786',
#  'spontaneous abortion, nos': 'C0000786',
#  'abortion spontaneous': 'C0000786',
#  'history of pregnancy with abortive outcome': 'C0000790',
#  'abortion, criminal': 'C0000804',
#  'illegal abortion': 'C0000804',
#  'illegally induced abortion': 'C0000804',
#  'abortion, habitual': 'C0000809',
#  'habitual abortion': 'C0000809',
#  'habitual aborter': 'C0000809',
#  'recurrent abortion': 'C0000809',
#  'recurrent miscarriage': 'C0000809',
#  'abortion spontaneous incomplete': 'C0000810',
#  'incomplete miscarriage': 'C0000810',
#  'retained products after miscarriage': 'C0000810',
#  'missed abortion': 'C0000814',
#  'abortion missed': 'C0000814',
#  'abortion, missed': 'C0000814',
#  'missed miscarriage': 'C0000814',
#  'abortion, septic': 'C0000817',
#  'septic abortion': 'C0000817',
#  'unspecified abortion with sepsis': 'C0000817',
#  'abortion infected': 'C0000817',
#  'threatened abortion': 'C0000821',
#  'abortion threatened': 'C0000821',
#  'abortion, threatened': 'C0000821',
#  'threatened abortion, nos': 'C0000821',
#  'threatened abortion, antepartum condition or complication': 'C0000821',
#  'threatened miscarriage': 'C0000821',
#  'miscarriage of tubal ectopic pregnancy': 'C0000822',
#  'abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection': 'C0000827',
#  'abruptio placentae': 'C0000832',
#  'premature separation of placenta': 'C0000832',
#  'placental separation': 'C0000832',
#  'placental abruption': 'C0000832',
#  'premature separation of placenta, unspecified': 'C0000832',
#  'abruptio placentae syndrome': 'C0000832',
#  'premature separation of placenta, unspecified as to episode of care or not applicable': 'C0000832',
#  'premature separation of placenta, unspecified, unspecified trimester': 'C0000832',
#  'abscess': 'C0000833',
#  'abscess morphology': 'C0000833',
#  'agenesis': 'C0000846',
#  'posterior tibial pulse absent': 'C0000848',
#  'academic problem': 'C0000873',
#  'acanthamoeba keratitis': 'C0000880',
#  'acantholysis': 'C0000887',
#  'acanthosis nigricans': 'C0000889',
#  'accident caused by caustic and corrosive substances': 'C0000908',
#  'accident caused by excessive heat due to weather conditions': 'C0000909',
#  'accident due to changes in air pressure due to diving': 'C0000914',
#  'accident caused by lightning': 'C0000915',
#  'accident due to lightning': 'C0000915',
#  'accidents due to residence or prolonged visit at high altitude': 'C0000916',
#  'accident due to residence or prolonged visit at high altitude': 'C0000916',
#  'accidental falls': 'C0000921',
#  'accidental fall': 'C0000921',
#  'falls (accidents)': 'C0000921',
#  'accidental mechanical suffocation by unspecified means': 'C0000922',
#  'accidental poisoning from other fish': 'C0000923',
#  'incised wound': 'C0000925',
#  'incised wound, nos': 'C0000925',
#  'wound, incised': 'C0000925',
#  'cut': 'C0000925',
#  'incised wound   morphology': 'C0000925',
#  'accidents due to excessive heat of unspecified origin': 'C0000926',
#  'accidents, traffic': 'C0000932',
#  'traffic accident': 'C0000932',
#  'achlorhydria': 'C0001075',
#  'achylia gastrica': 'C0001075',
#  'gastric acidity, absent': 'C0001075',
#  'achondrogenesis': 'C0001079',
#  'achondrogenesis, nos': 'C0001079',
#  'achondrogenesis syndrome': 'C0001079',
#  'achondroplasia': 'C0001080',
#  'dwarf, achondroplastic': 'C0001080',
#  'achondroplasia syndrome': 'C0001080',
#  'acid base imbalance': 'C0001118',
#  'acid base imbalances': 'C0001118',
#  'acidosis': 'C0001122',
#  'acidosis, nos': 'C0001122',
#  'acidosis, unspecified': 'C0001122',
#  'lactic acidosis': 'C0001125',
#  'acidosis lactic': 'C0001125',
#  'renal tubular acidosis': 'C0001126',
#  'renal tubular acidosis, nos': 'C0001126',
#  'respiratory acidosis': 'C0001127',
#  'acidosis respiratory': 'C0001127',
#  'acidosis, respiratory': 'C0001127',
#  'respiratory acidosis, nos': 'C0001127',
#  'acinetobacter infection': 'C0001139',
#  'infection caused by acinetobacter': 'C0001139',
#  'acladiosis': 'C0001142',
#  'acne vulgaris': 'C0001144',
#  'acne': 'C0702166',
#  'acne keloid': 'C0001145',
#  'acne keloidalis': 'C0001145',
#  'folliculitis keloidalis nuchae': 'C0001145',
#  'dermatitis papillaris capillitii': 'C0001145',
#  'disorder of acoustic nerve': 'C0001163',
#  'disorders of acoustic nerve': 'C0001163',
#  'disorder of acoustic nerve, nos': 'C0001163',
#  'vestibulocochlear nerve disorder': 'C0001163',
#  'eighth cranial nerve disease or syndrome': 'C0001163',
#  'eight cranial nerve disorder': 'C0001163',
#  'auditory nerve disorder': 'C0001163',
#  'complete obstruction': 'C0001168',
#  'acquired coagulation factor deficiency': 'C0001169',
#  'acquired coagulation factor deficiency, nos': 'C0001169',
#  'acquired deformities of auricle or pinna': 'C0001170',
#  'acquired deformity of chest and rib': 'C0001171',
#  'acquired obstruction of pylorus': 'C0001173',
#  'acquired immunodeficiency syndrome': 'C0001175',
#  'aids': 'C0001175',
#  'aids, nos': 'C0001175',
#  'hiv/aids': 'C0001175',
#  "apert's syndrome": 'C0001193',
#  'apert syndrome': 'C0001193',
#  'acrocephalosyndactyly type i': 'C0001193',
#  'type i acrocephalosyndactyly': 'C0001193',
#  'acrodermatitis': 'C0001197',
#  'acrodermatitis, nos': 'C0001197',
#  'acrodynia': 'C0001198',
#  'acrodynia due to mercury poisoning': 'C0001198',
#  'acrokeratosis': 'C0001202',
#  'acromegaly': 'C0001206',
#  'hypersomatotropic gigantism': 'C0001207',
#  'ectopic acth syndrome': 'C0001231',
#  'hypercortisolism due to nonpituitary tumor': 'C0001231',
#  'ectopic acth secretion': 'C0001231',
#  'ectopic acth secretion syndrome': 'C0001231',
#  'actinobacillus infection, nos': 'C0001249',
#  'actinobacillus infection': 'C0001249',
#  'actinomycetales infection': 'C0001255',
#  'infection caused by actinomycetales': 'C0001255',
#  'actinomycosis': 'C0001261',
#  'actinomycosis, nos': 'C0001261',
#  'actinomycotic infection of unspecified site': 'C0001261',
#  'actinomycotic infection': 'C0001261',
#  'actinomycotic infection, nos': 'C0001261',
#  'actinomycosis, unspecified': 'C0001261',
#  'abdominal actinomycosis': 'C0001263',
#  'actinomycotic abdominal infection': 'C0001263',
#  'abdominal actinomycotic infection': 'C0001263',
#  'cervicofacial actinomycosis': 'C0001264',
#  'cervicofacial actinomycotic infection': 'C0001264',
#  'actinomycotic infection of other specified sites': 'C0001265',
#  'acute abscess': 'C0001304',
#  'acute adenoviral follicular conjunctivitis': 'C0001305',
#  'acute alcoholic liver disease': 'C0001306',
#  'acute alcoholic hepatitis': 'C0001306',
#  'acute and subacute liver necrosis': 'C0001308',
#  'acute and subacute necrosis of liver': 'C0001308',
#  'acute atopic conjunctivitis': 'C0001309',
#  'critical allergic conjunctivitis syndrome': 'C0001309',
#  'acute bronchiolitis': 'C0001311',
#  'acute bronchiolitis, nos': 'C0001311',
#  'acute bronchiolitis, unspecified': 'C0001311',
#  'acute disease, nos': 'C0001314',
#  'acute disease': 'C0001314',
#  'acute erythremia and erythroleukemia': 'C0001317',
#  'acute erythraemia and erythroleukaemia': 'C0001317',
#  'acute laryngitis': 'C0001327',
#  'acute necrotizing encephalitis, herpetic': 'C0001338',
#  'herpetic acute necrotizing encephalitis': 'C0001338',
#  'acute pancreatitis': 'C0001339',
#  'pancreatitis acute': 'C0001339',
#  'acute periodontitis': 'C0001342',
#  'acute pharyngitis': 'C0001344',
#  'acute pharyngitis, nos': 'C0001344',
#  'acute pharyngitis, unspecified': 'C0001344',
#  'acute phase reaction': 'C0001349',
#  'acute phase response': 'C0001349',
#  'acute thyroiditis': 'C0001360',
#  'thyroiditis acute': 'C0001360',
#  'acute tonsillitis': 'C0001361',
#  'acute tonsillitis, unspecified': 'C0001361',
#  'acute vascular insufficiency of intestine': 'C0001363',
#  'acute vascular insufficiency of intestine, nos': 'C0001363',
#  'acute intestinal ischemia': 'C0001363',
#  'atrophy, acute yellow': 'C0001364',
#  'acute yellow liver atrophy': 'C0001364',
#  'acute hepatic necrosis': 'C0001364',
#  'acute necrosis of liver': 'C0001364',
#  'acute, but ill defined, cerebrovascular disease': 'C0001365',
#  'stokes adams syndrome': 'C0001396',
#  'adams stokes syndrome': 'C0001396',
#  'stokes adams morgagni syndrome': 'C0001396',
#  'stokes adams attack': 'C0001396',
#  'addison disease': 'C0001403',
#  "addison's disease": 'C0001403',
#  "addison's disease, nos": 'C0001403',
#  'primary adrenal insufficiency': 'C3887896',
#  'primary adrenocortical insufficiency': 'C0001403',
#  'adenocarcinoma': 'C0001418',
#  'adenocarcinoma nos': 'C0001418',
#  'adenocarcinoma, nos': 'C0001418',
#  'papillary adenocarcinoma': 'C0001420',
#  'papillary adenocarcinoma, nos': 'C0001420',
#  'papillary adenocarcinoma nos': 'C0001420',
#  'adenofibroma': 'C0001422',
#  'adenofibroma, nos': 'C0001422',
#  'adenofibroma nos': 'C0001422',
#  'benign adenofibroma': 'C0001422',
#  'adenoiditis': 'C0001427',
#  'adenoiditis, nos': 'C0001427',
#  'adenolymphoma': 'C0001429',
#  'papillary cystadenoma lymphomatosum': 'C0001429',
#  'warthin tumor': 'C0001429',
#  'adenoma': 'C0001430',
#  'adenoma, nos': 'C0001430',
#  'adenoma nos': 'C0001430',
#  'adenoma benign': 'C0001430',
#  'benign adenomatous neoplasm': 'C0001430',
#  'basophil adenoma': 'C0001431',
#  'pituitary gland basophil adenoma': 'C0001431',
#  'chromophobe adenoma': 'C0001432',
#  'pituitary gland chromophobe adenoma': 'C0001432',
#  'acidophil adenoma': 'C0001433',
#  'pituitary gland acidophil adenoma': 'C0001433',
#  'adenosarcoma': 'C0001442',
#  'adenovirus infection in conditions classified elsewhere and of unspecified site': 'C0001485',
#  'adenovirus infection': 'C0001486',
#  'disease due to adenovirus': 'C0001486',
#  'disease due to adenovirus, nos': 'C0001486',
#  'adenovirus infection, unspecified': 'C0001486',
#  'postoperative adhesion': 'C0001510',
#  'tissue adhesion': 'C0001511',
#  'adhesion': 'C0001511',
#  'adhesions': 'C0001511',
#  'adhesion, nos': 'C0001511',
#  'holmes adie syndrome': 'C0001519',
#  'adiposis dolorosa': 'C0001529',
#  'lipomatosis dolorosa': 'C0001529',
#  'adjustment disorder with depressed mood': 'C0001539',
#  'adjustment disorder with disturbance of conduct': 'C0001540',
#  'adjustment disorder with mixed disturbance of emotions and conduct': 'C0001541',
#  'adjustment disorder with mixed disturbance of emotion and conduct': 'C0001541',
#  'adjustment disorder with mixed emotional features': 'C0001542',
#  'adjustment disorder with physical complaints': 'C0001543',
#  'adjustment disorder with withdrawal': 'C0001544',
#  'adjustment disorder': 'C0001546',
#  'adjustment disorder, nos': 'C0001546',
#  'adjustment disorders': 'C0001546',
#  'adjustment disorder, unspecified': 'C0001546',
#  'brief depressive adjustment reaction': 'C0001548',
#  'adjustment reaction with brief depressive reaction': 'C0001548',
#  'adnexitis': 'C0001577',
#  'disease of adrenal cortex': 'C0001614',
#  'disorder of adrenal cortex': 'C0001614',
#  'adrenal cortex neoplasm': 'C0001618',
#  'neoplasm of adrenal cortex': 'C0001618',
#  'disease of adrenal gland': 'C0001621',
#  'disease of adrenal gland, nos': 'C0001621',
#  'unspecified disorder of adrenal glands': 'C0001621',
#  'disorder of adrenal gland, unspecified': 'C0001621',
#  'adrenal disorder': 'C0001621',
#  'disorder of adrenal gland': 'C0001621',
#  'adrenal gland disorders': 'C0001621',
#  'adrenal gland disorder': 'C0001621',
#  'hyperadrenocorticism': 'C0001622',
#  'hyperadrenalism': 'C0001622',
#  'hypercortisolism': 'C0001622',
#  'adrenocortical hyperfunction': 'C0001622',
#  'hypercortisolemia': 'C0001622',
#  'adrenal gland hypofunction': 'C0001623',
#  'adrenal insufficiency': 'C0001623',
#  'hypoadrenalism': 'C0001623',
#  'adrenal gland neoplasm': 'C0001624',
#  'neoplasm of adrenal gland': 'C0001624',
#  'adrenal neoplasm': 'C0001624',
#  'congenital adrenal hyperplasia': 'C0001627',
#  'adrenal hyperplasia syndrome, congenital': 'C0001627',
#  'adrenal rest tumor': 'C0001630',
#  'adrenal rest tumour': 'C0001630',
#  'adult antisocial behavior': 'C2919118',
#  'adult maltreatment syndrome': 'C0001678',
#  'aerophagy': 'C0001707',
#  'aerophagia': 'C0001707',
#  'psychosis, affective': 'C0001723',
#  'affective psychosis': 'C0001723',
#  'afferent loop syndrome': 'C0001727',
#  'afibrinogenemia': 'C0001733',
#  'african horse sickness': 'C0001748',
#  'african swine fever': 'C0001752',
#  'agammaglobulinemia': 'C0001768',
#  'agammaglobulinemia, nos': 'C0001768',
#  'primary myelofibrosis': 'C0001815',
#  'myelofibrosis with myeloid metaplasia': 'C0001815',
#  'myelosclerosis with myeloid metaplasia': 'C0001815',
#  'agnosia': 'C0001816',
#  'agnosia, nos': 'C0001816',
#  'agoraphobia': 'C0001818',
#  'agoraphobia, nos': 'C0001818',
#  'fear of open spaces': 'C0001818',
#  'agoraphobia, unspecified': 'C0001818',
#  'agoraphobia without history of panic disorder': 'C0001819',
#  'agoraphobia without history of panic disorder, nos': 'C0001819',
#  'agoraphobia without mention of panic attacks': 'C0001819',
#  'agoraphobia without a history of panic disorder': 'C0001819',
#  'agoraphobia without mention of panic disorder': 'C0001819',
#  'agranulocytosis': 'C0001824',
#  'agraphia': 'C0001825',
#  'aids with dementia, nos': 'C0001849',
#  'aids dementia': 'C0001849',
#  'dementia in human immunodeficiency virus [hiv] disease': 'C0001849',
#  'dementia with aids (acquired immunodeficiency syndrome)': 'C0001849',
#  'aids related complex': 'C0001857',
#  'aids like syndrome': 'C0001857',
#  'ainhum': 'C0001860',
#  'air sickness': 'C0001882',
#  'airway obstruction': 'C0001883',
#  'airway obstruction, nos': 'C0001883',
#  'airways obstruction': 'C0001883',
#  'respiratory obstruction': 'C0001883',
#  'akinetic mutism': 'C0001889',
#  'coma vigilans': 'C0001889',
#  'alastrim': 'C0001906',
#  'albinism': 'C0001916',
#  'albinism, nos': 'C0001916',
#  'albinism, unspecified': 'C0001916',
#  'abnormal presence of albumin': 'C0001922',
#  'albumin, abnormal presence': 'C0001922',
#  'albuminuria': 'C0001925',
#  'alcohol amnestic disorder': 'C0001940',
#  'alcohol induced persisting amnestic disorder': 'C0001940',
#  'mental and behavioral disorders due to use of alcohol, amnesic syndrome': 'C0001940',
#  'mental and behavioural disorders due to use of alcohol, amnesic syndrome': 'C0001940',
#  'idiosyncratic alcohol intoxication': 'C0001950',
#  'alcohol intoxication, pathological': 'C0001950',
#  'idiosyncratic intoxication': 'C0001950',
#  'alcohol use disorder': 'C0001956',
#  'alcohol use disorder (aud)': 'C0001956',
#  'alcohol withdrawal delirium': 'C0001957',
#  'delirium tremens': 'C0001957',
#  'mental and behavioral disorders due to use of alcohol, withdrawal state with delirium': 'C0001957',
#  'mental and behavioural disorders due to use of alcohol, withdrawal state with delirium': 'C0001957',
#  'alcohol intoxication': 'C0001969',
#  'alcohol dependence': 'C0001973',
#  'alcoholism': 'C0001973',
#  'alcoholism, nos': 'C0001973',
#  'dipsomania': 'C0001973',
#  'alcoholism, chronic': 'C0001973',
#  'mental and behavioral disorders due to use of alcohol, dependence syndrome': 'C0001973',
#  'mental and behavioural disorders due to use of alcohol, dependence syndrome': 'C0001973',
#  'alcoholism with alcohol dependence': 'C0001973',
#  'persistent alcohol abuse': 'C0001973',
#  'aleutian disease': 'C0002016',
#  'alexia': 'C0002018',
#  'alexia, nos': 'C0002018',
#  'dyslexia and alexia': 'C0002019',
#  'alexia and dyslexia': 'C0002019',
#  'alexithymia': 'C0002020',
#  'algor mortis': 'C0002044',
#  'alkalosis': 'C0002063',
#  'alkalosis, nos': 'C0002063',
#  'respiratory alkalosis': 'C0002064',
#  'alkalosis respiratory': 'C0002064',
#  'alkalosis, respiratory': 'C0002064',
#  'respiratory alkalosis, nos': 'C0002064',
#  'alkaptonuria': 'C0002066',
#  'homogentisicaciduria': 'C0002066',
#  'homogentisate 1,2 dioxygenase deficiency': 'C0002066',
#  'hypersensitivity granuloma': 'C0002098',
#  'atopic rhinitis': 'C0002103',
#  'allergic pneumonia': 'C0002106',
#  'alopecia': 'C0002170',
#  'alopecia, nos': 'C0002170',
#  'hair loss': 'C0002170',
#  'loss of hair': 'C0002170',
#  'alopecia, unspecified': 'C0002170',
#  'alopecia areata': 'C0002171',
#  'alopecia areata, unspecified': 'C0002171',
#  'follicular mucinosis': 'C0002173',
#  'alopecia mucinosa': 'C0002173',
#  'endocrine alopecia': 'C0002176',
#  'nutritional alopecia': 'C0002178',
#  'nutritional alopecia, nos': 'C0002178',
#  'hypotrichosis following infectious disease': 'C0002179',
#  'postinfectional hypotrichosis, nos': 'C0002179',
#  'postpartum alopecia': 'C0002180',
#  'syphilitic alopecia': 'C0002181',
#  'alopecia syphilitic': 'C0002181',
#  'traumatic alopecia': 'C0002182',
#  'alopecia, traction': 'C0002182',
#  'alpha thalassemia': 'C0002312',
#  'alpha thalassemia, nos': 'C0002312',
#  'alpha thalassaemia': 'C0002312',
#  'thalassaemia alpha': 'C0002312',
#  'hemoglobin h disease': 'C3161174',
#  'hypobaropathy': 'C0002351',
#  'anoxia due to high altitude': 'C0002351',
#  'effects of high altitude': 'C0002351',
#  'effects of high altitude, nos': 'C0002351',
#  'alveolar bone loss': 'C0002382',
#  'extrinsic allergic alveolitis': 'C0002390',
#  'extrinsic allergic alveolitis, nos': 'C0002390',
#  'alveolitis allergic': 'C0002390',
#  'allergic pneumonitis': 'C0002390',
#  'hypersensitivity pneumonitis': 'C0002390',
#  'unspecified allergic alveolitis and pneumonitis': 'C0002390',
#  "alzheimer's disease": 'C0002395',
#  "alzheimer's disease, nos": 'C0002395',
#  "dementia alzheimer's type": 'C0002395',
#  "alzheimer's disease, unspecified": 'C0002395',
#  'ambidexterity': 'C0002416',
#  'ambidextrous': 'C0002416',
#  'amblyopia': 'C0002418',
#  'amblyopia, nos': 'C0002418',
#  'amblyopia, unspecified': 'C0002418',
#  'tobacco amblyopia': 'C0002419',
#  'amblyopia tobacco': 'C0002419',
#  'amebiasis': 'C0002438',
#  'amoebiasis': 'C0002438',
#  'disease due to endamoebidae': 'C0002438',
#  'amebiasis, unspecified': 'C0002438',
#  'amoebiasis, unspecified': 'C0002438',
#  'amebic infection': 'C0002438',
#  'amebiasis of skin': 'C0002441',
#  'cutaneous amebiasis': 'C0002441',
#  'cutaneous amoebiasis': 'C0002441',
#  'ameboma': 'C0002445',
#  'amoeboma': 'C0002445',
#  'amelia': 'C0002447',
#  'amelia, nos': 'C0002447',
#  'congenital absence of unspecified limb(s)': 'C0002447',
#  'ameloblastoma': 'C0002448',
#  'ameloblastoma, nos': 'C0002448',
#  'ameloblastoma nos': 'C0002448',
#  'amelogenesis imperfecta': 'C0002452',
#  'amenorrhea': 'C0002453',
#  'amenorrhoea': 'C0002453',
#  'amenorrhea, nos': 'C0002453',
#  'absence of menstruation': 'C0002453',
#  'amenorrhea, unspecified': 'C0002453',
#  'amenorrhoea, unspecified': 'C0002453',
#  'amino acid metabolism, inborn errors of': 'C0002514',
#  'inborn error of amino acid metabolism, nos': 'C0002514',
#  'inborn error of amino acid metabolism': 'C0002514',
#  'disorders of amino acid transport and metabolism': 'C0002514',
#  'unspecified disorder of amino acid metabolism': 'C0002514',
#  'disorder of amino acid metabolism, unspecified': 'C0002514',
#  'disorder of amino acid metabolism': 'C0002514',
#  'disorder of amino acid metabolism, nos': 'C0002514',
#  'amino acid metabolism disorder': 'C0002514',
#  'amino acid metabolism disorders': 'C0002514',
#  'amino acidopathy': 'C0002514',
#  'amnesia': 'C0002622',
#  'amnesia, nos': 'C0002622',
#  'post traumatic amnesia': 'C0002623',
#  'posttraumatic amnesia': 'C0002623',
#  'retrograde amnesia': 'C0002624',
#  'amnestic disorder': 'C0002625',
#  'amnestic disorder, nos': 'C0002625',
#  'amnestic disorder in conditions classified elsewhere': 'C0002625',
#  'infection of amniotic cavity': 'C0002631',
#  'infection of amniotic cavity, nos': 'C0002631',
#  'amniotic cavity infection': 'C0002631',
#  'amnionitis': 'C0002631',
#  'infection of amniotic cavity, unspecified as to episode of care or not applicable': 'C0002631',
#  'inflammation of amnion': 'C0002631',
#  'amniotic band syndrome': 'C0002636',
#  'constriction ring syndrome': 'C0002636',
#  'amputation stump': 'C0002690',
#  'amputation stumps': 'C0002690',
#  'stump': 'C0002690',
#  'traumatic amputation': 'C0002694',
#  'amyloidosis': 'C0002726',
#  'amyloidosis, nos': 'C0002726',
#  'amyloidosis, unspecified': 'C0002726',
#  'amyotonia congenita': 'C0002735',
#  'amyotrophic lateral sclerosis': 'C0002736',
#  'anal and rectal polyp': 'C0002753',
#  'anal or rectal pain': 'C0002758',
#  'congenital indifference to pain': 'C0002768',
#  'anaphylaxis': 'C0002792',
#  'anaphylactic reaction': 'C0002792',
#  'generalized anaphylaxis': 'C0002792',
#  'anaphylaxis, generalized': 'C0002792',
#  'dedifferentiation': 'C0002793',
#  'anaplastic lesion': 'C0002793',
#  'anaplasmosis': 'C0002797',
#  'anaplasmosis, nos': 'C0002797',
#  'ancylostomiasis': 'C0002831',
#  'anemia': 'C0002871',
#  'anaemia': 'C0002871',
#  'anemia, nos': 'C0002871',
#  'anemia, unspecified': 'C0002871',
#  'anaemia, unspecified': 'C0002871',
#  'anemia of chronic disease': 'C0002873',
#  'anaemia of chronic disease': 'C0002873',
#  'anemia of chronic disorder, nos': 'C0002873',
#  'anemia due to chronic disorder': 'C0002873',
#  'aplastic anemia': 'C0002874',
#  'aplastic anemia, nos': 'C0002874',
#  'aplastic anaemia': 'C0002874',
#  'hematopoietic aplasia': 'C0002874',
#  'aplastic anaemia, unspecified': 'C0002874',
#  'aplastic anemia, unspecified': 'C0002874',
#  'homozygous beta thalassemia': 'C0002875',
#  'beta thalassemia, homozygous': 'C0002875',
#  'thalassemia major': 'C0002875',
#  'thalassemia major, nos': 'C0002875',
#  'beta thalassemia major': 'C0002875',
#  'congenital dyserythropoietic anemia': 'C0002876',
#  'congenital dyserythropoietic anemia, nos': 'C0002876',
#  'congenital dyserythropoietic anaemia': 'C0002876',
#  'hemolytic anemia': 'C0002878',
#  'hemolytic anemia, nos': 'C0002878',
#  'haemolytic anaemia': 'C0002878',
#  'acquired hemolytic anemia': 'C0002879',
#  'acquired hemolytic anemia, nos': 'C0002879',
#  'acquired haemolytic anaemia, unspecified': 'C0002879',
#  'acquired hemolytic anemia, unspecified': 'C0002879',
#  'autoimmune hemolytic anemia': 'C0002880',
#  'hemolytic anemia, autoimmune': 'C0002880',
#  'autoimmune hemolytic anemias': 'C0002880',
#  'autoimmune hemolytic anemia, nos': 'C0002880',
#  'autoimmune haemolytic anaemia': 'C0002880',
#  'anemia, autoimmune hemolytic': 'C0002880',
#  'congenital hemolytic anemia, nos': 'C0002881',
#  'congenital hemolytic anemia': 'C0002881',
#  'hereditary hemolytic anemia': 'C0002881',
#  'hereditary hemolytic anemia, nos': 'C0002881',
#  'hereditary haemolytic anaemia': 'C0002881',
#  'hereditary haemolytic anaemia, unspecified': 'C0002881',
#  'hereditary hemolytic anemia, unspecified': 'C0002881',
#  'congenital nonspherocytic hemolytic anemia, nos': 'C0002882',
#  'hereditary nonspherocytic hemolytic anemia': 'C0002882',
#  'congenital non spherocytic hemolytic anemia': 'C0002882',
#  'anaemia hypochromic': 'C0002884',
#  'hypochromic anemia': 'C0002884',
#  'hypochromic anaemia': 'C0002884',
#  'macrocytic anemia': 'C0002886',
#  'anaemia macrocytic': 'C0002886',
#  'megaloblastic anemia': 'C0002888',
#  'anaemia megaloblastic': 'C0002888',
#  'megaloblastic anemia, nos': 'C0002888',
#  'leukoerythroblastic anaemia': 'C0002890',
#  'myelophthisic anemia': 'C0002890',
#  'leukoerythroblastosis': 'C0002890',
#  'anaemia neonatal': 'C0002891',
#  'neonatal anemia': 'C0002891',
#  'pernicious anemia': 'C0002892',
#  'pernicious anemia, nos': 'C0002892',
#  'pernicious anaemia': 'C0002892',
#  'refractory anemia': 'C0002893',
#  'refractory anemia, nos': 'C0002893',
#  'refractory anaemia nos': 'C0002893',
#  'refractory anemia nos': 'C0002893',
#  'refractory anaemia with excess of blasts': 'C0002894',
#  'refractory anemia with excess of blasts': 'C0002894',
#  'refractory anemia with excess blasts (raeb)': 'C0002894',
#  'refractory anaemia with an excess of blasts': 'C0002894',
#  'myelodysplastic syndrome with excess blasts': 'C0002894',
#  'refractory anemia with excess of blasts, unspecified': 'C0002894',
#  'sickle cell anemia': 'C0002895',
#  'sickle cell anaemia': 'C0002895',
#  'hemoglobin s disease': 'C0002895',
#  'sickle cell disease': 'C0002895',
#  'sickle cell disease, unspecified': 'C0002895',
#  'sickling disorder due to hemoglobin s': 'C0002895',
#  'sickle cell hemoglobin ss disease': 'C0002895',
#  'sideroblastic anemia': 'C0002896',
#  'anaemia sideroblastic': 'C0002896',
#  'sideroblastic anemia, nos': 'C0002896',
#  'sideroblastic anaemia': 'C0002896',
#  'anaemia splenic': 'C0002897',
#  'anemias due to disorders of glutathione metabolism': 'C0002899',
#  'anemia due to disorder of glutathione metabolism': 'C0002899',
#  'anencephaly': 'C0002902',
#  'anencephalus': 'C0002902',
#  'fetal anencephaly': 'C0002902',
#  'aneuploidy': 'C0002938',
#  'aneuploidy, nos': 'C0002938',
#  'alteration of chromosome number': 'C0002938',
#  'aneurysm': 'C0002940',
#  'aneurysms': 'C0002940',
#  'aneurysm, nos': 'C0002940',
#  'aneurysm of unspecified site': 'C0002940',
#  'aneurysm of other specified arteries': 'C0002945',
#  'aneurysm of other specified artery': 'C0002946',
#  'arterial dissection': 'C0002949',
#  'dissecting aneurysm': 'C0002949',
#  'aneurysm, dissecting': 'C0002949',
#  'dissecting aneurysm of artery, nos': 'C0002949',
#  'dissection of artery': 'C0002949',
#  'artery dissection': 'C0002949',
#  'infective aneurysm': 'C0002950',
#  'angiectasis': 'C0002959',
#  'angiectasis, nos': 'C0002959',
#  'angiectasia': 'C0002959',
#  'hemangiectasis': 'C0002959',
#  'vascular ectasia': 'C0002959',
#  'phlebarteriectasis': 'C0002959',
#  'angioectasia': 'C0002959',
#  'angina pectoris': 'C0002962',
#  'angina pectoris, nos': 'C0002962',
#  'angina': 'C0002962',
#  'angina pectoris syndrome': 'C0002962',
#  'angina pectoris, unspecified': 'C0002962',
#  'ischemic chest pain': 'C0002962',
#  'prinzmetal angina': 'C0002963',
#  'variant angina': 'C0002963',
#  'unstable angina': 'C0002965',
#  'angina unstable': 'C0002965',
#  'intermediate coronary syndrome': 'C0002965',
#  'intermediate ischemic heart syndrome': 'C0002965',
#  'angina pectoris, unstable': 'C0002965',
#  'impending infarction': 'C0002965',
#  'angina pectoris, crescendo': 'C0002965',
#  'preinfarction angina': 'C0002965',
#  'angioid streaks': 'C0002982',
#  'angioid streaks of choroid': 'C0002983',
#  'angiokeratoma': 'C0002985',
#  'fabry disease': 'C0002986',
#  "fabry's disease": 'C0002986',
#  'fabry ( anderson) disease': 'C0002986',
#  'ceramide lactoside lipidosis': 'C0002986',
#  'deficiency of alpha galactosidase': 'C0002986',
#  'epithelioid hemangioma of skin': 'C0002989',
#  'skin epithelioid hemangioma': 'C0002989',
#  'angiolymphoid hyperplasia': 'C0002989',
#  'sclerosing angioma': 'C0002991',
#  'dermatofibroma': 'C0002991',
#  'dermatofibroma, nos': 'C0002991',
#  'dermatofibroma nos': 'C0002991',
#  'fibrous histiocytoma of skin': 'C0002991',
#  'skin fibrous histiocytoma': 'C0002991',
#  'sclerosing angioma of skin': 'C0002991',
#  'cutaneous histiocytoma': 'C0002991',
#  'angiomatosis': 'C0002992',
#  'angiomatosis, nos': 'C0002992',
#  'angioedema': 'C0002994',
#  'angioedema, nos': 'C0002994',
#  'angioneurotic edema': 'C0002994',
#  'angioneurotic oedema': 'C0002994',
#  'giant urticaria': 'C0002994',
#  'anhidrosis': 'C0003028',
#  'absent sweating': 'C0003028',
#  'sweating, absent': 'C0003028',
#  'absence of sweating': 'C0003028',
#  'animal bite': 'C0003044',
#  'animal bites': 'C0003044',
#  'bite by unspecified animal': 'C0003044',
#  'aniridia': 'C0003076',
#  'absence of iris': 'C0003076',
#  'congenital aniridia': 'C0003076',
#  'aniseikonia': 'C0003078',
#  'anisocoria': 'C0003079',
#  'unequal pupils': 'C0003079',
#  'anisometropia': 'C0003081',
#  'ankylosis': 'C0003090',
#  'ankylosis, nos': 'C0003090',
#  'ankylosis of joint': 'C0003090',
#  'joint ankylosis': 'C0003090',
#  'ankylosis of joint, site unspecified': 'C0003090',
#  'anniversary reaction': 'C0003099',
#  'pruritis of skin of anogenital region': 'C0003107',
#  'anogenital pruritus, unspecified': 'C0003107',
#  'anomalies of jaw cranial base relationship': 'C0003110',
#  'unspecified anomaly of jaw cranial base relationship': 'C0003110',
#  'anomalies of relationship of jaw to cranial base, unspecified anomaly': 'C0003110',
#  'anomia': 'C0003113',
#  'anomic aphasia': 'C0003113',
#  'aphasia, anomic': 'C0003113',
#  'aphasia, nominal': 'C0003113',
#  'anophthalmos': 'C0003119',
#  'anophthalmos, nos': 'C0003119',
#  'anophthalmia': 'C0003119',
#  'clinical anophthalmos, unspecified': 'C0003119',
#  'anorexia': 'C0003123',
#  'anorexia nervosa': 'C0003125',
#  'anorexia nervosa, unspecified': 'C0003125',
#  'anosmia': 'C0003126',
#  'sense of smell, absent': 'C0003126',
#  'absent sense of smell': 'C0003126',
#  'loss of sense of smell': 'C0003126',
#  'anovulation': 'C0003128',
#  'anoxemia': 'C0003129',
#  'anoxia': 'C0003130',
#  'oxygen, absence': 'C0003130',
#  'oxygen supply absent': 'C0003130',
#  'anoxic encephalopathy': 'C0003132',
#  'anoxic brain damage': 'C0003132',
#  'anoxic brain damage, nos': 'C0003132',
#  'anoxic encephalopathy syndrome': 'C0003132',
#  'antemortem thrombus': 'C0003148',
#  'anterior tibial compartment syndrome': 'C0003152',
#  'anthracosilicosis': 'C0003164',
#  'anthracosis': 'C0003165',
#  "coal workers' pneumoconiosis": 'C0003165',
#  "coalworker's pneumoconiosis": 'C0003165',
#  'anthrax': 'C0003175',
#  'anthrax, nos': 'C0003175',
#  'anthrax, unspecified': 'C0003175',
#  'cutaneous anthrax': 'C0003177',
#  'antisocial personality disorder': 'C0003431',
#  'antisocial personality disorders': 'C0003431',
#  'antisocial personality': 'C0003431',
#  'psychopathic personality': 'C0003431',
#  'sociopathic personality': 'C0003431',
#  'dissocial personality disorder': 'C0003431',
#  'anuria': 'C0003460',
#  'absence of urine volume': 'C0003460',
#  'urine volume, absence': 'C0003460',
#  'disease of anus, nos': 'C0003462',
#  'disorder of anus': 'C0003462',
#  'anal disorders': 'C0003462',
#  'anal disorder': 'C0003462',
#  'neoplasm of anus': 'C0003463',
#  'anal neoplasm': 'C0003463',
#  'anus imperforate': 'C0003466',
#  'imperforate anus': 'C0003466',
#  'anus, imperforate': 'C0003466',
#  'anal atresia': 'C0003466',
#  'congenital atresia of anus': 'C0003466',
#  'anxiety': 'C0003467',
#  'anxiety disorders': 'C0003469',
#  'anxiety disorder': 'C0003469',
#  'anxiety disorder, nos': 'C0003469',
#  'anxiety disorder, unspecified': 'C0003469',
#  'anxiety disorder of childhood or adolescence': 'C0003471',
#  'anxiety disorder of childhood or adolescence, nos': 'C0003471',
#  'castration anxiety complex': 'C0003476',
#  'separation anxiety disorder': 'C0003477',
#  'separation anxiety': 'C0003477',
#  'aortic aneurysm': 'C0003486',
#  'aortic aneurysms': 'C0003486',
#  'aortic aneurysm, nos': 'C0003486',
#  'aortic arch syndrome': 'C0003490',
#  'aortic coarctation': 'C0003492',
#  'coarctation of aorta': 'C0003492',
#  'coarctation of the aorta': 'C0003492',
#  'coarctation of aorta (preductal) (postductal)': 'C0003492',
#  'disorder of aorta': 'C0003493',
#  'disease of the aorta, nos': 'C0003493',
#  'aorta disease': 'C0003493',
#  'aortic disorder': 'C0003493',
#  'aortic rupture': 'C0003496',
#  'supravalvular aortic stenosis': 'C0003499',
#  'supravalvar aortic stenosis': 'C0003499',
#  'nonrheumatic aortic valve disorder, unspecified': 'C0003502',
#  'aortic valve insufficiency': 'C0003504',
#  'aortic (valve) insufficiency': 'C0003504',
#  'aortic valve incompetence': 'C0003504',
#  'aortic valve regurgitation, nos': 'C0003504',
#  'aortic valve regurgitation': 'C0003504',
#  'aortic valve prolapse': 'C0003505',
#  'aortic valve stenosis': 'C0003507',
#  'aortic valve stenosis, nos': 'C0003507',
#  'aortic (valve) stenosis': 'C0003507',
#  'aortic stenosis': 'C0003507',
#  'stenosis of aorta': 'C0003507',
#  'aortitis': 'C0003509',
#  'aortitis, nos': 'C0003509',
#  'syphilitic aortitis': 'C0003511',
#  'aortitis syphilitic': 'C0003511',
#  'aortopulmonary septal defect': 'C0003516',
#  'aorticopulmonary septal defect': 'C4085634',
#  'aortic septal defect': 'C0003516',
#  'aortopulmonary window': 'C0003516',
#  'aphakia': 'C0003534',
#  'aphasia': 'C0003537',
#  'aphasia, nos': 'C0003537',
#  'aphasia syndrome': 'C0003537',
#  "broca's aphasia": 'C0003550',
#  'motor aphasia': 'C0003550',
#  'aphasia syndrome, motor': 'C0003550',
#  "broca's dysphasia": 'C0003550',
#  'aphonia': 'C0003564',
#  'loss of voice': 'C0003564',
#  'apnea': 'C0003578',
#  'apnea, nos': 'C0003578',
#  'apnoea': 'C0003578',
#  'stops breathing': 'C0003578',
#  'drug induced apnea': 'C0003580',
#  'neoplasm of appendix': 'C0003614',
#  'appendix neoplasm': 'C0003614',
#  'appendicitis': 'C0003615',
#  'appendicitis, nos': 'C0003615',
#  'appendicitis, unqualified': 'C0003615',
#  'unspecified appendicitis': 'C0003615',
#  'appetite disorder': 'C0003621',
#  'apraxia': 'C0003635',
#  'apraxia, nos': 'C0003635',
#  'dyspraxia': 'C0003635',
#  'apudoma': 'C0003650',
#  'neoplasm of the diffuse neuroendocrine system': 'C0003650',
#  'poisoning by venomous spider bite, nos': 'C0003705',
#  'poisoning due to venomous spider': 'C0003705',
#  'arachnodactyly': 'C0003706',
#  'arachnoiditis': 'C0003708',
#  'arachnoiditis, nos': 'C0003708',
#  'arbovirus hemorrhagic fever': 'C0003721',
#  'arbovirus hemorrhagic fever, nos': 'C0003721',
#  'arthropod borne hemorrhagic fever': 'C0003721',
#  'arthropod borne hemorrhagic fever, unspecified': 'C0003721',
#  'arbovirus infection': 'C0003723',
#  'arbovirus infection, nos': 'C0003723',
#  'arthropod borne viral infection': 'C0003723',
#  'arthropod borne viral disease, unspecified': 'C0003723',
#  'arcus senilis': 'C0003742',
#  'arcus of cornea': 'C0003742',
#  'arcus corneae': 'C0003742',
#  'disease due to arenavirus': 'C0003756',
#  'disease due to arenavirus, nos': 'C0003756',
#  'argyria': 'C0003782',
#  'deposition of silver': 'C0003782',
#  'silver poisoning': 'C0003782',
#  'silver poisoning syndrome': 'C0003782',
#  'arm injuries': 'C0003794',
#  'injury of upper extremity': 'C0003794',
#  'arm injuries and disorders': 'C0003794',
#  'arnold chiari malformation': 'C0003803',
#  'arnold chiari syndrome': 'C0003803',
#  'chiari malformation': 'C0003803',
#  'sertoli leydig cell tumor of ovary': 'C0003810',
#  'androblastoma nos': 'C0003810',
#  'androblastoma': 'C0003810',
#  'androblastoma, nos': 'C0003810',
#  'ovarian sertoli leydig cell tumour': 'C0003810',
#  'ovarian sertoli leydig cell tumor': 'C0003810',
#  'cardiac arrhythmia': 'C0003811',
#  'arrhythmia': 'C0003811',
#  'cardiac dysrhythmia, nos': 'C0003811',
#  'cardiac rhythm, abnormal': 'C0003811',
#  'cardiac dysrhythmia, unspecified': 'C0003811',
#  'cardiac arrhythmia, unspecified': 'C0003811',
#  'sinus arrhythmia': 'C0003813',
#  'arrhythmia, sinus node': 'C0003813',
#  'sinus arrhythmia by ecg finding': 'C0003813',
#  'arterial insufficiency': 'C0003834',
#  'arterial occlusive diseases': 'C0003838',
#  'arterial occlusive disease': 'C0003838',
#  'arterial ph': 'C0003840',
#  'arteriolitis': 'C0003848',
#  'arteriolitis, nos': 'C0003848',
#  'arteriosclerosis': 'C0003850',
#  'arteriosclerosis, nos': 'C0003850',
#  'arteriosclerotic vascular disease': 'C0003850',
#  'arteriosclerotic vascular disease, nos': 'C0003850',
#  'vascular sclerosis': 'C0003850',
#  'arteriosclerosis obliterans': 'C0003851',
#  'arteriovenous fistula': 'C0003855',
#  'fistula, arteriovenous': 'C0003855',
#  'congenital arteriovenous malformation': 'C0003857',
#  'arteriovenous malformations': 'C0003857',
#  'arteriovenous malformation': 'C0003857',
#  'arteriovenous malformation, nos': 'C0003857',
#  'arteritis': 'C0003860',
#  'arteritis, nos': 'C0003860',
#  'arteritis, unspecified': 'C0003860',
#  'pulmonary arteritis': 'C0003861',
#  'arthralgia': 'C0003862',
#  'pain in joint': 'C0003862',
#  'joint pain': 'C0003862',
#  'pain in joint, site unspecified': 'C0003862',
#  'pain in a joint, site unspecified': 'C0003862',
#  'arthritis': 'C0003864',
#  'arthritis, nos': 'C0003864',
#  'inflammatory arthropathy': 'C0003864',
#  'arthritis, unspecified': 'C0003864',
#  'arthritis, unspecified, site unspecified': 'C0003864',
#  'adjuvant disease': 'C0003865',
#  'gouty arthritis': 'C0003868',
#  'gouty arthropathy': 'C0003868',
#  'joints gout affected': 'C0003868',
#  'articular gout': 'C0003868',
#  'articular gout, nos': 'C0003868',
#  'gouty arthropathy, unspecified': 'C0003868',
#  'infectious arthritis': 'C0003869',
#  'pyogenic arthritis, nos': 'C0003869',
#  'infective arthritis': 'C0003869',
#  'infective arthritis, nos': 'C0003869',
#  'arthritis infective': 'C0003869',
#  'unspecified infective arthritis, site unspecified': 'C0003869',
#  'pyogenic arthritis, unspecified': 'C0003869',
#  'pyogenic arthritis, unspecified, site unspecified': 'C0003869',
#  'psoriatic arthritis': 'C0003872',
#  'arthritis, psoriatic': 'C0003872',
#  'psoriatic arthropathy': 'C0003872',
#  'arthropathic psoriasis': 'C0003872',
#  'psoriasis with arthropathy': 'C0003872',
#  'arthropathic psoriasis, unspecified': 'C0003872',
#  'rheumatoid arthritis': 'C0003873',
#  'rheumatoid disease': 'C0003873',
#  'rheumatoid arthritis, unspecified': 'C0003873',
#  'rheumatoid arthritis, unspecified, site unspecified': 'C0003873',
#  'acute suppurative arthritis due to bacteria': 'C0003874',
#  'arthritis viral': 'C0003875',
#  'arthritis due to viral infection': 'C0003875',
#  'arthrogryposis': 'C0003886',
#  'arthrogryposis multiplex congenita': 'C0003886',
#  'congenital multiplex arthrogryposis': 'C0003886',
#  'neurogenic arthropathy': 'C0003892',
#  'arthritis, neuropathic': 'C0003892',
#  'arthropathy associated with neurological disorders': 'C0003892',
#  "charcot's arthropathy": 'C0003892',
#  'neuropathic arthropathy': 'C0003892',
#  'arthropathy associated with a neurological disorder': 'C0003892',
#  'neurogenic arthropathy of charcot': 'C0003892',
#  'arthus reaction': 'C0003907',
#  'arthus phenomenon': 'C0003907',
#  'arthus type urticaria': 'C0003907',
#  'articulation disorders': 'C0003910',
#  'exposure to asbestos': 'C0003948',
#  'asbestos exposure': 'C0003948',
#  'asbestosis': 'C0003949',
#  'ascariasis': 'C0003950',
#  'ascariasis, unspecified': 'C0003950',
#  'infection by ascaridia': 'C0003952',
#  'infection by ascaridia, nos': 'C0003952',
#  'aschoff body': 'C0003960',
#  'ascites': 'C0003962',
#  'ascites, nos': 'C0003962',
#  'ascorbic acid deficiency': 'C0003969',
#  'vitamin c deficiency': 'C0036474',
#  'vitamin c deficiency disease': 'C0003969',
#  'aseptic necrosis of head and/or neck of femur': 'C0003977',
#  'aseptic necrosis of head and neck of femur': 'C0003977',
#  'aspergillosis': 'C0004030',
#  'aspergillosis, nos': 'C0004030',
#  'aspergillosis, unspecified': 'C0004030',
#  'aspergillus infection': 'C0004030',
#  'allergic bronchopulmonary aspergillosis': 'C0004031',
#  'bronchopulmonary aspergillosis allergic': 'C0004031',
#  'disseminated aspergillosis': 'C0004032',
#  'asphyxia': 'C0004044',
#  'suffocation': 'C0004044',
#  'asphyxiation': 'C0004044',
#  'asphyxiation, nos': 'C0004044',
#  'suffocating': 'C0004044',
#  'asphyxia neonatorum': 'C0004045',
#  'unspecified severity of birth asphyxia in liveborn infant': 'C0004045',
#  'neonatal asphyxia': 'C0004045',
#  'asphyxia neonatal': 'C0004045',
#  'asphyxia, nos, in liveborn infant': 'C0004045',
#  'birth asphyxia': 'C0004045',
#  'birth asphyxia, unspecified': 'C0004045',
#  'aspiration, gastric contents': 'C0004052',
#  'aspiration of gastric contents': 'C0004052',
#  'inhalation of gastric contents': 'C0004052',
#  'pulmonary aspiration of gastric contents': 'C0004052',
#  'allergy to aspirin': 'C0004058',
#  'aspirin intolerance': 'C0004059',
#  'aspirin intoxication': 'C0004060',
#  'assault': 'C0004063',
#  'assault by unspecified means': 'C0004063',
#  'astasia abasia': 'C0004090',
#  'hysterical ataxia': 'C0004090',
#  "blocq's syndrome": 'C0004090',
#  'astasia abasia syndrome': 'C0004090',
#  'asthenia': 'C0004093',
#  'asthenopia': 'C0004095',
#  ...}

# %%
abbr_dict
# Out:
# {}
