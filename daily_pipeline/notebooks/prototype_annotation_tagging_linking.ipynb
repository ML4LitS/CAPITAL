# %%
# !python -m ipykernel install --user --name=falconframes_env --display-name "Python (falconframes_env)"

# %%
import os

print("Files in /home/stirunag/work/github/CAPITAL/daily_pipeline/lib:")
print(os.listdir("/home/stirunag/work/github/CAPITAL/daily_pipeline/lib"))
# Out:
# Files in /home/stirunag/work/github/CAPITAL/daily_pipeline/lib:
# ['__init__.py', 'python_scripts']

# %%
import json
import os
import sys
import gzip
from collections import defaultdict, Counter
from transformers import AutoTokenizer, pipeline
from optimum.onnxruntime import ORTModelForTokenClassification
import argparse
from tqdm import tqdm

import sys
from pathlib import Path

# Add the parent directory to the sys.path
sys.path.append(str(Path('/home/stirunag/work/github/CAPITAL/daily_pipeline/lib/python_scripts/').resolve()))

# Import the functions
from entity_linker import map_to_url, map_terms, map_terms_batch, map_terms_reverse, get_exact_match, get_embedding_match, clean_term, clean_term_EM
# Out:
# /home/stirunag/falconframes_env/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/stirunag/falconframes_env/lib/python3.10/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/stirunag/work/github/CAPITAL/normalisation/en_floret_model
# /home/stirunag/work/github/CAPITAL/normalisation/dictionary/
# Loading spaCy model for entity linking...
# /home/stirunag/falconframes_env/lib/python3.10/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.2.5 and may not be 100% compatible with the current version (3.7.5). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# SpaCy model loaded successfully.
# Loaded data for CD
# Loaded data for OG
# Loaded data for DS
# Loaded data for GP
# Loaded data for GO
# Loaded data for EM

# %%
# Directly assign the paths
input_path = "/home/stirunag/work/github/CAPITAL/daily_pipeline/notebooks/data/patch_2024_10_28_0.json.gz"  # Replace with your actual input file path
output_path = "/home/stirunag/work/github/CAPITAL/daily_pipeline/results"  # Replace with your actual output directory path
model_path_quantised = "/home/stirunag/work/github/CAPITAL/model"  # Replace with your actual model directory path

# Check that input is a file
if not os.path.isfile(input_path):
    raise ValueError(f"Expected a file for input, but got: {input_path}")

# Check if output directory exists; if not, create it
if not os.path.isdir(output_path):
    print(f"Output directory '{output_path}' does not exist. Creating it.")
    os.makedirs(output_path, exist_ok=True)

# Ensure 'no_matches' directory exists within the output directory
no_match_dir = os.path.join(output_path, "no_matches")
os.makedirs(no_match_dir, exist_ok=True)
no_match_file_path = os.path.join(no_match_dir, "patch_no_match.json")

# Initialize NER model using the provided model path
print("Loading NER model and tokenizer from " + model_path_quantised)
model_quantized = ORTModelForTokenClassification.from_pretrained(
    model_path_quantised, file_name="model_quantized.onnx")
tokenizer_quantized = AutoTokenizer.from_pretrained(
    model_path_quantised,
    model_max_length=512,
    batch_size=4,
    truncation=True
)
ner_quantized = pipeline(
    "token-classification",
    model=model_quantized,
    tokenizer=tokenizer_quantized,
    aggregation_strategy="first"
)
print("NER model and tokenizer loaded successfully.")
# Out:
# Loading NER model and tokenizer from /home/stirunag/work/github/CAPITAL/model
# NER model and tokenizer loaded successfully.

# %%
SECTIONS_MAP = {
    "TITLE": "Title",
    "ABSTRACT": "Abstract",
    "INTRO": "Introduction",
    "METHODS": "Methods",
    "RESULTS": "Results",
    "DISCUSS": "Discussion",
    "CONCL": "Conclusion",
    "CASE": "Case study",
    "ACK_FUND": "Acknowledgments",
    "AUTH_CONT": "Author Contributions",
    "COMP_INT": "Competing Interests",
    "ABBR": "Abbreviations",
    "SUPPL": "Supplementary material",
    "REF": "References",
    "TABLE": "Table",
    "FIGURE": "Figure",
    "DATA SHARING STATEMENT": "Data Availability",
    "APPENDIX": "Appendix",
    "OTHER": "Other"
}

# %%
def count_lines_in_gzip(file_path):
    """Counts the lines in a gzipped file."""
    with gzip.open(file_path, "rt") as f:
        return sum(1 for _ in f)

# %%
PROVIDER = "europepmc"

# Mapping from abbreviation to full form
ENTITY_TYPE_MAP = {
    "EM": "methods",
    "DS": "disease",
    "GP": "gene_protein",
    "GO": "go_term",
    "CD": "chemical",
    "OG": "organism"
    # Add other mappings as necessary
}


# Helper Functions
def map_entity_type(abbrev):
    """Map abbreviation to full form."""
    return ENTITY_TYPE_MAP.get(abbrev, abbrev.lower())


def get_word_position(sent_id, sentence_text, char_start):
    """
    Calculate the word position based on character start index.
    Returns a string in the format 'sent_id.word_position'.
    """
    words = sentence_text.split()
    current_char = 0
    for idx, word in enumerate(words):
        word_start = sentence_text.find(word, current_char)
        if word_start == char_start:
            return f"{sent_id}.{idx + 1}"
        current_char = word_start + len(word)
    return f"{sent_id}.0"  # Return 0 if position not found


def get_prefix_postfix(sentence_text, char_start, char_end, num_words=3, max_chars=30):
    """
    Extract prefix and postfix based on word positions with constraints:
    - Returns up to `num_words` before and after the target term.
    - Ensures each prefix and postfix does not exceed `max_chars`.
    """
    words = sentence_text.split()
    word_positions = [sentence_text.find(word) for word in words]

    # Identify the word index for the starting character of the entity
    word_index = None
    for idx, start in enumerate(word_positions):
        if start == char_start:
            word_index = idx
            break

    prefix, postfix = "", ""
    if word_index is not None:
        # Extract prefix words up to `num_words` or `max_chars`
        prefix_words = words[max(0, word_index - num_words):word_index]
        prefix = ' '.join(prefix_words)
        if len(prefix) > max_chars:
            prefix = prefix[-max_chars:]  # Truncate to the last `max_chars` characters

        # Extract postfix words up to `num_words` or `max_chars`
        postfix_words = words[word_index + 1:word_index + 1 + num_words]
        postfix = ' '.join(postfix_words)
        if len(postfix) > max_chars:
            postfix = postfix[:max_chars]  # Truncate to the first `max_chars` characters

    return prefix, postfix

# %%
def batch_annotate_sentences(sentences, section):
    batched_text = [s["text"] for s in sentences]
    ner_results = ner_quantized(batched_text)

    annotations = []

    for i, sentence_entities in enumerate(ner_results):
        sentence_id = sentences[i]["sent_id"]
        sentence_text = sentences[i]["text"]
        for entity in sentence_entities:
            term = sentence_text[entity['start']:entity['end']]
            position = get_word_position(sentence_id, sentence_text, entity['start'])
            prefix, postfix = get_prefix_postfix(sentence_text, entity['start'], entity['end'])
            full_entity_type = entity["entity_group"]

            annotations.append({
                "type": full_entity_type,
                "position": position,
                "prefix": prefix,
                "exact": term,
                "section": section,
                "postfix": postfix
            })
    return annotations

# %%
# Mapping from abbreviation to full form
ENTITY_TYPE_MAP = {
    "EM": "methods",
    "DS": "disease",
    "GP": "gene_protein",
    "GO": "go_term",
    "CD": "chemical",
    "OG": "organism"
    # Add other mappings as necessary
}


# Helper Functions
def map_entity_type(abbrev):
    """Map abbreviation to full form."""
    return ENTITY_TYPE_MAP.get(abbrev, abbrev.lower())

# %%
def generate_tags(all_annotations):
    """
    Generate tags for each annotation in all_annotations using map_terms_reverse and map_to_url.
    Each annotation will have 'name' and 'uri' fields in the 'tags' list.
    """
    output_annotations = []
    
    # Group entities by type for map_terms_reverse
    entities_by_type = defaultdict(set)
    for annotation in all_annotations:
        entities_by_type[annotation['type']].add(annotation['exact'])
    
    # Process each entity type with map_terms_reverse to get mapped terms and URLs
    mapped_results = {}
    for entity_type, entities in entities_by_type.items():
        mapped_results[entity_type] = map_terms_reverse(entities, entity_type)
    
    # Generate tags for each annotation
    for annotation in all_annotations:
        entity_type = annotation['type']
        term = annotation['exact']
        
        # Retrieve grounded code and term from mapped results
        if term in mapped_results[entity_type]:
            grounded_code, grounded_term = mapped_results[entity_type][term]
            uri = map_to_url(entity_type, grounded_code)  # Generate URI based on entity group and code
            
            # Add the annotation with tags
            output_annotations.append({
                "type": map_entity_type(entity_type),
                "position": annotation["position"],
                "prefix": annotation["prefix"],
                "exact": term,
                "section": annotation["section"],
                "postfix": annotation["postfix"],
                "tags": [
                    {
                        "name": grounded_term,
                        "uri": uri
                    }
                ]
            })
        else:
            # In case there’s no mapping found, skip or add with no URI
            output_annotations.append({
                "type": map_entity_type(entity_type),
                "position": annotation["position"],
                "prefix": annotation["prefix"],
                "exact": term,
                "section": annotation["section"],
                "postfix": annotation["postfix"],
                "tags": [
                    {
                        "name": "#",
                        "uri": "#"
                    }
                ]
            })

    return output_annotations

# %%
input_filename = os.path.basename(input_path).replace(".json.gz", "")
output_file_OA = os.path.join(output_path, f"{input_filename}_OA.json")
output_file_NOA = os.path.join(output_path, f"{input_filename}_NOA.json")

# Similarly, create no match filenames
no_match_file_OA = os.path.join(output_path, "no_matches", f"{input_filename}_OA_no_match.json")
no_match_file_NOA = os.path.join(output_path, "no_matches", f"{input_filename}_NOA_no_match.json")

# Count the total number of lines for the progress bar
total_lines = count_lines_in_gzip(input_path)

print(total_lines)
# Out:
# 909

# %%
with gzip.open(input_path, "rt") as infile:
    for line in tqdm(infile, desc="Processing lines", unit="line", total=total_lines):
        article_data = json.loads(line)
        open_status = article_data.get("open_status", "")
        if open_status == "O":
            break
# Out:
# Processing lines:   1%|          | 10/909 [00:00<00:00, 3371.36line/s]

# %%
article_data
# Out:
# {'article_ids': {'pmcid': '11380737', 'doi': '10.34172/jrhs.2024.159'},
#  'open_status': 'O',
#  'article_type': 'research-article',
#  'keywords': ['Dietary inflammatory index',
#   'Diet',
#   'Head and neck neoplasms',
#   'Case-control studies'],
#  'sections': {'TITLE': [{'text': 'Dietary Inflammatory Index and Head and Neck Cancer: A Multicenter Case-Control Study in Iran',
#     'sent_id': 1}],
#   'ABSTRACT': [{'text': 'Background: The inflammatory potential of diet may affect carcinogenesis.',
#     'sent_id': 2},
#    {'text': 'This study aimed to determine the association between dietary inflammatory index (DII) and the risk of head and neck cancer (HNC), as well as the interaction between DII and cigarette smoking in HNC development within the Iranian population.',
#     'sent_id': 3},
#    {'text': 'Study Design: This is a case-control study.', 'sent_id': 4},
#    {'text': 'Methods: In this multicenter case-control study, participants’ dietary intake was assessed using a validated 130-item food frequency questionnaire, from which DII was computed.',
#     'sent_id': 5},
#    {'text': 'The study recruited 876 new cases from referral hospitals across 10 provinces and 3409 healthy controls who were frequency-matched based on age, gender, and residential place.',
#     'sent_id': 6},
#    {'text': 'Logistic regression was used to obtain odds ratios (ORs) for HNC across tertiles of DII, which were adjusted for confounding variables.',
#     'sent_id': 7},
#    {'text': 'Results: A higher pro-inflammatory diet was associated with an increased risk of all HNC (OR T3 vs. T1 [95% CI]: 1.31 [1.06, 1.62]; P -trend=0.013).',
#     'sent_id': 8},
#    {'text': 'There was a significant association between lip and oral cavity cancers and DII (OR T3 vs. T1 [95% CI]: 1.56 [1.16, 1.66]; P -trend=0.004).',
#     'sent_id': 9},
#    {'text': 'Furthermore, an inflammatory diet was associated with an increased risk of pharynx cancer (OR T3 vs. T1 [95% CI]: 2.08 [1.14, 3.79]; P -trend=0.02).',
#     'sent_id': 10},
#    {'text': 'Additionally, no significant association was observed between DII and larynx cancer, while an interaction was found between DII and tobacco use on the risk of HNC (OR T3 vs. T1 [95% CI]: 2.52 [1.78, 3.57]; P -interaction=0.03).',
#     'sent_id': 11},
#    {'text': 'Conclusion: DII was positively associated with HNC risk.',
#     'sent_id': 12},
#    {'text': 'There was a significant association between DII and the risk of lip, oral cavity, and pharynx cancers.',
#     'sent_id': 13},
#    {'text': 'Additionally, there was an interaction between tobacco use and DII in determining the risk of HNC.',
#     'sent_id': 14}],
#   'INTRO': [{'text': 'Background', 'sent_id': 15},
#    {'text': 'The global burden of diseasse study in 2017 reported that 5.3 % of all cancers are related to head and neck cancer (HNC).',
#     'sent_id': 16},
#    {'text': '1 HNC includes cancers of the oral cavity, oropharynx, nasopharynx, hypopharynx, and larynx.',
#     'sent_id': 17},
#    {'text': 'The HNC’s prevalence has recently increased in Iran, with the age-standardized rate rising from 4.8 per 100\u2005000 in 2003 to 8.5 in 2008.',
#     'sent_id': 18},
#    {'text': '2 Patients with HNC have different complications including, breathing and eating difficulties, and cancer treatment imposes a significant financial burden on patients and their families.',
#     'sent_id': 19},
#    {'text': '3 Therefore, prevention is the best strategy for all people, and identifying the risk factors is vital.',
#     'sent_id': 20},
#    {'text': 'Tobacco (both cigarette and waterpipe) and alcohol consumption are major risk factors for HNC.',
#     'sent_id': 21},
#    {'text': '4 Other important risk factors include asbestos exposure, human papillomavirus infection, and opium use.',
#     'sent_id': 22},
#    {'text': '5 , 6 Evidence shows the protective effect of fruits and vegetables against HNC.',
#     'sent_id': 23},
#    {'text': '4 However, the recent comprehensive review of nutritional factors and cancer risk by the World Cancer Research Fund and the American Cancer Institute concluded that the data on the association between several dietary components with HNC is not convincing.',
#     'sent_id': 24},
#    {'text': '5', 'sent_id': 25},
#    {'text': 'Chronic inflammation has been recognized as one of the possible mechanisms of carcinogenesis, including HNC.',
#     'sent_id': 26},
#    {'text': '7 Dietary components have been shown to have anti-inflammatory and pro-inflammatory effects.',
#     'sent_id': 27},
#    {'text': '8 Dietary components such as phenols, antioxidant vitamins, and other nutrients have been associated with the development of several cancers.',
#     'sent_id': 28},
#    {'text': 'Some studies have investigated the association between one or several foods or nutrients and cancer risk separately; however, dietary components are consumed together and have synergic or antagonistic interactions.',
#     'sent_id': 29},
#    {'text': 'To deal with this, the Dietary Inflammatory Index (DII) was proposed to compute the inflammatory effects of the overall diet.',
#     'sent_id': 30},
#    {'text': '9 Several studies have investigated the association between DII and cancers such as colorectal, breast, prostate, and endometrium.',
#     'sent_id': 31},
#    {'text': '10 , 11 Few studies have been conducted on the association between DII and aerodigestive tract cancer, 12 , 13 and most data come from non-Asian countries with different dietary habits.',
#     'sent_id': 32},
#    {'text': '14 - 16 As such, studies on the association between DII and the risk of HNC, especially in southwestern Asia, are rare.',
#     'sent_id': 33},
#    {'text': 'The present study used a large case-control study among the Iranian population to determine the association between DII and the risk of HNC development within the Iranian population.',
#     'sent_id': 34}],
#   'METHODS': [{'text': 'Methods', 'sent_id': 35},
#    {'text': 'Participants and study design', 'sent_id': 36},
#    {'text': 'The Iranian Study of Opium and Cancer (IROPICAN) is a multicenter case-control study conducted between 2018 to 2020 in referral hospitals affiliated with Universities of Medical Sciences in 10 provinces of Iran, including Sistan and Baluchestan, Kerman, Bushehr, Hormozgan, Khorasan Razavi, Golestan, Mazandaran, Kermanshah, and Tehran.',
#     'sent_id': 37},
#    {'text': '17 We selected cases and controls from the IROPICAN study.',
#     'sent_id': 38},
#    {'text': 'There were 876 pathologically confirmed HNC patients who received a cancer diagnosis in less than one year and with no history of any cancers.',
#     'sent_id': 39},
#    {'text': 'HNCs in this study were the ICD-O-3 codes of HNC, including the oral, larynx, and pharyngeal cancers (i.e., C00-C09, C11, C12, C14, C31, and C32).',
#     'sent_id': 40},
#    {'text': 'We included 3409 controls who were frequently matched with cases based on age (in 5-year intervals), gender, and residential place.',
#     'sent_id': 41},
#    {'text': 'They were selected from hospital visitors who were without cancer, were not family members or friends of the cancer patients, and were visiting the hospital for reasons other than their health complaints.',
#     'sent_id': 42},
#    {'text': 'Participants were asked detailed questions about opium use and its history (e.g., age at initiation, duration, frequency, typical amount, and route), tobacco use (e.g., cigarettes, naswar, chopogh, and waterpipe), history of alcohol consumption, demographic and socioeconomic factors (e.g. age, ethnicity, rural/urban status, education, and occupational history), physical activity (using the validated International Physical Activity Questionnaire, IPAQ 18 ).',
#     'sent_id': 43},
#    {'text': 'Information on various aspects of health (personal and family history of cancer) was also obtained.',
#     'sent_id': 44},
#    {'text': 'Socioeconomic status (SES) was determined by combining data on education, income, and ownership of some household appliances using principal component analysis.',
#     'sent_id': 45},
#    {'text': 'The SES score determined for the control group was used to classify participants into three groups: high, medium, and low social classes.',
#     'sent_id': 46},
#    {'text': 'Physical activity workload (PPWL) was estimated based on the job history of participants using the Finland Job Exposure Matrix (FINJEM) 19 .',
#     'sent_id': 47},
#    {'text': 'Based on the PPWL scores in control groups, participants were divided into three groups: sedentary (zero PPWL-years), moderate (PPWL-years above zero and less than or equal to 4.80), and heavy (PPWL-years above 4.80).',
#     'sent_id': 48},
#    {'text': 'Dental health was assessed by considering decayed, missing, and filled teeth, and participants were divided into three groups based on the scores of the control group.',
#     'sent_id': 49},
#    {'text': 'Assessment of dietary intake and dietary inflammatory index scoring',
#     'sent_id': 50},
#    {'text': 'To assess the dietary intake of participants, we used a validated 130-item food frequency questionnaire (FFQ) which was designed for Persian Cohort Study.',
#     'sent_id': 51},
#    {'text': '20 Cases and controls were asked to answer the FFQ based on their dietary habits one year before cancer diagnosis and one year before the interview, respectively.',
#     'sent_id': 52},
#    {'text': 'Total energy and nutrient intake were calculated using the USDA Food Composition Table.',
#     'sent_id': 53},
#    {'text': '21 The DII score was computed based on the method suggested by Shivappa using 38 food parameters, including energy, carbohydrate, fat, protein, fiber, cholesterol, mono-unsaturated fatty acids (MUFA), polyunsaturated fatty acids (PUFA), n-3 fatty acids, n-6 fatty acids, saturated fats (SFAs), trans fat, thiamin, riboflavin, niacin, pyridoxine, folic acid, cobalamin, vitamins A, C, and D, alpha-tocopherol, β-carotene, zinc, selenium, magnesium, iron, caffeine, onion, garlic, black tea, coffee, flavan-3-ol, flavones, flavonols, flavonones, anthocyanidins, and isoflavones.',
#     'sent_id': 54},
#    {'text': '9 Then, the residual method was used to calculate energy-adjusted quantities of all these parameters before analyzing the DII score.',
#     'sent_id': 55},
#    {'text': '22', 'sent_id': 56},
#    {'text': 'Statistical analysis', 'sent_id': 57},
#    {'text': 'All statistical analyses were performed by Stata software (Stata 14.1, College Station, Texas 77845 USA).',
#     'sent_id': 58},
#    {'text': 'Two-sided P values <\u20050.05 were considered statistically significant.',
#     'sent_id': 59},
#    {'text': 'Participants were classified into tertiles of DII scores based on the distribution in the control group.',
#     'sent_id': 60},
#    {'text': 'To examine the association between DII and odds of HNC, unconditional logistic regression analysis was used which was controlled for several covariates.',
#     'sent_id': 61},
#    {'text': 'The full model was adjusted for energy (kcal/d), age (years), gender (female, male), province (10 provinces), socioeconomic status (low, medium, and high), tobacco use (yes, no), opium use (yes, no), alcohol use (yes, no), dental health (poor, moderate, and good), and physical activity (sedentary, moderate, and high).',
#     'sent_id': 62},
#    {'text': 'The trend of odds ratios (ORs) was examined using the median of DII as a continuous variable in the logistic regression models.',
#     'sent_id': 63},
#    {'text': 'An interaction term was added to models to analyze the interaction between DII and tobacco or opium use and the risk of HNC.',
#     'sent_id': 64},
#    {'text': 'The P value for interactions was estimated by the likelihood ratio test between models with and without the interaction term.',
#     'sent_id': 65},
#    {'text': 'We recruited 894 HNC patients from the IROPICAN study and 3483 apparently healthy controls whose data has been used in this study.',
#     'sent_id': 66},
#    {'text': 'Participants with unusual energy intake (less than 500 and over 4500 kcal/d) were considered outliers (18 subjects out of 894 patients and 74 subjects out of 3484 controls) and were omitted.',
#     'sent_id': 67}],
#   'RESULTS': [{'text': 'Results', 'sent_id': 68},
#    {'text': 'Totally 876 patients and 3409 healthy controls were recruited for the present study.',
#     'sent_id': 69},
#    {'text': 'Almost a quarter of the participants in both groups were female ( Table 1 ).',
#     'sent_id': 70},
#    {'text': 'Tobacco smoking and opium use were more common among the cases.',
#     'sent_id': 71},
#    {'text': 'Regular alcohol use was scarce in both groups.', 'sent_id': 72},
#    {'text': 'The physical activity status of the participants in both groups was almost similar.',
#     'sent_id': 73},
#    {'text': 'Energy and dietary intakes did not significantly differ between patients and controls ( Table 2 ).',
#     'sent_id': 74},
#    {'text': 'As observed, the intake of energy, carbohydrate, and trans fatty acids increased from tertile 1 to tertile 3 of DII.',
#     'sent_id': 75},
#    {'text': 'However, the intake of vegetables, tomato, garlic, onion, dairy, legumes, and tea decreased.',
#     'sent_id': 76},
#    {'text': 'Table 3 presents the association between DII scores and the risk of all subtypes of HNC and total HNC.',
#     'sent_id': 77},
#    {'text': 'After adjusting for confounders, a more pro-inflammatory diet was associated with an increased risk of all HNC (OR [95% CI]: 1.31 [1.06-1.62]; P -trend\u2005=\u20050.013).',
#     'sent_id': 78},
#    {'text': 'Additionally, there was a significant association between DII and lip and oral cavity cancer (OR [95% CI]: 1.56 [1.16-1.66]; P -trend\u2005=\u20050.004) in the adjusted model.',
#     'sent_id': 79},
#    {'text': 'Notably, an inflammatory diet was associated with an increased risk of pharynx cancer even after adjustment for confounders (OR T3 vs. T1: 2.08 [1.14-3.79]; P -trend\u2005=\u20050.02).',
#     'sent_id': 80},
#    {'text': 'There was no significant association between DII and larynx cancer, and no interaction was seen between DII and opium use.',
#     'sent_id': 81},
#    {'text': 'However, an interaction was found between tobacco use and DII on the risk of HNC, meaning that participants who used tobacco and had higher DII scores were at a greater risk of HNC compared to participants who did not use tobacco and were in the first tertile (OR T3 vs. T1 [95% CI]: 2.52 [1.78-3.57]; P -interaction\u2005=\u20050.03, as depicted in Table 4 ).',
#     'sent_id': 82},
#    {'text': 'It is worth noting that participants who did not use tobacco or opium but were in the third tertile of DII were still at great risk of HNC (OR T3 vs. T1 [95% CI]: 1.66 [1.20-2.29]).',
#     'sent_id': 83}],
#   'DISCUSS': [{'text': 'Discussion', 'sent_id': 84},
#    {'text': 'This study found that DII is positively associated with HNC risk overall.',
#     'sent_id': 85},
#    {'text': 'In addition, there was a significant association between DII and lip and oral cavity cancer and pharynx cancer.',
#     'sent_id': 86},
#    {'text': 'However, no significant association was found between DII and larynx cancer.',
#     'sent_id': 87},
#    {'text': 'There was an interaction between tobacco use and DII in determining the risk of HNC, whereas no interaction effect was found between opium use and DII.',
#     'sent_id': 88},
#    {'text': 'DII is a marker of the pro-inflammatory potential of the diet.',
#     'sent_id': 89},
#    {'text': 'Some studies with large sample sizes investigated the association between DII and HNC worldwide, but they are limited, especially in low and middle-income countries.',
#     'sent_id': 90},
#    {'text': '12 , 15 , 16 , 23 , 24 Our overall findings are consistent with these studies, indicating that a pro-inflammatory diet, as indicated by higher DII scores, is associated with HNC.',
#     'sent_id': 91},
#    {'text': 'Previous studies evaluated the interaction effect of tobacco or smoking with DII on HNC risk, however, but none of them have assessed the interaction between opium use and DII on HNC.',
#     'sent_id': 92},
#    {'text': '16 Shivappa et al reported a positive association between DII and laryngeal cancer in a case-control study in Italy, 25 which is in contrast with our findings.',
#     'sent_id': 93},
#    {'text': 'Furthermore, we found a positive significant association between DII and pharynx cancer which is in line with Shivappa’s case-control study in Italy.',
#     'sent_id': 94},
#    {'text': '23 Mazul et al reported a significant interaction between smoking, alcohol intake, and DII on HNC risk.',
#     'sent_id': 95},
#    {'text': '16 We assessed opium use in detail, including its interaction effect, finding no interaction effect between opium use and DII on HNC risk.',
#     'sent_id': 96},
#    {'text': 'Overall, tobacco use was more prevalent in our population compared to opium use.',
#     'sent_id': 97},
#    {'text': 'Moreover, based on the information in Table 1 , opium use was not consistent with DII tertiles, indicating that the distribution of opium users in the DII tertiles is not similar.',
#     'sent_id': 98},
#    {'text': 'Therefore, we cannot conclude that opium users have a more pro-inflammatory diet.',
#     'sent_id': 99},
#    {'text': 'Evidence suggested that the intake of a diet high in pro-inflammatory parameters accompanied by smoking could exacerbate carcinogenesis.',
#     'sent_id': 100},
#    {'text': 'Smoking and alcoholic consumption have been linked with increased oxidative stress.',
#     'sent_id': 101},
#    {'text': '26 , 27 Smoking-associated oxidative stress activates the inflammatory response pathway, triggering a cascade of events in which the production and release of reactive oxygen species (ROS) at the site of damage and inflammation potentially increase oxidative damage to macromolecular targets, which may lead to cancer initiation and progression.',
#     'sent_id': 102},
#    {'text': '28', 'sent_id': 103},
#    {'text': 'The positive association between the DII and HNC might be mediated through the excess production of cytokines such as interleukin-6 (IL-6), IL-8, platelet-derived growth factor, and vascular endothelial growth factor in the tumor microenvironment, which are responsible for carcinogenic activities like anti-apoptosis, tumor angiogenesis, and metastasis.',
#     'sent_id': 104},
#    {'text': '29 Inflammatory cytokines can affect the oral microbiota, which in turn can cause an increased risk of periodontitis and cancer.',
#     'sent_id': 105},
#    {'text': '30 - 32 Moreover, the direct impact of carbohydrate consumption on the mouth microbiota, leading to increased populations of lactobacilli bacteria, can be another pathway.',
#     'sent_id': 106},
#    {'text': '3 The oral cavity, pharynx, and larynx are all connected anatomical sites, so dysbiosis in one site can lead to dysbiosis in another.',
#     'sent_id': 107},
#    {'text': '34', 'sent_id': 108},
#    {'text': 'This study has several strengths.', 'sent_id': 109},
#    {'text': 'To our knowledge, this is the first large multicenter case-control study in the East Mediterranean region examining the association between DII and the risk of HNC.',
#     'sent_id': 110},
#    {'text': 'Additionally, the large sample size allowed us to study the association between DII and overall HNC and its subsites, including oral cavity and larynx cancers.',
#     'sent_id': 111},
#    {'text': 'The patients were pathologically confirmed by a pathologist.',
#     'sent_id': 112},
#    {'text': 'We also adjusted for several confounding variables, including tobacco, opium, and alcohol use, province, socioeconomic status, dental health, and physical activity.',
#     'sent_id': 113},
#    {'text': 'Using a validated FFQ was another strength of the current study.',
#     'sent_id': 114},
#    {'text': '20', 'sent_id': 115},
#    {'text': 'However, this study suffers from some limitations.',
#     'sent_id': 116},
#    {'text': 'The lack of an Iranian food composition table is one of the main limitations as food components would differ by country due to environmental and food processing factors.',
#     'sent_id': 117},
#    {'text': 'However, using the international food composition table minimizes this problem.',
#     'sent_id': 118},
#    {'text': 'Moreover, several Iranian studies showed an association between DII scores calculated using this food composition table, inflammatory index, and health status.',
#     'sent_id': 119},
#    {'text': '35 - 37', 'sent_id': 120},
#    {'text': 'Highlights', 'sent_id': 121},
#    {'text': 'The inflammatory potential of diet may affect carcinogenesis.',
#     'sent_id': 122},
#    {'text': 'In this multicenter case-control study, we assessed dietary inflammatory index (DII) of 876 new cases of head and neck cancer (HNC) and 3409 healthy controls.',
#     'sent_id': 123},
#    {'text': 'DII was positively associated with HNC risk.', 'sent_id': 124},
#    {'text': 'There was an interaction between tobacco use and DII in determining the risk of HNC.',
#     'sent_id': 125}],
#   'CONCL': [{'text': 'Conclusion', 'sent_id': 126},
#    {'text': 'In conclusion, subjects who consumed a pro-inflammatory diet had an increased risk of lip and oral cavity cancer and pharynx cancer compared to those who consumed a low-inflammatory diet in this Iranian population.',
#     'sent_id': 127},
#    {'text': 'This is the first study in Iran to examine this association, and the results suggest that increasing the intake of anti-inflammatory dietary factors such as plant-based foods rich in fiber and phytochemicals and reducing the intake of pro-inflammatory factors such as fried or processed foods rich in saturated fat or animal protein may be a strategy for reducing the risk of HNC.',
#     'sent_id': 128},
#    {'text': 'This can also be the key measure of avoiding tobacco use, indicating that the interaction between a pro-inflammatory diet and tobacco use leads to strikingly higher risks of HNC.',
#     'sent_id': 129}],
#   'ACK_FUND': [{'text': 'Acknowledgments', 'sent_id': 130},
#    {'text': 'This study was conducted using data from the IROPICAN study, which was funded by the National Institute for Medical Research Development (NIMAD) with project No.17198.',
#     'sent_id': 131},
#    {'text': 'The authors thank all participants and the healthcare workers who patiently support this study.',
#     'sent_id': 132},
#    {'text': 'Funding', 'sent_id': 133},
#    {'text': 'This study analyzed the IROPICAN study, which was granted by NIMAD (project code: No.17198).It was partially supported by a grant from the Italian Association for Cancer Research (IACR) (No. GI 60742).',
#     'sent_id': 134}],
#   'COMP_INT': [{'text': 'Competing Interests', 'sent_id': 135},
#    {'text': 'The authors declare no potential conflict of interests.',
#     'sent_id': 136}],
#   'REF': [{'text': 'References 1 Fitzmaurice C Abate D Abbasi N Abbastabar H Abd-Allah F Abdel-Rahman O Global, regional, and national cancer incidence, mortality, years of life lost, years lived with disability, and disability-adjusted life-years for 29 cancer groups, 1990 to 2017: a systematic analysis for the global burden of disease study JAMA Oncol 2019 5 12 1749 68 10.1001/jamaoncol.2019.2996 31560378 2 Mirzaei M Hosseini SA Ghoncheh M Soheilipour F Soltani S Soheilipour F Epidemiology and trend of head and neck cancers in Iran Glob J Health Sci 2015 8 1 189 93 10.5539/gjhs.v8n1p189 3 Joshi P Dutta S Chaturvedi P Nair S Head and neck cancers in developing countries Rambam Maimonides Med J 2014 5 2 e0009 10.5041/rmmj.10143 24808947 4 Aupérin A Epidemiology of head and neck cancers: an update Curr Opin Oncol 2020 32 3 178 86 10.1097/cco.0000000000000629 32209823 5 Clinton SK Giovannucci EL Hursting SD The World Cancer Research Fund/American institute for cancer research third expert report on diet, nutrition, physical activity, and cancer: impact and future directions J Nutr 2020 150 4 663 71 10.1093/jn/nxz268 31758189 6 Mohebbi E Hadji M Rashidian H Rezaianzadeh A Marzban M Haghdoost AA Opium use and the risk of head and neck squamous cell carcinoma Int J Cancer 2021 148 5 1066 76 10.1002/ijc.33289 
#     'sent_id': 146}],
#   'TABLE': [{'text': 'Table 1', 'sent_id': 147},
#    {'text': 'Characteristics of HNC patients and controls participated in the IROPICAN study in Iran (2018 and 2020)',
#     'sent_id': 148},
#    {'text': 'Characteristics', 'sent_id': 149},
#    {'text': 'Patients', 'sent_id': 150},
#    {'text': 'Controls', 'sent_id': 151},
#    {'text': 'P value', 'sent_id': 152},
#    {'text': 'Tertiles of DII in patients', 'sent_id': 153},
#    {'text': 'Tertiles of DII in controls', 'sent_id': 154},
#    {'text': 'T1', 'sent_id': 155},
#    {'text': 'T2', 'sent_id': 156},
#    {'text': 'T3', 'sent_id': 157},
#    {'text': 'P value', 'sent_id': 158},
#    {'text': 'T1', 'sent_id': 159},
#    {'text': 'T2', 'sent_id': 160},
#    {'text': 'T3', 'sent_id': 161},
#    {'text': 'P value', 'sent_id': 162},
#    {'text': 'Total', 'sent_id': 163},
#    {'text': '876', 'sent_id': 164},
#    {'text': '3409', 'sent_id': 165},
#    {'text': '262', 'sent_id': 166},
#    {'text': '316', 'sent_id': 167},
#    {'text': '298', 'sent_id': 168},
#    {'text': '1138', 'sent_id': 169},
#    {'text': '1136', 'sent_id': 170},
#    {'text': '1135', 'sent_id': 171},
#    {'text': 'Gender', 'sent_id': 172},
#    {'text': '0.001', 'sent_id': 173},
#    {'text': '0.438', 'sent_id': 174},
#    {'text': '0.024', 'sent_id': 175},
#    {'text': 'Male', 'sent_id': 176},
#    {'text': '662', 'sent_id': 177},
#    {'text': '2356', 'sent_id': 178},
#    {'text': '201', 'sent_id': 179},
#    {'text': '231', 'sent_id': 180},
#    {'text': '230', 'sent_id': 181},
#    {'text': '760', 'sent_id': 182},
#    {'text': '779', 'sent_id': 183},
#    {'text': '817', 'sent_id': 184},
#    {'text': 'Female', 'sent_id': 185},
#    {'text': '214', 'sent_id': 186},
#    {'text': '1053', 'sent_id': 187},
#    {'text': '61', 'sent_id': 188},
#    {'text': '85', 'sent_id': 189},
#    {'text': '68', 'sent_id': 190},
#    {'text': '378', 'sent_id': 191},
#    {'text': '357', 'sent_id': 192},
#    {'text': '318', 'sent_id': 193},
#    {'text': 'Socio economic status', 'sent_id': 194},
#    {'text': '0.001', 'sent_id': 195},
#    {'text': '0.964', 'sent_id': 196},
#    {'text': '0.420', 'sent_id': 197},
#    {'text': 'Poor', 'sent_id': 198},
#    {'text': '342', 'sent_id': 199},
#    {'text': '953', 'sent_id': 200},
#    {'text': '101', 'sent_id': 201},
#    {'text': '120', 'sent_id': 202},
#    {'text': '121', 'sent_id': 203},
#    {'text': '297', 'sent_id': 204},
#    {'text': '336', 'sent_id': 205},
#    {'text': '320', 'sent_id': 206},
#    {'text': 'Moderate', 'sent_id': 207},
#    {'text': '290', 'sent_id': 208},
#    {'text': '1141', 'sent_id': 209},
#    {'text': '89', 'sent_id': 210},
#    {'text': '105', 'sent_id': 211},
#    {'text': '96', 'sent_id': 212},
#    {'text': '389', 'sent_id': 213},
#    {'text': '379', 'sent_id': 214},
#     'sent_id': 363},
#    {'text': 'a Dental health was defined by the DMFT score sum of the number of decayed, missing, or filled teeth.',
#     'sent_id': 364},
#    {'text': 'Table 2', 'sent_id': 365},
#    {'text': 'Energy-adjusted dietary intakes of participants across case (n\u2005=\u2005876) and control (n\u2005=\u20053409) groups and tertiles of the dietary inflammatory index (DII) in the IROPICAN study between 2018 and 2020',
#     'sent_id': 366},
#    {'text': 'Tertiles of DII in patients', 'sent_id': 367},
#    {'text': 'Tertiles of DII in controls', 'sent_id': 368},
#    {'text': 'Patients', 'sent_id': 369},
#    {'text': 'Controls', 'sent_id': 370},
#    {'text': 'T1 (n=262)', 'sent_id': 371},
#    {'text': 'T2 (n=316)', 'sent_id': 372},
#    {'text': 'T3 (n=298)', 'sent_id': 373},
#    {'text': 'T1 (n=1138)', 'sent_id': 374},
#    {'text': 'T2 (n=1136)', 'sent_id': 375},
#    {'text': 'T3 (n=1135)', 'sent_id': 376},
#    {'text': 'Dietary intake', 'sent_id': 377},
#    {'text': 'Mean', 'sent_id': 378},
#    {'text': 'SD', 'sent_id': 379},
#    {'text': 'Mean', 'sent_id': 380},
#    {'text': 'SD', 'sent_id': 381},
#    {'text': 'P value', 'sent_id': 382},
#    {'text': 'Mean', 'sent_id': 383},
#    {'text': 'SD', 'sent_id': 384},
#    {'text': 'Mean', 'sent_id': 385},
#    {'text': 'SD', 'sent_id': 386},
#    {'text': 'Mean', 'sent_id': 387},
#    {'text': 'SD', 'sent_id': 388},
#    {'text': 'P value', 'sent_id': 389},
#    {'text': 'Mean', 'sent_id': 390},
#    {'text': 'SD', 'sent_id': 391},
#    {'text': 'Mean', 'sent_id': 392},
#    {'text': 'SD', 'sent_id': 393},
#    {'text': 'Mean', 'sent_id': 394},
#    {'text': 'SD', 'sent_id': 395},
#    {'text': 'P value', 'sent_id': 396},
#    {'text': 'DII', 'sent_id': 397},
#    {'text': '1.9', 'sent_id': 398},
#    {'text': '0.8', 'sent_id': 399},
#    {'text': '2.0', 'sent_id': 400},
#    {'text': '0.8', 'sent_id': 401},
#    {'text': '0.173', 'sent_id': 402},
#    {'text': '-2.3', 'sent_id': 403},
#    {'text': '1.0', 'sent_id': 404},
#    {'text': '0.0', 'sent_id': 405},
#    {'text': '0.6', 'sent_id': 406},
#    {'text': '2.5', 'sent_id': 407},
#    {'text': '1.2', 'sent_id': 408},
#    {'text': '0.001', 'sent_id': 409},
#    {'text': '-2.4', 'sent_id': 410},
#    {'text': '1.1', 'sent_id': 411},
#    {'text': '0.0', 'sent_id': 412},
#    {'text': '0.5', 'sent_id': 413},
#    {'text': '2.4', 'sent_id': 414},
#    {'text': '1.1', 'sent_id': 415},
#    {'text': '0.001', 'sent_id': 416},
#    {'text': 'Energy', 'sent_id': 417},
#    {'text': '1845.9', 'sent_id': 418},
#    {'text': '796.6', 'sent_id': 419},
#    {'text': '1850.6', 'sent_id': 420},
#    {'text': '682.9', 'sent_id': 421},
#    {'text': '0.860', 'sent_id': 422},
#    {'text': '1780.7', 'sent_id': 423},
#    {'text': '21.8', 'sent_id': 493},
#    {'text': '48.6', 'sent_id': 494},
#    {'text': '21.7', 'sent_id': 495},
#    {'text': '0.001', 'sent_id': 496},
#    {'text': 'Cholesterol', 'sent_id': 497},
#    {'text': '222.4', 'sent_id': 498},
#    {'text': '147.3', 'sent_id': 499},
#    {'text': '215.3', 'sent_id': 500},
#    {'text': '141.0', 'sent_id': 501},
#    {'text': '0.189', 'sent_id': 502},
#    {'text': '247.9', 'sent_id': 503},
#    {'text': '160.7', 'sent_id': 504},
#    {'text': '201.2', 'sent_id': 505},
#    {'text': '128.4', 'sent_id': 506},
#    {'text': '222.4', 'sent_id': 507},
#    {'text': '150.7', 'sent_id': 508},
#    {'text': '0.001', 'sent_id': 509},
#    {'text': '227.3', 'sent_id': 510},
#    {'text': '136.9', 'sent_id': 511},
#    {'text': '206.7', 'sent_id': 512},
#    {'text': '140.9', 'sent_id': 513},
#    {'text': '211.8', 'sent_id': 514},
#    {'text': '144.5', 'sent_id': 515},
#    {'text': '0.001', 'sent_id': 516},
#    {'text': 'SFA', 'sent_id': 517},
#    {'text': '14.8', 'sent_id': 518},
#    {'text': '6.6', 'sent_id': 519},
#    {'text': '14.8', 'sent_id': 520},
#    {'text': '7.3', 'sent_id': 521},
#    {'text': '0.990', 'sent_id': 522},
#    {'text': '14.9', 'sent_id': 523},
#    {'text': '6.6', 'sent_id': 524},
#    {'text': '13.5', 'sent_id': 525},
#    {'text': '6.6', 'sent_id': 526},
#    {'text': '15.9', 'sent_id': 527},
#    {'text': '8.3', 'sent_id': 528},
#    {'text': '0.001', 'sent_id': 529},
#    {'text': '14.6', 'sent_id': 530},
#    {'text': '5.9', 'sent_id': 531},
#    {'text': '14.3', 'sent_id': 532},
#    {'text': '6.9', 'sent_id': 533},
#    {'text': '15.4', 'sent_id': 534},
#    {'text': '6.9', 'sent_id': 535},
#    {'text': '0.001', 'sent_id': 536},
#    {'text': 'Trans fatty acids', 'sent_id': 537},
#    {'text': '0.4', 'sent_id': 538},
#    {'text': '0.3', 'sent_id': 539},
#    {'text': '0.4', 'sent_id': 540},
#    {'text': '0.3', 'sent_id': 541},
#    {'text': '0.069', 'sent_id': 542},
#    {'text': '0.4', 'sent_id': 543},
#    {'text': '0.3', 'sent_id': 544},
#    {'text': '0.4', 'sent_id': 545},
#    {'text': '0.2', 'sent_id': 546},
#    {'text': '0.5', 'sent_id': 547},
#    {'text': '0.3', 'sent_id': 548},
#    {'text': '0.001', 'sent_id': 549},
#    {'text': '0.4', 'sent_id': 550},
#    {'text': '0.2', 'sent_id': 551},
#    {'text': '0.4', 'sent_id': 552},
#    {'text': '0.3', 'sent_id': 553},
#    {'text': '0.5', 'sent_id': 554},
#    {'text': '0.3', 'sent_id': 555},
#    {'text': '0.001', 'sent_id': 556},
#    {'text': 'MUFA', 'sent_id': 557},
#    {'text': '14.6', 'sent_id': 558},
#    {'text': '6.8', 'sent_id': 559},
#    {'text': '14.8', 'sent_id': 560},
#    {'text': '6.7', 'sent_id': 561},
#    {'text': '0.484', 'sent_id': 562},
#    {'text': 'Energy intake is expressed as kcal/day, cholesterol as mg/d, coffee and tea as cc/d, and others are presented as gram/day.',
#     'sent_id': 979},
#    {'text': 'Sweets include ice cream, chocolate, cube sugar, sugar, jam, Halva, biscuits, wafers, cookies, carbonated beverages, non-alcoholic beer, and sweetened beverages.',
#     'sent_id': 980},
#    {'text': 'Table 3', 'sent_id': 981},
#    {'text': 'Odds Ratios and Confidence Intervals for the Association Between DII as Continuous Variable Across Tertiles and HNC by Subtypes in the IROPICAN Study of Iran (2018 and 2020)',
#     'sent_id': 982},
#    {'text': 'Variables', 'sent_id': 983},
#    {'text': 'T1', 'sent_id': 984},
#    {'text': 'T2', 'sent_id': 985},
#    {'text': 'T3', 'sent_id': 986},
#    {'text': 'P -trend *', 'sent_id': 987},
#    {'text': 'OR (95% CI)', 'sent_id': 988},
#    {'text': 'All HNC', 'sent_id': 989},
#    {'text': 'Case/control', 'sent_id': 990},
#    {'text': '262/1138', 'sent_id': 991},
#    {'text': '316/1136', 'sent_id': 992},
#    {'text': '298/1135', 'sent_id': 993},
#    {'text': '-', 'sent_id': 994},
#    {'text': '-', 'sent_id': 995},
#    {'text': 'Crude', 'sent_id': 996},
#    {'text': 'Ref.', 'sent_id': 997},
#    {'text': '1.2 (1.01, 1.45)', 'sent_id': 998},
#    {'text': '1.14 (0.95, 1.37)', 'sent_id': 999},
#    {'text': '0.173', 'sent_id': 1000},
#    {'text': '1.04 (1.00, 1.07)', 'sent_id': 1001},
#    {'text': 'Adjusted *', 'sent_id': 1002},
#    {'text': 'Ref.', 'sent_id': 1003},
#    {'text': '1.13 (0.92, 1.39)', 'sent_id': 1004},
#    {'text': '1.31 (1.06, 1.62)', 'sent_id': 1005},
#    {'text': '0.013', 'sent_id': 1006},
#    {'text': '1.07 (1.03, 1.12)', 'sent_id': 1007},
#    {'text': 'Lip and oral cavity', 'sent_id': 1008},
#    {'text': 'Case/control', 'sent_id': 1009},
#    {'text': '88/1138', 'sent_id': 1010},
#    {'text': '116/1136', 'sent_id': 1011},
#    {'text': '109/1135', 'sent_id': 1012},
#    {'text': '-', 'sent_id': 1013},
#    {'text': '-', 'sent_id': 1014},
#    {'text': 'Crude', 'sent_id': 1015},
#    {'text': 'Ref.', 'sent_id': 1016},
#    {'text': '1.3 (0.99, 1.76)', 'sent_id': 1017},
#    {'text': '1.24 (0.93, 1.66)', 'sent_id': 1018},
#    {'text': '0.16', 'sent_id': 1019},
#    {'text': '1.05 (0.99, 1.11)', 'sent_id': 1020},
#    {'text': 'Adjusted', 'sent_id': 1021},
#    {'text': 'Ref.', 'sent_id': 1022},
#    {'text': '1.33 (0.99, 1.79)', 'sent_id': 1023},
#    {'text': '1.56 (1.16, 1.66)', 'sent_id': 1024},
#    {'text': '0.004', 'sent_id': 1025},
#    {'text': '1.12 (1.05, 1.19)', 'sent_id': 1026},
#    {'text': 'Pharynx', 'sent_id': 1027},
#    {'text': 'Case/Control', 'sent_id': 1028},
#    {'text': '19/1138', 'sent_id': 1029},
#    {'text': '28/1136', 'sent_id': 1030},
#    {'text': '35/1135', 'sent_id': 1031},
#    {'text': '-', 'sent_id': 1032},
#    {'text': '-', 'sent_id': 1033},
#    {'text': 'Crude', 'sent_id': 1034},
#    {'text': 'Ref.', 'sent_id': 1035},
#    {'text': '1.48 (0.82, 2.66)', 'sent_id': 1036},
#    {'text': '1.85 (1.05, 3.25)', 'sent_id': 1037},
#    {'text': '0.03', 'sent_id': 1038},
#    {'text': '1.09 (0.99, 1.22)', 'sent_id': 1039},
#    {'text': 'Adjusted', 'sent_id': 1040},
#    {'text': 'Ref.', 'sent_id': 1041},
#    {'text': '1.49 (0.82, 2.72)', 'sent_id': 1042},
#    {'text': '2.08 (1.14, 3.79)', 'sent_id': 1043},
#    {'text': '0.02', 'sent_id': 1044},
#    {'text': '1.14 (1.02, 1.28)', 'sent_id': 1045},
#    {'text': 'Larynx', 'sent_id': 1046},
#    {'text': 'Case/control', 'sent_id': 1047},
#    {'text': '139/1138', 'sent_id': 1048},
#    {'text': '153/1136', 'sent_id': 1049},
#    {'text': '135/1135', 'sent_id': 1050},
#    {'text': '-', 'sent_id': 1051},
#    {'text': '-', 'sent_id': 1052},
#    {'text': 'Crude', 'sent_id': 1053},
#    {'text': 'Ref.', 'sent_id': 1054},
#    {'text': '1.10 (0.86, 1.41)', 'sent_id': 1055},
#    {'text': '0.97 (0.76, 1.25)', 'sent_id': 1056},
#    {'text': '0.84', 'sent_id': 1057},
#    {'text': '1.01 (0.97, 1.06)', 'sent_id': 1058},
#    {'text': 'Adjusted', 'sent_id': 1059},
#    {'text': 'Ref.', 'sent_id': 1060},
#    {'text': '0.88 (0.65, 1.21)', 'sent_id': 1061},
#    {'text': '0.89 (0.65, 1.24)', 'sent_id': 1062},
#    {'text': '0.50', 'sent_id': 1063},
#    {'text': '1.01 (0.95, 1.07)', 'sent_id': 1064},
#    {'text': 'Note.', 'sent_id': 1065},
#    {'text': 'DII: Dietary inflammatory index; HNC: Head and neck cancer; OR: Odds ratio; CI: Confidence interval; Adjusted for energy (kcal/d), age (years), gender (female, male), province (10 provinces), social economic status (low, medium, and high), tobacco use (yes, no), opium use (yes, no), alcohol use (yes, no), dental health (poor, moderate, and good), and physical activity (sedentary, moderate, and high).',
#     'sent_id': 1066},
#    {'text': 'The difference in the association between DII and the risk of subtypes of HNC is significant ( P of heterogeneity\u2005=\u20050.03).',
#     'sent_id': 1067},
#    {'text': 'Table 4', 'sent_id': 1068},
#    {'text': 'Odds Ratios of HNC Stratified by Opium and Tobacco in Relation to DII Treated as Continuous Variable',
#     'sent_id': 1069},
#    {'text': 'Variables', 'sent_id': 1070},
#    {'text': 'T1', 'sent_id': 1071},
#    {'text': 'T2', 'sent_id': 1072},
#    {'text': 'T3', 'sent_id': 1073},
#    {'text': 'Case/Control', 'sent_id': 1074},
#    {'text': 'OR (95% CI)', 'sent_id': 1075},
#    {'text': 'Case/Control', 'sent_id': 1076},
#    {'text': 'OR (95% CI)', 'sent_id': 1077},
#    {'text': 'Case/Control', 'sent_id': 1078},
#    {'text': 'OR (95% CI)', 'sent_id': 1079},
#    {'text': 'P interaction', 'sent_id': 1080},
#    {'text': 'Cigarette smoking', 'sent_id': 1081},
#    {'text': '0.264', 'sent_id': 1082},
#    {'text': 'No', 'sent_id': 1083},
#    {'text': '110/844', 'sent_id': 1084},
#    {'text': 'Ref.', 'sent_id': 1085},
#    {'text': '139/818', 'sent_id': 1086},
#    {'text': '1.29 (0.97, 1.70)', 'sent_id': 1087},
#    {'text': '133/786', 'sent_id': 1088},
#    {'text': '1.5 (1.13, 2.01)', 'sent_id': 1089},
#    {'text': 'Yes', 'sent_id': 1090},
#    {'text': '152/294', 'sent_id': 1091},
#    {'text': '2.34 (1.69, 3.24)', 'sent_id': 1092},
#    {'text': '171/318', 'sent_id': 1093},
#    {'text': '2.27 (1.65, 3.14)', 'sent_id': 1094},
#    {'text': '165/349', 'sent_id': 1095},
#    {'text': '2.57 (1.86, 3.56)', 'sent_id': 1096},
#    {'text': 'Water pipe use', 'sent_id': 1097},
#    {'text': '0.271', 'sent_id': 1098},
#    {'text': 'No', 'sent_id': 1099},
#    {'text': '227/1056', 'sent_id': 1100},
#    {'text': 'Ref.', 'sent_id': 1101},
#    {'text': '293/1054', 'sent_id': 1102},
#    {'text': '1.19 (0.96, 1.47)', 'sent_id': 1103},
#    {'text': '276/1075', 'sent_id': 1104},
#    {'text': '1.32 (1.05, 1.65)', 'sent_id': 1105},
#    {'text': 'Yes', 'sent_id': 1106},
#    {'text': '35/82', 'sent_id': 1107},
#    {'text': '1.33 (0.83, 2.14)', 'sent_id': 1108},
#    {'text': '23/82', 'sent_id': 1109},
#    {'text': '0.91 (0.54, 1.55)', 'sent_id': 1110},
#    {'text': '22/60', 'sent_id': 1111},
#    {'text': '1.52 (0.91, 2.78)', 'sent_id': 1112},
#    {'text': 'Opium use', 'sent_id': 1113},
#    {'text': '0.120', 'sent_id': 1114},
#    {'text': 'No', 'sent_id': 1115},
#    {'text': '79/759', 'sent_id': 1116},
#    {'text': 'Ref.', 'sent_id': 1117},
#    {'text': '112/723', 'sent_id': 1118},
#    {'text': '1.54 (1.13, 2.11)', 'sent_id': 1119},
#    {'text': '105/710', 'sent_id': 1120},
#    {'text': '1.78 (1.28, 2.46)', 'sent_id': 1121},
#    {'text': 'Yes', 'sent_id': 1122},
#    {'text': '119/132', 'sent_id': 1123},
#    {'text': '4.8 (2.89, 7.97)', 'sent_id': 1124},
#    {'text': '154/166', 'sent_id': 1125},
#    {'text': '4.67 (2.85, 7.68)', 'sent_id': 1126},
#    {'text': '129/157', 'sent_id': 1127},
#    {'text': '5.57 (3.35, 9.26)', 'sent_id': 1128},
#    {'text': 'Note.', 'sent_id': 1129},
#    {'text': 'HNC: Head and neck cancer; DII: Dietary inflammatory index; OR: Odds ratio; CI: Confidence interval.',
#     'sent_id': 1130}],
#   'AUTHORS’ CONTRIBUTION': [{'text': 'Authors’ Contribution', 'sent_id': 1131},
#    {'text': 'Conceptualization : Kazem Zendehdel, Fatemeh Toorang, Saba Narmcheshm.',
#     'sent_id': 1132},
#    {'text': 'Data curation: Fatemeh Toorang, Saba Narmcheshm.',
#     'sent_id': 1133},
#    {'text': 'Formal analysis: Fatemeh Toorang, Saba Narmcheshm, Bahareh Sasanfar.',
#     'sent_id': 1134},
#    {'text': 'Funding acquisition: Kazem Zendehdel, Paolo Boffetta.',
#     'sent_id': 1135},
#    {'text': 'Investigation: Kazem Zendehdel, Fatemeh Toorang, Monireh Sadat Seyyedsalehi, Elham Mohebbi, Ahmad Naghibzadeh-Tahami, Hamideh Rashidian, Bahareh Sasanfar.',
#     'sent_id': 1136},
#    {'text': 'Methodology : Kazem Zendehdel, Fatemeh Toorang, Paolo Boffetta, Saba Narmcheshm, Elham Mohebbi, Maryam Hadji.',
#     'sent_id': 1137},
#    {'text': 'Project administration: Fatemeh Toorang, Monireh Sadat Seyyedsalehi, Elham Mohebbi, Ahmad Naghibzadeh-Tahami, Hamideh Rashidian, Maryam Hadji.',
#     'sent_id': 1138},
#    {'text': 'Resources: Paolo Boffetta, Kazem Zendehdel.', 'sent_id': 1139},
#    {'text': 'Software: Fatemeh Toorang, Bahareh Sasanfar.', 'sent_id': 1140},
#    {'text': 'Supervision: Kazem Zendehdel, Fatemeh Toorang.', 'sent_id': 1141},
#    {'text': 'Validation: Fatemeh Toorang, Saba Narmcheshm.', 'sent_id': 1142},
#    {'text': 'Visualization: Kazem Zendehdel, Fatemeh Toorang, Paolo Boffetta, Saba Narmcheshm.',
#     'sent_id': 1143},
#    {'text': 'Writing–original draft: Saba Narmcheshm.', 'sent_id': 1144},
#    {'text': 'Writing–review & editing : Saba Narmcheshm, Kazem Zendehdel, Fatemeh Toorang, Paolo Buffetta.',
#     'sent_id': 1145}],
#   'ETHICAL APPROVAL': [{'text': 'Ethical Approval', 'sent_id': 1146},
#    {'text': 'The IROPICAN study received the ethical code from the NIMAD committee (IR.NIMAD.REC.1394.027).',
#     'sent_id': 1147},
#    {'text': 'None of the data are published in the name of the participants.',
#     'sent_id': 1148}]}}

# %%
pmcid = article_data.get("article_ids", {}).get("pmcid")
ft_id = article_data.get("article_ids", {}).get("archive") or article_data.get("article_ids", {}).get("manuscript")

print(pmcid, ft_id)
# Out:
# 11380737 None

# %%
all_annotations = []
for section_key, sentences in article_data.get("sections", {}).items():
        if section_key == "REF":
            continue  # Skip processing this section
        section = SECTIONS_MAP.get(section_key, "Other")
        print(section)
        batch_annotations = batch_annotate_sentences(sentences, section)
        if not batch_annotations:
            continue
      
        all_annotations.extend(batch_annotations)
# Out:
# Title
# Abstract
# Introduction
# Methods
# Results
# Discussion
# Conclusion
# Acknowledgments
# Competing Interests
# Table
# Other
# Other

# %%
all_linked_annotations = generate_tags(all_annotations)
all_linked_annotations
# Out:
# [{'type': 'disease',
#   'position': '1.5',
#   'prefix': 'Inflammatory Index and',
#   'exact': 'Head and Neck Cancer',
#   'section': 'Title',
#   'postfix': 'and Neck Cancer:',
#   'tags': [{'name': 'malignant tumour of head andor neck',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0278996'}]},
#  {'type': 'disease',
#   'position': '3.17',
#   'prefix': 'the risk of',
#   'exact': 'head and neck cancer',
#   'section': 'Abstract',
#   'postfix': 'and neck cancer',
#   'tags': [{'name': 'malignant tumour of head andor neck',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0278996'}]},
#  {'type': 'disease',
#   'position': '3.0',
#   'prefix': 'cigarette smoking in',
#   'exact': 'HNC',
#   'section': 'Abstract',
#   'postfix': 'development within the',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '3.33',
#   'prefix': '',
#   'exact': 'HNC',
#   'section': 'Abstract',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '7.11',
#   'prefix': 'ratios (ORs) for',
#   'exact': 'HNC',
#   'section': 'Abstract',
#   'postfix': 'across tertiles of',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '8.14',
#   'prefix': 'risk of all',
#   'exact': 'HNC',
#   'section': 'Abstract',
#   'postfix': '(OR T3 vs.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '9.9',
#   'prefix': 'between lip and',
#   'exact': 'oral cavity cancers',
#   'section': 'Abstract',
#   'postfix': 'cavity cancers and',
#   'tags': [{'name': 'relapsed carcinoma of the mouth',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1335718'}]},
#  {'type': 'disease',
#   'position': '10.12',
#   'prefix': 'increased risk of',
#   'exact': 'pharynx cancer',
#   'section': 'Abstract',
#   'postfix': 'cancer (OR T3',
#   'tags': [{'name': 'mal neo pharynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0153405'}]},
#  {'type': 'disease',
#   'position': '11.10',
#   'prefix': 'between DII and',
#   'exact': 'larynx cancer',
#   'section': 'Abstract',
#   'postfix': 'cancer, while an',
#   'tags': [{'name': 'malignant neo larynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0007107'}]},
#  {'type': 'disease',
#   'position': '11.26',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Abstract',
#   'postfix': '(OR T3 vs.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '12.7',
#   'prefix': 'positively associated with',
#   'exact': 'HNC',
#   'section': 'Abstract',
#   'postfix': 'risk.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '13.16',
#   'prefix': 'oral cavity, and',
#   'exact': 'pharynx cancers',
#   'section': 'Abstract',
#   'postfix': 'cancers.',
#   'tags': [{'name': 'mal neo pharynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0153405'}]},
#  {'type': 'disease',
#   'position': '14.16',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Abstract',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '16.15',
#   'prefix': '% of all',
#   'exact': 'cancers',
#   'section': 'Introduction',
#   'postfix': 'are related to',
#   'tags': [{'name': 'neoplasms or cancers',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0006826'}]},
#  {'type': 'disease',
#   'position': '16.19',
#   'prefix': 'are related to',
#   'exact': 'head and neck cancer',
#   'section': 'Introduction',
#   'postfix': 'and neck cancer',
#   'tags': [{'name': 'malignant tumour of head andor neck',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0278996'}]},
#  {'type': 'disease',
#   'position': '16.0',
#   'prefix': '',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '17.2',
#   'prefix': '1',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': 'includes cancers of',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '17.4',
#   'prefix': '1 HNC includes',
#   'exact': 'cancers of the oral cavity',
#   'section': 'Introduction',
#   'postfix': 'of the oral',
#   'tags': [{'name': 'oral carcinomas',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0151546'}]},
#  {'type': 'disease',
#   'position': '18.2',
#   'prefix': 'The',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': 'prevalence has recently',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '19.4',
#   'prefix': '2 Patients with',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': 'have different complications',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '19.14',
#   'prefix': 'eating difficulties, and',
#   'exact': 'cancer',
#   'section': 'Introduction',
#   'postfix': 'treatment imposes a',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'chemical',
#   'position': '21.7',
#   'prefix': 'and waterpipe) and',
#   'exact': 'alcohol',
#   'section': 'Introduction',
#   'postfix': 'consumption are major',
#   'tags': [{'name': 'alcohol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30879'}]},
#  {'type': 'disease',
#   'position': '21.14',
#   'prefix': 'risk factors for',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'chemical',
#   'position': '22.7',
#   'prefix': 'risk factors include',
#   'exact': 'asbestos',
#   'section': 'Introduction',
#   'postfix': 'exposure, human papillomavirus',
#   'tags': [{'name': 'asbestos',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_46661'}]},
#  {'type': 'disease',
#   'position': '22.9',
#   'prefix': 'include asbestos exposure,',
#   'exact': 'human papillomavirus infection',
#   'section': 'Introduction',
#   'postfix': 'papillomavirus infection, and',
#   'tags': [{'name': 'hpv human papillomavirus',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0343641'}]},
#  {'type': 'disease',
#   'position': '23.14',
#   'prefix': 'and vegetables against',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '24.11',
#   'prefix': 'nutritional factors and',
#   'exact': 'cancer',
#   'section': 'Introduction',
#   'postfix': 'risk by the',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'disease',
#   'position': '24.36',
#   'prefix': 'dietary components with',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': 'is not convincing.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '26.15',
#   'prefix': 'of carcinogenesis, including',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'chemical',
#   'position': '28.6',
#   'prefix': 'components such as',
#   'exact': 'phenols',
#   'section': 'Introduction',
#   'postfix': 'antioxidant vitamins, and',
#   'tags': [{'name': 'phenols',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_33853'}]},
#  {'type': 'chemical',
#   'position': '28.8',
#   'prefix': 'as phenols, antioxidant',
#   'exact': 'vitamins',
#   'section': 'Introduction',
#   'postfix': 'and other nutrients',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'disease',
#   'position': '28.20',
#   'prefix': 'development of several',
#   'exact': 'cancers',
#   'section': 'Introduction',
#   'postfix': '',
#   'tags': [{'name': 'neoplasms or cancers',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0006826'}]},
#  {'type': 'disease',
#   'position': '29.15',
#   'prefix': 'or nutrients and',
#   'exact': 'cancer',
#   'section': 'Introduction',
#   'postfix': 'risk separately; however,',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'disease',
#   'position': '31.11',
#   'prefix': 'between DII and',
#   'exact': 'cancers',
#   'section': 'Introduction',
#   'postfix': 'such as colorectal,',
#   'tags': [{'name': 'neoplasms or cancers',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0006826'}]},
#  {'type': 'disease',
#   'position': '32.15',
#   'prefix': 'between DII and',
#   'exact': 'aerodigestive tract cancer',
#   'section': 'Introduction',
#   'postfix': 'tract cancer, 12',
#   'tags': [{'name': 'malignant digestive system neoplasm',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0685938'}]},
#  {'type': 'disease',
#   'position': '33.16',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': 'especially in southwestern',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '34.23',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Introduction',
#   'postfix': 'development within the',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '37.7',
#   'prefix': 'of Opium and',
#   'exact': 'Cancer',
#   'section': 'Methods',
#   'postfix': '(IROPICAN) is a',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'disease',
#   'position': '39.6',
#   'prefix': '876 pathologically confirmed',
#   'exact': 'HNC',
#   'section': 'Methods',
#   'postfix': 'patients who received',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '39.11',
#   'prefix': 'who received a',
#   'exact': 'cancer',
#   'section': 'Methods',
#   'postfix': 'diagnosis in less',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'disease',
#   'position': '39.24',
#   'prefix': 'history of any',
#   'exact': 'cancers',
#   'section': 'Methods',
#   'postfix': '',
#   'tags': [{'name': 'neoplasms or cancers',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0006826'}]},
#  {'type': 'disease',
#   'position': '40.1',
#   'prefix': '',
#   'exact': 'HNCs',
#   'section': 'Methods',
#   'postfix': 'in this study',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '40.10',
#   'prefix': 'ICD-O-3 codes of',
#   'exact': 'HNC',
#   'section': 'Methods',
#   'postfix': 'including the oral,',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '40.16',
#   'prefix': 'oral, larynx, and',
#   'exact': 'pharyngeal cancers',
#   'section': 'Methods',
#   'postfix': 'cancers (i.e., C00-C09,',
#   'tags': [{'name': 'mal neo pharynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0153405'}]},
#  {'type': 'disease',
#   'position': '42.10',
#   'prefix': 'who were without',
#   'exact': 'cancer',
#   'section': 'Methods',
#   'postfix': 'were not family',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'disease',
#   'position': '42.19',
#   'prefix': '',
#   'exact': 'cancer',
#   'section': 'Methods',
#   'postfix': '',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'chemical',
#   'position': '43.7',
#   'prefix': 'detailed questions about',
#   'exact': 'opium',
#   'section': 'Methods',
#   'postfix': 'use and its',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'chemical',
#   'position': '43.32',
#   'prefix': 'waterpipe), history of',
#   'exact': 'alcohol',
#   'section': 'Methods',
#   'postfix': 'consumption, demographic and',
#   'tags': [{'name': 'alcohol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30879'}]},
#  {'type': 'disease',
#   'position': '44.12',
#   'prefix': 'family history of',
#   'exact': 'cancer',
#   'section': 'Methods',
#   'postfix': 'was also obtained.',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'disease',
#   'position': '52.19',
#   'prefix': 'one year before',
#   'exact': 'cancer',
#   'section': 'Methods',
#   'postfix': 'diagnosis and one',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'chemical',
#   'position': '54.20',
#   'prefix': 'parameters, including energy,',
#   'exact': 'carbohydrate',
#   'section': 'Methods',
#   'postfix': 'fat, protein, fiber,',
#   'tags': [{'name': 'carbohydrate',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16646'}]},
#  {'type': 'chemical',
#   'position': '54.24',
#   'prefix': 'fat, protein, fiber,',
#   'exact': 'cholesterol',
#   'section': 'Methods',
#   'postfix': 'mono-unsaturated fatty acids',
#   'tags': [{'name': 'cholesterol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16113'}]},
#  {'type': 'chemical',
#   'position': '54.25',
#   'prefix': 'protein, fiber, cholesterol,',
#   'exact': 'mono-unsaturated fatty acids',
#   'section': 'Methods',
#   'postfix': 'fatty acids (MUFA),',
#   'tags': [{'name': '2,3,4-saturated fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_71667'}]},
#  {'type': 'chemical',
#   'position': '54.29',
#   'prefix': 'fatty acids (MUFA),',
#   'exact': 'polyunsaturated fatty acids',
#   'section': 'Methods',
#   'postfix': 'fatty acids (PUFA),',
#   'tags': [{'name': 'polyunsaturated fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_26208'}]},
#  {'type': 'chemical',
#   'position': '54.0',
#   'prefix': '',
#   'exact': '-3 fatty acids',
#   'section': 'Methods',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'chemical',
#   'position': '54.0',
#   'prefix': '',
#   'exact': '-6 fatty acids',
#   'section': 'Methods',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'chemical',
#   'position': '54.44',
#   'prefix': '(SFAs), trans fat,',
#   'exact': 'thiamin',
#   'section': 'Methods',
#   'postfix': 'riboflavin, niacin, pyridoxine',
#   'tags': [{'name': 'cobalamin',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30411'}]},
#  {'type': 'chemical',
#   'position': '54.45',
#   'prefix': 'trans fat, thiamin,',
#   'exact': 'riboflavin',
#   'section': 'Methods',
#   'postfix': 'niacin, pyridoxine, folic',
#   'tags': [{'name': 'riboflavin',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_17015'}]},
#  {'type': 'chemical',
#   'position': '54.46',
#   'prefix': 'fat, thiamin, riboflavin,',
#   'exact': 'niacin',
#   'section': 'Methods',
#   'postfix': 'pyridoxine, folic acid,',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'chemical',
#   'position': '54.47',
#   'prefix': 'thiamin, riboflavin, niacin,',
#   'exact': 'pyridoxine',
#   'section': 'Methods',
#   'postfix': 'folic acid, cobalamin,',
#   'tags': [{'name': 'pyridoxine',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16709'}]},
#  {'type': 'chemical',
#   'position': '54.48',
#   'prefix': 'iboflavin, niacin, pyridoxine,',
#   'exact': 'folic acid',
#   'section': 'Methods',
#   'postfix': 'acid, cobalamin, vitamins',
#   'tags': [{'name': 'folic acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_27470'}]},
#  {'type': 'chemical',
#   'position': '54.50',
#   'prefix': 'pyridoxine, folic acid,',
#   'exact': 'cobalamin',
#   'section': 'Methods',
#   'postfix': 'vitamins A, C,',
#   'tags': [{'name': 'cobalamin',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30411'}]},
#  {'type': 'chemical',
#   'position': '54.51',
#   'prefix': 'folic acid, cobalamin,',
#   'exact': 'vitamins',
#   'section': 'Methods',
#   'postfix': 'A, C, and',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'chemical',
#   'position': '54.56',
#   'prefix': 'C, and D,',
#   'exact': 'alpha-tocopherol',
#   'section': 'Methods',
#   'postfix': 'β-carotene, zinc, selenium,',
#   'tags': [{'name': 'alpha-tocopherol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_22470'}]},
#  {'type': 'chemical',
#   'position': '54.57',
#   'prefix': 'and D, alpha-tocopherol,',
#   'exact': 'β-carotene',
#   'section': 'Methods',
#   'postfix': 'zinc, selenium, magnesium,',
#   'tags': [{'name': 'amyloid-beta',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_64645'}]},
#  {'type': 'chemical',
#   'position': '54.58',
#   'prefix': ' alpha-tocopherol, β-carotene,',
#   'exact': 'zinc',
#   'section': 'Methods',
#   'postfix': 'selenium, magnesium, iron,',
#   'tags': [{'name': 'zinc',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_27364'}]},
#  {'type': 'chemical',
#   'position': '54.59',
#   'prefix': '-tocopherol, β-carotene, zinc,',
#   'exact': 'selenium',
#   'section': 'Methods',
#   'postfix': 'magnesium, iron, caffeine,',
#   'tags': [{'name': 'selenium',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_27568'}]},
#  {'type': 'chemical',
#   'position': '54.60',
#   'prefix': 'β-carotene, zinc, selenium,',
#   'exact': 'magnesium',
#   'section': 'Methods',
#   'postfix': 'iron, caffeine, onion,',
#   'tags': [{'name': 'magnesium',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_25108'}]},
#  {'type': 'chemical',
#   'position': '54.61',
#   'prefix': 'zinc, selenium, magnesium,',
#   'exact': 'iron',
#   'section': 'Methods',
#   'postfix': 'caffeine, onion, garlic,',
#   'tags': [{'name': 'iron',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_24873'}]},
#  {'type': 'chemical',
#   'position': '54.62',
#   'prefix': 'selenium, magnesium, iron,',
#   'exact': 'caffeine',
#   'section': 'Methods',
#   'postfix': 'onion, garlic, black',
#   'tags': [{'name': 'caffeine',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_27732'}]},
#  {'type': 'chemical',
#   'position': '54.63',
#   'prefix': 'magnesium, iron, caffeine,',
#   'exact': 'onion',
#   'section': 'Methods',
#   'postfix': 'garlic, black tea,',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'chemical',
#   'position': '54.68',
#   'prefix': 'black tea, coffee,',
#   'exact': 'flavan',
#   'section': 'Methods',
#   'postfix': 'flavones, flavonols, flavonone',
#   'tags': [{'name': 'flavan',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_38691'}]},
#  {'type': 'chemical',
#   'position': '54.0',
#   'prefix': '',
#   'exact': 'ol',
#   'section': 'Methods',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#  {'type': 'chemical',
#   'position': '54.69',
#   'prefix': 'tea, coffee, flavan-3-ol,',
#   'exact': 'flavones',
#   'section': 'Methods',
#   'postfix': 'flavonols, flavonones, anthocy',
#   'tags': [{'name': 'flavones',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_24043'}]},
#  {'type': 'chemical',
#   'position': '54.70',
#   'prefix': 'coffee, flavan-3-ol, flavones,',
#   'exact': 'flavonols',
#   'section': 'Methods',
#   'postfix': 'flavonones, anthocyanidins, an',
#   'tags': [{'name': 'flavonols',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_28802'}]},
#  {'type': 'chemical',
#   'position': '54.71',
#   'prefix': 'van-3-ol, flavones, flavonols,',
#   'exact': 'flavonones',
#   'section': 'Methods',
#   'postfix': 'anthocyanidins, and isoflavone',
#   'tags': [{'name': 'flavones',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_24043'}]},
#  {'type': 'chemical',
#   'position': '54.72',
#   'prefix': 'avones, flavonols, flavonones,',
#   'exact': 'anthocyanidins',
#   'section': 'Methods',
#   'postfix': 'and isoflavones.',
#   'tags': [{'name': 'anthocyanidin',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_38695'}]},
#  {'type': 'chemical',
#   'position': '54.74',
#   'prefix': 'lavonones, anthocyanidins, and',
#   'exact': 'isoflavones',
#   'section': 'Methods',
#   'postfix': '',
#   'tags': [{'name': 'isoflavones',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_38757'}]},
#  {'type': 'disease',
#   'position': '61.10',
#   'prefix': 'and odds of',
#   'exact': 'HNC',
#   'section': 'Methods',
#   'postfix': 'unconditional logistic regress',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'chemical',
#   'position': '62.31',
#   'prefix': 'use (yes, no),',
#   'exact': 'alcohol',
#   'section': 'Methods',
#   'postfix': 'use (yes, no),',
#   'tags': [{'name': 'alcohol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30879'}]},
#  {'type': 'disease',
#   'position': '64.23',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Methods',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '66.4',
#   'prefix': 'We recruited 894',
#   'exact': 'HNC',
#   'section': 'Methods',
#   'postfix': 'patients from the',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'chemical',
#   'position': '72.2',
#   'prefix': 'Regular',
#   'exact': 'alcohol',
#   'section': 'Results',
#   'postfix': 'use was scarce',
#   'tags': [{'name': 'alcohol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30879'}]},
#  {'type': 'chemical',
#   'position': '75.7',
#   'prefix': 'intake of energy,',
#   'exact': 'carbohydrate',
#   'section': 'Results',
#   'postfix': 'and trans fatty',
#   'tags': [{'name': 'carbohydrate',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16646'}]},
#  {'type': 'chemical',
#   'position': '75.9',
#   'prefix': 'energy, carbohydrate, and',
#   'exact': 'trans fatty acids',
#   'section': 'Results',
#   'postfix': 'fatty acids increased',
#   'tags': [{'name': 'monounsaturated fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_25413'}]},
#  {'type': 'disease',
#   'position': '77.16',
#   'prefix': 'all subtypes of',
#   'exact': 'HNC',
#   'section': 'Results',
#   'postfix': 'and total HNC.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '77.19',
#   'prefix': 'HNC and total',
#   'exact': 'HNC',
#   'section': 'Results',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '78.17',
#   'prefix': 'risk of all',
#   'exact': 'HNC',
#   'section': 'Results',
#   'postfix': '(OR [95% CI]:',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '79.12',
#   'prefix': 'and lip and',
#   'exact': 'oral cavity cancer',
#   'section': 'Results',
#   'postfix': 'cavity cancer (OR',
#   'tags': [{'name': 'relapsed carcinoma of the mouth',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1335718'}]},
#  {'type': 'disease',
#   'position': '80.12',
#   'prefix': 'increased risk of',
#   'exact': 'pharynx cancer',
#   'section': 'Results',
#   'postfix': 'cancer even after',
#   'tags': [{'name': 'mal neo pharynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0153405'}]},
#  {'type': 'disease',
#   'position': '81.9',
#   'prefix': 'between DII and',
#   'exact': 'larynx cancer',
#   'section': 'Results',
#   'postfix': 'cancer, and no',
#   'tags': [{'name': 'malignant neo larynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0007107'}]},
#  {'type': 'disease',
#   'position': '82.15',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Results',
#   'postfix': 'meaning that participants',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '82.33',
#   'prefix': '',
#   'exact': 'HNC',
#   'section': 'Results',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '83.28',
#   'prefix': 'great risk of',
#   'exact': 'HNC',
#   'section': 'Results',
#   'postfix': '(OR T3 vs.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '85.10',
#   'prefix': 'positively associated with',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'risk overall.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '86.13',
#   'prefix': 'and lip and',
#   'exact': 'oral cavity cancer',
#   'section': 'Discussion',
#   'postfix': 'cavity cancer and',
#   'tags': [{'name': 'relapsed carcinoma of the mouth',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1335718'}]},
#  {'type': 'disease',
#   'position': '86.17',
#   'prefix': 'cavity cancer and',
#   'exact': 'pharynx cancer',
#   'section': 'Discussion',
#   'postfix': 'cancer.',
#   'tags': [{'name': 'mal neo pharynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0153405'}]},
#  {'type': 'disease',
#   'position': '87.10',
#   'prefix': 'between DII and',
#   'exact': 'larynx cancer',
#   'section': 'Discussion',
#   'postfix': 'cancer.',
#   'tags': [{'name': 'malignant neo larynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0007107'}]},
#  {'type': 'disease',
#   'position': '88.15',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'whereas no interaction',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '90.13',
#   'prefix': 'between DII and',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'worldwide, but they',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '91.32',
#   'prefix': 'is associated with',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '92.14',
#   'prefix': 'with DII on',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'risk, however, but',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '92.31',
#   'prefix': 'and DII on',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '93.12',
#   'prefix': 'between DII and',
#   'exact': 'laryngeal cancer',
#   'section': 'Discussion',
#   'postfix': 'cancer in a',
#   'tags': [{'name': 'larnyx carcinoma',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0595989'}]},
#  {'type': 'disease',
#   'position': '94.11',
#   'prefix': 'between DII and',
#   'exact': 'pharynx cancer',
#   'section': 'Discussion',
#   'postfix': 'cancer which is',
#   'tags': [{'name': 'mal neo pharynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0153405'}]},
#  {'type': 'chemical',
#   'position': '95.11',
#   'prefix': 'interaction between smoking,',
#   'exact': 'alcohol',
#   'section': 'Discussion',
#   'postfix': 'intake, and DII',
#   'tags': [{'name': 'alcohol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30879'}]},
#  {'type': 'disease',
#   'position': '95.16',
#   'prefix': 'and DII on',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'risk.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '96.22',
#   'prefix': 'and DII on',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'risk.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'go_term',
#   'position': '102.9',
#   'prefix': 'stress activates the',
#   'exact': 'inflammatory response',
#   'section': 'Discussion',
#   'postfix': 'response pathway, triggering',
#   'tags': [{'name': 'inflammatory response',
#     'uri': 'http://identifiers.org/go/GO:0006954'}]},
#  {'type': 'chemical',
#   'position': '102.25',
#   'prefix': 'release of reactive',
#   'exact': 'oxygen',
#   'section': 'Discussion',
#   'postfix': 'species (ROS) at',
#   'tags': [{'name': 'oxygen',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_25806'}]},
#  {'type': 'disease',
#   'position': '102.46',
#   'prefix': 'may lead to',
#   'exact': 'cancer',
#   'section': 'Discussion',
#   'postfix': 'initiation and progression.',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'disease',
#   'position': '104.8',
#   'prefix': 'the DII and',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'might be mediated',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'gene_protein',
#   'position': '104.17',
#   'prefix': 'excess production of',
#   'exact': 'cytokines',
#   'section': 'Discussion',
#   'postfix': 'such as interleukin-6',
#   'tags': [{'name': '#', 'uri': 'https://www.uniprot.org/uniprotkb/#/entry'}]},
#  {'type': 'gene_protein',
#   'position': '104.20',
#   'prefix': 'cytokines such as',
#   'exact': 'interleukin-6',
#   'section': 'Discussion',
#   'postfix': '(IL-6), IL-8, platelet-derived',
#   'tags': [{'name': '#', 'uri': 'https://www.uniprot.org/uniprotkb/#/entry'}]},
#  {'type': 'gene_protein',
#   'position': '104.0',
#   'prefix': '',
#   'exact': 'IL-6',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': 'IL6',
#     'uri': 'https://www.uniprot.org/uniprotkb/Q25BC2/entry'}]},
#  {'type': 'gene_protein',
#   'position': '104.22',
#   'prefix': 'as interleukin-6 (IL-6),',
#   'exact': 'IL-8',
#   'section': 'Discussion',
#   'postfix': 'platelet-derived growth factor',
#   'tags': [{'name': 'IL8',
#     'uri': 'https://www.uniprot.org/uniprotkb/Q7YRB5/entry'}]},
#  {'type': 'gene_protein',
#   'position': '104.23',
#   'prefix': 'interleukin-6 (IL-6), IL-8,',
#   'exact': 'platelet-derived growth factor',
#   'section': 'Discussion',
#   'postfix': 'growth factor, and',
#   'tags': [{'name': 'THBGB1',
#     'uri': 'https://www.uniprot.org/uniprotkb/P02775/entry'}]},
#  {'type': 'gene_protein',
#   'position': '104.27',
#   'prefix': 'growth factor, and',
#   'exact': 'vascular endothelial growth factor',
#   'section': 'Discussion',
#   'postfix': 'endothelial growth factor',
#   'tags': [{'name': 'A2R',
#     'uri': 'https://www.uniprot.org/uniprotkb/P52585/entry'}]},
#  {'type': 'disease',
#   'position': '104.33',
#   'prefix': 'factor in the',
#   'exact': 'tumor',
#   'section': 'Discussion',
#   'postfix': 'microenvironment, which are',
#   'tags': [{'name': 'tumor mass',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C3273930'}]},
#  {'type': 'disease',
#   'position': '104.43',
#   'prefix': '',
#   'exact': 'tumor',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': 'tumor mass',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C3273930'}]},
#  {'type': 'go_term',
#   'position': '104.44',
#   'prefix': 'like anti-apoptosis, tumor',
#   'exact': 'angiogenesis',
#   'section': 'Discussion',
#   'postfix': 'and metastasis.',
#   'tags': [{'name': 'angiogenesis',
#     'uri': 'http://identifiers.org/go/GO:0001525'}]},
#  {'type': 'gene_protein',
#   'position': '105.2',
#   'prefix': '29',
#   'exact': 'Inflammatory cytokines',
#   'section': 'Discussion',
#   'postfix': 'cytokines can affect',
#   'tags': [{'name': '#', 'uri': 'https://www.uniprot.org/uniprotkb/#/entry'}]},
#  {'type': 'organism',
#   'position': '105.8',
#   'prefix': 'affect the oral',
#   'exact': 'microbiota',
#   'section': 'Discussion',
#   'postfix': 'which in turn',
#   'tags': [{'name': 'microbiota',
#     'uri': 'http://identifiers.org/taxonomy/13613'}]},
#  {'type': 'disease',
#   'position': '105.18',
#   'prefix': 'increased risk of',
#   'exact': 'periodontitis',
#   'section': 'Discussion',
#   'postfix': 'and cancer.',
#   'tags': [{'name': 'inflammation around tooth',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0031099'}]},
#  {'type': 'disease',
#   'position': '105.20',
#   'prefix': 'of periodontitis and',
#   'exact': 'cancer',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': 'malignant neoplastic primary',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1306459'}]},
#  {'type': 'chemical',
#   'position': '106.9',
#   'prefix': 'direct impact of',
#   'exact': 'carbohydrate',
#   'section': 'Discussion',
#   'postfix': 'consumption on the',
#   'tags': [{'name': 'carbohydrate',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16646'}]},
#  {'type': 'organism',
#   'position': '106.20',
#   'prefix': 'increased populations of',
#   'exact': 'lactobacilli bacteria',
#   'section': 'Discussion',
#   'postfix': 'bacteria, can be',
#   'tags': [{'name': 'bacteria stick insect',
#     'uri': 'http://identifiers.org/taxonomy/629395'}]},
#  {'type': 'disease',
#   'position': '110.26',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '111.16',
#   'prefix': 'DII and overall',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'and its subsites,',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '111.24',
#   'prefix': 'oral cavity and',
#   'exact': 'larynx cancers',
#   'section': 'Discussion',
#   'postfix': 'cancers.',
#   'tags': [{'name': 'malignant neo larynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0007107'}]},
#  {'type': 'chemical',
#   'position': '113.12',
#   'prefix': 'tobacco, opium, and',
#   'exact': 'alcohol',
#   'section': 'Discussion',
#   'postfix': 'use, province, socioeconomic',
#   'tags': [{'name': 'alcohol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30879'}]},
#  {'type': 'disease',
#   'position': '123.17',
#   'prefix': 'new cases of',
#   'exact': 'head and neck cancer',
#   'section': 'Discussion',
#   'postfix': 'and neck cancer',
#   'tags': [{'name': 'malignant tumour of head andor neck',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0278996'}]},
#  {'type': 'disease',
#   'position': '123.0',
#   'prefix': '',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '124.6',
#   'prefix': 'positively associated with',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': 'risk.',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '125.15',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Discussion',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '127.16',
#   'prefix': 'of lip and',
#   'exact': 'oral cavity cancer',
#   'section': 'Conclusion',
#   'postfix': 'cavity cancer and',
#   'tags': [{'name': 'relapsed carcinoma of the mouth',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C1335718'}]},
#  {'type': 'disease',
#   'position': '127.20',
#   'prefix': 'cavity cancer and',
#   'exact': 'pharynx cancer',
#   'section': 'Conclusion',
#   'postfix': 'cancer compared to',
#   'tags': [{'name': 'mal neo pharynx',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0153405'}]},
#  {'type': 'organism',
#   'position': '128.26',
#   'prefix': 'factors such as',
#   'exact': 'plant',
#   'section': 'Conclusion',
#   'postfix': 'foods rich in',
#   'tags': [{'name': 'mosquito plant',
#     'uri': 'http://identifiers.org/taxonomy/180016'}]},
#  {'type': 'organism',
#   'position': '128.51',
#   'prefix': 'saturated fat or',
#   'exact': 'animal',
#   'section': 'Conclusion',
#   'postfix': 'protein may be',
#   'tags': [{'name': 'rodents',
#     'uri': 'http://identifiers.org/taxonomy/9989'}]},
#  {'type': 'disease',
#   'position': '128.62',
#   'prefix': 'the risk of',
#   'exact': 'HNC',
#   'section': 'Conclusion',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '129.29',
#   'prefix': 'higher risks of',
#   'exact': 'HNC',
#   'section': 'Conclusion',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '148.3',
#   'prefix': 'Characteristics of',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': 'patients and controls',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'organism',
#   'position': '153.1',
#   'prefix': '',
#   'exact': 'Tertiles',
#   'section': 'Table',
#   'postfix': 'of DII in',
#   'tags': [{'name': '#', 'uri': 'http://identifiers.org/taxonomy/#'}]},
#  {'type': 'organism',
#   'position': '154.1',
#   'prefix': '',
#   'exact': 'Tertiles',
#   'section': 'Table',
#   'postfix': 'of DII in',
#   'tags': [{'name': '#', 'uri': 'http://identifiers.org/taxonomy/#'}]},
#  {'type': 'disease',
#   'position': '363.1',
#   'prefix': '',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': 'Head and neck',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '363.2',
#   'prefix': 'HNC:',
#   'exact': 'Head and neck cancer',
#   'section': 'Table',
#   'postfix': 'and neck cancer;',
#   'tags': [{'name': 'malignant tumour of head andor neck',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0278996'}]},
#  {'type': 'organism',
#   'position': '367.1',
#   'prefix': '',
#   'exact': 'Tertiles',
#   'section': 'Table',
#   'postfix': 'of DII in',
#   'tags': [{'name': '#', 'uri': 'http://identifiers.org/taxonomy/#'}]},
#  {'type': 'organism',
#   'position': '368.1',
#   'prefix': '',
#   'exact': 'Tertiles',
#   'section': 'Table',
#   'postfix': 'of DII in',
#   'tags': [{'name': '#', 'uri': 'http://identifiers.org/taxonomy/#'}]},
#  {'type': 'chemical',
#   'position': '437.1',
#   'prefix': '',
#   'exact': 'Carbohydrate',
#   'section': 'Table',
#   'postfix': '',
#   'tags': [{'name': 'carbohydrate',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16646'}]},
#  {'type': 'chemical',
#   'position': '497.1',
#   'prefix': '',
#   'exact': 'Cholesterol',
#   'section': 'Table',
#   'postfix': '',
#   'tags': [{'name': 'cholesterol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16113'}]},
#  {'type': 'chemical',
#   'position': '537.2',
#   'prefix': 'Trans',
#   'exact': 'fatty acids',
#   'section': 'Table',
#   'postfix': 'acids',
#   'tags': [{'name': 'polyunsaturated fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_26208'}]},
#  {'type': 'chemical',
#   'position': '597.1',
#   'prefix': '',
#   'exact': 'Omega-3 fatty acids',
#   'section': 'Table',
#   'postfix': 'fatty acids',
#   'tags': [{'name': 'omega-3 fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_25681'}]},
#  {'type': 'chemical',
#   'position': '617.1',
#   'prefix': '',
#   'exact': 'Omega-6 fatty acids',
#   'section': 'Table',
#   'postfix': 'fatty acids',
#   'tags': [{'name': 'omega-3 fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_25681'}]},
#  {'type': 'chemical',
#   'position': '978.9',
#   'prefix': 'Standard deviation; SFA:',
#   'exact': 'Saturated fatty acids',
#   'section': 'Table',
#   'postfix': 'fatty acids;MUFA: Mono',
#   'tags': [{'name': 'saturated fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_26607'}]},
#  {'type': 'chemical',
#   'position': '978.12',
#   'prefix': 'Saturated fatty acids;MUFA:',
#   'exact': 'Mono unsaturated fatty acids',
#   'section': 'Table',
#   'postfix': 'unsaturated fatty acids;PUFA:',
#   'tags': [{'name': 'hydroxy monounsaturated fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_131869'}]},
#  {'type': 'chemical',
#   'position': '978.16',
#   'prefix': 'unsaturated fatty acids;PUFA:',
#   'exact': 'Poly unsaturated fatty acids',
#   'section': 'Table',
#   'postfix': 'unsaturated fatty acids.',
#   'tags': [{'name': 'polyunsaturated fatty acid',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_26208'}]},
#  {'type': 'chemical',
#   'position': '979.7',
#   'prefix': 'expressed as kcal/day,',
#   'exact': 'cholesterol',
#   'section': 'Table',
#   'postfix': 'as mg/d, coffee',
#   'tags': [{'name': 'cholesterol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_16113'}]},
#  {'type': 'chemical',
#   'position': '980.7',
#   'prefix': 'cream, chocolate, cube',
#   'exact': 'sugar',
#   'section': 'Table',
#   'postfix': 'sugar, jam, Halva,',
#   'tags': [{'name': 'deoxy sugar',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_23639'}]},
#  {'type': 'chemical',
#   'position': '980.8',
#   'prefix': '',
#   'exact': 'sugar',
#   'section': 'Table',
#   'postfix': '',
#   'tags': [{'name': 'deoxy sugar',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_23639'}]},
#  {'type': 'disease',
#   'position': '982.17',
#   'prefix': 'Across Tertiles and',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': 'by Subtypes in',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '989.2',
#   'prefix': 'All',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': '',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '1066.5',
#   'prefix': 'Dietary inflammatory index;',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': 'Head and neck',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '1066.6',
#   'prefix': 'inflammatory index; HNC:',
#   'exact': 'Head and neck cancer',
#   'section': 'Table',
#   'postfix': 'and neck cancer;',
#   'tags': [{'name': 'malignant tumour of head andor neck',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0278996'}]},
#  {'type': 'chemical',
#   'position': '1066.43',
#   'prefix': 'use (yes, no),',
#   'exact': 'alcohol',
#   'section': 'Table',
#   'postfix': 'use (yes, no),',
#   'tags': [{'name': 'alcohol',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_30879'}]},
#  {'type': 'disease',
#   'position': '1067.14',
#   'prefix': 'of subtypes of',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': 'is significant (',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '1069.4',
#   'prefix': 'Odds Ratios of',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': 'Stratified by Opium',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'chemical',
#   'position': '1097.1',
#   'prefix': '',
#   'exact': 'Water',
#   'section': 'Table',
#   'postfix': 'pipe use',
#   'tags': [{'name': 'water',
#     'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI_15377'}]},
#  {'type': 'disease',
#   'position': '1130.1',
#   'prefix': '',
#   'exact': 'HNC',
#   'section': 'Table',
#   'postfix': 'Head and neck',
#   'tags': [{'name': '#',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#  {'type': 'disease',
#   'position': '1130.2',
#   'prefix': 'HNC:',
#   'exact': 'Head and neck cancer',
#   'section': 'Table',
#   'postfix': 'and neck cancer;',
#   'tags': [{'name': 'malignant tumour of head andor neck',
#     'uri': 'http://linkedlifedata.com/resource/umls-concept/C0278996'}]}]

# %%
print(pmcid)
# Out:
# 11380737

# %%
from collections import OrderedDict

def format_output_annotations(all_linked_annotations_, pmcid, ft_id):
    """
    Formats output annotations into two JSON structures:
    - 'match_json' for matched annotations
    - 'non_match_json' for unmatched annotations
    """
    match_annotations = []
    non_match_annotations = []

    # Separate annotations based on tags
    for annotation in all_linked_annotations_:
        # Check if the annotation is unmatched (name and uri are '#')
        if annotation["tags"][0]["name"] == "#" and annotation["tags"][0]["uri"].endswith("#"):
            non_match_annotations.append(annotation)
        else:
            match_annotations.append(annotation)

    # Construct final JSON outputs
    match_json = OrderedDict()
    non_match_json = OrderedDict()

    # Add pmcid or ft_id to both match and non-match JSONs
    if pmcid:
        match_json["pmcid"] = pmcid
        non_match_json["pmcid"] = pmcid
    elif ft_id:
        match_json["ft_id"] = ft_id
        non_match_json["ft_id"] = ft_id

    # Add provider and anns fields to each JSON
    match_json["provider"] = "europepmc"
    match_json["anns"] = match_annotations

    non_match_json["provider"] = "europepmc"
    non_match_json["anns"] = non_match_annotations

    return match_json, non_match_json

# %%
match_json, non_match_json = format_output_annotations(all_linked_annotations, pmcid, ft_id)

# %%
non_match_json
# Out:
# OrderedDict([('pmcid', '11380737'),
#              ('provider', 'europepmc'),
#              ('anns',
#               [{'type': 'disease',
#                 'position': '3.0',
#                 'prefix': 'cigarette smoking in',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': 'development within the',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '3.33',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '7.11',
#                 'prefix': 'ratios (ORs) for',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': 'across tertiles of',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '8.14',
#                 'prefix': 'risk of all',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '(OR T3 vs.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '11.26',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '(OR T3 vs.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '12.7',
#                 'prefix': 'positively associated with',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '14.16',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '16.0',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '17.2',
#                 'prefix': '1',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'includes cancers of',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '18.2',
#                 'prefix': 'The',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'prevalence has recently',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '19.4',
#                 'prefix': '2 Patients with',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'have different complications',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '21.14',
#                 'prefix': 'risk factors for',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '23.14',
#                 'prefix': 'and vegetables against',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '24.36',
#                 'prefix': 'dietary components with',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'is not convincing.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '26.15',
#                 'prefix': 'of carcinogenesis, including',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'chemical',
#                 'position': '28.8',
#                 'prefix': 'as phenols, antioxidant',
#                 'exact': 'vitamins',
#                 'section': 'Introduction',
#                 'postfix': 'and other nutrients',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'disease',
#                 'position': '33.16',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'especially in southwestern',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '34.23',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'development within the',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '39.6',
#                 'prefix': '876 pathologically confirmed',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'patients who received',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '40.1',
#                 'prefix': '',
#                 'exact': 'HNCs',
#                 'section': 'Methods',
#                 'postfix': 'in this study',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '40.10',
#                 'prefix': 'ICD-O-3 codes of',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'including the oral,',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'chemical',
#                 'position': '43.7',
#                 'prefix': 'detailed questions about',
#                 'exact': 'opium',
#                 'section': 'Methods',
#                 'postfix': 'use and its',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.0',
#                 'prefix': '',
#                 'exact': '-3 fatty acids',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.0',
#                 'prefix': '',
#                 'exact': '-6 fatty acids',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.46',
#                 'prefix': 'fat, thiamin, riboflavin,',
#                 'exact': 'niacin',
#                 'section': 'Methods',
#                 'postfix': 'pyridoxine, folic acid,',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.51',
#                 'prefix': 'folic acid, cobalamin,',
#                 'exact': 'vitamins',
#                 'section': 'Methods',
#                 'postfix': 'A, C, and',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.63',
#                 'prefix': 'magnesium, iron, caffeine,',
#                 'exact': 'onion',
#                 'section': 'Methods',
#                 'postfix': 'garlic, black tea,',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.0',
#                 'prefix': '',
#                 'exact': 'ol',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'disease',
#                 'position': '61.10',
#                 'prefix': 'and odds of',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'unconditional logistic regress',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '64.23',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '66.4',
#                 'prefix': 'We recruited 894',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'patients from the',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '77.16',
#                 'prefix': 'all subtypes of',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': 'and total HNC.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '77.19',
#                 'prefix': 'HNC and total',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '78.17',
#                 'prefix': 'risk of all',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '(OR [95% CI]:',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '82.15',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': 'meaning that participants',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '82.33',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '83.28',
#                 'prefix': 'great risk of',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '(OR T3 vs.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '85.10',
#                 'prefix': 'positively associated with',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk overall.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '88.15',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'whereas no interaction',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '90.13',
#                 'prefix': 'between DII and',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'worldwide, but they',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '91.32',
#                 'prefix': 'is associated with',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '92.14',
#                 'prefix': 'with DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk, however, but',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '92.31',
#                 'prefix': 'and DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '95.16',
#                 'prefix': 'and DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '96.22',
#                 'prefix': 'and DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '104.8',
#                 'prefix': 'the DII and',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'might be mediated',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '110.26',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '111.16',
#                 'prefix': 'DII and overall',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'and its subsites,',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '123.0',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '124.6',
#                 'prefix': 'positively associated with',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '125.15',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '128.62',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Conclusion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '129.29',
#                 'prefix': 'higher risks of',
#                 'exact': 'HNC',
#                 'section': 'Conclusion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '148.3',
#                 'prefix': 'Characteristics of',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'patients and controls',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'organism',
#                 'position': '153.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'organism',
#                 'position': '154.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'disease',
#                 'position': '363.1',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Head and neck',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'organism',
#                 'position': '367.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'organism',
#                 'position': '368.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'disease',
#                 'position': '982.17',
#                 'prefix': 'Across Tertiles and',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'by Subtypes in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '989.2',
#                 'prefix': 'All',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1066.5',
#                 'prefix': 'Dietary inflammatory index;',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Head and neck',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1067.14',
#                 'prefix': 'of subtypes of',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'is significant (',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1069.4',
#                 'prefix': 'Odds Ratios of',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Stratified by Opium',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1130.1',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Head and neck',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]}])])

# %%
from collections import defaultdict, OrderedDict

def modify_restricted_json(json_data, open_status):
    """
    Modifies the JSON structure for restricted access:
    - Removes 'prefix' and 'postfix' fields.
    - Adds 'frequency' field to count occurrences of each unique 'exact' term.
    """
    if open_status in ["OA", "O"]:
        return json_data  # No modification if open access

    # Count frequency of each 'exact' term
    frequency_counter = defaultdict(int)
    for annotation in json_data["anns"]:
        frequency_counter[annotation["exact"]] += 1

    # Modify each annotation
    restricted_annotations = []
    for annotation in json_data["anns"]:
        # Remove 'prefix' and 'postfix' fields, add 'frequency'
        restricted_annotation = {
            "exact": annotation["exact"],
            "tags": annotation["tags"],
            "type": annotation["type"],
            "section": annotation["section"],
            "provider": json_data["provider"],
            "frequency": frequency_counter[annotation["exact"]]
        }
        restricted_annotations.append(restricted_annotation)

    # Build the modified JSON structure
    modified_json = OrderedDict()
    modified_json["provider"] = json_data["provider"]
    modified_json["anns"] = restricted_annotations

    # Preserve 'pmcid' or 'ft_id' in the modified JSON
    if "pmcid" in json_data:
        modified_json["pmcid"] = json_data["pmcid"]
    elif "ft_id" in json_data:
        modified_json["ft_id"] = json_data["ft_id"]

    return modified_json

# %%
xx = modify_restricted_json(non_match_json, open_status='OA')

# %%
xx
# Out:
# OrderedDict([('pmcid', '11380737'),
#              ('provider', 'europepmc'),
#              ('anns',
#               [{'type': 'disease',
#                 'position': '3.0',
#                 'prefix': 'cigarette smoking in',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': 'development within the',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '3.33',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '7.11',
#                 'prefix': 'ratios (ORs) for',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': 'across tertiles of',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '8.14',
#                 'prefix': 'risk of all',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '(OR T3 vs.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '11.26',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '(OR T3 vs.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '12.7',
#                 'prefix': 'positively associated with',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '14.16',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Abstract',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '16.0',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '17.2',
#                 'prefix': '1',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'includes cancers of',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '18.2',
#                 'prefix': 'The',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'prevalence has recently',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '19.4',
#                 'prefix': '2 Patients with',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'have different complications',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '21.14',
#                 'prefix': 'risk factors for',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '23.14',
#                 'prefix': 'and vegetables against',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '24.36',
#                 'prefix': 'dietary components with',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'is not convincing.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '26.15',
#                 'prefix': 'of carcinogenesis, including',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'chemical',
#                 'position': '28.8',
#                 'prefix': 'as phenols, antioxidant',
#                 'exact': 'vitamins',
#                 'section': 'Introduction',
#                 'postfix': 'and other nutrients',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'disease',
#                 'position': '33.16',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'especially in southwestern',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '34.23',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Introduction',
#                 'postfix': 'development within the',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '39.6',
#                 'prefix': '876 pathologically confirmed',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'patients who received',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '40.1',
#                 'prefix': '',
#                 'exact': 'HNCs',
#                 'section': 'Methods',
#                 'postfix': 'in this study',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '40.10',
#                 'prefix': 'ICD-O-3 codes of',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'including the oral,',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'chemical',
#                 'position': '43.7',
#                 'prefix': 'detailed questions about',
#                 'exact': 'opium',
#                 'section': 'Methods',
#                 'postfix': 'use and its',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.0',
#                 'prefix': '',
#                 'exact': '-3 fatty acids',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.0',
#                 'prefix': '',
#                 'exact': '-6 fatty acids',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.46',
#                 'prefix': 'fat, thiamin, riboflavin,',
#                 'exact': 'niacin',
#                 'section': 'Methods',
#                 'postfix': 'pyridoxine, folic acid,',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.51',
#                 'prefix': 'folic acid, cobalamin,',
#                 'exact': 'vitamins',
#                 'section': 'Methods',
#                 'postfix': 'A, C, and',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.63',
#                 'prefix': 'magnesium, iron, caffeine,',
#                 'exact': 'onion',
#                 'section': 'Methods',
#                 'postfix': 'garlic, black tea,',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'chemical',
#                 'position': '54.0',
#                 'prefix': '',
#                 'exact': 'ol',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'https://www.ebi.ac.uk/chebi/searchId.do?chebiId=#'}]},
#                {'type': 'disease',
#                 'position': '61.10',
#                 'prefix': 'and odds of',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'unconditional logistic regress',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '64.23',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '66.4',
#                 'prefix': 'We recruited 894',
#                 'exact': 'HNC',
#                 'section': 'Methods',
#                 'postfix': 'patients from the',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '77.16',
#                 'prefix': 'all subtypes of',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': 'and total HNC.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '77.19',
#                 'prefix': 'HNC and total',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '78.17',
#                 'prefix': 'risk of all',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '(OR [95% CI]:',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '82.15',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': 'meaning that participants',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '82.33',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '83.28',
#                 'prefix': 'great risk of',
#                 'exact': 'HNC',
#                 'section': 'Results',
#                 'postfix': '(OR T3 vs.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '85.10',
#                 'prefix': 'positively associated with',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk overall.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '88.15',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'whereas no interaction',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '90.13',
#                 'prefix': 'between DII and',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'worldwide, but they',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '91.32',
#                 'prefix': 'is associated with',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '92.14',
#                 'prefix': 'with DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk, however, but',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '92.31',
#                 'prefix': 'and DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '95.16',
#                 'prefix': 'and DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '96.22',
#                 'prefix': 'and DII on',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '104.8',
#                 'prefix': 'the DII and',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'might be mediated',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '110.26',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '111.16',
#                 'prefix': 'DII and overall',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'and its subsites,',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '123.0',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '124.6',
#                 'prefix': 'positively associated with',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': 'risk.',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '125.15',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Discussion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '128.62',
#                 'prefix': 'the risk of',
#                 'exact': 'HNC',
#                 'section': 'Conclusion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '129.29',
#                 'prefix': 'higher risks of',
#                 'exact': 'HNC',
#                 'section': 'Conclusion',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '148.3',
#                 'prefix': 'Characteristics of',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'patients and controls',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'organism',
#                 'position': '153.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'organism',
#                 'position': '154.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'disease',
#                 'position': '363.1',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Head and neck',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'organism',
#                 'position': '367.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'organism',
#                 'position': '368.1',
#                 'prefix': '',
#                 'exact': 'Tertiles',
#                 'section': 'Table',
#                 'postfix': 'of DII in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://identifiers.org/taxonomy/#'}]},
#                {'type': 'disease',
#                 'position': '982.17',
#                 'prefix': 'Across Tertiles and',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'by Subtypes in',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '989.2',
#                 'prefix': 'All',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': '',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1066.5',
#                 'prefix': 'Dietary inflammatory index;',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Head and neck',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1067.14',
#                 'prefix': 'of subtypes of',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'is significant (',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1069.4',
#                 'prefix': 'Odds Ratios of',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Stratified by Opium',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]},
#                {'type': 'disease',
#                 'position': '1130.1',
#                 'prefix': '',
#                 'exact': 'HNC',
#                 'section': 'Table',
#                 'postfix': 'Head and neck',
#                 'tags': [{'name': '#',
#                   'uri': 'http://linkedlifedata.com/resource/umls-concept/#'}]}])])
