# %%
import json
import pandas as pd

# Replace 'sample.jsonl' with your actual file path
file_path = 'data/patch-27-10-2024-0.api.json'
extracted_data = []

# Manually reading each line as JSON since jsonlines isn't available
# Mapping for type abbreviations
type_map = {
    "go_term": "GO",
    "exp_methods": "EM",
    "gene_protein": "GP",
    "disease": "DS",
    "chemical": "CD",
    "organism": "OG",
    "gene expression": 'GO',
    "methods":'EM'
}

# Open file with 'latin-1' encoding
with open(file_path, 'r', encoding='latin-1') as file:
    for line in file:
        obj = json.loads(line)
        for ann in obj.get('anns', []):
            exact_text = ann['exact']
            uri = ann['tags'][0]['uri']  # Assumes each tag has a single URI
            link = ann['tags'][0]['uri'].split('/')[-1]
            ann_type = type_map.get(ann['type'], "Unknown")  # Map the type or use "Unknown" if not in type_map
            # ann_type = ann['type']
            extracted_data.append({"exact": exact_text, "ground": link, "uri": uri, "type": ann_type})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 22
#      10 type_map = {
#      11     "go_term": "GO",
#      12     "exp_methods": "EM",
#    (...)
#      18     "methods":'EM'
#      19 }
#      21 # Open file with 'latin-1' encoding
# ---> 22 with open(file_path, 'r', encoding='latin-1') as file:
#      23     for line in file:
#      24         obj = json.loads(line)
#
# File ~/falconframes_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/patch-28-10-2024-0.api.json'

# %%
# Convert to DataFrame for easy viewing and manipulation
extracted_df = pd.DataFrame(extracted_data)
print(extracted_df.head())  # Display first few rows
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
extracted_df['type'].unique()
# Out:
# array(['GP', 'DS', 'EM', 'CD', 'OG', 'Unknown', 'GO'], dtype=object)

# %%
import faiss
import pickle
import spacy
import numpy as np
from fuzzywuzzy import fuzz, process
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Load spaCy model
nlp = spacy.load("/home/stirunag/work/github/CAPITAL/normalisation/en_floret_model")

# Mapping of file names to each annotation type
file_mapping = {
    'CD': ('chebi_terms.index', 'chebi_terms.pkl'),
    'OG': ('NCBI_terms.index', 'NCBI_terms.pkl'),
    'DS': ('umls_terms.index', 'umls_terms.pkl'),
    'GP': ('uniprot_terms.index', 'uniprot_terms.pkl'),
    'GO': ('go_terms.index', 'go_terms.pkl'),
    'EM': ('em_terms.index', 'em_terms.pkl')
}

# Load data and indices for each annotation type
base_path = "/home/stirunag/work/github/CAPITAL/normalisation/dictionary/"
loaded_data = {}
for annotation_type, (index_file, pkl_file) in file_mapping.items():
    with open(base_path + pkl_file, "rb") as infile:
        data = pickle.load(infile)
    index = faiss.read_index(base_path + index_file)
    
    # Create a reverse mapping from CUI to term
    id_to_term = {v: k for k, v in data["term_to_id"].items()}
    
    # Store loaded data
    loaded_data[annotation_type] = {
        "term_to_id": data["term_to_id"],
        "indexed_terms": data["indexed_terms"],
        "index": index,
        "id_to_term": id_to_term
    }
    print(f"Loaded data for {annotation_type}")


# List of phrases to remove (converted to lowercase)
phrases_to_remove = [
    '--', 'physical finding', 'diagnosis', 'disorder', 'procedure', 'finding',
    'symptom', 'history', 'treatment', 'manifestation', 'disease', 'finding',
    'morphologic abnormality', 'etiology', 'observable entity', 'event',
    'situation', 'degrees', 'in some patients', 'cm', 'mm',
    '#', 'rare', 'degree', 'including anastomotic', 'navigational concept',
    '1 patient', 'qualifier value', 'lab test', 'unintentional',
    'tophi', 'nos', 'msec', 'reni', 'less common', 'as symptom'
]

# Function to clean term
def clean_term(term):
    # Convert term to lowercase for consistent comparison
    term_lower = term.lower()
    
    # Remove specified phrases
    for phrase in phrases_to_remove:
        term_lower = re.sub(rf'\b{re.escape(phrase)}\b', '', term_lower, flags=re.IGNORECASE)
    
    # Remove punctuation
    term_cleaned = term_lower.translate(str.maketrans('', '', string.punctuation))
    
    # Remove extra whitespace
    term_cleaned = ' '.join(term_cleaned.split())
    
    return term_cleaned

# Function to clean term
def clean_term_EM(term):
    # Convert term to lowercase for consistent comparison
    if term.endswith("es"):
        return term[:-2]
    elif term.endswith("s"):
        return term[:-1]
    return term
    
    return term_cleaned
    

# Matching functions
def get_exact_match(term, term_dict):
    return term_dict.get(term)

def get_fuzzy_match(term, term_dict, threshold=70):
    result = process.extractOne(term, term_dict.keys(), scorer=fuzz.ratio)
    if result:
        match, score = result[0], result[1]
        if score >= threshold:
            return term_dict[match]
    return None

def is_flat_index(index):
    return isinstance(index, faiss.IndexFlat)

def get_embedding_match(term, index, indexed_terms, term_dict, model, threshold=0.7):
    term_vector = model(term).vector.reshape(1, -1).astype('float32')
    faiss.normalize_L2(term_vector)
    
    # Perform search on the FAISS index
    _, I = index.search(term_vector, 1)
    
    if I[0][0] != -1:
        matched_term = indexed_terms[I[0][0]]
        similarity = cosine_similarity(term_vector, model(matched_term).vector.reshape(1, -1))[0][0]
        if similarity >= threshold:
            return term_dict.get(matched_term, "No Match")
    return None

def map_terms(entities, annotation_type, model):
    """Map new entities using exact, fuzzy, and embedding matches, with abbreviation fallback."""
    data = loaded_data[annotation_type]
    term_dict = data["term_to_id"]
    indexed_terms = data["indexed_terms"]
    index = data["index"]

    mapped_entities = {}
    for entity in entities:
        match = get_exact_match(entity, term_dict)
        if not match:
            if annotation_type =='DS':
                match = get_embedding_match(clean_term(entity.lower()), index, indexed_terms, term_dict, model)
            elif annotation_type =='EM':
                match = get_embedding_match(clean_term_EM(entity.lower()), index, indexed_terms, term_dict, model)
            else:
                match = get_embedding_match(entity.lower(), index, indexed_terms, term_dict, model)
        mapped_entities[entity] = match if match else "No Match"
    return mapped_entities
    
def map_terms_reverse(entities, annotation_type, model):
    """Map entities using exact, similarity, and embedding matches, returning both code and term."""
    data = loaded_data[annotation_type]
    term_dict = data["term_to_id"]
    id_to_term = data["id_to_term"]
    indexed_terms = data["indexed_terms"]
    index = data["index"]

    mapped_entities = {}
    for entity in entities:
        # Normalize entity based on annotation type requirements
        normalized_entity = entity.lower() if annotation_type != 'GP' else entity
        
        # Try exact match
        match = get_exact_match(normalized_entity, term_dict)
        
        # If exact match fails, try similarity or embedding matching
        if not match:
            if annotation_type =='DS':
                match = get_embedding_match(clean_term(entity.lower()), index, indexed_terms, term_dict, model)
            elif annotation_type =='EM':
                match = get_embedding_match(clean_term_EM(entity.lower()), index, indexed_terms, term_dict, model)
            else:
                match = get_embedding_match(entity.lower(), index, indexed_terms, term_dict, model)
        
        # Set grounded_code and grounded_term based on match
        if match:
            grounded_code = match
            grounded_term = id_to_term.get(match, "Unknown Term")  # Retrieve term from id_to_term or use default
        else:
            grounded_code, grounded_term = "No Match", "No Match"
        
        # Ensure both code and term are consistently stored in the result
        mapped_entities[entity] = (grounded_code, grounded_term)
    
    return mapped_entities
# Out:
# /home/stirunag/falconframes_env/lib/python3.10/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.2.5 and may not be 100% compatible with the current version (3.7.5). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /home/stirunag/falconframes_env/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/stirunag/falconframes_env/lib/python3.10/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# Loaded data for CD
# Loaded data for OG
# Loaded data for DS
# Loaded data for GP
# Loaded data for GO
# Loaded data for EM

# %%
extracted_df = extracted_df[(extracted_df["type"] != "Unknown")]
extracted_df
# Out:
#                 exact       ground  \
# 0                 SR1       Q9LZW4
# 1                HRAS       P01115
# 2         Spitz Nevus     C0206739
# 3         Spitz nevus     C0206739
# 4         Spitz nevus     C0206739
# ...               ...          ...
# 264542   fibrosarcoma     C0016057
# 264543  translocation  EFO_0004024
# 264544         tumors     C0027651
# 264545           MUC4       Q99102
# 264546        spindle   GO:0005819
#
#                                                       uri type
# 0                  http://purl.uniprot.org/uniprot/Q9LZW4   GP
# 1                  http://purl.uniprot.org/uniprot/P01115   GP
# 2       http://linkedlifedata.com/resource/umls-concep...   DS
# 3       http://linkedlifedata.com/resource/umls-concep...   DS
# 4       http://linkedlifedata.com/resource/umls-concep...   DS
# ...                                                   ...  ...
# 264542  http://linkedlifedata.com/resource/umls-concep...   DS
# 264543               http://www.ebi.ac.uk/efo/EFO_0004024   EM
# 264544  http://linkedlifedata.com/resource/umls-concep...   DS
# 264545             http://purl.uniprot.org/uniprot/Q99102   GP
# 264546               http://identifiers.org/go/GO:0005819   GO
#
# [263091 rows x 4 columns]

# %%
extracted_df = extracted_df.drop_duplicates(subset="exact", keep="first")
extracted_df
# Out:
#                                       exact    ground  \
# 0                                       SR1    Q9LZW4
# 1                                      HRAS    P01115
# 2                               Spitz Nevus  C0206739
# 3                               Spitz nevus  C0206739
# 5                         Spitzoid melanoma  C3495721
# ...                                     ...       ...
# 264530                    deep fibromatosis  C0079218
# 264531         Desmoplastic fibroma of bone  C0206645
# 264533                       Leiomyosarcoma  C0023269
# 264540        Low-grade fibromyxoid sarcoma  C1275282
# 264541  sclerosing epithelioid fibrosarcoma  C1710026
#
#                                                       uri type
# 0                  http://purl.uniprot.org/uniprot/Q9LZW4   GP
# 1                  http://purl.uniprot.org/uniprot/P01115   GP
# 2       http://linkedlifedata.com/resource/umls-concep...   DS
# 3       http://linkedlifedata.com/resource/umls-concep...   DS
# 5       http://linkedlifedata.com/resource/umls-concep...   DS
# ...                                                   ...  ...
# 264530  http://linkedlifedata.com/resource/umls-concep...   DS
# 264531  http://linkedlifedata.com/resource/umls-concep...   DS
# 264533  http://linkedlifedata.com/resource/umls-concep...   DS
# 264540  http://linkedlifedata.com/resource/umls-concep...   DS
# 264541  http://linkedlifedata.com/resource/umls-concep...   DS
#
# [24115 rows x 4 columns]

# %%
from tqdm import tqdm
import re
import string
df = extracted_df.copy()

 
# Initialize columns for grounded codes, terms, and match status
df["grounded_code"] = "No Match"
df["grounded_term"] = "No Match"

# Iterate over each unique annotation type with a progress bar
for anno_type in tqdm(df["type"].unique(), desc="Processing annotation types"):
    # Filter for rows of the current annotation type and get a list of unique exact terms
    anno_list = df[df['type'] == anno_type]['exact'].unique().tolist()
    
    # Get the mapped results for the current annotation type
    mapped_result = map_terms_reverse(anno_list, anno_type, nlp)
    
    # Update the DataFrame with the mapped results
    for exact_term, (grounded_code, grounded_term) in mapped_result.items(): # tqdm(, desc=f"Mapping terms for {anno_type}", leave=False, position=1):
        # Filter rows in df that match both the exact term and the annotation type
        matched_rows = df[(df['type'] == anno_type) & (df['exact'] == exact_term)]
        
        if not matched_rows.empty:
            # Update 'grounded_code' and 'grounded_term' for all matching rows
            df.loc[matched_rows.index, "grounded_code"] = grounded_code
            df.loc[matched_rows.index, "grounded_term"] = grounded_term
        else:
            # Log if the exact term doesn't find a matching row
            print(f"No match found in DataFrame for term: {exact_term} in type: {anno_type}")


# Replace "GO_" with "GO:" and "CHEBI:" with "CHEBI_" in relevant columns
df["grounded_code"] = df["grounded_code"].str.replace("GO_", "GO:", regex=False)
df["grounded_code"] = df["grounded_code"].str.replace("CHEBI:", "CHEBI_", regex=False)
# Out:
# Processing annotation types: 100%|████████████████████████████████████████████████████████████| 6/6 [01:25<00:00, 14.26s/it]

# %%
# Enhanced match_status logic with case-insensitive matching for 'exact'
df["match_status"] = df.apply(
    lambda row: (
        row["ground"] == row["grounded_code"] or  # Exact match check
        row["exact"].lower() in row["grounded_term"].lower() or  # exact in grounded_term (case-insensitive)
        row["grounded_term"].lower() in row["exact"].lower()     # grounded_term in exact (case-insensitive)
    ),
    axis=1
)

# %%
df
# Out:
#                                       exact    ground  \
# 0                                       SR1    Q9LZW4
# 1                                      HRAS    P01115
# 2                               Spitz Nevus  C0206739
# 3                               Spitz nevus  C0206739
# 5                         Spitzoid melanoma  C3495721
# ...                                     ...       ...
# 264530                    deep fibromatosis  C0079218
# 264531         Desmoplastic fibroma of bone  C0206645
# 264533                       Leiomyosarcoma  C0023269
# 264540        Low-grade fibromyxoid sarcoma  C1275282
# 264541  sclerosing epithelioid fibrosarcoma  C1710026
#
#                                                       uri type grounded_code  \
# 0                  http://purl.uniprot.org/uniprot/Q9LZW4   GP        Q3E796
# 1                  http://purl.uniprot.org/uniprot/P01115   GP        Q60529
# 2       http://linkedlifedata.com/resource/umls-concep...   DS      C0206739
# 3       http://linkedlifedata.com/resource/umls-concep...   DS      C0206739
# 5       http://linkedlifedata.com/resource/umls-concep...   DS      C3495721
# ...                                                   ...  ...           ...
# 264530  http://linkedlifedata.com/resource/umls-concep...   DS      C0079218
# 264531  http://linkedlifedata.com/resource/umls-concep...   DS      C0206645
# 264533  http://linkedlifedata.com/resource/umls-concep...   DS      C0023269
# 264540  http://linkedlifedata.com/resource/umls-concep...   DS      C1275282
# 264541  http://linkedlifedata.com/resource/umls-concep...   DS      C1710026
#
#                                 grounded_term  match_status
# 0                                    smORF121         False
# 1                                        HRAS          True
# 2       spindle and or epithelioid cell nevus          True
# 3       spindle and or epithelioid cell nevus          True
# 5                       malignant spitz tumor          True
# ...                                       ...           ...
# 264530              desmoid type fibromatosis          True
# 264531                  desmoid tumor of bone          True
# 264533              leiomyosarcoma no subtype          True
# 264540          low grade fibromyxoid sarcoma          True
# 264541    sclerosing epithelioid fibrosarcoma          True
#
# [24115 rows x 7 columns]

# %%
# Separate into matched, unmatched, and no match DataFrames
no_match_df = df[(df["grounded_code"] == "No Match") | (df["grounded_term"] == "No Match")]
matched_df = df[df["match_status"] == True]
unmatched_df = df[(df["match_status"] == False) & (df["grounded_code"] != "No Match") & (df["grounded_term"] != "No Match")]

# %%
# Display results
print("No ML grounding DataFrame:")
no_match_df = no_match_df[['exact', 'ground', 'uri', 'type']]

no_match_df
# Out:
# No ML grounding DataFrame:
#             exact       ground                                         uri  \
# 73      Bisulfite  CHEBI_17137  http://purl.obolibrary.org/obo/CHEBI_17137
# 80      bisulfite  CHEBI_17137  http://purl.obolibrary.org/obo/CHEBI_17137
# 95         lipids  CHEBI_18059  http://purl.obolibrary.org/obo/CHEBI_18059
# 128          hood   GO:1990343        http://identifiers.org/go/GO:1990343
# 129           Cy3  CHEBI_37990  http://purl.obolibrary.org/obo/CHEBI_37990
# ...           ...          ...                                         ...
# 261273  cyclin E1       Q91780      http://purl.uniprot.org/uniprot/Q91780
# 262314    procure  CHEBI_81784  http://purl.obolibrary.org/obo/CHEBI_81784
# 262447   Tafinlar  CHEBI_75048  http://purl.obolibrary.org/obo/CHEBI_75048
# 262947     PI3KÎ´       O00329      http://purl.uniprot.org/uniprot/O00329
# 263574    p16INK4       P42771      http://purl.uniprot.org/uniprot/P42771
#
#        type
# 73       CD
# 80       CD
# 95       CD
# 128      GO
# 129      CD
# ...     ...
# 261273   GP
# 262314   CD
# 262447   CD
# 262947   GP
# 263574   GP
#
# [1127 rows x 4 columns]

# %%
print("\nML Grounded:")
matched_df[['exact', 'ground', 'uri', 'type']]
# Out:
# ML Grounded:
#                                       exact    ground  \
# 1                                      HRAS    P01115
# 2                               Spitz Nevus  C0206739
# 3                               Spitz nevus  C0206739
# 5                         Spitzoid melanoma  C3495721
# 8                                      nevi  C0027960
# ...                                     ...       ...
# 264530                    deep fibromatosis  C0079218
# 264531         Desmoplastic fibroma of bone  C0206645
# 264533                       Leiomyosarcoma  C0023269
# 264540        Low-grade fibromyxoid sarcoma  C1275282
# 264541  sclerosing epithelioid fibrosarcoma  C1710026
#
#                                                       uri type
# 1                  http://purl.uniprot.org/uniprot/P01115   GP
# 2       http://linkedlifedata.com/resource/umls-concep...   DS
# 3       http://linkedlifedata.com/resource/umls-concep...   DS
# 5       http://linkedlifedata.com/resource/umls-concep...   DS
# 8       http://linkedlifedata.com/resource/umls-concep...   DS
# ...                                                   ...  ...
# 264530  http://linkedlifedata.com/resource/umls-concep...   DS
# 264531  http://linkedlifedata.com/resource/umls-concep...   DS
# 264533  http://linkedlifedata.com/resource/umls-concep...   DS
# 264540  http://linkedlifedata.com/resource/umls-concep...   DS
# 264541  http://linkedlifedata.com/resource/umls-concep...   DS
#
# [16240 rows x 4 columns]

# %%
print("\nMatch Summary by Type:")

# Calculate statistics of matches by annotation type, ensuring both True and False columns exist
match_summary = df.groupby("type")["match_status"].value_counts().unstack().fillna(0)
match_summary = match_summary.reindex(columns=[False, True], fill_value=0)

# Rename columns for clarity
match_summary.columns = ["mismatch_count", "match_count"]

# Calculate error rate as the percentage of mismatches for each type
match_summary["error_rate"] = (match_summary["mismatch_count"] / 
                               (match_summary["match_count"] + match_summary["mismatch_count"])) * 100

# Display the match summary with error rates
print(match_summary)


match_summary




# CD             1672  2753   37.785311
# DS             1441  4490   24.296071
# EM               47   447    9.514170
# GO              699  1380   33.621934
# GP             3520   239   93.641926
# OG              674  2348   22.303111
# Out:
# Match Summary by Type:
#       mismatch_count  match_count  error_rate
# type
# CD              1373         3518   28.071969
# DS               958         5009   16.054969
# EM                36          473    7.072692
# GO               671         1464   31.428571
# GP              4218         3258   56.420546
# OG               619         2518   19.732228
#       mismatch_count  match_count  error_rate
# type
# CD              1373         3518   28.071969
# DS               958         5009   16.054969
# EM                36          473    7.072692
# GO               671         1464   31.428571
# GP              4218         3258   56.420546
# OG               619         2518   19.732228

# %%
print("\nUnmatched Rows DataFrame:")
unmatched_df
# Out:
# Unmatched Rows DataFrame:
#                           exact    ground  \
# 0                           SR1    Q9LZW4
# 7                      melanoma  C0025202
# 10                         MAPK    O42781
# 41                         mice     10088
# 42                          SR2    Q9XIW0
# ...                         ...       ...
# 263904  cytochrome-B5 reductase    P07514
# 263961               cadherin-5    Q6URK6
# 264143   myofibroblastic tumors  C0334121
# 264323                      Ae1    P04919
# 264324                      Ae3    P16283
#
#                                                       uri type grounded_code  \
# 0                  http://purl.uniprot.org/uniprot/Q9LZW4   GP        Q3E796
# 7       http://linkedlifedata.com/resource/umls-concep...   DS      C1302746
# 10                 http://purl.uniprot.org/uniprot/O42781   GP        P27638
# 41                  http://identifiers.org/taxonomy/10088   OG         10095
# 42                 http://purl.uniprot.org/uniprot/Q9XIW0   GP        Q3E789
# ...                                                   ...  ...           ...
# 263904             http://purl.uniprot.org/uniprot/P07514   GP        P83291
# 263961             http://purl.uniprot.org/uniprot/Q6URK6   GP        O02840
# 264143  http://linkedlifedata.com/resource/umls-concep...   DS      C0027070
# 264323             http://purl.uniprot.org/uniprot/P04919   GP        Q9NJQ2
# 264324             http://purl.uniprot.org/uniprot/P16283   GP        P23348
#
#                  grounded_term  match_status
# 0                     smORF121         False
# 7         melanocytic neoplasm         False
# 10                SPAC31G5.09c         False
# 41                     mus sp.         False
# 42                    smORF118         False
# ...                        ...           ...
# 263904              F28I16.230         False
# 263961                    CDH5         False
# 264143  myoepithelial neoplasm         False
# 264323         Neurotoxin Ae I         False
# 264324                   B3rp3         False
#
# [6749 rows x 7 columns]

# %%
unmatched_df[unmatched_df['type']=='GP']
# Out:
#                           exact  ground  \
# 0                           SR1  Q9LZW4
# 10                         MAPK  O42781
# 42                          SR2  Q9XIW0
# 125                        Ago2  Q8CJG0
# 213        RNA-binding proteins  P28890
# ...                         ...     ...
# 263897               Cadherin 5  Q6URK6
# 263904  cytochrome-B5 reductase  P07514
# 263961               cadherin-5  Q6URK6
# 264323                      Ae1  P04919
# 264324                      Ae3  P16283
#
#                                            uri type grounded_code  \
# 0       http://purl.uniprot.org/uniprot/Q9LZW4   GP        Q3E796
# 10      http://purl.uniprot.org/uniprot/O42781   GP        P27638
# 42      http://purl.uniprot.org/uniprot/Q9XIW0   GP        Q3E789
# 125     http://purl.uniprot.org/uniprot/Q8CJG0   GP        Q9QZ81
# 213     http://purl.uniprot.org/uniprot/P28890   GP        Q3KI09
# ...                                        ...  ...           ...
# 263897  http://purl.uniprot.org/uniprot/Q6URK6   GP        Q925C0
# 263904  http://purl.uniprot.org/uniprot/P07514   GP        P83291
# 263961  http://purl.uniprot.org/uniprot/Q6URK6   GP        O02840
# 264323  http://purl.uniprot.org/uniprot/P04919   GP        Q9NJQ2
# 264324  http://purl.uniprot.org/uniprot/P16283   GP        P23348
#
#           grounded_term  match_status
# 0              smORF121         False
# 10         SPAC31G5.09c         False
# 42             smORF118         False
# 125              GERp95         False
# 213          Pfl01_0854         False
# ...                 ...           ...
# 263897  Synaptotagmin 5         False
# 263904       F28I16.230         False
# 263961             CDH5         False
# 264323  Neurotoxin Ae I         False
# 264324            B3rp3         False
#
# [3725 rows x 7 columns]

# %%
matched_df[matched_df['type']=='DS']
# Out:
#                                       exact    ground  \
# 2                               Spitz Nevus  C0206739
# 3                               Spitz nevus  C0206739
# 5                         Spitzoid melanoma  C3495721
# 8                                      nevi  C0027960
# 11                                melanomas  C0025202
# ...                                     ...       ...
# 264530                    deep fibromatosis  C0079218
# 264531         Desmoplastic fibroma of bone  C0206645
# 264533                       Leiomyosarcoma  C0023269
# 264540        Low-grade fibromyxoid sarcoma  C1275282
# 264541  sclerosing epithelioid fibrosarcoma  C1710026
#
#                                                       uri type grounded_code  \
# 2       http://linkedlifedata.com/resource/umls-concep...   DS      C0206739
# 3       http://linkedlifedata.com/resource/umls-concep...   DS      C0206739
# 5       http://linkedlifedata.com/resource/umls-concep...   DS      C3495721
# 8       http://linkedlifedata.com/resource/umls-concep...   DS      C0027960
# 11      http://linkedlifedata.com/resource/umls-concep...   DS      C0025202
# ...                                                   ...  ...           ...
# 264530  http://linkedlifedata.com/resource/umls-concep...   DS      C0079218
# 264531  http://linkedlifedata.com/resource/umls-concep...   DS      C0206645
# 264533  http://linkedlifedata.com/resource/umls-concep...   DS      C0023269
# 264540  http://linkedlifedata.com/resource/umls-concep...   DS      C1275282
# 264541  http://linkedlifedata.com/resource/umls-concep...   DS      C1710026
#
#                                 grounded_term  match_status
# 2       spindle and or epithelioid cell nevus          True
# 3       spindle and or epithelioid cell nevus          True
# 5                       malignant spitz tumor          True
# 8                                  moles skin          True
# 11                            mnaevocarcinoma          True
# ...                                       ...           ...
# 264530              desmoid type fibromatosis          True
# 264531                  desmoid tumor of bone          True
# 264533              leiomyosarcoma no subtype          True
# 264540          low grade fibromyxoid sarcoma          True
# 264541    sclerosing epithelioid fibrosarcoma          True
#
# [5009 rows x 7 columns]

# %%
unmatched_df[unmatched_df['type']=='EM']
# Out:
#                                          exact       ground  \
# 278              size-exclusion chromatography      MI_0071
# 2940                                 gene-trap  EFO_0004030
# 15615                                pull-down      MI_0096
# 15644      fluorescence activated cell sorting  EFO_0009108
# 17496            cognitive-behavioural therapy  EFO_0007820
# 19414        enzyme-linked immunosorbent assay      MI_0411
# 19754                           gel-filtration      MI_0071
# 24544                          protein-folding      MI_1031
# 27831        Enzyme-Linked Immunosorbent Assay      MI_0411
# 27835                                 Dot-Blot      MI_0049
# 27851                                 Dot-blot      MI_0049
# 29309        Enzyme-linked immunosorbent assay      MI_0411
# 36459                reverse-transcription PCR  OBI_0000552
# 37241                reverse transcription-PCR  OBI_0000552
# 46260                                    X ray      MI_0114
# 69569              ion-exchange chromatography      MI_0226
# 73171                   single-cell sequencing  EFO_0007832
# 77255                            gene knockout  EFO_0000506
# 79702                           gene knockouts  EFO_0000506
# 93908                               pull-downs      MI_0096
# 94936                         light-scattering      MI_0067
# 125931           Size-Exclusion Chromatography      MI_0071
# 133087                                 RNA seq  EFO_0008896
# 136493                            gene knockin  EFO_0004963
# 144544            reverse-phase chromatography      MI_0227
# 147317                               Pull-down      MI_0096
# 160933         density-gradient centrifugation  EFO_0009112
# 165410               Reverse-Transcription PCR  OBI_0000552
# 169705  homogeneous time resolved fluorescence      MI_0509
# 192399                          flow-cytometry      MI_0054
# 194140                                 RNA Seq  EFO_0008896
# 208364     Fluorescence activated cell sorting  EFO_0009108
# 214161                        phenotypes based      MI_1088
# 214383           Size-exclusion chromatography      MI_0071
# 244738                           gene-knockout  EFO_0000506
#
#                                                uri type grounded_code  \
# 278         http://purl.obolibrary.org/obo/MI_0071   EM       MI_2213
# 2940          http://www.ebi.ac.uk/efo/EFO_0004030   EM       MI_2170
# 15615       http://purl.obolibrary.org/obo/MI_0096   EM       MI_0112
# 15644         http://www.ebi.ac.uk/efo/EFO_0009108   EM       MI_0054
# 17496         http://www.ebi.ac.uk/efo/EFO_0007820   EM       MI_2222
# 19414       http://purl.obolibrary.org/obo/MI_0411   EM       MI_2170
# 19754       http://purl.obolibrary.org/obo/MI_0071   EM       MI_0966
# 24544       http://purl.obolibrary.org/obo/MI_1031   EM       MI_2188
# 27831       http://purl.obolibrary.org/obo/MI_0411   EM       MI_2170
# 27835       http://purl.obolibrary.org/obo/MI_0049   EM   EFO_0008833
# 27851       http://purl.obolibrary.org/obo/MI_0049   EM   EFO_0008833
# 29309       http://purl.obolibrary.org/obo/MI_0411   EM       MI_2170
# 36459   http://purl.obolibrary.org/obo/OBI_0000552   EM       MI_2170
# 37241   http://purl.obolibrary.org/obo/OBI_0000552   EM       MI_2170
# 46260       http://purl.obolibrary.org/obo/MI_0114   EM       MI_0826
# 69569       http://purl.obolibrary.org/obo/MI_0226   EM       MI_2188
# 73171         http://www.ebi.ac.uk/efo/EFO_0007832   EM   EFO_0009108
# 77255         http://www.ebi.ac.uk/efo/EFO_0000506   EM       MI_0057
# 79702         http://www.ebi.ac.uk/efo/EFO_0000506   EM       MI_0057
# 93908       http://purl.obolibrary.org/obo/MI_0096   EM       MI_0112
# 94936       http://purl.obolibrary.org/obo/MI_0067   EM       MI_0966
# 125931      http://purl.obolibrary.org/obo/MI_0071   EM       MI_2213
# 133087        http://www.ebi.ac.uk/efo/EFO_0008896   EM   EFO_0003752
# 136493        http://www.ebi.ac.uk/efo/EFO_0004963   EM       MI_0057
# 144544      http://purl.obolibrary.org/obo/MI_0227   EM       MI_2188
# 147317      http://purl.obolibrary.org/obo/MI_0096   EM       MI_0112
# 160933        http://www.ebi.ac.uk/efo/EFO_0009112   EM       MI_2213
# 165410  http://purl.obolibrary.org/obo/OBI_0000552   EM       MI_2170
# 169705      http://purl.obolibrary.org/obo/MI_0509   EM       MI_0510
# 192399      http://purl.obolibrary.org/obo/MI_0054   EM   EFO_0008723
# 194140        http://www.ebi.ac.uk/efo/EFO_0008896   EM   EFO_0003752
# 208364        http://www.ebi.ac.uk/efo/EFO_0009108   EM       MI_0054
# 214161      http://purl.obolibrary.org/obo/MI_1088   EM       MI_0101
# 214383      http://purl.obolibrary.org/obo/MI_0071   EM       MI_2213
# 244738        http://www.ebi.ac.uk/efo/EFO_0000506   EM       MI_2170
#
#                                             grounded_term  match_status
# 278                            superresolution microscopy         False
# 2940                      splitluciferase complementation         False
# 15615                                   ub reconstruction         False
# 15644                  fluorescenceactivated cell sorting         False
# 17496                         socioaffinity index scoring         False
# 19414                     splitluciferase complementation         False
# 19754                                               uv/vi         False
# 24544   photoactivatableribonucleosideenhanced crossli...         False
# 27831                     splitluciferase complementation         False
# 27835                                          nucchipseq         False
# 27851                                          nucchipseq         False
# 29309                     splitluciferase complementation         False
# 36459                     splitluciferase complementation         False
# 37241                     splitluciferase complementation         False
# 46260                                                 sax         False
# 69569   photoactivatableribonucleosideenhanced crossli...         False
# 73171                 fluorescence-activated cell sorting         False
# 77255                                  gene neighbourhood         False
# 79702                                  gene neighbourhood         False
# 93908                                   ub reconstruction         False
# 94936                                               uv/vi         False
# 125931                         superresolution microscopy         False
# 133087                          dnasehypersensitivity seq         False
# 136493                                 gene neighbourhood         False
# 144544  photoactivatableribonucleosideenhanced crossli...         False
# 147317                                  ub reconstruction         False
# 160933                         superresolution microscopy         False
# 165410                    splitluciferase complementation         False
# 169705                                               htrf         False
# 192399                                      dropletcirseq         False
# 194140                          dnasehypersensitivity seq         False
# 208364                 fluorescenceactivated cell sorting         False
# 214161                               predict from sequenc         False
# 214383                         superresolution microscopy         False
# 244738                    splitluciferase complementation         False

# %%
no_match_df[no_match_df['type']=='EM']
# Out:
#         exact   ground                                     uri type
# 4090  GTPases  MI_0419  http://purl.obolibrary.org/obo/MI_0419   EM

# %%
no_match_df[no_match_df['type']=='OG']
# Out:
#                  exact   ground                                      uri type
# 722           T. cruzi     5693     http://identifiers.org/taxonomy/5693   OG
# 17870    O. insidiosus    83647    http://identifiers.org/taxonomy/83647   OG
# 17916   T. euproctidis   373118   http://identifiers.org/taxonomy/373118   OG
# 17977         B. oleae   104688   http://identifiers.org/taxonomy/104688   OG
# 18066      C. sesamiae    89807    http://identifiers.org/taxonomy/89807   OG
# ...                ...      ...                                      ...  ...
# 255250    C. nauseosus    71039    http://identifiers.org/taxonomy/71039   OG
# 260411      E. coli K1  1392869  http://identifiers.org/taxonomy/1392869   OG
# 260854             EPV    10376    http://identifiers.org/taxonomy/10376   OG
# 260857            EPVs    10376    http://identifiers.org/taxonomy/10376   OG
# 260924       C. aurata   290679   http://identifiers.org/taxonomy/290679   OG
#
# [115 rows x 4 columns]

# %%
annotation_type = 'DS'
terms = no_match_df[no_match_df['type']==annotation_type].exact.tolist()
# terms = ['CMD']
# Use the updated function to map the terms
results = map_terms_reverse(terms, annotation_type, nlp)

results
# Out:
# {'sacral pressure sores': ('No Match', 'No Match'),
#  'Sacral pressure sores': ('No Match', 'No Match'),
#  'rare disorder': ('No Match', 'No Match'),
#  'rare disease': ('No Match', 'No Match'),
#  'hydrocystomas': ('No Match', 'No Match'),
#  'opacities': ('No Match', 'No Match'),
#  'rare-disease': ('No Match', 'No Match')}

# %%
annotation_type = 'CD'
terms = no_match_df[no_match_df['type']==annotation_type].exact.tolist()
# terms = ['CMD']
# Use the updated function to map the terms
results = map_terms_reverse(terms, annotation_type, nlp)

results
# Out:
# {'Bisulfite': ('No Match', 'No Match'),
#  'bisulfite': ('No Match', 'No Match'),
#  'lipids': ('No Match', 'No Match'),
#  'Cy3': ('No Match', 'No Match'),
#  'E210': ('No Match', 'No Match'),
#  'Waters': ('No Match', 'No Match'),
#  'formalin': ('No Match', 'No Match'),
#  'tenacity': ('No Match', 'No Match'),
#  'Lipids': ('No Match', 'No Match'),
#  ' pros': ('No Match', 'No Match'),
#  'histones': ('No Match', 'No Match'),
#  '-Da': ('No Match', 'No Match'),
#  'prospers': ('No Match', 'No Match'),
#  'pmsf': ('No Match', 'No Match'),
#  'bromo': ('No Match', 'No Match'),
#  ' pro-': ('No Match', 'No Match'),
#  'temodar': ('No Match', 'No Match'),
#  'gamma': ('No Match', 'No Match'),
#  'Iressa': ('No Match', 'No Match'),
#  'advanced glycation end products': ('No Match', 'No Match'),
#  'radio': ('No Match', 'No Match'),
#  'Gamma': ('No Match', 'No Match'),
#  'Velcade': ('No Match', 'No Match'),
#  'ketone bodies': ('No Match', 'No Match'),
#  'Temodar': ('No Match', 'No Match'),
#  '-Met': ('No Match', 'No Match'),
#  'flash': ('No Match', 'No Match'),
#  'snap': ('No Match', 'No Match'),
#  'Gliadel': ('No Match', 'No Match'),
#  'at 125': ('No Match', 'No Match'),
#  'Glivec': ('No Match', 'No Match'),
#  'Zactima': ('No Match', 'No Match'),
#  'platin': ('No Match', 'No Match'),
#  'Nexavar': ('No Match', 'No Match'),
#  'Sprycel': ('No Match', 'No Match'),
#  'streptozotocin': ('No Match', 'No Match'),
#  'Farnesyl': ('No Match', 'No Match'),
#  'farnesyl': ('No Match', 'No Match'),
#  'reticulin': ('No Match', 'No Match'),
#  'Cyclic Amp': ('No Match', 'No Match'),
#  'Formalin': ('No Match', 'No Match'),
#  'Decadron': ('No Match', 'No Match'),
#  'Radio': ('No Match', 'No Match'),
#  'photons': ('No Match', 'No Match'),
#  'deltad': ('No Match', 'No Match'),
#  'Ferumoxytol': ('No Match', 'No Match'),
#  'ferumoxytol': ('No Match', 'No Match'),
#  'Omniscan': ('No Match', 'No Match'),
#  'Cho': ('No Match', 'No Match'),
#  '-Pro': ('No Match', 'No Match'),
#  'versed': ('No Match', 'No Match'),
#  '-sec': ('No Match', 'No Match'),
#  'thyroid': ('No Match', 'No Match'),
#  'Actigard': ('No Match', 'No Match'),
#  'gemina': ('No Match', 'No Match'),
#  'dodecyl': ('No Match', 'No Match'),
#  'abate': ('No Match', 'No Match'),
#  'Cuban': ('No Match', 'No Match'),
#  'mold': ('No Match', 'No Match'),
#  'Avid': ('No Match', 'No Match'),
#  'Sanmite': ('No Match', 'No Match'),
#  'dara': ('No Match', 'No Match'),
#  'Low Density Lipoprotein': ('No Match', 'No Match'),
#  'low density lipoprotein': ('No Match', 'No Match'),
#  'dextrose': ('No Match', 'No Match'),
#  'plumbum': ('No Match', 'No Match'),
#  'waters': ('No Match', 'No Match'),
#  'malondialdehyde': ('No Match', 'No Match'),
#  'Reticulin': ('No Match', 'No Match'),
#  'Flash': ('No Match', 'No Match'),
#  'bilirubin': ('No Match', 'No Match'),
#  '-His': ('No Match', 'No Match'),
#  'Rubber': ('No Match', 'No Match'),
#  'rubber': ('No Match', 'No Match'),
#  'gaba': ('No Match', 'No Match'),
#  'epoxy': ('No Match', 'No Match'),
#  'Zantac': ('No Match', 'No Match'),
#  'Plasil': ('No Match', 'No Match'),
#  'princeps': ('No Match', 'No Match'),
#  'iressa': ('No Match', 'No Match'),
#  'lime': ('No Match', 'No Match'),
#  'Thiobarbituricacid': ('No Match', 'No Match'),
#  'gelatine': ('No Match', 'No Match'),
#  'Epoxy': ('No Match', 'No Match'),
#  'caprine': ('No Match', 'No Match'),
#  'peek': ('No Match', 'No Match'),
#  'lata': ('No Match', 'No Match'),
#  'low density lipoproteins': ('No Match', 'No Match'),
#  'Thyroid': ('No Match', 'No Match'),
#  ' sec': ('No Match', 'No Match'),
#  'Histoacryl': ('No Match', 'No Match'),
#  'histoacryl': ('No Match', 'No Match'),
#  'dormicum': ('No Match', 'No Match'),
#  'wad': ('No Match', 'No Match'),
#  'Nembutal': ('No Match', 'No Match'),
#  'Streptozotocin': ('No Match', 'No Match'),
#  'Abate': ('No Match', 'No Match'),
#  'olein': ('No Match', 'No Match'),
#  'Plexiglas': ('No Match', 'No Match'),
#  'Chrom': ('No Match', 'No Match'),
#  'chrom': ('No Match', 'No Match'),
#  'mesalazine': ('No Match', 'No Match'),
#  'Nova': ('No Match', 'No Match'),
#  'Dextrose': ('No Match', 'No Match'),
#  'flagyl': ('No Match', 'No Match'),
#  'hemo': ('No Match', 'No Match'),
#  ' Alas': ('No Match', 'No Match'),
#  '1001': ('No Match', 'No Match'),
#  'Tylenol': ('No Match', 'No Match'),
#  'Mage': ('No Match', 'No Match'),
#  'polydioxanone': ('No Match', 'No Match'),
#  'bore': ('No Match', 'No Match'),
#  'oxalo': ('No Match', 'No Match'),
#  'mets': ('No Match', 'No Match'),
#  ' mets': ('No Match', 'No Match'),
#  'Dermatol': ('No Match', 'No Match'),
#  'fades': ('No Match', 'No Match'),
#  'alle': ('No Match', 'No Match'),
#  'epoxies': ('No Match', 'No Match'),
#  'Tamra': ('No Match', 'No Match'),
#  'Atri': ('No Match', 'No Match'),
#  'septra': ('No Match', 'No Match'),
#  'l vs': ('No Match', 'No Match'),
#  '90th': ('No Match', 'No Match'),
#  'niacin': ('No Match', 'No Match'),
#  'singular': ('No Match', 'No Match'),
#  'styrofoam': ('No Match', 'No Match'),
#  'torque': ('No Match', 'No Match'),
#  'Atoms': ('No Match', 'No Match'),
#  'atoms': ('No Match', 'No Match'),
#  'oxazolone': ('No Match', 'No Match'),
#  'cyano': ('No Match', 'No Match'),
#  'Zephyr': ('No Match', 'No Match'),
#  'colcemid': ('No Match', 'No Match'),
#  'Filipina': ('No Match', 'No Match'),
#  'ch': ('No Match', 'No Match'),
#  'Benz': ('No Match', 'No Match'),
#  'Tween-20': ('No Match', 'No Match'),
#  'Sepharose': ('No Match', 'No Match'),
#  'Rh123': ('No Match', 'No Match'),
#  'dien': ('No Match', 'No Match'),
#  'diazo': ('No Match', 'No Match'),
#  'Afrin': ('No Match', 'No Match'),
#  'Saha': ('No Match', 'No Match'),
#  'mangostin': ('No Match', 'No Match'),
#  'Styrofoam': ('No Match', 'No Match'),
#  ' Das': ('No Match', 'No Match'),
#  'Phen': ('No Match', 'No Match'),
#  'Steward': ('No Match', 'No Match'),
#  'succinyl': ('No Match', 'No Match'),
#  'Kern': ('No Match', 'No Match'),
#  'Chrome': ('No Match', 'No Match'),
#  'Zinn': ('No Match', 'No Match'),
#  'Silvers': ('No Match', 'No Match'),
#  'celite': ('No Match', 'No Match'),
#  'Teflon': ('No Match', 'No Match'),
#  'tyrosol': ('No Match', 'No Match'),
#  'psi': ('No Match', 'No Match'),
#  'azido': ('No Match', 'No Match'),
#  'alum': ('No Match', 'No Match'),
#  'Alum': ('No Match', 'No Match'),
#  'dppf': ('No Match', 'No Match'),
#  'Celite': ('No Match', 'No Match'),
#  'phosphino': ('No Match', 'No Match'),
#  'taxanes': ('No Match', 'No Match'),
#  'camptothecins': ('No Match', 'No Match'),
#  'Taxanes': ('No Match', 'No Match'),
#  'Camptothecins': ('No Match', 'No Match'),
#  'an amine': ('No Match', 'No Match'),
#  'Abraxane': ('No Match', 'No Match'),
#  'pimaranes': ('No Match', 'No Match'),
#  'tosylate': ('No Match', 'No Match'),
#  'abates': ('No Match', 'No Match'),
#  'Definity': ('No Match', 'No Match'),
#  'fade': ('No Match', 'No Match'),
#  'Gln- ': ('No Match', 'No Match'),
#  'G418': ('No Match', 'No Match'),
#  'nucleobases': ('No Match', 'No Match'),
#  'Fluor': ('No Match', 'No Match'),
#  '-Cys-': ('No Match', 'No Match'),
#  '-His-': ('No Match', 'No Match'),
#  ' His-': ('No Match', 'No Match'),
#  'myristoyl': ('No Match', 'No Match'),
#  'camp': ('No Match', 'No Match'),
#  'Kerns': ('No Match', 'No Match'),
#  'Camp': ('No Match', 'No Match'),
#  'mad': ('No Match', 'No Match'),
#  '-Asn ': ('No Match', 'No Match'),
#  '-Asn': ('No Match', 'No Match'),
#  'Azido': ('No Match', 'No Match'),
#  'tpdc': ('No Match', 'No Match'),
#  'low density lipoprotein cholesterol': ('No Match', 'No Match'),
#  'aldarate': ('No Match', 'No Match'),
#  'avid': ('No Match', 'No Match'),
#  'fluorouracil': ('No Match', 'No Match'),
#  'Helio': ('No Match', 'No Match'),
#  'Argent': ('No Match', 'No Match'),
#  ' Cho': ('No Match', 'No Match'),
#  'Kaptan': ('No Match', 'No Match'),
#  'argent': ('No Match', 'No Match'),
#  'radios': ('No Match', 'No Match'),
#  'cialis': ('No Match', 'No Match'),
#  'coumadin': ('No Match', 'No Match'),
#  '-ser-': ('No Match', 'No Match'),
#  '1041': ('No Match', 'No Match'),
#  'no2': ('No Match', 'No Match'),
#  'Hoechst 33342': ('No Match', 'No Match'),
#  'Gaba': ('No Match', 'No Match'),
#  'Polydioxanone': ('No Match', 'No Match'),
#  'polyglactin 910': ('No Match', 'No Match'),
#  'Polyglactin 910': ('No Match', 'No Match'),
#  'pros': ('No Match', 'No Match'),
#  '-Trp': ('No Match', 'No Match'),
#  '-Met ': ('No Match', 'No Match'),
#  'Zocor': ('No Match', 'No Match'),
#  'phox': ('No Match', 'No Match'),
#  ' Sec': ('No Match', 'No Match'),
#  'tech': ('No Match', 'No Match'),
#  'Tech': ('No Match', 'No Match'),
#  'Nafion': ('No Match', 'No Match'),
#  'dosulepin': ('No Match', 'No Match'),
#  'aldimines': ('No Match', 'No Match'),
#  'Fmoc': ('No Match', 'No Match'),
#  'Boc group': ('No Match', 'No Match'),
#  'Titan': ('No Match', 'No Match'),
#  '-val': ('No Match', 'No Match'),
#  'C2n2': ('No Match', 'No Match'),
#  '-pro ': ('No Match', 'No Match'),
#  'Base1': ('No Match', 'No Match'),
#  ' secs': ('No Match', 'No Match'),
#  'neopentyl': ('No Match', 'No Match'),
#  'taxol': ('No Match', 'No Match'),
#  'carbons atoms': ('No Match', 'No Match'),
#  'attapulgite': ('No Match', 'No Match'),
#  'perc': ('No Match', 'No Match'),
#  'Eisen': ('No Match', 'No Match'),
#  'dpsi': ('No Match', 'No Match'),
#  'mages': ('No Match', 'No Match'),
#  'Mecl': ('No Match', 'No Match'),
#  'Bilirubin': ('No Match', 'No Match'),
#  ' sss': ('No Match', 'No Match'),
#  'rally': ('No Match', 'No Match'),
#  'formyl': ('No Match', 'No Match'),
#  ' Sec ': ('No Match', 'No Match'),
#  '22:5': ('No Match', 'No Match'),
#  'al13': ('No Match', 'No Match'),
#  'iodo': ('No Match', 'No Match'),
#  '2ab': ('No Match', 'No Match'),
#  '2ag': ('No Match', 'No Match'),
#  'molds': ('No Match', 'No Match'),
#  'Mold': ('No Match', 'No Match'),
#  'Ophiobolin': ('No Match', 'No Match'),
#  'ophiobolins': ('No Match', 'No Match'),
#  'ophiobolin': ('No Match', 'No Match'),
#  'lls': ('No Match', 'No Match'),
#  'Android': ('No Match', 'No Match'),
#  'Hoechst 33258': ('No Match', 'No Match'),
#  'Bis Tris': ('No Match', 'No Match'),
#  'Das': ('No Match', 'No Match'),
#  '11:1': ('No Match', 'No Match'),
#  'tributyltin': ('No Match', 'No Match'),
#  'No2': ('No Match', 'No Match'),
#  'sulfonylurea': ('No Match', 'No Match'),
#  'Baytril': ('No Match', 'No Match'),
#  ' Ala-': ('No Match', 'No Match'),
#  '-Ala': ('No Match', 'No Match'),
#  '-pro': ('No Match', 'No Match'),
#  'monensin': ('No Match', 'No Match'),
#  'Premarin': ('No Match', 'No Match'),
#  'muons': ('No Match', 'No Match'),
#  'Muons': ('No Match', 'No Match'),
#  'Aadd': ('No Match', 'No Match'),
#  'sulfo': ('No Match', 'No Match'),
#  '2,3 diaminopropionate': ('No Match', 'No Match'),
#  ' Orn': ('No Match', 'No Match'),
#  '-Thr-': ('No Match', 'No Match'),
#  '-Ala ': ('No Match', 'No Match'),
#  'chop': ('No Match', 'No Match'),
#  'aqua': ('No Match', 'No Match'),
#  'Amin': ('No Match', 'No Match'),
#  'Lyrica': ('No Match', 'No Match'),
#  'caco3': ('No Match', 'No Match'),
#  'AlexaFluor-488': ('No Match', 'No Match'),
#  'AlexaFluor-594': ('No Match', 'No Match'),
#  'teflon': ('No Match', 'No Match'),
#  'Bodipy': ('No Match', 'No Match'),
#  'las': ('No Match', 'No Match'),
#  'Saran': ('No Match', 'No Match'),
#  'polyols': ('No Match', 'No Match'),
#  'diaminopimelate': ('No Match', 'No Match'),
#  '1042': ('No Match', 'No Match'),
#  'Alkan': ('No Match', 'No Match'),
#  'Tween20': ('No Match', 'No Match'),
#  'Atto565': ('No Match', 'No Match'),
#  'Hemo': ('No Match', 'No Match'),
#  'tren': ('No Match', 'No Match'),
#  'acac': ('No Match', 'No Match'),
#  'Hoechst33342': ('No Match', 'No Match'),
#  'mage': ('No Match', 'No Match'),
#  'android': ('No Match', 'No Match'),
#  'k17': ('No Match', 'No Match'),
#  'BisTris': ('No Match', 'No Match'),
#  'oxoacids': ('No Match', 'No Match'),
#  ' sec ': ('No Match', 'No Match'),
#  'Formyl': ('No Match', 'No Match'),
#  'Leucyl': ('No Match', 'No Match'),
#  'sulthiame': ('No Match', 'No Match'),
#  'sandal': ('No Match', 'No Match'),
#  'Thein': ('No Match', 'No Match'),
#  'prolyl': ('No Match', 'No Match'),
#  'Prolyl': ('No Match', 'No Match'),
#  ' Val-': ('No Match', 'No Match'),
#  'Sulfo': ('No Match', 'No Match'),
#  'retinaldehyde': ('No Match', 'No Match'),
#  'Mekinist': ('No Match', 'No Match'),
#  'Avandia': ('No Match', 'No Match'),
#  'cephazolin': ('No Match', 'No Match'),
#  'Bala': ('No Match', 'No Match'),
#  'marizomib': ('No Match', 'No Match'),
#  'boronates': ('No Match', 'No Match'),
#  'hept': ('No Match', 'No Match'),
#  ' Suc': ('No Match', 'No Match'),
#  'lithium atoms': ('No Match', 'No Match'),
#  'actinides': ('No Match', 'No Match'),
#  'levothyroxine': ('No Match', 'No Match'),
#  'sepharose': ('No Match', 'No Match'),
#  'oxido': ('No Match', 'No Match'),
#  'oxidos': ('No Match', 'No Match'),
#  'silicane': ('No Match', 'No Match'),
#  'Helios': ('No Match', 'No Match'),
#  'Fuchsin': ('No Match', 'No Match'),
#  'potassium atoms': ('No Match', 'No Match'),
#  'deep purple': ('No Match', 'No Match'),
#  'Acqua': ('No Match', 'No Match'),
#  'perks': ('No Match', 'No Match'),
#  'Aqua': ('No Match', 'No Match'),
#  '-Ome': ('No Match', 'No Match'),
#  'oxalyl': ('No Match', 'No Match'),
#  'Perk': ('No Match', 'No Match'),
#  'phosphorus atoms': ('No Match', 'No Match'),
#  'Snap': ('No Match', 'No Match'),
#  'Blazer': ('No Match', 'No Match'),
#  'xenon atom': ('No Match', 'No Match'),
#  'cyclam': ('No Match', 'No Match'),
#  'dicas': ('No Match', 'No Match'),
#  'dithiotreitol': ('No Match', 'No Match'),
#  'E500': ('No Match', 'No Match'),
#  '-du': ('No Match', 'No Match'),
#  'camps': ('No Match', 'No Match'),
#  'BafilomycinA1': ('No Match', 'No Match'),
#  'Psi': ('No Match', 'No Match'),
#  'asymmetric dimethylarginine': ('No Match', 'No Match'),
#  'lead acetate': ('No Match', 'No Match'),
#  'saccharopine': ('No Match', 'No Match'),
#  ' ome': ('No Match', 'No Match'),
#  'Histones': ('No Match', 'No Match'),
#  'ads': ('No Match', 'No Match'),
#  'Opal': ('No Match', 'No Match'),
#  '-Gln': ('No Match', 'No Match'),
#  'hem': ('No Match', 'No Match'),
#  'Harg': ('No Match', 'No Match'),
#  'neoprene': ('No Match', 'No Match'),
#  'acetyls': ('No Match', 'No Match'),
#  'Acetyls': ('No Match', 'No Match'),
#  'Ritalin': ('No Match', 'No Match'),
#  'Provigil': ('No Match', 'No Match'),
#  'R1881': ('No Match', 'No Match'),
#  '_val': ('No Match', 'No Match'),
#  '1241': ('No Match', 'No Match'),
#  'racemic mixtures': ('No Match', 'No Match'),
#  'Florbetapir': ('No Match', 'No Match'),
#  'patrol': ('No Match', 'No Match'),
#  '-clos': ('No Match', 'No Match'),
#  '-Clos': ('No Match', 'No Match'),
#  'quantum dots': ('No Match', 'No Match'),
#  ' sec-': ('No Match', 'No Match'),
#  '12:1': ('No Match', 'No Match'),
#  'deuterio': ('No Match', 'No Match'),
#  'carbinol': ('No Match', 'No Match'),
#  '17:1': ('No Match', 'No Match'),
#  'xylol': ('No Match', 'No Match'),
#  'Ono': ('No Match', 'No Match'),
#  ' Ono': ('No Match', 'No Match'),
#  'C18:2': ('No Match', 'No Match'),
#  'aceto': ('No Match', 'No Match'),
#  'Ethan': ('No Match', 'No Match'),
#  'lipoxins': ('No Match', 'No Match'),
#  'zymosan': ('No Match', 'No Match'),
#  'cromolyn': ('No Match', 'No Match'),
#  'tween-20': ('No Match', 'No Match'),
#  'acylcarnitines': ('No Match', 'No Match'),
#  'Dee': ('No Match', 'No Match'),
#  'exisulind': ('No Match', 'No Match'),
#  '-val ': ('No Match', 'No Match'),
#  '4ap': ('No Match', 'No Match'),
#  '24:1': ('No Match', 'No Match'),
#  '_ss': ('No Match', 'No Match'),
#  'fluor': ('No Match', 'No Match'),
#  'Alexa fluor-488': ('No Match', 'No Match'),
#  'linoleoyl': ('No Match', 'No Match'),
#  'Alexafluor-488': ('No Match', 'No Match'),
#  'Balas': ('No Match', 'No Match'),
#  'procures': ('No Match', 'No Match'),
#  'Zink': ('No Match', 'No Match'),
#  't   a  s': ('No Match', 'No Match'),
#  'ferrienterochelin': ('No Match', 'No Match'),
#  'hemes': ('No Match', 'No Match'),
#  'Dval': ('No Match', 'No Match'),
#  'Ketone bodies': ('No Match', 'No Match'),
#  '-His ': ('No Match', 'No Match'),
#  'His-': ('No Match', 'No Match'),
#  'aap': ('No Match', 'No Match'),
#  'dichromats': ('No Match', 'No Match'),
#  '17:1n7': ('No Match', 'No Match'),
#  'caprate': ('No Match', 'No Match'),
#  '20:2n6': ('No Match', 'No Match'),
#  'C16:1': ('No Match', 'No Match'),
#  'C22:2': ('No Match', 'No Match'),
#  'C20:2': ('No Match', 'No Match'),
#  'C14:1': ('No Match', 'No Match'),
#  'Monensin': ('No Match', 'No Match'),
#  'vitamin K3': ('No Match', 'No Match'),
#  'dl vs': ('No Match', 'No Match'),
#  'very low density lipoprotein': ('No Match', 'No Match'),
#  'E218': ('No Match', 'No Match'),
#  'Kupfer': ('No Match', 'No Match'),
#  '-his': ('No Match', 'No Match'),
#  'canavanine': ('No Match', 'No Match'),
#  'Pro-': ('No Match', 'No Match'),
#  'an aliphatic alcohol': ('No Match', 'No Match'),
#  'decadron': ('No Match', 'No Match'),
#  'Torque': ('No Match', 'No Match'),
#  'alpha particle': ('No Match', 'No Match'),
#  'noble gases': ('No Match', 'No Match'),
#  'Inert gases': ('No Match', 'No Match'),
#  '-no2': ('No Match', 'No Match'),
#  'ureido': ('No Match', 'No Match'),
#  'Ureido': ('No Match', 'No Match'),
#  'Plata': ('No Match', 'No Match'),
#  'Polo': ('No Match', 'No Match'),
#  'creatin': ('No Match', 'No Match'),
#  'base2': ('No Match', 'No Match'),
#  'muurolene': ('No Match', 'No Match'),
#  'pulegone': ('No Match', 'No Match'),
#  'carotatoxin': ('No Match', 'No Match'),
#  'buten': ('No Match', 'No Match'),
#  'Lupron': ('No Match', 'No Match'),
#  'trigonelline': ('No Match', 'No Match'),
#  'chrome': ('No Match', 'No Match'),
#  'Azen': ('No Match', 'No Match'),
#  'Das ': ('No Match', 'No Match'),
#  'sulfonylureas': ('No Match', 'No Match'),
#  'palmitoleoyl': ('No Match', 'No Match'),
#  'procure': ('No Match', 'No Match'),
#  'Tafinlar': ('No Match', 'No Match')}

# %%
annotation_type = 'GO'
terms = no_match_df[no_match_df['type']==annotation_type].exact.tolist()
# terms = ['CMD']
# Use the updated function to map the terms
results = map_terms_reverse(terms, annotation_type, nlp)

results
# Out:
# {'hood': ('No Match', 'No Match'),
#  'S1 Development': ('No Match', 'No Match'),
#  'breakdown': ('No Match', 'No Match'),
#  'deaths': ('No Match', 'No Match'),
#  'efflux pump': ('No Match', 'No Match'),
#  'efflux pumps': ('No Match', 'No Match'),
#  'Upar': ('No Match', 'No Match'),
#  'parasitism': ('No Match', 'No Match'),
#  'Parasitism': ('No Match', 'No Match'),
#  'macropain': ('No Match', 'No Match'),
#  'Hood': ('No Match', 'No Match'),
#  'Discs': ('No Match', 'No Match'),
#  'discs': ('No Match', 'No Match'),
#  'germplasm': ('No Match', 'No Match'),
#  'mutualisms': ('No Match', 'No Match'),
#  'Germplasm': ('No Match', 'No Match'),
#  'taste': ('No Match', 'No Match'),
#  'chorion': ('No Match', 'No Match'),
#  'crown': ('No Match', 'No Match'),
#  'crowns': ('No Match', 'No Match'),
#  'mucous': ('No Match', 'No Match'),
#  'lands': ('No Match', 'No Match'),
#  'smoother': ('No Match', 'No Match'),
#  'short term memory': ('No Match', 'No Match'),
#  'excretions': ('No Match', 'No Match'),
#  'breakdowns': ('No Match', 'No Match'),
#  'oxidative burst': ('No Match', 'No Match'),
#  'hearings': ('No Match', 'No Match'),
#  'visions': ('No Match', 'No Match'),
#  'metabolisms': ('No Match', 'No Match'),
#  'no binding': ('No Match', 'No Match'),
#  'rougher': ('No Match', 'No Match'),
#  'tastes': ('No Match', 'No Match'),
#  'commensalism': ('No Match', 'No Match'),
#  'invadopodium': ('No Match', 'No Match'),
#  'Deaths': ('No Match', 'No Match'),
#  'Efflux Pump': ('No Match', 'No Match'),
#  'Crown': ('No Match', 'No Match'),
#  'gems': ('No Match', 'No Match'),
#  'chemolithotrophy': ('No Match', 'No Match'),
#  'heterotrophy': ('No Match', 'No Match'),
#  'anammox': ('No Match', 'No Match'),
#  'K+ conductance': ('No Match', 'No Match'),
#  'giving birth': ('No Match', 'No Match'),
#  'Breakdown': ('No Match', 'No Match'),
#  'Neto': ('No Match', 'No Match'),
#  'smoothers': ('No Match', 'No Match'),
#  'Lands': ('No Match', 'No Match'),
#  'geotaxis': ('No Match', 'No Match'),
#  'No binding': ('No Match', 'No Match'),
#  'boutons': ('No Match', 'No Match'),
#  'Bouton': ('No Match', 'No Match'),
#  'perineuronal nets': ('No Match', 'No Match'),
#  'mgmt': ('No Match', 'No Match'),
#  'autotrophy': ('No Match', 'No Match'),
#  'fimbria': ('No Match', 'No Match')}

# %%
annotation_type ='CD'
data = loaded_data[annotation_type]
term_dict = data["term_to_id"]
id_to_term = data["id_to_term"]
indexed_terms = data["indexed_terms"]
index = data["index"]

# %%
term_dict
# Out:
# {'(+)-atherospermoline': 'CHEBI_10',
#  '(-)-medicarpin': 'CHEBI_100',
#  'vismione d': 'CHEBI_10000',
#  '(2s,3s,4r)-3-[4-(3-cyclopentylprop-1-ynyl)phenyl]-4-(hydroxymethyl)-1-(2-methoxy-1-oxoethyl)-2-azetidinecarbonitrile': 'CHEBI_100000',
#  'n-[(2r,3s,6r)-2-(hydroxymethyl)-6-[2-[[oxo-[4-(trifluoromethyl)anilino]methyl]amino]ethyl]-3-oxanyl]-3-pyridinecarboxamide': 'CHEBI_100001',
#  '3-chloro-n-[(5s,6s,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzenesulfonamide': 'CHEBI_100002',
#  '(4r,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-14-(1-oxobutylamino)-n-propyl-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-triene-5-carboxamide': 'CHEBI_100003',
#  '1-(2,5-difluorophenyl)-3-[(5s,6s,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-8-[oxo(2-pyrazinyl)methyl]-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]urea': 'CHEBI_100004',
#  'n-[(1s,3s,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-(1-piperidinyl)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-methoxybenzenesulfonamide': 'CHEBI_100005',
#  'n-(1,3-benzodioxol-5-ylmethyl)-2-[(2r,3r,6s)-3-[[(2,5-difluoroanilino)-oxomethyl]amino]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]acetamide': 'CHEBI_100006',
#  'lsm-11386': 'CHEBI_100007',
#  '(2r,3r,4r)-1-[1,3-benzodioxol-5-yl(oxo)methyl]-4-(hydroxymethyl)-3-phenyl-2-azetidinecarbonitrile': 'CHEBI_100008',
#  '(2r,3s,4s)-1-(4-fluorophenyl)sulfonyl-4-(hydroxymethyl)-3-phenyl-2-azetidinecarbonitrile': 'CHEBI_100009',
#  'visnadin': 'CHEBI_10001',
#  'n-[(5s,6s,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(2-phenylethyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]propanamide': 'CHEBI_100010',
#  '2-[(3r,6ar,8r,10ar)-1-[(4-fluorophenyl)-oxomethyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-1-(1-piperidinyl)ethanone': 'CHEBI_100011',
#  'n-[(2r,4ar,12ar)-2-[2-(cyclohexylmethylamino)-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-2-pyrazinecarboxamide': 'CHEBI_100012',
#  '2-[(2s,4ar,12as)-8-(ethylcarbamoylamino)-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(1s)-1-phenylethyl]acetamide': 'CHEBI_100013',
#  'n-[(4s,7r,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3,5-dimethyl-4-isoxazolesulfonamide': 'CHEBI_100014',
#  'n-[(4-chlorophenyl)methyl]-2-[(2s,3r,6r)-2-(hydroxymethyl)-3-[(2-methoxy-1-oxoethyl)amino]-3,6-dihydro-2h-pyran-6-yl]acetamide': 'CHEBI_100015',
#  '2-[(3r,6ar,8s,10ar)-3-hydroxy-1-(pyridin-4-ylmethyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-ethylacetamide': 'CHEBI_100016',
#  '2-[(1r,3s,4ar,9as)-1-(hydroxymethyl)-6-[(1-oxo-2-pyridin-4-ylethyl)amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-pyridinylmethyl)acetamide': 'CHEBI_100017',
#  '(3s)-2-tert-butylsulfinyl-4-[3-(3-fluorophenyl)phenyl]-3-(2-hydroxyethyl)-n-[3-(4-morpholinyl)propyl]-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100018',
#  '1-[(2s,3r,6r)-2-(hydroxymethyl)-6-[2-[4-(methoxymethyl)-1-triazolyl]ethyl]-3-oxanyl]-3-[4-(trifluoromethyl)phenyl]urea': 'CHEBI_100019',
#  'visnagin': 'CHEBI_10002',
#  '2-[(2r,3s,6s)-2-(hydroxymethyl)-3-[[1-oxo-2-(2-pyridinyl)ethyl]amino]-3,6-dihydro-2h-pyran-6-yl]-n-[(1s)-1-phenylethyl]acetamide': 'CHEBI_100020',
#  'n-[(2r,4ar,12as)-2-[2-(3,4-dihydro-1h-isoquinolin-2-yl)-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-3-fluorobenzenesulfonamide': 'CHEBI_100021',
#  'n-[(1s,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-(3-pyridinylmethylamino)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100022',
#  'n-[(5r,6s,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(2-phenylethyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]propanamide': 'CHEBI_100023',
#  '(2s,3s,4r)-2-cyano-3-[4-(2-cyclohexylethynyl)phenyl]-4-(hydroxymethyl)-n-propan-2-yl-1-azetidinecarboxamide': 'CHEBI_100024',
#  'lsm-11404': 'CHEBI_100025',
#  '2-[(1r,3r,4ar,9as)-1-(hydroxymethyl)-6-[[(4-methoxyanilino)-oxomethyl]amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-cyclohexylacetamide': 'CHEBI_100026',
#  '2-[(2r,4as,12as)-8-[[(3,5-dimethylanilino)-oxomethyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid methyl ester': 'CHEBI_100027',
#  'n-[(1r,3s,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[[(1r)-1-phenylethyl]amino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100028',
#  '2-[(3s,6ar,8r,10ar)-3-hydroxy-1-[oxo(3-pyridinyl)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(4-phenylphenyl)acetamide': 'CHEBI_100029',
#  'ribostamycin sulfate': 'CHEBI_10003',
#  '2-methoxy-n-[(4s,7r,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzenesulfonamide': 'CHEBI_100030',
#  '2-[(3s,6as,8s,10as)-1-[cyclopentyl(oxo)methyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n,n-dimethylacetamide': 'CHEBI_100031',
#  '(2s,3r,4r)-3-[4-[2-(3-fluorophenyl)ethynyl]phenyl]-4-(hydroxymethyl)-1-[4-oxanyl(oxo)methyl]-2-azetidinecarbonitrile': 'CHEBI_100032',
#  'n-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[2-(1-piperidinyl)ethylamino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-pyridinecarboxamide': 'CHEBI_100033',
#  '2-[(2s,5r,6r)-5-[(2-fluorophenyl)sulfonylamino]-6-(hydroxymethyl)-2-oxanyl]acetic acid methyl ester': 'CHEBI_100034',
#  'lsm-11414': 'CHEBI_100035',
#  'n-[(5r,6s,9r)-5-methoxy-8-(2-methoxy-1-oxoethyl)-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-2-pyrazinecarboxamide': 'CHEBI_100036',
#  '1-(3-fluorophenyl)-3-[(5s,6r,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]urea': 'CHEBI_100037',
#  'n-[(5r,6s,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-4-phenylbenzamide': 'CHEBI_100038',
#  '2-[(2s,3r,6r)-2-(hydroxymethyl)-3-[[(3-methoxyanilino)-oxomethyl]amino]-3,6-dihydro-2h-pyran-6-yl]-n-(4-phenylphenyl)acetamide': 'CHEBI_100039',
#  'lsm-11419': 'CHEBI_100040',
#  'n-[(2r,3s)-4-[1,3-benzodioxol-5-ylmethyl(methyl)amino]-3-methoxy-2-methylbutyl]-n-[(2r)-1-hydroxypropan-2-yl]benzamide': 'CHEBI_100041',
#  'n-[(5r,6r,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-1-methyl-4-imidazolesulfonamide': 'CHEBI_100042',
#  '2-[(2s,4as,12ar)-8-[[(4-chlorophenyl)-oxomethyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid': 'CHEBI_100043',
#  '2-[(2s,3s,6r)-2-(hydroxymethyl)-3-[[1-oxo-2-(3-pyridinyl)ethyl]amino]-3,6-dihydro-2h-pyran-6-yl]-n-phenylacetamide': 'CHEBI_100044',
#  '2-[(3s,6as,8r,10as)-1-(2-fluorophenyl)sulfonyl-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(2-methoxyethyl)acetamide': 'CHEBI_100045',
#  '2-[(3r,6ar,8r,10ar)-3-hydroxy-1-(1-oxo-2-phenylethyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(2,3-dihydro-1h-inden-2-yl)acetamide': 'CHEBI_100046',
#  '4-fluoro-n-[(2r,3r,6r)-2-(hydroxymethyl)-6-[2-oxo-2-(4-pyrimidinylmethylamino)ethyl]-3-oxanyl]benzamide': 'CHEBI_100047',
#  'lsm-11427': 'CHEBI_100048',
#  'n-[(5s,6s,9s)-8-benzoyl-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-4-oxanecarboxamide': 'CHEBI_100049',
#  '2-[(2s,4as,12ar)-8-[[anilino(oxo)methyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid': 'CHEBI_100050',
#  'lsm-11430': 'CHEBI_100051',
#  'n-[(2r,3s,6r)-2-(hydroxymethyl)-6-[2-(4-morpholinyl)-2-oxoethyl]-3-oxanyl]-2-pyridinecarboxamide': 'CHEBI_100052',
#  'n-[(4r,7r,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-[oxo(2-pyrazinyl)methyl]-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]acetamide': 'CHEBI_100053',
#  '2-[(1s,3s,4ar,9as)-1-(hydroxymethyl)-6-[(3-methoxyphenyl)sulfonylamino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-cyclohexylacetamide': 'CHEBI_100054',
#  '(3r)-2-[(r)-tert-butylsulfinyl]-4-[3-(4-cyanophenyl)phenyl]-3-(2-hydroxyethyl)-n-[2-(1-pyrrolidinyl)ethyl]-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100055',
#  '2-[(2r,4as,12as)-5-methyl-6-oxo-8-[(1-oxo-2-thiophen-2-ylethyl)amino]-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(3s)-1-(phenylmethyl)-3-pyrrolidinyl]acetamide': 'CHEBI_100056',
#  'n-[(4s,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-5-methyl-3-isoxazolecarboxamide': 'CHEBI_100057',
#  'n-[(2s,3r)-4-[[(2r)-1-hydroxypropan-2-yl]-[oxo-[4-(trifluoromethyl)anilino]methyl]amino]-2-methoxy-3-methylbutyl]-n-methylcyclopropanecarboxamide': 'CHEBI_100058',
#  '2-[(3s,6as,8s,10as)-3-hydroxy-1-(2-methylphenyl)sulfonyl-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(2-chlorophenyl)methyl]acetamide': 'CHEBI_100059',
#  '2-[(3r,6ar,8r,10ar)-3-hydroxy-1-(3,3,3-trifluoropropyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(4-phenoxyphenyl)methyl]acetamide': 'CHEBI_100060',
#  'n-[(2s,3r)-4-[(4-chlorophenyl)sulfonyl-[(2r)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-2-fluoro-n-methylbenzamide': 'CHEBI_100061',
#  'lsm-11441': 'CHEBI_100062',
#  'n-[(4s,7r,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(2-thiazolylmethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]butanamide': 'CHEBI_100063',
#  'n-[(2s,3s,6r)-6-[2-[(3,5-difluorophenyl)methylamino]-2-oxoethyl]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-3-yl]-2-pyridinecarboxamide': 'CHEBI_100064',
#  '2-[(1r,3s,4as,9ar)-6-[[anilino(oxo)methyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(phenylmethyl)acetamide': 'CHEBI_100065',
#  'lsm-11445': 'CHEBI_100066',
#  'n-[(4r,7s,8s)-8-methoxy-5-(2-methoxy-1-oxoethyl)-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-5-methyl-3-isoxazolecarboxamide': 'CHEBI_100067',
#  '2-[(3s,6as,8s,10as)-1-(benzenesulfonyl)-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[2-(1-piperidinyl)ethyl]acetamide': 'CHEBI_100068',
#  'lsm-11448': 'CHEBI_100069',
#  '[(3s)-2-[(s)-tert-butylsulfinyl]-3-(2-hydroxyethyl)-4-[3-(2-methoxyphenyl)phenyl]-1,3-dihydropyrrolo[3,4-c]pyridin-6-yl]-(1-piperidinyl)methanone': 'CHEBI_100070',
#  '(2s,3s,4s)-2-cyano-n-(3-fluorophenyl)-4-(hydroxymethyl)-3-phenyl-1-azetidinecarboxamide': 'CHEBI_100071',
#  'n-[(2s,3r,6r)-2-(hydroxymethyl)-6-[2-[[oxo-[4-(trifluoromethyl)anilino]methyl]amino]ethyl]-3-oxanyl]-3-pyridinecarboxamide': 'CHEBI_100072',
#  'lsm-11452': 'CHEBI_100073',
#  'n-[(2s,3r,6s)-6-[2-(4-cyclohexyl-1-triazolyl)ethyl]-2-(hydroxymethyl)-3-oxanyl]-2-(4-morpholinyl)acetamide': 'CHEBI_100074',
#  'n-[(4s,7r,8s)-8-methoxy-4,5,7,10-tetramethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]methanesulfonamide': 'CHEBI_100075',
#  '2-[(1r,3s,4as,9ar)-1-(hydroxymethyl)-6-[(3-methoxyphenyl)sulfonylamino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-phenylethyl)acetamide': 'CHEBI_100076',
#  'lsm-11456': 'CHEBI_100077',
#  'lsm-11457': 'CHEBI_100078',
#  '2-[(2s,4ar,12ar)-8-(ethylsulfonylamino)-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(3s)-1-(phenylmethyl)-3-pyrrolidinyl]acetamide': 'CHEBI_100079',
#  '2-[(1s,3r,4as,9ar)-6-[[1,3-benzodioxol-5-yl(oxo)methyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]acetic acid methyl ester': 'CHEBI_100080',
#  '2-[(2s,3r,6r)-2-(hydroxymethyl)-3-[[oxo-[4-(trifluoromethyl)anilino]methyl]amino]-3,6-dihydro-2h-pyran-6-yl]acetic acid methyl ester': 'CHEBI_100081',
#  '2-[(2r,4as,12ar)-5-methyl-8-[[(4-methylanilino)-oxomethyl]amino]-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-(2,2,2-trifluoroethyl)acetamide': 'CHEBI_100082',
#  'n-[(1r,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-(4-morpholinyl)-2-oxoethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]benzenesulfonamide': 'CHEBI_100083',
#  'n-[(2r,3s)-4-[[(4-fluoroanilino)-oxomethyl]-[(2s)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-n-methyl-4-oxanecarboxamide': 'CHEBI_100084',
#  'lsm-11464': 'CHEBI_100085',
#  'n-[2-[(2s,5s,6s)-5-[[1,3-benzodioxol-5-yl(oxo)methyl]amino]-6-(hydroxymethyl)-2-oxanyl]ethyl]-2-pyrazinecarboxamide': 'CHEBI_100086',
#  '2-[(1r,3r,4as,9ar)-6-[[1,3-benzodioxol-5-yl(oxo)methyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]acetic acid methyl ester': 'CHEBI_100087',
#  'n-[(4r,7s,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(2-thiazolylmethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]butanamide': 'CHEBI_100088',
#  'n-[(2r,4ar,12as)-5-methyl-6-oxo-2-[2-oxo-2-(propylamino)ethyl]-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100089',
#  '2-[(3r,6as,8s,10as)-1-[(2,5-difluorophenyl)methyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(4-chlorophenyl)methyl]acetamide': 'CHEBI_100090',
#  '1-[(5s,6r,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(3,3,3-trifluoropropyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-propylurea': 'CHEBI_100091',
#  '(2r,3s,4r)-2-cyano-3-[4-(2-fluorophenyl)phenyl]-4-(hydroxymethyl)-n-propyl-1-azetidinecarboxamide': 'CHEBI_100092',
#  'lsm-11472': 'CHEBI_100093',
#  'lsm-11473': 'CHEBI_100094',
#  'n-[(2s,3s)-4-[[(4-fluoroanilino)-oxomethyl]-[(2s)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-n-methyl-4-oxanecarboxamide': 'CHEBI_100095',
#  'n-[2-[(2r,5r,6r)-5-[(3-chlorophenyl)sulfonylamino]-6-(hydroxymethyl)-2-oxanyl]ethyl]-3-(1-piperidinyl)propanamide': 'CHEBI_100096',
#  '2-[(3r,6ar,8r,10ar)-1-(4-fluorophenyl)sulfonyl-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(cyclohexylmethyl)acetamide': 'CHEBI_100097',
#  '2-[(3r,6ar,8r,10ar)-3-hydroxy-1-(2-methylphenyl)sulfonyl-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(2-chlorophenyl)methyl]acetamide': 'CHEBI_100098',
#  'n-[2-[(2r,5s,6s)-5-[[1,3-benzodioxol-5-yl(oxo)methyl]amino]-6-(hydroxymethyl)-2-oxanyl]ethyl]-2-pyrazinecarboxamide': 'CHEBI_100099',
#  '(2s,3s,3ar,9br)-1-acetyl-n-[3-(dimethylamino)propyl]-7-(3-fluorophenyl)-3-(hydroxymethyl)-6-oxo-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100100',
#  '2-[(3s,6as,8r,10as)-1-[(2-fluorophenyl)methyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-cyclobutylacetamide': 'CHEBI_100101',
#  '2-[(1r,3s,4ar,9as)-1-(hydroxymethyl)-6-[[4-oxanyl(oxo)methyl]amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]acetic acid methyl ester': 'CHEBI_100102',
#  '2-[(3r,6ar,8s,10ar)-3-hydroxy-1,2,3,4,6,6a,8,9,10,10a-decahydropyrano[2,3-c][1,5]oxazocin-8-yl]-n-(1,3-benzodioxol-5-ylmethyl)acetamide': 'CHEBI_100103',
#  '(3r)-2-[(r)-tert-butylsulfinyl]-4-[3-(3-fluorophenyl)phenyl]-3-(2-hydroxyethyl)-n-(2-methoxyethyl)-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100104',
#  'lsm-11484': 'CHEBI_100105',
#  'n-[(2r,3s,6r)-2-(hydroxymethyl)-6-[2-oxo-2-[(4-phenoxyphenyl)methylamino]ethyl]-3-oxanyl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100106',
#  '1-cyclohexyl-3-[(2r,3r,6r)-2-(hydroxymethyl)-6-[2-(4-morpholinyl)-2-oxoethyl]-3,6-dihydro-2h-pyran-3-yl]urea': 'CHEBI_100107',
#  'n-[(2r,4as,12ar)-5-methyl-2-[2-(4-methyl-1-piperazinyl)-2-oxoethyl]-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]ethanesulfonamide': 'CHEBI_100108',
#  'n-[(2r,4ar,12as)-2-[2-(dimethylamino)-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-4-fluorobenzamide': 'CHEBI_100109',
#  '(2s,3s,3ar,9br)-n-(cyclohexylmethyl)-1-(2-cyclopropyl-1-oxoethyl)-3-(hydroxymethyl)-6-oxo-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100110',
#  'lsm-11490': 'CHEBI_100111',
#  '(2s,3s,4s)-2-cyano-3-[4-(2-cyclohexylethynyl)phenyl]-4-(hydroxymethyl)-n-propan-2-yl-1-azetidinecarboxamide': 'CHEBI_100112',
#  'lsm-11492': 'CHEBI_100113',
#  'lsm-11493': 'CHEBI_100114',
#  'lsm-11494': 'CHEBI_100115',
#  '(3s)-2-[(s)-tert-butylsulfinyl]-4-[3-(4-fluorophenyl)phenyl]-3-(2-hydroxyethyl)-n,n-dimethyl-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100116',
#  '2-[(3s,6ar,8s,10ar)-3-hydroxy-1,2,3,4,6,6a,8,9,10,10a-decahydropyrano[2,3-c][1,5]oxazocin-8-yl]-n-[2-(1-piperidinyl)ethyl]acetamide': 'CHEBI_100117',
#  'lsm-11497': 'CHEBI_100118',
#  'lsm-11498': 'CHEBI_100119',
#  'lsm-11499': 'CHEBI_100120',
#  '1-[(5r,6r,9s)-8-(cyclopropylmethyl)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-(2-fluorophenyl)urea': 'CHEBI_100121',
#  'lsm-11501': 'CHEBI_100122',
#  '(2s,3s,3ar,9br)-3-(hydroxymethyl)-2-[oxo(1-piperidinyl)methyl]-1-(1-oxopropyl)-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizin-6-one': 'CHEBI_100123',
#  '2-[(2r,4as,12as)-5-methyl-6-oxo-8-[[oxo-[(phenylmethyl)amino]methyl]amino]-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n,n-dimethylacetamide': 'CHEBI_100124',
#  '[(3r)-2-[(r)-tert-butylsulfinyl]-3-(2-hydroxyethyl)-4-[3-(2-methoxyphenyl)phenyl]-1,3-dihydropyrrolo[3,4-c]pyridin-6-yl]-(4-morpholinyl)methanone': 'CHEBI_100125',
#  '2-[(1r,3r,4as,9ar)-6-(dimethylamino)-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[(1s)-1-phenylethyl]acetamide': 'CHEBI_100126',
#  '1-(4-chlorophenyl)-3-[(5r,6r,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(1-oxopropyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]urea': 'CHEBI_100127',
#  'n-[(2r,3r,6r)-6-[2-[4-[(dimethylamino)methyl]-1-triazolyl]ethyl]-2-(hydroxymethyl)-3-oxanyl]-2-(3-pyridinyl)acetamide': 'CHEBI_100128',
#  'n-[(2r,3s,6s)-2-(hydroxymethyl)-6-[2-oxo-2-[(4-phenoxyphenyl)methylamino]ethyl]-3-oxanyl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100129',
#  '2-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-6-(methanesulfonamido)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-pyridinylmethyl)acetamide': 'CHEBI_100130',
#  '1-[(2r,3r)-4-[(2,5-difluorophenyl)methyl-methylamino]-3-methoxy-2-methylbutyl]-1-[(2s)-1-hydroxypropan-2-yl]-3-[4-(trifluoromethyl)phenyl]urea': 'CHEBI_100131',
#  '2-fluoro-n-[2-[(2r,5s,6s)-6-(hydroxymethyl)-5-[(4-methylphenyl)sulfonylamino]-2-oxanyl]ethyl]benzamide': 'CHEBI_100132',
#  'lsm-11512': 'CHEBI_100133',
#  'n-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[[(1r)-1-phenylethyl]amino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-pyridinecarboxamide': 'CHEBI_100134',
#  'lsm-11514': 'CHEBI_100135',
#  'n-[(5r,6r,9r)-8-[(4-fluorophenyl)-oxomethyl]-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]propanamide': 'CHEBI_100136',
#  '(2s,3s,3ar,9br)-7-(1-cyclopentenyl)-1-[(2-fluorophenyl)-oxomethyl]-3-(hydroxymethyl)-n,n-dimethyl-6-oxo-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100137',
#  '(3r,6ar,8s,10ar)-8-[2-(3,4-dihydro-1h-isoquinolin-2-yl)-2-oxoethyl]-n-(3,5-dimethyl-4-isoxazolyl)-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocine-1-carboxamide': 'CHEBI_100138',
#  '(2r,3r,3as,9bs)-n2-(cyclopropylmethyl)-3-(hydroxymethyl)-7-(4-methoxyphenyl)-6-oxo-n1-propan-2-yl-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-1,2-dicarboxamide': 'CHEBI_100139',
#  'voacamine': 'CHEBI_10014',
#  'lsm-11519': 'CHEBI_100140',
#  'lsm-11520': 'CHEBI_100141',
#  '(2r,3s,4s)-4-(hydroxymethyl)-3-[4-(2-methoxyphenyl)phenyl]-2-azetidinecarbonitrile': 'CHEBI_100142',
#  '1-[(5s,6r,9s)-8-acetyl-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-(3-fluorophenyl)urea': 'CHEBI_100143',
#  'lsm-11523': 'CHEBI_100144',
#  'n-[(2s,4as,12as)-2-[2-[(4-methoxyphenyl)methylamino]-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-2-methylpropanamide': 'CHEBI_100145',
#  'nalidixic acid': 'CHEBI_100147',
#  '1,1,1-propanetricarboxylic acid': 'CHEBI_100148',
#  '(3s)-2-[(s)-tert-butylsulfinyl]-3-(2-hydroxyethyl)-4-[3-(2-methoxyphenyl)phenyl]-n-(pyridin-4-ylmethyl)-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100149',
#  'vobasine': 'CHEBI_10015',
#  'n-[(5r,6r,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(2-phenylethyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]propanamide': 'CHEBI_100150',
#  'n-[(3,4-dichlorophenyl)methyl]-2-[(2s,5s,6r)-6-(hydroxymethyl)-5-[[(2-methoxyanilino)-oxomethyl]amino]-2-oxanyl]acetamide': 'CHEBI_100151',
#  'n-[(4r,7r,8r)-8-methoxy-5-[(2-methoxyphenyl)methyl]-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]acetamide': 'CHEBI_100152',
#  '4-chloro-n-[(2s,3r)-4-[(2,5-difluorophenyl)methyl-methylamino]-3-methoxy-2-methylbutyl]-n-[(2s)-1-hydroxypropan-2-yl]benzenesulfonamide': 'CHEBI_100153',
#  'n-[(2s,4as,12as)-2-[2-(cyclopentylamino)-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-5-methyl-3-isoxazolecarboxamide': 'CHEBI_100154',
#  '2-[(3s,6as,8r,10as)-1-benzoyl-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[3-(4-morpholinyl)propyl]acetamide': 'CHEBI_100155',
#  'n-[(2r,3r,6r)-2-(hydroxymethyl)-6-[2-[4-(2-methoxyphenyl)-1-triazolyl]ethyl]-3-oxanyl]-2-pyrazinecarboxamide': 'CHEBI_100156',
#  '2-[(3s,6ar,8r,10ar)-1-[(2-fluorophenyl)-oxomethyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-1-(4-methyl-1-piperazinyl)ethanone': 'CHEBI_100157',
#  '1-[(2s,3s)-4-[(2,5-difluorophenyl)methyl-methylamino]-3-methoxy-2-methylbutyl]-3-(4-fluorophenyl)-1-[(2s)-1-hydroxypropan-2-yl]urea': 'CHEBI_100158',
#  'n-[(1s,3r,4as,9ar)-3-[2-[(2,5-difluorophenyl)methylamino]-2-oxoethyl]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100159',
#  'vobtusine': 'CHEBI_10016',
#  '(2s,3s,3ar,9br)-1-(cyclopropylmethyl)-3-(hydroxymethyl)-2-[(4-methyl-1-piperazinyl)-oxomethyl]-7-(5-pyrimidinyl)-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizin-6-one': 'CHEBI_100160',
#  '2-[(2s,4as,12ar)-8-(ethylsulfonylamino)-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-(2-methoxyethyl)acetamide': 'CHEBI_100161',
#  'n-[(4s,7s,8r)-8-methoxy-5-[(2-methoxyphenyl)methyl]-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]acetamide': 'CHEBI_100162',
#  '2-fluoro-n-[(4r,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzamide': 'CHEBI_100163',
#  '(2r,3s,4r)-4-(hydroxymethyl)-1-methylsulfonyl-3-(4-pent-1-ynylphenyl)-2-azetidinecarbonitrile': 'CHEBI_100164',
#  'lsm-11542': 'CHEBI_100165',
#  'n-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-(1-piperidinyl)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-methoxybenzenesulfonamide': 'CHEBI_100166',
#  '(2s,3s,3ar,9br)-7-(1-cyclopentenyl)-3-(hydroxymethyl)-1-methylsulfonyl-6-oxo-n-(2-pyridin-4-ylethyl)-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100167',
#  'n-[(4r,7r,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(2-pyridinylmethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]ethanesulfonamide': 'CHEBI_100168',
#  '[(3s)-2-[(s)-tert-butylsulfinyl]-3-(2-hydroxyethyl)-4-[3-(3-pyridinyl)phenyl]-1,3-dihydropyrrolo[3,4-c]pyridin-6-yl]-(3,4-dihydro-1h-isoquinolin-2-yl)methanone': 'CHEBI_100169',
#  'volemitol': 'CHEBI_10017',
#  '1-(2,5-difluorophenyl)-3-[(2r,3r,6s)-6-[2-(3,4-dihydro-1h-isoquinolin-2-yl)-2-oxoethyl]-2-(hydroxymethyl)-3-oxanyl]urea': 'CHEBI_100170',
#  'n-[(5s,6s,9s)-8-acetyl-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-2-methoxybenzamide': 'CHEBI_100171',
#  '2-[(3s,6ar,8s,10ar)-1-[(3,5-difluorophenyl)methyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(2-thiazolyl)acetamide': 'CHEBI_100172',
#  'lsm-11550': 'CHEBI_100173',
#  'lsm-11551': 'CHEBI_100174',
#  '2-[(1s,3r,4as,9ar)-6-[[(4-fluoroanilino)-oxomethyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n,n-dimethylacetamide': 'CHEBI_100175',
#  '3-(4-fluorophenyl)-1-[(2r)-1-hydroxypropan-2-yl]-1-[(2r,3r)-3-methoxy-2-methyl-4-[methyl-[(1-methyl-4-imidazolyl)sulfonyl]amino]butyl]urea': 'CHEBI_100176',
#  'lsm-11554': 'CHEBI_100177',
#  '(2r,3r,3as,9bs)-3-(hydroxymethyl)-6-oxo-7-pyridin-4-yl-1-(pyridin-4-ylmethyl)-n-(2,2,2-trifluoroethyl)-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100178',
#  'n-[(4s,7s,8r)-8-methoxy-4,7,10-trimethyl-5-[2-(4-morpholinyl)-1-oxoethyl]-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclopropanecarboxamide': 'CHEBI_100179',
#  'volkenin': 'CHEBI_10018',
#  '1-[(4r,7r,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(phenylmethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-propan-2-ylurea': 'CHEBI_100180',
#  'n-[(2s,4ar,12ar)-5-methyl-6-oxo-2-[2-oxo-2-(2-pyridin-4-ylethylamino)ethyl]-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-2-methoxybenzamide': 'CHEBI_100181',
#  'n-[(1s,3s,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[[(1r)-1-phenylethyl]amino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100182',
#  '2-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-6-(methanesulfonamido)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-cyclopentylacetamide': 'CHEBI_100183',
#  'n-[(4r,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-[oxo(3-pyridinyl)methyl]-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclopropanecarboxamide': 'CHEBI_100184',
#  '1-(3-chlorophenyl)-3-[(2s,3r,6r)-2-(hydroxymethyl)-6-[2-[4-(phenylmethyl)-1-triazolyl]ethyl]-3-oxanyl]urea': 'CHEBI_100185',
#  '(3s,6as,8r,10as)-3-hydroxy-8-[2-[2-(1-methyl-4-imidazolyl)ethylamino]-2-oxoethyl]-n-[4-(trifluoromethyl)phenyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocine-1-carboxamide': 'CHEBI_100186',
#  '2-[(3r,6as,8r,10as)-3-hydroxy-1-(1-oxopropyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(3,5-difluorophenyl)methyl]acetamide': 'CHEBI_100187',
#  '2-[(1r,3r,4as,9ar)-6-[(4-fluorophenyl)sulfonylamino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[(2-methoxyphenyl)methyl]acetamide': 'CHEBI_100188',
#  'n-[(1r,3s,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-(2-phenylethylamino)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100189',
#  'vomicine': 'CHEBI_10019',
#  '(3r,6as,8s,10as)-8-[2-(dimethylamino)-2-oxoethyl]-3-hydroxy-n-(3-methoxyphenyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocine-1-carboxamide': 'CHEBI_100190',
#  'n-[(4s,7r,8s)-5-benzoyl-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-2-methoxyacetamide': 'CHEBI_100191',
#  '2-[(2s,3s,6r)-3-[(2-fluorophenyl)sulfonylamino]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]-n-[3-(4-morpholinyl)propyl]acetamide': 'CHEBI_100192',
#  'n-[(1s,3r,4ar,9as)-3-[2-(cyclohexylamino)-2-oxoethyl]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100193',
#  '(3r)-2-[(r)-tert-butylsulfinyl]-4-[3-(3-cyanophenyl)phenyl]-3-(2-hydroxyethyl)-n-[(3-methoxyphenyl)methyl]-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100194',
#  '2-[(3s,6as,8r,10as)-3-hydroxy-1-[oxo(3-pyridinyl)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(4-phenylphenyl)acetamide': 'CHEBI_100195',
#  '2-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-6-(methanesulfonamido)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-cyclopentylacetamide': 'CHEBI_100196',
#  'n-[(5s,6r,9s)-8-(cyclohexylmethyl)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclobutanecarboxamide': 'CHEBI_100197',
#  '2-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-6-[(2-methoxy-1-oxoethyl)amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(3-pyridinylmethyl)acetamide': 'CHEBI_100198',
#  '2-[(3r,6as,8s,10as)-3-hydroxy-1-(2-thiazolylmethyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(2-chlorophenyl)methyl]acetamide': 'CHEBI_100199',
#  '2-[(2s,4as,12ar)-8-[(4-chlorophenyl)sulfonylamino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(1s)-1-phenylethyl]acetamide': 'CHEBI_100200',
#  '3-(1,3-benzodioxol-5-yl)-1-[[(3r,9r,10s)-16-(dimethylamino)-12-[(2r)-1-hydroxypropan-2-yl]-3,10-dimethyl-13-oxo-2,8-dioxa-12-azabicyclo[12.4.0]octadeca-1(14),15,17-trien-9-yl]methyl]-1-methylurea': 'CHEBI_100201',
#  'n-[(4s,7s,8r)-5-benzoyl-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-2-methoxyacetamide': 'CHEBI_100202',
#  'lsm-11580': 'CHEBI_100203',
#  'lsm-11581': 'CHEBI_100204',
#  '2-[(2s,4as,12as)-8-[[(3,5-dimethylanilino)-oxomethyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid methyl ester': 'CHEBI_100205',
#  '2-[(3r,6ar,8s,10ar)-3-hydroxy-1,2,3,4,6,6a,8,9,10,10a-decahydropyrano[2,3-c][1,5]oxazocin-8-yl]-n-(4-phenylphenyl)acetamide': 'CHEBI_100206',
#  '1-cyclohexyl-3-[(4r,7s,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(2-phenylethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]urea': 'CHEBI_100207',
#  '3-methoxy-n-[(4r,7r,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzamide': 'CHEBI_100208',
#  'n-(2,3-dihydro-1h-inden-2-yl)-2-[(2s,3s,6s)-2-(hydroxymethyl)-3-[[oxo-(propan-2-ylamino)methyl]amino]-3,6-dihydro-2h-pyran-6-yl]acetamide': 'CHEBI_100209',
#  'lsm-11587': 'CHEBI_100210',
#  'lsm-11588': 'CHEBI_100211',
#  'lsm-11589': 'CHEBI_100212',
#  '2-[(2r,4as,12ar)-8-[(4-chlorophenyl)sulfonylamino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(1s)-1-phenylethyl]acetamide': 'CHEBI_100213',
#  'lsm-11591': 'CHEBI_100214',
#  'n-[(4r,7r,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-5-propyl-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-2-pyrazinecarboxamide': 'CHEBI_100215',
#  '(3s,6as,8s,10as)-n-(3-chlorophenyl)-3-hydroxy-8-[2-oxo-2-[[(1s)-1-phenylethyl]amino]ethyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocine-1-carboxamide': 'CHEBI_100216',
#  '2-[(3s,6as,8r,10as)-1-[(3-chlorophenyl)methyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(cyclohexylmethyl)acetamide': 'CHEBI_100217',
#  'lsm-11595': 'CHEBI_100218',
#  '(2s,3r,4r)-1-[cyclopentyl(oxo)methyl]-4-(hydroxymethyl)-3-phenyl-2-azetidinecarbonitrile': 'CHEBI_100219',
#  'deoxynivalenol': 'CHEBI_10022',
#  'n-[2-[(2s,5r,6s)-5-[[(2-fluoroanilino)-oxomethyl]amino]-6-(hydroxymethyl)-2-oxanyl]ethyl]cyclohexanecarboxamide': 'CHEBI_100220',
#  '2-[(2s,4ar,12as)-8-[(4-chlorophenyl)sulfonylamino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(1r)-1-phenylethyl]acetamide': 'CHEBI_100221',
#  '2-[(1s,3s,4as,9ar)-1-(hydroxymethyl)-6-[[oxo-[4-(trifluoromethyl)anilino]methyl]amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[(1s)-1-phenylethyl]acetamide': 'CHEBI_100222',
#  '(2s,3s,3ar,9br)-7-(1-cyclohexenyl)-3-(hydroxymethyl)-2-[oxo-[4-(phenylmethyl)-1-piperidinyl]methyl]-1,2,3,3a,4,9b-hexahydropyrrolo[2,3-a]indolizin-6-one': 'CHEBI_100223',
#  'lsm-11601': 'CHEBI_100224',
#  'n-[(2r,3r)-4-[benzenesulfonyl-[(2s)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-n-methyl-1,3-benzodioxole-5-carboxamide': 'CHEBI_100225',
#  '1-[(4s,7r,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-5-[[4-(2-pyridinyl)phenyl]methyl]-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-propylurea': 'CHEBI_100226',
#  '2-[(1r,3s,4as,9ar)-1-(hydroxymethyl)-6-[[(4-methoxyanilino)-oxomethyl]amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-pyridinylmethyl)acetamide': 'CHEBI_100227',
#  '(2r,3s,4s)-1-(5-ethyl-2-thiazolyl)-3-[4-(3-fluorophenyl)phenyl]-4-(hydroxymethyl)-2-azetidinecarbonitrile': 'CHEBI_100228',
#  'n-[(2s,4as,12as)-2-[2-[(3-fluorophenyl)methylamino]-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]butanamide': 'CHEBI_100229',
#  'voriconazole': 'CHEBI_10023',
#  'lsm-11607': 'CHEBI_100230',
#  'lsm-11608': 'CHEBI_100231',
#  '2-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-6-[[oxo-[4-(trifluoromethyl)anilino]methyl]amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[(2-methoxyphenyl)methyl]acetamide': 'CHEBI_100232',
#  '(2r,3s,4s)-3-[4-(1-cyclohexenyl)phenyl]-1-[(3-fluorophenyl)-oxomethyl]-4-(hydroxymethyl)-2-azetidinecarbonitrile': 'CHEBI_100233',
#  '2-[(1r,3r,4ar,9as)-6-(dimethylamino)-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-pyridinylmethyl)acetamide': 'CHEBI_100234',
#  'n-[(1s,3s,4as,9ar)-3-[2-[(2,5-difluorophenyl)methylamino]-2-oxoethyl]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100235',
#  'n-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[(4-phenoxyphenyl)methylamino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100236',
#  '2-fluoro-n-[(5s,6r,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzenesulfonamide': 'CHEBI_100237',
#  'n-[(4s,7s,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(2-thiazolylmethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]butanamide': 'CHEBI_100238',
#  '2-[(2r,4as,12ar)-8-(ethylsulfonylamino)-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(3s)-1-(phenylmethyl)-3-pyrrolidinyl]acetamide': 'CHEBI_100239',
#  'vulgarin': 'CHEBI_10024',
#  '1-(2-chlorophenyl)-3-[(5r,6r,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]urea': 'CHEBI_100240',
#  'ciprofloxacin': 'CHEBI_100241',
#  'n-succinimidyl 5-(3-azidopropylamino)-5-oxopentanoate': 'CHEBI_100242',
#  '1-[(2s,3s,6r)-6-[2-[[(2,5-difluoroanilino)-oxomethyl]amino]ethyl]-2-(hydroxymethyl)-3-oxanyl]-3-(4-methoxyphenyl)urea': 'CHEBI_100243',
#  'n-[(1s,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-[(4-phenoxyphenyl)methylamino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100244',
#  '(3r,6as,8s,10as)-3-hydroxy-8-[2-oxo-2-[[(3s)-1-(phenylmethyl)-3-pyrrolidinyl]amino]ethyl]-n-propyl-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocine-1-carboxamide': 'CHEBI_100245',
#  'norfloxacin': 'CHEBI_100246',
#  '5-(3-azidopropylamino)-5-oxopentanoic acid': 'CHEBI_100247',
#  '2-[(3r,6ar,8s,10ar)-3-hydroxy-1-[oxo(propylamino)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]acetic acid': 'CHEBI_100248',
#  '(2r,3s,4s)-2-cyano-3-[4-(2-fluorophenyl)phenyl]-4-(hydroxymethyl)-n-propyl-1-azetidinecarboxamide': 'CHEBI_100249',
#  'vulgaxanthin-i': 'CHEBI_10025',
#  'lsm-11625': 'CHEBI_100250',
#  'lsm-11626': 'CHEBI_100251',
#  'n-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-(4-morpholinyl)-2-oxoethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-2-methoxyacetamide': 'CHEBI_100252',
#  'n-[(4s,7r,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(3,3,3-trifluoropropyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclopropanecarboxamide': 'CHEBI_100253',
#  '2-[(1s,3s,4as,9ar)-6-(dimethylamino)-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(cyclopropylmethyl)acetamide': 'CHEBI_100254',
#  'n-(cyclohexylmethyl)-2-[(2s,5s,6s)-6-(hydroxymethyl)-5-[(1-methyl-4-imidazolyl)sulfonylamino]-2-oxanyl]acetamide': 'CHEBI_100255',
#  'n-[(1s,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-(2-pyridinylmethylamino)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100256',
#  'lsm-11632': 'CHEBI_100257',
#  'n-[(1r,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-(2-phenylethylamino)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-pyridinecarboxamide': 'CHEBI_100258',
#  '(2s,3r,4s)-2-cyano-3-[4-(2-fluorophenyl)phenyl]-4-(hydroxymethyl)-n-propyl-1-azetidinecarboxamide': 'CHEBI_100259',
#  'vulgaxanthin-ii': 'CHEBI_10026',
#  '1-[(2r,3r)-4-[(4-chlorophenyl)sulfonyl-methylamino]-3-methoxy-2-methylbutyl]-3-(2-fluorophenyl)-1-[(2s)-1-hydroxypropan-2-yl]urea': 'CHEBI_100260',
#  'n-[(1r,3s,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-(3-pyridinylmethylamino)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100261',
#  '1-[(2r,3s,6s)-6-[2-[4-(1-hydroxycyclopentyl)-1-triazolyl]ethyl]-2-(hydroxymethyl)-3-oxanyl]-3-(2-methoxyphenyl)urea': 'CHEBI_100262',
#  '1-[(5s,6s,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(2-pyridinylmethyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-propan-2-ylurea': 'CHEBI_100263',
#  'n-[(5s,6s,9s)-8-(2-cyclopropyl-1-oxoethyl)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-4-fluorobenzamide': 'CHEBI_100264',
#  '2-[(3s,6as,8r,10as)-3-hydroxy-1-methyl-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-cyclobutylacetamide': 'CHEBI_100265',
#  '(5r,6r,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-n-propyl-14-(2,2,2-trifluoroethylsulfonylamino)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-triene-8-carboxamide': 'CHEBI_100266',
#  '(2r,3r,4r)-1-[cyclopropyl(oxo)methyl]-3-[4-[2-(1-hydroxycyclopentyl)ethynyl]phenyl]-4-(hydroxymethyl)-2-azetidinecarbonitrile': 'CHEBI_100267',
#  '1-(3-chlorophenyl)-3-[(2s,3s,6r)-2-(hydroxymethyl)-6-[2-[4-(phenylmethyl)-1-triazolyl]ethyl]-3-oxanyl]urea': 'CHEBI_100268',
#  '2-[(1r,3r,4ar,9as)-6-[[2-(dimethylamino)-1-oxoethyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-cyclohexylacetamide': 'CHEBI_100269',
#  'win i(s)': 'CHEBI_10027',
#  '2-[(3r,6as,8s,10as)-3-hydroxy-1-[(4-methoxyphenyl)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[2-(1-pyrrolidinyl)ethyl]acetamide': 'CHEBI_100270',
#  '(2s,3r,4r)-1-(4-fluorophenyl)sulfonyl-4-(hydroxymethyl)-3-phenyl-2-azetidinecarbonitrile': 'CHEBI_100271',
#  '(2r,3r,3as,9bs)-1-acetyl-n-[3-(dimethylamino)propyl]-7-(3-fluorophenyl)-3-(hydroxymethyl)-6-oxo-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100272',
#  'lsm-11648': 'CHEBI_100273',
#  'n-[(1r,3s,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-(2-phenylethylamino)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-pyridinecarboxamide': 'CHEBI_100274',
#  '1-[(4s,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-[4-(trifluoromethyl)phenyl]urea': 'CHEBI_100275',
#  '2-[(3r,6ar,8r,10ar)-3-hydroxy-1-(4-methylphenyl)sulfonyl-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(1,3-benzodioxol-5-ylmethyl)acetamide': 'CHEBI_100276',
#  '1-(4-chlorophenyl)-3-[(5r,6s,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(1-oxopropyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]urea': 'CHEBI_100277',
#  'n-[(2r,4as,12as)-5-methyl-6-oxo-2-[2-oxo-2-[(4-phenylphenyl)methylamino]ethyl]-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-5-methyl-3-isoxazolecarboxamide': 'CHEBI_100278',
#  'n-[(5s,6r,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-8-[oxo(3-pyridinyl)methyl]-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]butanamide': 'CHEBI_100279',
#  'win vi': 'CHEBI_10028',
#  '1-[(2s,3s,6r)-2-(hydroxymethyl)-6-[2-oxo-2-(1-piperidinyl)ethyl]-3-oxanyl]-3-(3-methoxyphenyl)urea': 'CHEBI_100280',
#  'n-[(2r,3r)-4-[(4-chlorophenyl)sulfonyl-[(2s)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-n-methyl-2-pyrazinecarboxamide': 'CHEBI_100281',
#  '1-[2-[(2r,5s,6s)-6-(hydroxymethyl)-5-[(4-phenoxyphenyl)sulfonylamino]-2-oxanyl]ethyl]-3-propan-2-ylurea': 'CHEBI_100282',
#  'lsm-11658': 'CHEBI_100283',
#  '2-[(2s,3s,6r)-3-[[(1,3-benzodioxol-5-ylamino)-oxomethyl]amino]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]-n-[(1s)-1-phenylethyl]acetamide': 'CHEBI_100284',
#  '4-fluoro-n-[(2r,3s,6r)-2-(hydroxymethyl)-6-[2-[(phenylmethyl)sulfonylamino]ethyl]-3-oxanyl]benzenesulfonamide': 'CHEBI_100285',
#  'n-[(2r,3s,6r)-6-[2-(cyclobutylamino)-2-oxoethyl]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-3-yl]cyclopropanecarboxamide': 'CHEBI_100286',
#  'lsm-11662': 'CHEBI_100287',
#  '(2s,3s,4r)-3-[4-[2-(2-fluorophenyl)ethynyl]phenyl]-4-(hydroxymethyl)-1-[oxo(3-pyridinyl)methyl]-2-azetidinecarbonitrile': 'CHEBI_100288',
#  '(2r,3r,4s)-3-[4-(1-cyclopentenyl)phenyl]-4-(hydroxymethyl)-1-[oxo(2-pyridinyl)methyl]-2-azetidinecarbonitrile': 'CHEBI_100289',
#  'win54954': 'CHEBI_10029',
#  'n-[(1s,3r,4ar,9as)-3-[2-[(4-chlorophenyl)methylamino]-2-oxoethyl]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-2-cyclopropylacetamide': 'CHEBI_100290',
#  '2-[(1s,3r,4ar,9as)-6-[[2-(dimethylamino)-1-oxoethyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[(4-phenylphenyl)methyl]acetamide': 'CHEBI_100291',
#  'n-[(5s,6s,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]butanamide': 'CHEBI_100292',
#  'n-[(1s,3s,4as,9ar)-3-[2-(cyclopropylmethylamino)-2-oxoethyl]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-2-cyclopropylacetamide': 'CHEBI_100293',
#  'n-[(5r,6s,9r)-5-methoxy-3,6,9-trimethyl-8-methylsulfonyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclopentanecarboxamide': 'CHEBI_100294',
#  '(3s,6as,8r,10as)-8-[2-(cyclobutylamino)-2-oxoethyl]-n-(3,4-dichlorophenyl)-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocine-1-carboxamide': 'CHEBI_100295',
#  '2-[(1s,3r,4ar,9as)-6-[[anilino(oxo)methyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(phenylmethyl)acetamide': 'CHEBI_100296',
#  '2-[(3s,6ar,8s,10ar)-1-[1,3-benzodioxol-5-yl(oxo)methyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-cyclopentylacetamide': 'CHEBI_100297',
#  '(2r,3r,3as,9bs)-n1-cyclopentyl-n2-(cyclopropylmethyl)-3-(hydroxymethyl)-6-oxo-7-(5-pyrimidinyl)-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-1,2-dicarboxamide': 'CHEBI_100298',
#  'n-cyclohexyl-2-[(2s,3r,6r)-3-[(4-fluorophenyl)sulfonylamino]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]acetamide': 'CHEBI_100299',
#  '1-[(2s)-1-hydroxypropan-2-yl]-1-[(2s,3r)-3-methoxy-2-methyl-4-[methyl-[(1-methyl-4-imidazolyl)sulfonyl]amino]butyl]-3-[4-(trifluoromethyl)phenyl]urea': 'CHEBI_100300',
#  'n-[(2r,4as,12as)-2-[2-(3,4-dihydro-1h-isoquinolin-2-yl)-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-3-fluorobenzenesulfonamide': 'CHEBI_100301',
#  'n-[(2s,4ar,12as)-2-[2-(1,3-benzodioxol-5-ylmethylamino)-2-oxoethyl]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-2-fluorobenzamide': 'CHEBI_100302',
#  'lsm-11678': 'CHEBI_100303',
#  '3-methoxy-n-[(4s,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(2-phenylethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzamide': 'CHEBI_100304',
#  '2-[(2s,4ar,12as)-8-(methanesulfonamido)-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-cyclohexylacetamide': 'CHEBI_100305',
#  'n-[(2s,3s)-4-[benzenesulfonyl-[(2r)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-n-methyl-1,3-benzodioxole-5-carboxamide': 'CHEBI_100306',
#  'n-[(4s,7s,8s)-5-(cyclopropylmethyl)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-4-oxanecarboxamide': 'CHEBI_100307',
#  'n-[3-(dimethylamino)propyl]-2-[(2r,3r,6r)-3-[[[(3,5-dimethyl-4-isoxazolyl)amino]-oxomethyl]amino]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]acetamide': 'CHEBI_100308',
#  '2-methoxy-n-[(4r,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-[1-oxo-2-(3-pyridinyl)ethyl]-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]acetamide': 'CHEBI_100309',
#  '2-[(1s,3r,4ar,9as)-6-[[(4-fluoroanilino)-oxomethyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n,n-dimethylacetamide': 'CHEBI_100310',
#  '2-[(3s,6as,8s,10as)-3-hydroxy-1-(1-oxopropyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(3,5-difluorophenyl)methyl]acetamide': 'CHEBI_100311',
#  '2-[(2s,4ar,12ar)-8-[(2-chlorophenyl)sulfonylamino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid methyl ester': 'CHEBI_100312',
#  'n-[(2s,3s,6s)-2-(hydroxymethyl)-6-[2-oxo-2-[(4-phenoxyphenyl)methylamino]ethyl]-3,6-dihydro-2h-pyran-3-yl]benzamide': 'CHEBI_100313',
#  'lsm-11689': 'CHEBI_100314',
#  '1-[2-[(2s,5r,6s)-6-(hydroxymethyl)-5-[(4-phenoxyphenyl)sulfonylamino]-2-oxanyl]ethyl]-3-propan-2-ylurea': 'CHEBI_100315',
#  'lsm-11691': 'CHEBI_100316',
#  'n-[(2s,3r,6r)-6-[2-(4-cyclohexyl-1-triazolyl)ethyl]-2-(hydroxymethyl)-3-oxanyl]-2-(4-morpholinyl)acetamide': 'CHEBI_100317',
#  'lsm-11693': 'CHEBI_100318',
#  'n-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-(1-piperidinyl)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-2-(dimethylamino)acetamide': 'CHEBI_100319',
#  'warburganal': 'CHEBI_10032',
#  'lsm-11695': 'CHEBI_100320',
#  'n-[2-[(2s,5s,6r)-6-(hydroxymethyl)-5-[(3-methylphenyl)sulfonylamino]-2-oxanyl]ethyl]-2-pyrazinecarboxamide': 'CHEBI_100321',
#  '2-fluoro-n-[(2r,3r)-4-[[(2r)-1-hydroxypropan-2-yl]-(4-methylphenyl)sulfonylamino]-2-methoxy-3-methylbutyl]-n-methylbenzamide': 'CHEBI_100322',
#  '2-[(2r,4ar,12as)-8-[[(4-chloroanilino)-oxomethyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[2-(1-piperidinyl)ethyl]acetamide': 'CHEBI_100323',
#  '4-chloro-n-[(2s,3r)-4-[(2,5-difluorophenyl)methyl-methylamino]-3-methoxy-2-methylbutyl]-n-[(2r)-1-hydroxypropan-2-yl]benzenesulfonamide': 'CHEBI_100324',
#  '2-[(2r,4ar,12as)-8-[[(3,5-dimethylanilino)-oxomethyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid methyl ester': 'CHEBI_100325',
#  '(2s,3r,4r)-3-[4-[2-(2-fluorophenyl)ethynyl]phenyl]-4-(hydroxymethyl)-2-azetidinecarbonitrile': 'CHEBI_100326',
#  '2-[(1s,3r,4ar,9as)-1-(hydroxymethyl)-6-[(3-methoxyphenyl)sulfonylamino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[(4-chlorophenyl)methyl]acetamide': 'CHEBI_100327',
#  '2-[(3r,6as,8r,10as)-3-hydroxy-1-(4-oxanylmethyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(cyclopropylmethyl)acetamide': 'CHEBI_100328',
#  'n-[(4r,7s,8s)-5-[(2,5-difluorophenyl)methyl]-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-2-methoxyacetamide': 'CHEBI_100329',
#  'warfarin': 'CHEBI_10033',
#  'n-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-[(2-methoxyphenyl)methylamino]-2-oxoethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100330',
#  '2-[(2r,4ar,12ar)-8-[[[(3,5-dimethyl-4-isoxazolyl)amino]-oxomethyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(4-chlorophenyl)methyl]acetamide': 'CHEBI_100331',
#  'n-[(4r,7r,8s)-8-methoxy-4,5,7,10-tetramethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclobutanecarboxamide': 'CHEBI_100332',
#  'n-[(2r,3r)-4-[(4-chlorophenyl)sulfonyl-[(2s)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-n-methyl-1,3-benzodioxole-5-carboxamide': 'CHEBI_100333',
#  'n-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[[(1r)-1-phenylethyl]amino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100334',
#  'n-[(2r,3r,6r)-6-[2-(ethylsulfonylamino)ethyl]-2-(hydroxymethyl)-3-oxanyl]cyclohexanecarboxamide': 'CHEBI_100335',
#  '2-[(1s,3s,4as,9ar)-1-(hydroxymethyl)-6-[[oxo-[4-(trifluoromethyl)anilino]methyl]amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(3-pyridinylmethyl)acetamide': 'CHEBI_100336',
#  'n-[(4r,7s,8r)-8-methoxy-5-[(2-methoxyphenyl)methyl]-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]acetamide': 'CHEBI_100337',
#  '3-fluoro-n-[(4r,7r,8r)-8-methoxy-4,5,7,10-tetramethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzamide': 'CHEBI_100338',
#  'n-[(5s,6r,9r)-8-(4-fluorophenyl)sulfonyl-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-5-methyl-3-isoxazolecarboxamide': 'CHEBI_100339',
#  'warfarin sodium': 'CHEBI_10034',
# ...
#  'n-[2-[(2s,5s,6s)-6-(hydroxymethyl)-5-[(phenylmethyl)sulfonylamino]-2-oxanyl]ethyl]cyclobutanecarboxamide': 'CHEBI_100819',
#  'xylometazoline': 'CHEBI_10082',
#  'lsm-12194': 'CHEBI_100820',
#  'n-[(4s,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(3,3,3-trifluoropropyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclopropanecarboxamide': 'CHEBI_100821',
#  'lsm-12196': 'CHEBI_100822',
#  'n-[(1r,3s,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-(2-phenylethylamino)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]cyclobutanecarboxamide': 'CHEBI_100823',
#  'lsm-12198': 'CHEBI_100824',
#  'lsm-12199': 'CHEBI_100825',
#  'n-[(2s,3s,6s)-2-(hydroxymethyl)-6-[2-oxo-2-(1-piperidinyl)ethyl]-3,6-dihydro-2h-pyran-3-yl]-2-methoxyacetamide': 'CHEBI_100826',
#  '2-[(2s,5r,6s)-6-(hydroxymethyl)-5-[[1-oxo-2-(2-pyridinyl)ethyl]amino]-2-oxanyl]-n-(2-pyridin-4-ylethyl)acetamide': 'CHEBI_100827',
#  'n-[(5r,6s,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]butanamide': 'CHEBI_100828',
#  '(3r)-2-tert-butylsulfinyl-3-(2-hydroxyethyl)-n-(2-methoxyethyl)-4-[3-(3-methoxyphenyl)phenyl]-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100829',
#  'xylopine': 'CHEBI_10083',
#  '3-chloro-n-[(5r,6s,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzenesulfonamide': 'CHEBI_100830',
#  'n-[(2r,3r,6r)-2-(hydroxymethyl)-6-[2-oxo-2-[[(1r)-1-phenylethyl]amino]ethyl]-3-oxanyl]-3-pyridinecarboxamide': 'CHEBI_100831',
#  'n-[(5r,6r,9s)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(3,3,3-trifluoropropyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100832',
#  '2-[(2s,4as,12ar)-5-methyl-8-[(2-methylphenyl)sulfonylamino]-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid': 'CHEBI_100833',
#  'n-[(2s,3s,6s)-6-[2-[4-[(dimethylamino)methyl]-1-triazolyl]ethyl]-2-(hydroxymethyl)-3-oxanyl]-2-(3-pyridinyl)acetamide': 'CHEBI_100834',
#  'n-[(4s,7s,8s)-8-methoxy-4,7,10-trimethyl-5-[4-oxanyl(oxo)methyl]-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]methanesulfonamide': 'CHEBI_100835',
#  '2-[(2s,4as,12ar)-8-[(4-chlorophenyl)sulfonylamino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[(1r)-1-phenylethyl]acetamide': 'CHEBI_100836',
#  'n-[(1r,3r,4as,9ar)-3-[2-[(2,5-difluorophenyl)methylamino]-2-oxoethyl]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100837',
#  '2-[(2r,4as,12as)-5-methyl-6-oxo-8-(2,2,2-trifluoroethylsulfonylamino)-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-(3-fluorophenyl)acetamide': 'CHEBI_100838',
#  '1-[(4s,7s,8s)-5-(cyclopropylmethyl)-8-methoxy-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-(3-methoxyphenyl)urea': 'CHEBI_100839',
#  'xylopinine': 'CHEBI_10084',
#  'lsm-12214': 'CHEBI_100840',
#  'lsm-12215': 'CHEBI_100841',
#  '2-[(1s,3r,4ar,9as)-1-(hydroxymethyl)-6-(methanesulfonamido)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]acetic acid methyl ester': 'CHEBI_100842',
#  'lsm-12217': 'CHEBI_100843',
#  'n-[(2s,3r,6r)-2-(hydroxymethyl)-6-[2-(4-propan-2-yl-1-triazolyl)ethyl]-3-oxanyl]cyclopropanecarboxamide': 'CHEBI_100844',
#  '(2r,3r,3as,9bs)-7-(4-fluorophenyl)-3-(hydroxymethyl)-n,n-dimethyl-6-oxo-1-(1-oxopropyl)-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100845',
#  'lsm-12220': 'CHEBI_100846',
#  '(3r,6ar,8r,10ar)-n-(3,5-dichlorophenyl)-3-hydroxy-8-[2-(4-morpholinyl)-2-oxoethyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocine-1-carboxamide': 'CHEBI_100847',
#  'n-[(3-fluorophenyl)methyl]-2-[(2r,5s,6r)-6-(hydroxymethyl)-5-[(2-methoxyphenyl)sulfonylamino]-2-oxanyl]acetamide': 'CHEBI_100848',
#  'n-[(4-chlorophenyl)methyl]-2-[(2r,3s,6r)-2-(hydroxymethyl)-3-[(2-methoxy-1-oxoethyl)amino]-3,6-dihydro-2h-pyran-6-yl]acetamide': 'CHEBI_100849',
#  '2-[(3r,6ar,8s,10ar)-1-[(2-fluorophenyl)-oxomethyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(3,4-dichlorophenyl)methyl]acetamide': 'CHEBI_100850',
#  'lsm-12225': 'CHEBI_100851',
#  'lsm-12226': 'CHEBI_100852',
#  'lsm-12227': 'CHEBI_100853',
#  'lsm-12228': 'CHEBI_100854',
#  '1-[(4r,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(phenylmethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-propan-2-ylurea': 'CHEBI_100855',
#  '2-[(2r,4as,12ar)-8-[[anilino(oxo)methyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid': 'CHEBI_100856',
#  '2-[(2s,4as,12as)-8-[[anilino(oxo)methyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid': 'CHEBI_100857',
#  '2-[(1s,3s,4as,9ar)-1-(hydroxymethyl)-6-(methanesulfonamido)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-pyridinylmethyl)acetamide': 'CHEBI_100858',
#  'n-[(4s,7s,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-[oxo(3-pyridinyl)methyl]-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclopropanecarboxamide': 'CHEBI_100859',
#  'yamogenin': 'CHEBI_10086',
#  'n-[(2r,4as,12ar)-5-methyl-2-[2-(4-methyl-1-piperazinyl)-2-oxoethyl]-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-8-yl]-4-thiazolecarboxamide': 'CHEBI_100860',
#  'n-[(2r,3r,6r)-2-(hydroxymethyl)-6-[2-oxo-2-[2-(1-piperidinyl)ethylamino]ethyl]-3,6-dihydro-2h-pyran-3-yl]-3-pyridinecarboxamide': 'CHEBI_100861',
#  '(2r,3r,4r)-1-(4,5-dimethyl-2-thiazolyl)-4-(hydroxymethyl)-3-phenyl-2-azetidinecarbonitrile': 'CHEBI_100862',
#  '[(3s)-2-[(s)-tert-butylsulfinyl]-4-[3-(1-cyclopentenyl)phenyl]-3-(2-hydroxyethyl)-1,3-dihydropyrrolo[3,4-c]pyridin-6-yl]-(4-methyl-1-piperazinyl)methanone': 'CHEBI_100863',
#  '2-[(3s,6ar,8s,10ar)-3-hydroxy-1-[(3-pyridin-4-ylphenyl)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(2-methoxyphenyl)methyl]acetamide': 'CHEBI_100864',
#  'n-[(4r,7s,8s)-8-methoxy-5-[(2-methoxyphenyl)methyl]-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]acetamide': 'CHEBI_100865',
#  'n-[(5s,6r,9s)-8-(2-cyclopropyl-1-oxoethyl)-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-4-fluorobenzamide': 'CHEBI_100866',
#  '3-(4-chlorophenyl)-1-[(2r,3s)-4-[(2-chlorophenyl)methyl-[(2r)-1-hydroxypropan-2-yl]amino]-2-methoxy-3-methylbutyl]-1-methylurea': 'CHEBI_100867',
#  'n-[(1s,3s,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-(1-piperidinyl)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100868',
#  'n-[(3,5-difluorophenyl)methyl]-2-[(2s,5s,6r)-6-(hydroxymethyl)-5-[[oxo-[4-(trifluoromethyl)anilino]methyl]amino]-2-oxanyl]acetamide': 'CHEBI_100869',
#  'yamogenin 3-o-neohesperidoside': 'CHEBI_10087',
#  '2-[(2s,5s,6s)-5-[(2-fluorophenyl)sulfonylamino]-6-(hydroxymethyl)-2-oxanyl]acetic acid methyl ester': 'CHEBI_100870',
#  'n-[3-(dimethylamino)propyl]-2-[(2s,5r,6s)-6-(hydroxymethyl)-5-[(4-methylphenyl)sulfonylamino]-2-oxanyl]acetamide': 'CHEBI_100871',
#  '3-(4-fluorophenyl)-1-[(2r)-1-hydroxypropan-2-yl]-1-[(2s,3s)-3-methoxy-2-methyl-4-[methyl-[[4-(2-pyridinyl)phenyl]methyl]amino]butyl]urea': 'CHEBI_100872',
#  '2-[(3r,6as,8s,10as)-3-hydroxy-1-[4-oxanyl(oxo)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-ethylacetamide': 'CHEBI_100873',
#  '1-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-(1-piperidinyl)ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-cyclopentylurea': 'CHEBI_100874',
#  'lsm-12249': 'CHEBI_100875',
#  '2-[(1s,3r,4as,9ar)-1-(hydroxymethyl)-6-[[(4-methoxyanilino)-oxomethyl]amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-pyridinylmethyl)acetamide': 'CHEBI_100876',
#  'lsm-12251': 'CHEBI_100877',
#  'n-[2-[(2s,5s,6s)-6-(hydroxymethyl)-5-[(2-methylphenyl)sulfonylamino]-2-oxanyl]ethyl]-2-methylbenzenesulfonamide': 'CHEBI_100878',
#  '(3r)-n-(1,3-benzodioxol-5-ylmethyl)-2-[(r)-tert-butylsulfinyl]-3-(2-hydroxyethyl)-4-(3-phenylphenyl)-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100879',
#  'yangambin': 'CHEBI_10088',
#  '2-[(1r,3s,4as,9ar)-1-(hydroxymethyl)-6-[(2-methoxy-1-oxoethyl)amino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[(1r)-1-phenylethyl]acetamide': 'CHEBI_100880',
#  'lsm-12255': 'CHEBI_100881',
#  '(2s,3s,4s)-4-(hydroxymethyl)-1-[1-oxo-3-(1-piperidinyl)propyl]-3-phenyl-2-azetidinecarbonitrile': 'CHEBI_100882',
#  'lsm-12257': 'CHEBI_100883',
#  '2-[(2s,5r,6s)-5-(ethylsulfonylamino)-6-(hydroxymethyl)-2-oxanyl]-n-(2-pyridinylmethyl)acetamide': 'CHEBI_100884',
#  'n-[(1r,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-[2-(1-piperidinyl)ethylamino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-1,3-benzodioxole-5-carboxamide': 'CHEBI_100885',
#  '2-[(2s,4ar,12ar)-8-[(3-fluorophenyl)sulfonylamino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-[2-(1-piperidinyl)ethyl]acetamide': 'CHEBI_100886',
#  '2-[(3s,6as,8s,10as)-3-hydroxy-1-[oxo(propylamino)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]acetic acid': 'CHEBI_100887',
#  '2-[(3r,6as,8r,10as)-1-(1,3-benzodioxol-5-ylmethyl)-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(4-phenylphenyl)acetamide': 'CHEBI_100888',
#  'n-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[[(1s)-1-phenylethyl]amino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100889',
#  'yangonin': 'CHEBI_10089',
#  '(2s,3r,4s)-1-(4-fluorophenyl)sulfonyl-4-(hydroxymethyl)-3-phenyl-2-azetidinecarbonitrile': 'CHEBI_100890',
#  'n-[(5r,6r,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-8-[oxo(2-pyridinyl)methyl]-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]cyclopropanecarboxamide': 'CHEBI_100891',
#  '2-[(3s,6as,8r,10as)-3-hydroxy-1-[(4-methoxyphenyl)methyl]-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[2-(1-pyrrolidinyl)ethyl]acetamide': 'CHEBI_100892',
#  'lsm-12267': 'CHEBI_100893',
#  '2-[(1r,3r,4ar,9as)-1-(hydroxymethyl)-6-[(3-methoxyphenyl)sulfonylamino]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(2-phenylethyl)acetamide': 'CHEBI_100894',
#  'lsm-12269': 'CHEBI_100895',
#  '2-[(3r,6as,8s,10as)-1-(cyclohexylmethyl)-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-[(4-fluorophenyl)methyl]acetamide': 'CHEBI_100896',
#  'lsm-12271': 'CHEBI_100897',
#  'lsm-12272': 'CHEBI_100898',
#  '1-[(2s,3s,6s)-6-[2-(benzenesulfonamido)ethyl]-2-(hydroxymethyl)-3-oxanyl]-3-(2-methoxyphenyl)urea': 'CHEBI_100899',
#  '4-chloro-n-[(2r,3s)-4-[(2,5-difluorophenyl)methyl-methylamino]-3-methoxy-2-methylbutyl]-n-[(2r)-1-hydroxypropan-2-yl]benzenesulfonamide': 'CHEBI_100900',
#  '2-[(1r,3s,4ar,9as)-6-[(4-fluorophenyl)sulfonylamino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-[2-(1-piperidinyl)ethyl]acetamide': 'CHEBI_100901',
#  '1-[(2r,3s,6s)-6-[2-(benzenesulfonamido)ethyl]-2-(hydroxymethyl)-3-oxanyl]-3-(2-methoxyphenyl)urea': 'CHEBI_100902',
#  '2-[(3s,6as,8r,10as)-3-hydroxy-1-(4-oxanylmethyl)-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(cyclopropylmethyl)acetamide': 'CHEBI_100903',
#  '3-chloro-n-[(2r,3r)-4-[(4-fluorophenyl)sulfonyl-methylamino]-3-methoxy-2-methylbutyl]-n-[(2r)-1-hydroxypropan-2-yl]benzenesulfonamide': 'CHEBI_100904',
#  '1-[(2r,3s,6r)-6-[2-[4-(1-hydroxycyclopentyl)-1-triazolyl]ethyl]-2-(hydroxymethyl)-3-oxanyl]-3-(2-methoxyphenyl)urea': 'CHEBI_100905',
#  '(2r,3s,4r)-1-[2-(dimethylamino)-1-oxoethyl]-4-(hydroxymethyl)-3-[4-(2-methoxyphenyl)phenyl]-2-azetidinecarbonitrile': 'CHEBI_100906',
#  'n-[(1r,3r,4as,9ar)-1-(hydroxymethyl)-3-[2-oxo-2-[[(1s)-1-phenylethyl]amino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-pyridinecarboxamide': 'CHEBI_100907',
#  '2-[(2s,4ar,12as)-8-(ethylsulfonylamino)-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]-n-(2-methoxyethyl)acetamide': 'CHEBI_100908',
#  'n-[(4r,7r,8r)-8-methoxy-5-(2-methoxy-1-oxoethyl)-4,7,10-trimethyl-11-oxo-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-5-methyl-3-isoxazolecarboxamide': 'CHEBI_100909',
#  'n-[(2s,3r,6r)-6-[2-(cyclopropylmethylamino)-2-oxoethyl]-2-(hydroxymethyl)-3-oxanyl]cyclobutanecarboxamide': 'CHEBI_100910',
#  '(3r)-2-[(r)-tert-butylsulfinyl]-4-[3-(4-cyanophenyl)phenyl]-3-(2-hydroxyethyl)-n-(2-pyridin-4-ylethyl)-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100911',
#  '2-[(2s,3r,6r)-3-[[2-(dimethylamino)-1-oxoethyl]amino]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]-n-[(2-methoxyphenyl)methyl]acetamide': 'CHEBI_100912',
#  '(4s,7r,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-n-propan-2-yl-14-(2,2,2-trifluoroethylsulfonylamino)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-triene-5-carboxamide': 'CHEBI_100913',
#  'n-[(4r,7r,8r)-8-methoxy-4,7,10-trimethyl-11-oxo-5-(5-pyrimidinylmethyl)-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-1,3-benzothiazole-2-carboxamide': 'CHEBI_100914',
#  'lsm-12289': 'CHEBI_100915',
#  'n-[(1r,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-oxo-2-[2-(1-piperidinyl)ethylamino]ethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-pyridinecarboxamide': 'CHEBI_100916',
#  '(2r,3r,3as,9bs)-3-(hydroxymethyl)-1-methylsulfonyl-6-oxo-n-[(1s)-1-phenylethyl]-3,3a,4,9b-tetrahydro-2h-pyrrolo[2,3-a]indolizine-2-carboxamide': 'CHEBI_100917',
#  'n-[(5r,6s,9r)-8-[2-(dimethylamino)-1-oxoethyl]-5-methoxy-3,6,9-trimethyl-2-oxo-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]butanamide': 'CHEBI_100918',
#  '1-[(5r,6r,9r)-5-methoxy-3,6,9-trimethyl-2-oxo-8-(3,3,3-trifluoropropyl)-11-oxa-3,8-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]-3-propylurea': 'CHEBI_100919',
#  'yiamoloside b': 'CHEBI_10092',
#  'lsm-12294': 'CHEBI_100920',
#  'sb 505124': 'CHEBI_100922',
#  '(3r)-2-[(r)-tert-butylsulfinyl]-3-(2-hydroxyethyl)-4-[3-(3-methoxyphenyl)phenyl]-n-(2,2,2-trifluoroethyl)-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100923',
#  'n-[(1r,3r,4ar,9as)-1-(hydroxymethyl)-3-[2-[(2-methoxyphenyl)methylamino]-2-oxoethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-4-oxanecarboxamide': 'CHEBI_100924',
#  '2-[(2r,3s,6s)-3-(benzenesulfonamido)-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]-n-[(3,4-dichlorophenyl)methyl]acetamide': 'CHEBI_100925',
#  '2-[(3s,6ar,8r,10ar)-1-[(3-chlorophenyl)methyl]-3-hydroxy-3,4,6,6a,8,9,10,10a-octahydro-2h-pyrano[2,3-c][1,5]oxazocin-8-yl]-n-(cyclohexylmethyl)acetamide': 'CHEBI_100926',
#  '1-[(1s,3s,4ar,9as)-1-(hydroxymethyl)-3-[2-(4-methyl-1-piperazinyl)-2-oxoethyl]-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-6-yl]-3-(4-methoxyphenyl)urea': 'CHEBI_100927',
#  'lsm-12301': 'CHEBI_100928',
#  '2-[(1s,3s,4ar,9as)-6-[[anilino(oxo)methyl]amino]-1-(hydroxymethyl)-3,4,4a,9a-tetrahydro-1h-pyrano[3,4-b]benzofuran-3-yl]-n-(phenylmethyl)acetamide': 'CHEBI_100929',
#  'yohimbine': 'CHEBI_10093',
#  'lsm-12303': 'CHEBI_100930',
#  'n-[(2r,3s,6s)-6-[2-[(2-chlorophenyl)sulfonylamino]ethyl]-2-(hydroxymethyl)-3-oxanyl]-2-(3-pyridinyl)acetamide': 'CHEBI_100931',
#  'lsm-12305': 'CHEBI_100932',
#  '3-fluoro-n-[(4s,7r,8s)-8-methoxy-4,7,10-trimethyl-11-oxo-5-[1-oxo-2-(3-pyridinyl)ethyl]-2-oxa-5,10-diazabicyclo[10.4.0]hexadeca-1(12),13,15-trien-14-yl]benzenesulfonamide': 'CHEBI_100933',
#  '2-[(2r,3s,6s)-3-[[2-(dimethylamino)-1-oxoethyl]amino]-2-(hydroxymethyl)-3,6-dihydro-2h-pyran-6-yl]-n-[(2-methoxyphenyl)methyl]acetamide': 'CHEBI_100934',
#  'lsm-12308': 'CHEBI_100935',
#  'lsm-12309': 'CHEBI_100936',
#  '2-[(2s,4ar,12ar)-8-[[(2-fluorophenyl)-oxomethyl]amino]-5-methyl-6-oxo-2,3,4,4a,12,12a-hexahydropyrano[2,3-c][1,5]benzoxazocin-2-yl]acetic acid methyl ester': 'CHEBI_100937',
#  'n-[(2s,3r,6r)-2-(hydroxymethyl)-6-[2-oxo-2-[4-(phenylmethyl)-1-piperidinyl]ethyl]-3,6-dihydro-2h-pyran-3-yl]-2-pyrazinecarboxamide': 'CHEBI_100938',
#  '(3r)-n-(1,3-benzodioxol-5-ylmethyl)-2-[(r)-tert-butylsulfinyl]-3-(2-hydroxyethyl)-4-(3-pyridin-4-ylphenyl)-1,3-dihydropyrrolo[3,4-c]pyridine-6-carboxamide': 'CHEBI_100939',
#  'z-arg-arg': 'CHEBI_10094',
#  ...}

# %%
# Filter keys that start with "hand"
keys_starting_with_hand = [key for key in term_dict if key.lower().endswith("atom")]

# Display the result
print(keys_starting_with_hand)
# Out:
# []

# %%
get_embedding_match('lutetium', index, indexed_terms, term_dict, nlp, threshold=0.7)
# Out:
# 'CHEBI_37301'
