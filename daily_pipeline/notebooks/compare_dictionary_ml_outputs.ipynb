# %%
import json
import pandas as pd
from fuzzywuzzy import fuzz
from collections import defaultdict

# File paths
fulltext_dict_path = 'data/TM_pipelines_outputs/patch-28-10-2024-0.api.json'
fulltext_ml_path = '../results/fulltext/europepmc/patch-28-10-2024-0.jsonl.gz.json'


# Function to parse full-text files with filtering and type conversion
def parse_fulltext_file_with_filter(file_path, type_map=None):
    """
    Parse the full-text JSONL file and filter entities by specific types.
    Convert types and text to lowercase for deduplication.
    """
    type_map = type_map or {}  # Mapping for converting types
    valid_types = {"exp_methods", "disease", "gene_protein", "go_term", "chemical", "organism"}
    
    data = defaultdict(lambda: defaultdict(set))
    with open(file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            pmid = obj.get("pmcid", obj.get("ft_id", "Unknown")).lower()  # Normalize pmid/ft_id to lowercase
            for ann in obj.get('anns', []):
                ann_type = ann.get('type', "Unknown").lower()
                # Convert type if present in the type map
                ann_type = type_map.get(ann_type, ann_type)
                if ann_type in valid_types:
                    exact_text = ann['exact'].lower()  # Convert text to lowercase
                    data[pmid][ann_type].add(exact_text)
    return data

# Define the type mapping
type_map = {
    "gene expression": "go_term",
    "methods": "exp_methods"
}

# Parse full-text files with filtering and type conversion
fulltext_ml_data = parse_fulltext_file_with_filter(fulltext_ml_path, type_map=type_map)
fulltext_dict_data = parse_fulltext_file_with_filter(fulltext_dict_path, type_map=type_map)

# Full-text analysis using fuzzy matching for partial matches
results = []
for pmid in set(fulltext_ml_data.keys()).union(fulltext_dict_data.keys()):
    ml_ann_types = fulltext_ml_data.get(pmid, {})
    dict_ann_types = fulltext_dict_data.get(pmid, {})
    
    # Analyze for each annotation type in either file
    all_ann_types = set(ml_ann_types.keys()).union(dict_ann_types.keys())
    for ann_type in all_ann_types:
        ml_exact_texts = ml_ann_types.get(ann_type, set())
        dict_exact_texts = dict_ann_types.get(ann_type, set())
        
        # Calculate differences and overlaps
        ml_not_in_dict = ml_exact_texts - dict_exact_texts
        dict_not_in_ml = dict_exact_texts - ml_exact_texts
        partial_matches = {
            ml_text for ml_text in ml_exact_texts
            if any(fuzz.partial_ratio(ml_text, dict_text) >= 80 for dict_text in dict_exact_texts)
        }
        common_entities = ml_exact_texts & dict_exact_texts
        
        # Append the analysis result
        results.append({
            "pmid_or_ft_id": pmid,
            "ann_type": ann_type,
            "partial_match_count": len(partial_matches),
            "total_ml_count": len(ml_exact_texts),
            "total_dict_count": len(dict_exact_texts),
            "ml_not_in_dict_count": len(ml_not_in_dict),
            "dict_not_in_ml_count": len(dict_not_in_ml),
            # "common_count": len(common_entities),
            "ml_not_in_dict": "; ".join(ml_not_in_dict),  # Convert set to string for CSV
            "dict_not_in_ml": "; ".join(dict_not_in_ml),
            "partial_matches": "; ".join(partial_matches)
        })


# Create DataFrame and save to CSV
df = pd.DataFrame(results)
output_file = "../results/comparison_results_with_fuzzy_matching.csv"
df.to_csv(output_file, index=False)

# %%
len(fulltext_ml_data), len(fulltext_dict_data)
# Out:
# (983, 984)

# %%
df
# Out:
#      pmid_or_ft_id      ann_type  partial_match_count  total_ml_count  \
# 0         11321433      chemical                    8              10
# 1         11321433  gene_protein                    0               2
# 2         11321433       go_term                    2               2
# 3         11321433       disease                   17              24
# 4         11321433   exp_methods                    1               1
# ...            ...           ...                  ...             ...
# 4711      11347145  gene_protein                   75              90
# 4712      11347145       go_term                   20              24
# 4713      11347145       disease                   13              14
# 4714      11347145   exp_methods                   16              17
# 4715      11347145      organism                    9              10
#
#       total_dict_count  ml_not_in_dict_count  dict_not_in_ml_count  \
# 0                    7                     4                     1
# 1                    0                     2                     0
# 2                    3                     1                     2
# 3                   15                    12                     3
# 4                    1                     0                     0
# ...                ...                   ...                   ...
# 4711                62                    38                    10
# 4712                21                     6                     3
# 4713                16                     2                     4
# 4714                16                     7                     6
# 4715                10                     3                     3
#
#                                          ml_not_in_dict  \
# 0           lipoproteins; estrogen; triglyceride; sugar
# 1                                         insulin; mets
# 2                                             synthesis
# 3     hpv infections; insulin resistance; cardiovasc...
# 4
# ...                                                 ...
# 4711  hat; transcriptional activators; polymerase; r...
# 4712  binding; micronuclei; cytoplasmic; reverse tra...
# 4713                with oculomotor apraxia type; blood
# 4714  immunofluorescence; proximity; pla; assays; pr...
# 4715                    virus; lentivirus; e. coli bl21
#
#                                          dict_not_in_ml  \
# 0                                               insulin
# 1
# 2                         behaviour; estrogen synthesis
# 3                advanced cancer; infections; infection
# 4
# ...                                                 ...
# 4711  nucleolin; pol ii; histone acetyltransferase p...
# 4712  sites of double-strand breaks; cellular homeos...
# 4713  multiple cancers; tumorigenesis; oculomotor ap...
# 4714  histone acetylation; recombination; proximity ...
# 4715                             e. coli; comet; e.coli
#
#                                         partial_matches
# 0     cholesterol; triglyceride; triglycerides; lipo...
# 1
# 2                               synthesis; pathogenesis
# 3     hpv infections; hypertension; diabetes; cancer...
# 4                                                biopsy
# ...                                                 ...
# 4711  dna helicase; topoisomerases; rnase a; exo1; s...
# 4712  cytoplasm; replication fork; envelope; membran...
# 4713  myelodysplastic syndrome; ovarian cancer; acut...
# 4714  immunofluorescence; assay; proximity; assays; ...
# 4715  rabbit; human; baculovirus; mouse; e. coli bl2...
#
# [4716 rows x 10 columns]

# %%
# File paths for abstract dictionaries and machine learning outputs
abs_dict_path = 'data/TM_pipelines_outputs/patch-28-10-2024-0_abs.api.json'
abs_ml_path = '../results/abstracts/europepmc/patch-28-10-2024-0.json'

# Function to parse abstract files
def parse_abstract_file_with_filter(file_path, type_map=None):
    """
    Parse the abstract JSONL file and filter entities by specific types.
    Convert types and text to lowercase for deduplication.
    """
    type_map = type_map or {}  # Mapping for converting types
    valid_types = {"exp_methods", "disease", "gene_protein", "go_term", "chemical", "organism"}
    
    data = defaultdict(lambda: defaultdict(set))
    with open(file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            ext_id = obj.get("ext_id", "Unknown")
            for ann in obj.get('anns', []):
                ann_type = ann.get('type', "Unknown").lower()
                # Convert type if present in the type map
                ann_type = type_map.get(ann_type, ann_type)
                if ann_type in valid_types:
                    exact_text = ann['exact'].lower()  # Convert text to lowercase
                    data[ext_id][ann_type].add(exact_text)
    return data

# Define the type mapping
type_map = {
    "gene expression": "go_term",
    "methods": "exp_methods"
}

# Parse abstract files with filtering and type conversion
abs_dict_data = parse_abstract_file_with_filter(abs_dict_path, type_map=type_map)
abs_ml_data = parse_abstract_file_with_filter(abs_ml_path, type_map=type_map)

# Updated analysis
results = []
for ext_id in set(abs_dict_data.keys()).union(abs_ml_data.keys()):
    dict_ann_types = abs_dict_data.get(ext_id, {})
    ml_ann_types = abs_ml_data.get(ext_id, {})
    
    all_ann_types = set(dict_ann_types.keys()).union(ml_ann_types.keys())
    for ann_type in all_ann_types:
        dict_exact_texts = dict_ann_types.get(ann_type, set())
        ml_exact_texts = ml_ann_types.get(ann_type, set())
        
        # Calculate differences and overlaps with fuzzy matching
        dict_not_in_ml = dict_exact_texts - ml_exact_texts
        ml_not_in_dict = ml_exact_texts - dict_exact_texts
        partial_matches = {
            ml_text for ml_text in ml_exact_texts
            if any(fuzz.partial_ratio(ml_text, dict_text) >= 80 for dict_text in dict_exact_texts)
        }
        common_entities = ml_exact_texts & dict_exact_texts
        
        # Append analysis results
        results.append({
            "ext_id": ext_id,
            "ann_type": ann_type,
            "partial_match_count": len(partial_matches),
            "total_ml_count": len(ml_exact_texts),
            "total_dict_count": len(dict_exact_texts),
            "found_in_ml_not_in_dict_count": len(ml_not_in_dict),
            "found_in_dict_not_in_ml_count": len(dict_not_in_ml),
            # "common_count": len(common_entities),
            "ml_not_in_dict": "; ".join(ml_not_in_dict),
            "dict_not_in_ml": "; ".join(dict_not_in_ml),
            "partial_matches": "; ".join(partial_matches)
        })


# Create DataFrame and save to CSV
df = pd.DataFrame(results)
output_file = "../results/abstract_comparison_results_with_fuzzy_matching.csv"
df.to_csv(output_file, index=False)

# %%
df
# Out:
#           ext_id      ann_type  partial_match_count  total_ml_count  \
# 0      PPR930567       disease                    1               3
# 1      PPR930567      organism                    1               1
# 2       38385056       disease                    3               4
# 3       38385056   exp_methods                    0               0
# 4       38385056  gene_protein                    0               0
# ...          ...           ...                  ...             ...
# 45042   39183390      organism                   11              17
# 45043   39457007       disease                    4               4
# 45044   39457007  gene_protein                    0               0
# 45045   39457007      organism                    2               2
# 45046   39457007       go_term                    1               1
#
#        total_dict_count  found_in_ml_not_in_dict_count  \
# 0                     1                              2
# 1                     1                              0
# 2                     4                              1
# 3                     2                              0
# 4                     1                              0
# ...                 ...                            ...
# 45042                 9                              9
# 45043                 5                              0
# 45044                 1                              0
# 45045                 3                              1
# 45046                 2                              0
#
#        found_in_dict_not_in_ml_count  \
# 0                                  0
# 1                                  0
# 2                                  1
# 3                                  2
# 4                                  1
# ...                              ...
# 45042                              1
# 45043                              1
# 45044                              1
# 45045                              2
# 45046                              1
#
#                                           ml_not_in_dict  \
# 0                                adhd; -focused thoughts
# 1
# 2                                                    aml
# 3
# 4
# ...                                                  ...
# 45042  filamentous bacteria; s; bacillus; coccus; scu...
# 45043
# 45044
# 45045                                              virus
# 45046
#
#                                dict_not_in_ml  \
# 0
# 1
# 2                               tumorigenesis
# 3      translocation; chromosomal aberrations
# 4                                         p13
# ...                                       ...
# 45042                   s. baicalensis georgi
# 45043                                  myxoma
# 45044                                     myx
# 45045                    myxoma virus; murine
# 45046                            cell killing
#
#                                          partial_matches
# 0                                             depression
# 1                                                 humans
# 2         acute myeloid leukemia; cancer; acute leukemia
# 3
# 4
# ...                                                  ...
# 45042  s; clostridium; helicobacter; scutellaria baic...
# 45043       glioblastoma; glioma; viral infection; tumor
# 45044
# 45045                                       virus; human
# 45046                               apoptotic cell death
#
# [45047 rows x 10 columns]

# %%
# Function to check for missing JSON lines with no annotations
def check_missing_annotations(ml_file_path, dict_file_path, type_map=None):
    """
    Compare ML and dictionary files to check for missing JSON lines in ML and verify if they have no annotations.
    """
    type_map = type_map or {}  # Mapping for converting types
    ml_ids = set()
    dict_ids_with_annotations = set()

    # Read ML file and collect IDs
    with open(ml_file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            pmid = obj.get("pmcid", obj.get("ft_id", "Unknown")).lower()
            ml_ids.add(pmid)

    # Read dictionary file and collect IDs with annotations
    with open(dict_file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            pmid = obj.get("pmcid", obj.get("ft_id", "Unknown")).lower()
            if any(ann['type'].lower() in type_map or ann['type'].lower() in valid_types for ann in obj.get('anns', [])):
                dict_ids_with_annotations.add(pmid)

    # Find missing IDs in ML
    missing_ids = dict_ids_with_annotations - ml_ids

    return {
        "ml_ids_count": len(ml_ids),
        "dict_ids_with_annotations_count": len(dict_ids_with_annotations),
        "missing_ids_count": len(missing_ids),
        "missing_ids": missing_ids
    }

# Define valid types and type mapping
valid_types = {"exp_methods", "disease", "gene_protein", "go_term", "chemical", "organism"}
type_map = {"gene expression": "go_term", "methods": "exp_methods"}

# Check for abstracts
abstract_check = check_missing_annotations(abs_ml_path, abs_dict_path, type_map)

# Check for full-text
fulltext_check = check_missing_annotations(fulltext_ml_path, fulltext_dict_path, type_map)

# Prepare results for user
missing_analysis = {
    "Abstracts": abstract_check,
    "Full-Text": fulltext_check
}

# %%
def check_missing_annotations(ml_file_path, dict_file_path, id_key, type_map=None):
    """
    Compare ML and dictionary files to check for missing JSON lines in ML and verify if they have annotations.
    """
    type_map = type_map or {}  # Mapping for converting types
    valid_types = {"exp_methods", "disease", "gene_protein", "go_term", "chemical", "organism"}
    ml_ids = set()
    dict_ids_with_annotations = set()

    # Read ML file and collect IDs
    with open(ml_file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            doc_id = obj.get(id_key, "Unknown").lower()
            ml_ids.add(doc_id)

    # Read dictionary file and collect IDs with annotations
    with open(dict_file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            doc_id = obj.get(id_key, "Unknown").lower()
            if any(ann['type'].lower() in type_map or ann['type'].lower() in valid_types for ann in obj.get('anns', [])):
                dict_ids_with_annotations.add(doc_id)

    # Find missing IDs in ML
    missing_ids = dict_ids_with_annotations - ml_ids

    return {
        "ml_ids_count": len(ml_ids),
        "dict_ids_with_annotations_count": len(dict_ids_with_annotations),
        "missing_ids_count": len(missing_ids),
        "missing_ids": missing_ids
    }

# Define type mapping for conversion
type_map = {"gene expression": "go_term", "methods": "exp_methods"}

# # File paths for abstract and full-text data
abs_dict_path = 'data/TM_pipelines_outputs/patch-28-10-2024-0_abs.api.json'
abs_ml_path = '../results/abstracts/europepmc/patch-28-10-2024-0.json'
fulltext_dict_path = 'data/TM_pipelines_outputs/patch-28-10-2024-0.api.json'
fulltext_ml_path = '../results/fulltext/europepmc/patch-28-10-2024-0.jsonl.gz.json'
# Check for missing annotations in abstracts (using ext_id)
abstract_check = check_missing_annotations(abs_ml_path, abs_dict_path, "ext_id", type_map)

# Check for missing annotations in full-text (using pmcid or ft_id)
fulltext_check = check_missing_annotations(fulltext_ml_path, fulltext_dict_path, "pmcid", type_map)

# Prepare summary for user
summary = {
    "Dataset": ["Abstracts", "Full-Text"],
    "ML IDs Count": [abstract_check["ml_ids_count"], fulltext_check["ml_ids_count"]],
    "Dict IDs with Annotations Count": [
        abstract_check["dict_ids_with_annotations_count"],
        fulltext_check["dict_ids_with_annotations_count"],
    ],
    "Missing IDs Count": [abstract_check["missing_ids_count"], fulltext_check["missing_ids_count"]],
}

# Create DataFrame for summary
summary_df = pd.DataFrame(summary)

# # Save detailed missing annotations to CSV
# abstract_missing_file = "abstract_missing_annotations.csv"
# fulltext_missing_file = "fulltext_missing_annotations.csv"
# 
# abstract_missing_df = pd.DataFrame(list(abstract_check["missing_ids"]), columns=["Missing Abstract ext_id"])
# abstract_missing_df.to_csv(abstract_missing_file, index=False)
# 
# fulltext_missing_df = pd.DataFrame(list(fulltext_check["missing_ids"]), columns=["Missing Fulltext pmcid_or_ft_id"])
# fulltext_missing_df.to_csv(fulltext_missing_file, index=False)

# %%
print(summary_df)
# Out:
#      Dataset  ML IDs Count  Dict IDs with Annotations Count  Missing IDs Count
# 0  Abstracts         14777                            15384                912
# 1  Full-Text           974                              975                  4

# %%
missing_ids = set(fulltext_check["missing_ids"])
print(f"Missing IDs: {missing_ids}")
# Out:
# Missing IDs: {'11325299', '11249782', '11328371', '10470160'}

# %%
fulltext_check
# Out:
# {'ml_ids_count': 974,
#  'dict_ids_with_annotations_count': 975,
#  'missing_ids_count': 4,
#  'missing_ids': {'10470160', '11249782', '11325299', '11328371'}}

# %%
# Function for detailed analysis of missing annotations
def deep_analysis_of_annotations(ml_file_path, dict_file_path, id_key, type_map=None):
    """
    Perform a deep analysis of annotations:
    - Missing IDs in ML
    - Missing IDs with annotations
    - Found in Dict but not in ML
    - Found in ML but not in Dict
    """
    type_map = type_map or {}  # Mapping for converting types
    valid_types = {"exp_methods", "disease", "gene_protein", "go_term", "chemical", "organism"}

    ml_ids = {}
    dict_ids_with_annotations = {}

    # Read ML file and collect IDs and annotations
    with open(ml_file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            doc_id = obj.get(id_key, "Unknown").lower()
            annotations = {ann['exact'].lower() for ann in obj.get('anns', [])}
            ml_ids[doc_id] = annotations

    # Read dictionary file and collect IDs with annotations
    with open(dict_file_path, 'r', encoding='latin-1', errors='replace') as file:
        for line in file:
            obj = json.loads(line)
            doc_id = obj.get(id_key, "Unknown").lower()
            annotations = {
                ann['exact'].lower() for ann in obj.get('anns', [])
                if ann['type'].lower() in type_map or ann['type'].lower() in valid_types
            }
            if annotations:
                dict_ids_with_annotations[doc_id] = annotations

    # Missing IDs
    missing_ids = set(dict_ids_with_annotations.keys()) - set(ml_ids.keys())

    # IDs found in both with missing annotations in ML
    missing_annotations_in_ml = {
        doc_id: dict_ids_with_annotations[doc_id]
        for doc_id in dict_ids_with_annotations.keys()
        if doc_id in ml_ids and not ml_ids[doc_id]
    }

    # Found in Dict but not in ML
    found_in_dict_not_in_ml = {
        doc_id: dict_ids_with_annotations[doc_id]
        for doc_id in missing_ids
    }

    # Found in ML but not in Dict
    found_in_ml_not_in_dict = {
        doc_id: ml_ids[doc_id]
        for doc_id in ml_ids.keys()
        if doc_id not in dict_ids_with_annotations
    }

    return {
        "ml_ids_count": len(ml_ids),
        "dict_ids_with_annotations_count": len(dict_ids_with_annotations),
        "missing_ids_count": len(missing_ids),
        "missing_ids_with_annotations": found_in_dict_not_in_ml,
        "missing_annotations_in_ml": missing_annotations_in_ml,
        "found_in_dict_not_in_ml": found_in_dict_not_in_ml,
        "found_in_ml_not_in_dict": found_in_ml_not_in_dict,
    }

# %%
# Define type mapping for conversion
type_map = {"gene expression": "go_term", "methods": "exp_methods"}

# Perform deep analysis for abstracts
abstract_analysis = deep_analysis_of_annotations(abs_ml_path, abs_dict_path, "ext_id", type_map)

# Perform deep analysis for full-text
fulltext_analysis = deep_analysis_of_annotations(fulltext_ml_path, fulltext_dict_path, "pmcid", type_map)

# %%
fulltext_analysis
# Out:
# {'ml_ids_count': 974,
#  'dict_ids_with_annotations_count': 975,
#  'missing_ids_count': 4,
#  'missing_ids_with_annotations': {'11325299': {'uptake'},
#   '11249782': {' sec', 'behavior', 'c2n2', 'delta', 'gamma', 'singular'},
#   '11328371': {'learning'},
#   '10470160': {'behavior', 'learning'}},
#  'missing_annotations_in_ml': {},
#  'found_in_dict_not_in_ml': {'11325299': {'uptake'},
#   '11249782': {' sec', 'behavior', 'c2n2', 'delta', 'gamma', 'singular'},
#   '11328371': {'learning'},
#   '10470160': {'behavior', 'learning'}},
#  'found_in_ml_not_in_dict': {'10531108': {'gag'},
#   '11252919': {'covid-19'},
#   '11361398': {'animal', 'rhoa', 'rock'}}}

# %%
abstract_analysis
# Out:
# {'ml_ids_count': 14777,
#  'dict_ids_with_annotations_count': 15384,
#  'missing_ids_count': 912,
#  'missing_ids_with_annotations': {'39455799': {'mcm'},
#   '39466424': {'acne'},
#   '39459124': {'learning'},
#   '38822920': {'intracranial haemorrhage', 'trauma'},
#   'ppr930376': {'tpn'},
#   'ppr717598': {'learning'},
#   '39459706': {'behavior'},
#   '39463198': {'trauma'},
#   '39462477': {'electron'},
#   '38420485': {'learning'},
#   '39464207': {'learning'},
#   'ppr931380': {'learning'},
#   '39331295': {'mega'},
#   '38657901': {'critically ill'},
#   '39465076': {'aotearoa'},
#   '39465228': {'lam'},
#   '39462275': {'behaviours', 'learning'},
#   '39458770': {'adr', 'composites', 'pbat', 'pla'},
#   'ppr749756': {'singular'},
#   '38414887': {'pgy1', 'pgy2'},
#   '38405299': {'behavior'},
#   'ppr712067': {'inversion'},
#   '38425991': {'behavior'},
#   '39465985': {'electron', 'transport'},
#   'ppr867909': {'behavior', 'insertion'},
#   '39461914': {'learning'},
#   '39178809': {'learning'},
#   '39459418': {'vascularization'},
#   '36171462': {'mnp'},
#   '39464428': {'breakdown'},
#   '39467178': {'arizona', 'phoenix'},
#   '39460177': {'defect', 'defects'},
#   '39466789': {'grey wolf', 'mlp'},
#   '39459754': {'composites'},
#   '37880511': {'behavior'},
#   '38261496': {'learning'},
#   '39415472': {'defect', 'electron'},
#   '39463961': {'gpt'},
#   '39463591': {'alabama', 'coronary artery bypass', 'cpt'},
#   '39466381': {'rsa'},
#   '38936606': {'coi'},
#   'ppr877425': {'defect', 'defects', 'learning', 'mmd'},
#   '39461817': {'domestic violence', 'incest'},
#   'ppr720941': {'behavior'},
#   '39460167': {'learning'},
#   '39358655': {'learning'},
#   '39462223': {'cesarean section', 'giving birth'},
#   'ppr721972': {'smoother'},
#   'ppr922222': {'behavior', 'learning'},
#   '39369969': {' pros'},
#   '39457452': {'rare disorders'},
#   'ppr931451': {'calcification of stylohyoid ligament'},
#   '39466550': {'behaviors'},
#   'ppr899760': {'behavior', 'cfa'},
#   'ppr930528': {'feature extraction'},
#   '38405284': {'behavior'},
#   '39466863': {'defect', 'defects', 'learning'},
#   '39240531': {'behaviour', 'biosensors', 'learning', 'mic'},
#   'ppr931218': {'behaviours'},
#   'ppr729024': {'learning'},
#   '39463326': {'learning'},
#   '39034743': {'learning', 'nucleus'},
#   '39460192': {'learning'},
#   '39393782': {'gestation'},
#   '39464799': {'gpt'},
#   '39461815': {'incest'},
#   '39465299': {'aids', 'learning'},
#   'ppr929902': {'mutualism'},
#   '39464208': {'learning', 'pediatric diseases'},
#   '39341442': {'aids', 'uptake'},
#   'ppr931281': {'recombination'},
#   '39466858': {'learning'},
#   '39460165': {'learning', 'short-term memory'},
#   '38551339': {'learning', 'memory'},
#   'ppr719511': {'wildfire'},
#   '39459749': {'behavior', 'breakdown', 'rec'},
#   '39461485': {'learning'},
#   '39460056': {'tum'},
#   'ppr716326': {'crd', 'kiss', 'learning'},
#   'ppr722352': {'learning', 'wolfram'},
#   '39461287': {'behavior', 'learning'},
#   '39463414': {'learning'},
#   '39462116': {'mil', 'std'},
#   '37451338': {'insertion'},
#   '38384674': {'nlp'},
#   '39366556': {'learning', 'memory', 'perseveration', 'singular'},
#   '39459666': {'asphalt'},
#   '39463317': {' pros'},
#   '39459680': {'heat generation'},
#   '39463794': {'learning'},
#   '38390038': {'delta'},
#   'ppr726410': {'learning'},
#   'ppr931099': {'learning', 'python'},
#   'ppr911253': {'learning'},
#   '39158003': {'learning'},
#   '37658257': {'translation'},
#   'ppr931488': {'behaviour'},
#   '39463757': {'behaviors', 'learning'},
#   'ppr928686': {'behavior', 'behaviors'},
#   '39464776': {'vision'},
#   '39461486': {'learning', 'radio'},
#   '39463640': {'behavior', 'tri'},
#   '39462970': {'traumas'},
#   '39459767': {'behavior'},
#   '39462158': {'turkey'},
#   '39455698': {'behavior'},
#   '39236596': {'learning'},
#   '39466821': {'behavior'},
#   '38725349': {'alabama'},
#   '38414004': {'itc'},
#   '38349877': {'wildfire', 'wildfires'},
#   '39307285': {'learning'},
#   '39384295': {'deaths'},
#   '39466493': {'learning'},
#   '39458758': {'composites', 'smoother'},
#   '37962595': {'haemodynamic instability', 'iss'},
#   '39461813': {'incest', 'sexual violence'},
#   '39455621': {'abalone'},
#   '39463176': {'learning'},
#   '39462906': {'insertion'},
#   '39462130': {'memory'},
#   'ppr894342': {'behavior', 'disinhibition'},
#   '39465285': {'siren', 'sirens'},
#   '39455751': {'behavior'},
#   'ppr733186': {'learning'},
#   '39458075': {'radical'},
#   '39458531': {'turkey'},
#   '39460228': {'feature extraction', 'learning'},
#   '38862308': {'rr 2'},
#   '39165698': {'translation'},
#   '39459741': {'behavior', 'pore', 'pores'},
#   '39457267': {'athletes'},
#   '39459547': {'feature extraction', 'learning'},
#   '38266253': {'translation'},
#   'ppr836846': {'learning'},
#   '39463882': {'behaviour'},
#   '39459080': {'heat generation'},
#   '39270511': {'learning'},
#   '38378442': {'learning'},
#   '39451711': {'biosensors'},
#   '39459088': {'radio'},
#   '39465789': {'postoperative complications'},
#   '38358129': {'lead compounds'},
#   '39278184': {'learning'},
#   '39462760': {'emotionality'},
#   'ppr712526': {'ams'},
#   '39460156': {'feature extraction', 'learning'},
#   '39462734': {'transport', 'trauma'},
#   'ppr820409': {'social behavior'},
#   '39460095': {'transport'},
#   '39459644': {'aseptic loosening', 'kss', 'osteolysis'},
#   '39459786': {'limestone'},
#   '38752727': {'alt',
#    'cerebrospinal fluid leakage',
#    'defect',
#    'defects',
#    'lata',
#    'mater',
#    'skin graft necrosis'},
#   '38821001': {'drs'},
#   '39459719': {'behavior', 'ion transport', 'transport'},
#   '38425865': {'defects'},
#   '38405292': {'behavior'},
#   '39464241': {'polymerization'},
#   '38487195': {'python', 'translation'},
#   '39466611': {'crown',
#    'endodontically treated teeth',
#    'endodontically treated tooth'},
#   '38420630': {'behaviour'},
#   '39459663': {'behavior', 'rubber'},
#   '39459092': {'learning'},
#   '39458077': {'trauma'},
#   '38878952': {'left-sided heart', 'transposition'},
#   '39461812': {'incest'},
#   'ppr884422': {'anisometropia', 'myopic'},
#   '39418493': {'professional burnout'},
#   'ppr931324': {'learning'},
#   '37995204': {'aids', 'learning'},
#   '39466684': {'emotionality'},
#   '39464433': {'regeneration'},
#   '39462676': {'learning'},
#   '39465635': {'thromboembolism'},
#   '38397267': {'behaviour'},
#   '39190959': {'dios'},
#   '39466594': {'behavior', 'intermolecular forces', 'vis'},
#   '39463298': {'nbsp'},
#   '39466760': {'defect', 'defects', 'feature extraction'},
#   '39460212': {'feature-extraction'},
#   '39089706': {'erosion', 'learning'},
#   '37655561': {'goes'},
#   '39035075': {'memory'},
#   '39460125': {'delta', 'translation'},
#   '39466260': {'behavior', 'electron'},
#   '37697207': {'learning'},
#   '38705545': {'bone loss'},
#   '39461726': {'fmp', 'learning'},
#   '39404472': {'enamine', 'python'},
#   '39461603': {'retina'},
#   '39464276': {'learning'},
#   '39466680': {'hyperpigmentation'},
#   '39462300': {'bfr'},
#   '38941195': {'local disease'},
#   '39466845': {'behavior', 'translation'},
#   '38404565': {'defects', 'trauma'},
#   '39452508': {'behaviors'},
#   '38271164': {'tlx'},
#   '38403983': {'defects'},
#   '39458748': {'ppe'},
#   '39465399': {'learning', 'transposition'},
#   '39461962': {'feature extraction', 'learning'},
#   'ppr931486': {'twisting'},
#   '39464902': {'learning'},
#   'ppr717187': {'tls'},
#   'ppr931449': {'learning'},
#   '39183395': {'behavior'},
#   '39463597': {'defect', 'defects'},
#   '39462507': {'translation'},
#   '39463436': {'learning'},
#   '39458115': {'associated conditions', 'kidney replacement'},
#   'ppr928507': {'gfrp'},
#   '39467068': {'imaging techniques'},
#   '39231245': {'wildfires'},
#   '39467248': {'behavior', 'regeneration'},
#   '39443652': {'gpt'},
#   '39236595': {'human', 'learning'},
#   '39458126': {'defect', 'depression'},
#   'ppr708649': {'learning'},
#   '38383444': {'learning'},
#   '38404757': {'learning'},
#   '39463441': {'behaviors'},
#   '39465281': {'coney'},
#   '38705894': {'gpt', 'translations'},
#   'ppr931392': {'learning'},
#   '38384782': {'habituation'},
#   '38844634': {'learning', 'short-term memory'},
#   '39453782': {'symbiosis'},
#   '39190934': {'behaviours'},
#   '37651693': {'sos-1', 'sos-2'},
#   '39459095': {'breakdown'},
#   '38883237': {'learning'},
#   'ppr919104': {'learning'},
#   '39464530': {'learning'},
#   '39455708': {'asphalt', 'c2f', 'learning'},
#   'ppr717891': {'learning', 'python'},
#   'ppr919062': {'cylinder', 'hemolysis'},
#   '39462159': {'turkey'},
#   '39466981': {'atoms', 'electron'},
#   '39460214': {'android', 'fp1'},
#   '39465288': {'radical', 'visions'},
#   '39464843': {'contraception'},
#   'ppr931421': {'indo', 'taxes'},
#   '39465909': {'giving birth', 'preterm birth'},
#   'ppr555083': {'rare diseases'},
#   '38530460': {'curb'},
#   '38780006': {'behavior'},
#   '39462723': {'trauma'},
#   '39463753': {'learning', 'uptake'},
#   '37682624': {'learning'},
#   '39463407': {'memory'},
#   '39465739': {'learning', 'pneumoperitoneum'},
#   '38782856': {'learning'},
#   'ppr931514': {'chip', 'defect', 'radio'},
#   '39466289': {'learning', 'xxx'},
#   '38924666': {'behavior', 'behaviors'},
#   'ppr931406': {'learning', 'vision'},
#   '39460217': {'fps', 'learning', 'struck'},
#   '39460123': {'vision'},
#   '39363135': {'ssi1', 'ssi2'},
#   '39460153': {'behaviour'},
#   '39298030': {'erosion'},
#   'ppr931407': {'gpt'},
#   '39463146': {'mp2', 'polymerization', 'radical'},
#   'ppr928995': {'simp'},
#   '38398742': {'learning'},
#   '39459096': {'memory'},
#   'ppr924008': {'harvesters'},
#   '39463487': {'sbs'},
#   '39384676': {'behavior'},
#   'ppr929967': {'host organisms'},
#   '38221560': {'behavior'},
#   '39313074': {'lnp'},
#   '39460183': {'defects'},
#   '38311265': {'seal'},
#   '39462765': {'behaviors'},
#   '39466288': {'xxx'},
#   '39462035': {'pls'},
#   '39461254': {'turkey'},
#   'ppr898533': {'learning', 'memory', 'sma', 'smas'},
#   '38145962': {'growth factors'},
#   '39466108': {'cervical spine instability'},
#   '38410500': {'flutter'},
#   '38232221': {'scapholunate advanced collapse'},
#   '39462469': {'adc'},
#   '39465179': {'python'},
#   '38537727': {'seal'},
#   '39466303': {'cancer'},
#   '38839351': {'coronary artery bypass', 'graft failure', 'stenosis'},
#   '39465290': {'visions'},
#   '37723373': {'behavior', 'behaviors', 'learning'},
#   '39463917': {'acl', 'mcl', 'mpfl'},
#   '39172419': {'behavior', 'behaviors'},
#   '39462670': {'learning'},
#   '38391073': {'behaviors'},
#   '39466137': {'memory'},
#   '38971542': {'scb'},
#   '38393335': {'e9'},
#   '39459225': {'biosensors'},
#   '39465595': {'memory'},
#   '39250366': {'learning'},
#   'ppr718383': {'behaviour', 'transport'},
#   '39464331': {'congenital malformation', 'surgical resection'},
#   '39377908': {'behavior'},
#   '39460088': {'learning', 'rover'},
#   '39365531': {'andes', 'eruptions', 'icp'},
#   'ppr927693': {'photons'},
#   '39460131': {'vsg'},
#   '39207507': {'behaviors', 'hbm', 'ps2', 'ps3', 'ps5', 'pv1'},
#   'ppr909159': {'apa', 'psych'},
#   '39455887': {'whale'},
#   '39463451': {'python', 'transport'},
#   '39467262': {'harvesters'},
#   'ppr706306': {'light scattering'},
#   '39463749': {'learning'},
#   'ppr931456': {'cfa', 'mdc', 'vas'},
#   'ppr704269': {'behaviors'},
#   '39459112': {'spa'},
#   '39459831': {'composite'},
#   '38405276': {'behavior'},
#   '38183663': {'learning'},
#   '39197186': {'learning'},
#   '39250856': {'behavior'},
#   '39390326': {'torsion'},
#   '39464900': {'giving birth',
#    'preterm delivery',
#    'small-for-gestational-age'},
#   '39302414': {'rec'},
#   '38400500': {'learning'},
#   '39467180': {'cms', 'coronary artery bypass'},
#   '39461993': {'eys'},
#   '39045714': {'mdp', 'soft tissue lesions', 'uptake'},
#   '39466778': {'athletes', 'cond'},
#   '38404501': {'memory'},
#   '38315623': {'learning'},
#   '39457273': {'sfs'},
#   '39457980': {'total hip arthroplasty'},
#   '39462646': {'trauma'},
#   'ppr915698': {'behavior', 'pso'},
#   '39466589': {'cognition', 'memory'},
#   'ppr931204': {'interaction prediction'},
#   '39463197': {'learning'},
#   '39466092': {'learning'},
#   '38391086': {'memory'},
#   '38331366': {'graft failure', 'osteoarthritis'},
#   '39434846': {'preterm birth'},
#   '39032864': {'total hip arthroplasty'},
#   '37480290': {'tastes'},
#   '39464988': {'defects', 'lack of interest'},
#   '39465294': {'osc'},
#   '38420171': {'hallucination', 'lsd'},
#   '39453780': {'visual illusions'},
#   'ppr905361': {'lands', 'memory'},
#   '39460238': {' pros'},
#   '39455805': {'behaviour', 'translation'},
#   '39455752': {'learning', 'long-term memory'},
#   '39352527': {'rotator cuff tears'},
#   '39460057': {'light absorption'},
#   '39460051': {'lcr'},
#   '39311982': {'trauma'},
#   '39466366': {'learning'},
#   '39459746': {'asphalt', 'behavior'},
#   '38392367': {'learning'},
#   '39461169': {'sma'},
#   '39466101': {'chronic pain'},
#   '39462697': {'anorectal malformations',
#    'hydroureteronephrosis',
#    'septal defects'},
#   '39458105': {'adiposity', 'ageing', 'deaths', 'obese'},
#   '39423115': {'gpl', 'python'},
#   '39466090': {'learning'},
#   '39466290': {'xxx'},
#   '38861448': {'learning'},
#   '39014250': {'jama'},
#   '39416113': {'torque'},
#   'ppr712262': {'cheetah'},
#   '39069570': {'pod1'},
#   '39374921': {'behavior', 'behaviors'},
#   '39455785': {'learning'},
#   '38597913': {'medical procedure', 'translation'},
#   'ppr472628': {'memory'},
#   '39460085': {'short-term memory'},
#   '39460136': {'frozen shoulder', 'learning'},
#   '39460103': {'defect', 'defects', 'inversion'},
#   '39460197': {'defect', 'defects'},
#   '39465889': {'behavior'},
#   '39462218': {'behavior', 'behaviors', 'memory'},
#   '38963746': {'gan'},
#   '38252566': {'incoherence', 'singular'},
#   '39467165': {'behaviors', 'twisting'},
#   '39463854': {'physical disabilities'},
#   '38835192': {'behaviour'},
#   '39459715': {'behavior', 'feature extraction', 'learning', 'translation'},
#   '39466856': {'feature extraction'},
#   '39460041': {'behavior', 'defect', 'detection of light'},
#   '39453348': {'fear of pain', 'trauma'},
#   '38753490': {'molecular entities'},
#   'ppr930006': {'rsa'},
#   '39460215': {'coyote'},
#   '38425587': {'trauma'},
#   '39462305': {'rare disease', 'rare diseases'},
#   '39464796': {'learning'},
#   '38435706': {'memory'},
#   'ppr868669': {'erosion'},
#   '39453552': {'asthmatic', 'behavior', 'learning', 'mimesis', 'mof'},
#   'ppr930102': {'hood'},
#   '39458066': {'adl', 'lbp', 'translation'},
#   '39466457': {'reflux'},
#   '39460016': {'drl', 'learning'},
#   'ppr832637': {'boson'},
#   'ppr900531': {'nance'},
#   '38366371': {'postoperative complications', 'trigger thumb'},
#   '39464785': {'apn'},
#   '39461265': {'transport'},
#   '39466983': {'osteoarthritis'},
#   '39461309': {'vision'},
#   '39401935': {'actinide', 'actinides'},
#   'ppr799223': {'behaviour'},
#   '39459826': {'lime'},
#   '39464058': {'gpl', 'learning'},
#   'ppr931370': {'lema'},
#   '38145338': {'learning'},
#   '39460160': {'learning'},
#   '39465345': {'behaviour', 'transport'},
#   '39460245': {'radio'},
#   '39357689': {'memory'},
#   '39459688': {'behavior'},
#   '39462664': {'feature extraction', 'short-term memory'},
#   '39136105': {'electron', 'transport'},
#   'ppr931140': {'epithelial-mesenchymal transition', 'sim'},
#   '39462082': {'learning'},
#   '39459198': {'learning'},
#   '39465038': {'behaviors'},
#   '38397650': {'learning'},
#   '39448717': {'swimming'},
#   '39463940': {'learning'},
#   '39109600': {'learning', 'mlip'},
#   '38126743': {'ischaemia'},
#   '39260204': {'at a p'},
#   '39461118': {'bicuspid aortic valve', 'thrombotic'},
#   '38405609': {'interactions prediction', 'learning'},
#   '39463017': {'turkey'},
#   '39462873': {'composite'},
#   '39460249': {'radio'},
#   '39459603': {'amputation', 'trauma'},
#   '39095637': {'spam'},
#   '39465428': {'adc'},
#   '39120991': {'learning', 'visual fatigue'},
#   '39463014': {'behaviors', 'cfi', 'nfi'},
#   '39465230': {'aids', 'learning'},
#   '39207566': {'total hip arthroplasty'},
#   '39460235': {'asphalt', 'learning'},
#   '39463684': {'tobacco'},
#   'ppr320515': {'peach'},
#   '39401841': {'kidney replacement'},
#   '39465091': {'sensitization'},
#   '39234937': {'behavior'},
#   'ppr919220': {'plm'},
#   '38384363': {'spam'},
#   '38406474': {'learning'},
#   '39465306': {'memory', 'smoother'},
#   '39459781': {'behavior'},
#   '38400360': {'learning'},
#   '39231869': {'behaviors'},
#   '38990677': {'behavior'},
#   '39465547': {'eating behaviour', 'obese'},
#   '39463283': {'behaviour', 'behaviours'},
#   '39467096': {'learning'},
#   '38405981': {'python'},
#   '39463077': {'radio'},
#   '39459753': {'asphalt', 'behavior'},
#   '39460155': {'learning'},
#   '38703196': {'learning'},
#   '38857142': {'behavior', 'cannula'},
#   '39453801': {'learning'},
#   '39463602': {'hyperplasia', 'postoperative complications'},
#   '38395914': {'uptake'},
#   'ppr729768': {'recombination'},
#   'ppr925798': {'learning'},
#   '39464846': {'snap'},
#   'ppr931521': {'cmd'},
#   '39466165': {'athletes', 'torque'},
#   '39455601': {'eruptions', 'gamma', 'kiama'},
#   '38261075': {'trauma'},
#   '39467167': {'mage'},
#   '39465477': {'behavior', 'behaviors'},
#   '39459134': {'display technology'},
#   'ppr874144': {'torque'},
#   '39464205': {'meniscus'},
#   '39292579': {'learning'},
#   '39455875': {'memory'},
#   '39153136': {'ssv', 'tcv'},
#   '38564344': {'learning'},
#   '39465087': {'hysterectomy'},
#   '39456200': {'learning'},
#   '39466355': {'cerebellar hemorrhage', 'preterm birth'},
#   '39459056': {'insertion', 'radio'},
#   '37550466': {'bullseye', 'vision'},
#   'ppr837700': {'protein complex'},
#   '39008420': {'pi 4'},
#   '39465107': {'p300'},
#   '39465835': {'learning'},
#   'ppr928885': {'behavior'},
#   '39304175': {'transport'},
#   '39460055': {'satellites', 'sim', 'vision'},
#   '39460178': {'learning'},
#   '39404225': {'atoms'},
#   '38466307': {'gpt', 'hallucinations'},
#   '38190218': {'behaviors'},
#   '39463396': {'long-term memory', 'memory'},
#   '39459710': {'defects'},
#   '39466089': {'learning'},
#   '39404784': {'learning'},
#   '39460159': {'learning'},
#   '39465404': {'defect', 'defects'},
#   'ppr879323': {'learning'},
#   '16334054': {'memory'},
#   '39463087': {'learning'},
#   '39398201': {'behavior', 'vision'},
#   'ppr847123': {'sfs'},
#   '39466017': {'behavior'},
#   '38861532': {'amputations'},
#   '39464641': {'ism'},
#   '39466319': {'learning', 'xxx'},
#   '39459074': {'chips'},
#   '39459131': {'electron', 'nems'},
#   '39211998': {'exsanguination'},
#   '39464551': {'lanka'},
#   '39462976': {'behaviors'},
#   '38391987': {'biosensors'},
#   '39465375': {'medial cortex'},
#   '39459660': {'transport'},
#   '39321914': {'ind'},
#   '38404791': {'sag'},
#   '38831485': {'cold ischemia'},
#   'ppr906999': {'radio'},
#   'ppr928788': {'memory'},
#   '39455699': {'android',
#    'behaviour',
#    'learning',
#    'short-term memory',
#    'whale'},
#   '39460083': {'behavior'},
#   '39393057': {'learning'},
#   '38406285': {'31.2'},
#   '39460119': {'feature extraction', 'gtx', 'learning'},
#   '39297189': {'behaviours', 'deaths'},
#   'ppr931509': {'bends'},
#   'ppr931020': {'learning'},
#   '37776297': {'chronic low back pain'},
#   '39460139': {'learning', 'memory'},
#   '39460001': {'grf'},
#   '39463094': {'aids'},
#   '39459089': {'fsm'},
#   '39460190': {'tbm'},
#   '38399010': {'behavior'},
#   '39460050': {'learning'},
#   '39466466': {'learning'},
#   '39459997': {'pti'},
#   '38405681': {'salinas'},
#   '36848499': {'behavior', 'behaviors'},
#   '38641942': {'vascularization'},
#   'ppr931441': {'learning'},
#   '39208501': {'learning'},
#   '39459151': {'aquila', 'pid'},
#   '39462144': {'handedness'},
#   '39456178': {'learning', 'protein complex'},
#   '39464493': {'behavior'},
#   '38758252': {'oct 1'},
#   '39462247': {'neurotoxin'},
#   '39464749': {'learning'},
#   'ppr931323': {'hemoglobin',
#    'intraocular pressure',
#    'retina',
#    'retinal vascular changes'},
#   '39459722': {'behavior', 'rubber'},
#   '39465948': {'breakdown', 'transport'},
#   'ppr891993': {'learning'},
#   '39464437': {'behavior'},
#   '39457294': {'behaviours'},
#   '39466638': {'pulmonary aspiration', 'sga', 'sgas'},
#   '39464201': {'hood'},
#   '38815094': {'behaviors'},
#   '39460070': {'pid'},
#   '39458476': {'maf'},
#   '39466136': {'behaviour'},
#   '38331370': {'graft failure', 'ligamentous laxity'},
#   '39459059': {'mrf', 'torque'},
#   '39459774': {'behavior', 'defects'},
#   '39466496': {'pci'},
#   '39467017': {'trauma'},
#   '39462259': {'behavior', 'memory', 'torque'},
#   '39466711': {'florbetapir', 'flutemetamol', 'uptake'},
#   '39087515': {'cpt', 'insertion', 'peri-implant fracture'},
#   '39461171': {'aquila', 'learning'},
#   '39459805': {'behavior', 'learning', 'transport'},
#   '39462281': {'osteoarthritis', 'regeneration'},
#   'ppr931165': {'learning'},
#   '39467278': {'osteonecrosis', 'postoperative complications'},
#   '38943033': {'mater'},
#   '39464505': {'learning'},
#   '39465280': {'chip'},
#   '39455559': {'behaviors'},
#   'ppr739991': {'learning'},
#   'ppr881621': {'simp'},
#   '38687967': {'defects'},
#   '39462131': {'behaviour'},
#   '39463079': {'cnr', 'learning'},
#   'ppr931291': {'learning'},
#   'ppr876977': {'behavior'},
#   'ppr931213': {'memory'},
#   '39460166': {'chip'},
#   'ppr874002': {'critically ill'},
#   '38447775': {'chronic pain'},
#   '39460237': {'learning'},
#   '39464981': {'choking'},
#   'ppr837048': {'behavior'},
#   '39462539': {'deaths'},
#   '39464980': {'vision'},
#   '39460239': {'trailing edge'},
#   '38976042': {'aspn'},
#   '39464905': {'behavior'},
#   '39460091': {'learning', 'radio'},
#   '39460231': {'behavior', 'behaviors'},
#   '39448728': {'gnd'},
#   '39460094': {'behavior',
#    'cochlear implant',
#    'cochlear implants',
#    'cochlear-implant'},
#   '39462219': {'behaviors', 'hps', 'learning'},
#   '38593861': {'delta'},
#   '39460015': {'translation'},
#   'ppr925058': {'behavior', 'denial'},
#   '39464949': {'learnings'},
#   'ppr916362': {'cfd'},
#   'ppr913266': {'learning'},
#   'ppr928338': {'gamma'},
#   '37684495': {'behavior', 'learning'},
#   '39459081': {'chip'},
#   '39341472': {'ssp'},
#   'ppr682084': {'learning'},
#   '38087642': {'ecc'},
#   '39258871': {'organic compounds'},
#   '39463762': {'uptake'},
#   'ppr916263': {'gamma'},
#   '39458424': {'android'},
#   '39183417': {'python'},
#   '39459841': {'a10', 'cfd', 's24'},
#   '39093677': {'behavior'},
#   '39462107': {'behavior'},
#   '38376586': {'pathologic fractures'},
#   '39437295': {'learning'},
#   '39460161': {'learning'},
#   '39464525': {'behavior', 'behaviors', 'learning'},
#   '39462129': {'epi'},
#   '39464304': {'learning'},
#   '39462797': {'gestation', 'preterm delivery', 'small-for-gestational age'},
#   '38404314': {'imaging technique'},
#   '38260532': {'learning'},
#   '38771464': {'scars'},
#   '39448627': {'prp', 'rr 2', 'vip'},
#   '38388956': {'chop',
#    'immature cataract',
#    'intraoperative complications',
#    'php'},
#   '39230450': {'behaviour', 'behaviours'},
#   '39466777': {'cond', 'swimming'},
#   '39278182': {'perches', 'tenacity', 'the thing', 'trauma'},
#   '39463289': {'learning'},
#   '39460127': {'learning'},
#   '39466019': {'behavior'},
#   '38392107': {'muscle hypertrophy'},
#   '39382803': {'b10', 'biuret', 'carborundum', 'nanostructure', 'scr'},
#   '39322213': {'adiposity', 'behavior'},
#   '39237652': {'asa', 'total hip arthroplasty'},
#   'ppr716357': {'behavior', 'learning'},
#   '39455678': {'transport'},
#   'ppr931238': {'isn'},
#   '38334747': {'behavior', 'learning'},
#   '38430717': {'python'},
#   '37308115': {'preterm birth'},
#   '39465059': {'trauma'},
#   '39466015': {'acad', 'adem', 'behavior', 'las', 'micos', 'por'},
#   'ppr931357': {'learning', 'short-term memory'},
#   '39460033': {'gpc', 'spc'},
#   'ppr796855': {'learning'},
#   '39467274': {'cardiac arrest', 'learning'},
#   '39459110': {'display technologies'},
#   'ppr717330': {'learning'},
#   '39466534': {'behaviors'},
#   '39315475': {'ats', 'cms', 'hadron', 'leptons', 'top quark'},
#   '37507651': {'memory'},
#   '38397611': {'behavior'},
#   '39414664': {'insertion'},
#   '39456103': {'learning'},
#   '38408893': {'critically ill', 'vip'},
#   'ppr257396': {'python'},
#   '39461814': {'incest'},
#   '39178810': {'learning'},
#   '39455479': {'icer'},
#   '39457976': {'hemoglobin'},
#   '39457039': {'cotton'},
#   '39466717': {'deaths', 'uptake'},
#   '39432656': {'behavior'},
#   '39443624': {'learning'},
#   '39464062': {'actin', 'behavior'},
#   '39465289': {'radical'},
#   '39463458': {'learning'},
#   'ppr808367': {'defects'},
#   '38425687': {'behavior', 'behaviors'},
#   '38496488': {'learning', 'vision'},
#   '39460045': {'feature extraction', 'learning'},
#   '38383556': {'gpt'},
#   'ppr715899': {'congestion'},
#   '39464656': {'trauma'},
#   '39183402': {'python'},
#   '39460029': {'deaths', 'learning', 'radio', 'transport'},
#   '39459712': {'defect', 'defects'},
#   '39459135': {'defect', 'defects'},
#   '39461263': {'turkey'},
#   '39461409': {'dysplasia'},
#   'ppr922420': {'learning', 'vision'},
#   '39384672': {'gip'},
#   '39464780': {'simp'},
#   'ppr849705': {'behavior', 'learning'},
#   '39417148': {'composite', 'learning', 'translation'},
#   '39462356': {'ccta', 'coronary artery bypass'},
#   '38455454': {'defect'},
#   '39197187': {'learning'},
#   '39463390': {'behavior', 'golden eagle'},
#   '38392098': {'learning'},
#   '39464504': {'learning'},
#   '38271162': {'memory'},
#   '39460247': {'overconfidence'},
#   'ppr885879': {'learning'},
#   '39463752': {'learning'},
#   '39466979': {'behavior', 'learning'},
#   '39460991': {'recombination'},
#   '38279630': {'tri'},
#   '39465194': {'cesarean section'},
#   '39460188': {'learning'},
#   'ppr915806': {'learning'},
#   '39459771': {'composites'},
#   '38533532': {'breech presentation'},
#   '38997850': {'learning'},
#   '39458657': {'learning'},
#   '39460202': {'behavior', 'learning'},
#   '39459694': {'behavior'},
#   '38811388': {'compression fractures'},
#   '39349099': {'cannula', 'learning'},
#   '39462329': {'behaviour'},
#   '39463040': {'learning', 'translation'},
#   '39463504': {'baronia', 'critically ill', 'vision'},
#   '39460220': {'behavior', 'biosensor', 'display technology', 'learning'},
#   '39460318': {'uptake'},
#   '39459111': {'defects', 'heat generation'},
#   '39462692': {'chips'},
#   '39231652': {'grx'},
#   'ppr931372': {'regeneration'},
#   '39432649': {'obese'},
#   'ppr725396': {'behaviour', 'behaviours'},
#   'ppr712502': {'learning', 'quo'},
#   '39459057': {'singular'},
#   '39462017': {'nanostructure'},
#   '39465003': {'learning'},
#   '39464153': {'insertion', 'insertions', 'recombination'},
#   '39459989': {'behaviors', 'feature extraction'},
#   '38730032': {'learning'},
#   '39465406': {'cfi', 'gfi', 'translation'},
#   '39466455': {'learning', 'xxx'},
#   '39459730': {'behavior'},
#   '39455692': {'learning'},
#   '39463489': {'pharmacotherapy'},
#   '39465490': {'learning'},
#   '38461431': {'behavior', 'memory'},
#   '39466563': {'vas'},
#   '37695024': {'alba'},
#   '39236597': {'learning'},
#   '38355011': {'aids', 'insertion'},
#   '39465112': {'learning'},
#   '38194400': {'learning'},
#   '39460120': {'insertion', 's21'},
#   '39302449': {'osteoarthritis', 'total hip arthroplasty'},
#   'ppr900507': {'poems', 'tech'},
#   '39466806': {'learning'},
#   '39461816': {'incest', 'sexual violence'},
#   'ppr909731': {'eda'},
#   'ppr647230': {'memory'},
#   '39465036': {'trauma'},
#   '39459983': {'ams'},
#   '39466614': {'coffee'},
#   '39460248': {'learning'},
#   '39464306': {'transport'},
#   '39465648': {'fcs', 'quantum dot', 'transport'},
#   '39459149': {'cnc'},
#   'ppr899253': {'feature extraction'},
#   '39462758': {'memory'},
#   'ppr917491': {'fgd'},
#   '39361205': {'behavior'},
#   '39460122': {'adc'},
#   '39463844': {'degenerations'},
#   '39465192': {'learning'},
#   '39466802': {'torque'},
#   '39466423': {'behaviour', 'learning', 'scraping'},
#   'ppr931465': {'aar', 'feature extraction'},
#   '39459130': {'honeycomb'},
#   '39465533': {'learning'},
#   '39466999': {'vip'},
#   'ppr729197': {'waters'},
#   'ppr725206': {'learning', 'sca'},
#   '39461811': {'incest'},
#   '39462418': {'malo', 'transposition'},
#   '39460204': {'gan', 'learning', 'vif'},
#   '38582224': {'hss'},
#   '39457389': {'cellular homeostasis'},
#   '39461071': {'hoods'},
#   '39459099': {'quantum dots', 'quantum-dot'},
#   'ppr715893': {'learning'},
#   '39463080': {'short-term memory'},
#   '39416135': {'learning', 'orthrus'},
#   '38969956': {'behavior', 'fsi'},
#   '39466097': {'learning'},
#   '39466012': {'behavior'},
#   '39088713': {'bone regeneration',
#    'defect',
#    'defects',
#    'mastication',
#    'regeneration',
#    'stump',
#    'stumps'},
#   '39463335': {'trauma'},
#   'ppr898585': {'learning'},
#   '39461072': {'behavior'},
#   '39460102': {'ris'},
#   '39459429': {'bile leak', 'postoperative complications'},
#   '39464850': {'behaviour', 'behaviours'},
#   '37658256': {'behavior'},
#   '37916486': {'infarct', 'rubber', 'svv'},
#   'ppr729611': {'pci', 'ssv', 'u50'},
#   '39463032': {'behavior'},
#   '39461035': {'retrognathia'},
#   '39458956': {'behavior', 'learning'},
#   'ppr872573': {'turkey'},
#   '39458099': {'chronic pain'},
#   '39459148': {'chip', 'electron'},
#   '39459798': {'behavior', 'behaviors'},
#   '39460112': {'amd', 'memory', 'rice', 'vhdl'},
#   '39458239': {'composite', 'rsa'},
#   '39459709': {'behavior'},
#   '39465588': {'strabismus', 'xxx'},
#   '38405777': {'interaction predictions', 'learning'},
#   '39465034': {'behaviors'},
#   '16686795': {'sesame'},
#   'ppr721162': {'cdd', 'csv', 'versed'},
#   '39463755': {'learning'},
#   'ppr839515': {'defects'},
#   'ppr931507': {'panama'},
#   '39301949': {'ans'},
#   'ppr720980': {'learning'},
#   '39029584': {'trauma'},
#   '39463302': {'compulsion'},
#   '39459728': {'pores'},
#   'ppr670794': {'congestion', 'stc'},
#   '39462702': {'hemorrhage',
#    'hemorrhagic shock',
#    'hepatic artery pseudoaneurysm'},
#   '39461556': {'learning'},
#   '39466209': {'behavior'},
#   'ppr776308': {'learning'},
#   'ppr927626': {'learning'},
#   '39460022': {'short-term memory'},
#   '39463655': {'bone necrosis', 'heat generation'},
#   '39453898': {'behaviours'},
#   '39466011': {'behavior', 'behaviors'},
#   '39459987': {'inversion', 'venous engorgement'},
#   '39463468': {'delta', 'reproduction'},
#   '39464386': {'tobacco'},
#   '39465106': {'learning'},
#   '39466869': {'itr'},
#   'ppr931221': {'memory'},
#   '38308947': {'behavior', 'learning'},
#   '39463290': {'nbsp'},
#   'ppr931386': {'vhr'},
#   'ppr730579': {'behavior', 'learning'},
#   'ppr925042': {'asphalt', 'learning', 'python'},
#   '38406409': {'learning'},
#   '38829759': {'learning'},
#   'ppr919031': {'psychiatric diagnosis'},
#   '38406452': {'learning'},
#   '39404795': {'scrna-seq', 'single-cell sequencing'},
#   '39465070': {'hormone replacement therapies', 'tasmania'},
#   '39149838': {'atoms', 'electron'},
#   '39463459': {'behavior'},
#   '39466159': {'breakdowns', 'learning'},
#   'ppr922393': {'learning'},
#   '37730933': {'learning'},
#   '37890120': {'cancer'},
#   '39044009': {'nfp'},
#   '38390351': {'deaths'},
#   '39464874': {'trauma'},
#   '39466486': {'tectonic'},
#   '39462988': {'clare'},
#   '39265275': {'learning'},
#   'ppr914044': {'-dc'},
#   '39457276': {'haemoglobin'},
#   'ppr718136': {'wildfire', 'wildfires'},
#   '37604961': {'android'},
#   'ppr767199': {'learning', 'sev'},
#   '39466356': {'gpt', 'translation', 'translations'},
#   '38385144': {'mental impairments'},
#   '39460073': {'learning'},
#   '39467183': {'behavior'},
#   '38382881': {'learning', 'v(+)', 'v(0)'},
#   '39467198': {'rhode', 'trauma'},
#   'ppr917073': {'behaviours', 'learning', 'learnings'},
#   '39458746': {'composite', 'delamination'},
#   '39460089': {'c2f', 'feature extraction'},
#   '39460207': {'memory'},
#   'ppr931424': {'sex determination'},
#   '37902255': {'chronic low back pain'},
#   '39466426': {'xxx'},
#   '39459400': {'trauma'},
#   '39462735': {'learning', 'uptake'},
#   'ppr721681': {'aids', 'translation'},
#   '39462636': {'learning'},
#   '39457323': {'learning'},
#   '39368049': {'acp'},
#   '39190958': {'behavior', 'behaviors'},
#   '39455673': {'learning'},
#   '39459240': {'atoms'},
#   '38644742': {'critically ill'},
#   '39088409': {'mlp', 'mlps'},
#   '38767797': {'cardiogenic shock', 'ischemia'},
#   '39459985': {'learning', 'memory'},
#   '39285084': {'behavior'},
#   '39459300': {'recombination'},
#   '38320103': {'learning'}},
#  'missing_annotations_in_ml': {},
#  'found_in_dict_not_in_ml': {'39455799': {'mcm'},
#   '39466424': {'acne'},
#   '39459124': {'learning'},
#   '38822920': {'intracranial haemorrhage', 'trauma'},
#   'ppr930376': {'tpn'},
#   'ppr717598': {'learning'},
#   '39459706': {'behavior'},
#   '39463198': {'trauma'},
#   '39462477': {'electron'},
#   '38420485': {'learning'},
#   '39464207': {'learning'},
#   'ppr931380': {'learning'},
#   '39331295': {'mega'},
#   '38657901': {'critically ill'},
#   '39465076': {'aotearoa'},
#   '39465228': {'lam'},
#   '39462275': {'behaviours', 'learning'},
#   '39458770': {'adr', 'composites', 'pbat', 'pla'},
#   'ppr749756': {'singular'},
#   '38414887': {'pgy1', 'pgy2'},
#   '38405299': {'behavior'},
#   'ppr712067': {'inversion'},
#   '38425991': {'behavior'},
#   '39465985': {'electron', 'transport'},
#   'ppr867909': {'behavior', 'insertion'},
#   '39461914': {'learning'},
#   '39178809': {'learning'},
#   '39459418': {'vascularization'},
#   '36171462': {'mnp'},
#   '39464428': {'breakdown'},
#   '39467178': {'arizona', 'phoenix'},
#   '39460177': {'defect', 'defects'},
#   '39466789': {'grey wolf', 'mlp'},
#   '39459754': {'composites'},
#   '37880511': {'behavior'},
#   '38261496': {'learning'},
#   '39415472': {'defect', 'electron'},
#   '39463961': {'gpt'},
#   '39463591': {'alabama', 'coronary artery bypass', 'cpt'},
#   '39466381': {'rsa'},
#   '38936606': {'coi'},
#   'ppr877425': {'defect', 'defects', 'learning', 'mmd'},
#   '39461817': {'domestic violence', 'incest'},
#   'ppr720941': {'behavior'},
#   '39460167': {'learning'},
#   '39358655': {'learning'},
#   '39462223': {'cesarean section', 'giving birth'},
#   'ppr721972': {'smoother'},
#   'ppr922222': {'behavior', 'learning'},
#   '39369969': {' pros'},
#   '39457452': {'rare disorders'},
#   'ppr931451': {'calcification of stylohyoid ligament'},
#   '39466550': {'behaviors'},
#   'ppr899760': {'behavior', 'cfa'},
#   'ppr930528': {'feature extraction'},
#   '38405284': {'behavior'},
#   '39466863': {'defect', 'defects', 'learning'},
#   '39240531': {'behaviour', 'biosensors', 'learning', 'mic'},
#   'ppr931218': {'behaviours'},
#   'ppr729024': {'learning'},
#   '39463326': {'learning'},
#   '39034743': {'learning', 'nucleus'},
#   '39460192': {'learning'},
#   '39393782': {'gestation'},
#   '39464799': {'gpt'},
#   '39461815': {'incest'},
#   '39465299': {'aids', 'learning'},
#   'ppr929902': {'mutualism'},
#   '39464208': {'learning', 'pediatric diseases'},
#   '39341442': {'aids', 'uptake'},
#   'ppr931281': {'recombination'},
#   '39466858': {'learning'},
#   '39460165': {'learning', 'short-term memory'},
#   '38551339': {'learning', 'memory'},
#   'ppr719511': {'wildfire'},
#   '39459749': {'behavior', 'breakdown', 'rec'},
#   '39461485': {'learning'},
#   '39460056': {'tum'},
#   'ppr716326': {'crd', 'kiss', 'learning'},
#   'ppr722352': {'learning', 'wolfram'},
#   '39461287': {'behavior', 'learning'},
#   '39463414': {'learning'},
#   '39462116': {'mil', 'std'},
#   '37451338': {'insertion'},
#   '38384674': {'nlp'},
#   '39366556': {'learning', 'memory', 'perseveration', 'singular'},
#   '39459666': {'asphalt'},
#   '39463317': {' pros'},
#   '39459680': {'heat generation'},
#   '39463794': {'learning'},
#   '38390038': {'delta'},
#   'ppr726410': {'learning'},
#   'ppr931099': {'learning', 'python'},
#   'ppr911253': {'learning'},
#   '39158003': {'learning'},
#   '37658257': {'translation'},
#   'ppr931488': {'behaviour'},
#   '39463757': {'behaviors', 'learning'},
#   'ppr928686': {'behavior', 'behaviors'},
#   '39464776': {'vision'},
#   '39461486': {'learning', 'radio'},
#   '39463640': {'behavior', 'tri'},
#   '39462970': {'traumas'},
#   '39459767': {'behavior'},
#   '39462158': {'turkey'},
#   '39455698': {'behavior'},
#   '39236596': {'learning'},
#   '39466821': {'behavior'},
#   '38725349': {'alabama'},
#   '38414004': {'itc'},
#   '38349877': {'wildfire', 'wildfires'},
#   '39307285': {'learning'},
#   '39384295': {'deaths'},
#   '39466493': {'learning'},
#   '39458758': {'composites', 'smoother'},
#   '37962595': {'haemodynamic instability', 'iss'},
#   '39461813': {'incest', 'sexual violence'},
#   '39455621': {'abalone'},
#   '39463176': {'learning'},
#   '39462906': {'insertion'},
#   '39462130': {'memory'},
#   'ppr894342': {'behavior', 'disinhibition'},
#   '39465285': {'siren', 'sirens'},
#   '39455751': {'behavior'},
#   'ppr733186': {'learning'},
#   '39458075': {'radical'},
#   '39458531': {'turkey'},
#   '39460228': {'feature extraction', 'learning'},
#   '38862308': {'rr 2'},
#   '39165698': {'translation'},
#   '39459741': {'behavior', 'pore', 'pores'},
#   '39457267': {'athletes'},
#   '39459547': {'feature extraction', 'learning'},
#   '38266253': {'translation'},
#   'ppr836846': {'learning'},
#   '39463882': {'behaviour'},
#   '39459080': {'heat generation'},
#   '39270511': {'learning'},
#   '38378442': {'learning'},
#   '39451711': {'biosensors'},
#   '39459088': {'radio'},
#   '39465789': {'postoperative complications'},
#   '38358129': {'lead compounds'},
#   '39278184': {'learning'},
#   '39462760': {'emotionality'},
#   'ppr712526': {'ams'},
#   '39460156': {'feature extraction', 'learning'},
#   '39462734': {'transport', 'trauma'},
#   'ppr820409': {'social behavior'},
#   '39460095': {'transport'},
#   '39459644': {'aseptic loosening', 'kss', 'osteolysis'},
#   '39459786': {'limestone'},
#   '38752727': {'alt',
#    'cerebrospinal fluid leakage',
#    'defect',
#    'defects',
#    'lata',
#    'mater',
#    'skin graft necrosis'},
#   '38821001': {'drs'},
#   '39459719': {'behavior', 'ion transport', 'transport'},
#   '38425865': {'defects'},
#   '38405292': {'behavior'},
#   '39464241': {'polymerization'},
#   '38487195': {'python', 'translation'},
#   '39466611': {'crown',
#    'endodontically treated teeth',
#    'endodontically treated tooth'},
#   '38420630': {'behaviour'},
#   '39459663': {'behavior', 'rubber'},
#   '39459092': {'learning'},
#   '39458077': {'trauma'},
#   '38878952': {'left-sided heart', 'transposition'},
#   '39461812': {'incest'},
#   'ppr884422': {'anisometropia', 'myopic'},
#   '39418493': {'professional burnout'},
#   'ppr931324': {'learning'},
#   '37995204': {'aids', 'learning'},
#   '39466684': {'emotionality'},
#   '39464433': {'regeneration'},
#   '39462676': {'learning'},
#   '39465635': {'thromboembolism'},
#   '38397267': {'behaviour'},
#   '39190959': {'dios'},
#   '39466594': {'behavior', 'intermolecular forces', 'vis'},
#   '39463298': {'nbsp'},
#   '39466760': {'defect', 'defects', 'feature extraction'},
#   '39460212': {'feature-extraction'},
#   '39089706': {'erosion', 'learning'},
#   '37655561': {'goes'},
#   '39035075': {'memory'},
#   '39460125': {'delta', 'translation'},
#   '39466260': {'behavior', 'electron'},
#   '37697207': {'learning'},
#   '38705545': {'bone loss'},
#   '39461726': {'fmp', 'learning'},
#   '39404472': {'enamine', 'python'},
#   '39461603': {'retina'},
#   '39464276': {'learning'},
#   '39466680': {'hyperpigmentation'},
#   '39462300': {'bfr'},
#   '38941195': {'local disease'},
#   '39466845': {'behavior', 'translation'},
#   '38404565': {'defects', 'trauma'},
#   '39452508': {'behaviors'},
#   '38271164': {'tlx'},
#   '38403983': {'defects'},
#   '39458748': {'ppe'},
#   '39465399': {'learning', 'transposition'},
#   '39461962': {'feature extraction', 'learning'},
#   'ppr931486': {'twisting'},
#   '39464902': {'learning'},
#   'ppr717187': {'tls'},
#   'ppr931449': {'learning'},
#   '39183395': {'behavior'},
#   '39463597': {'defect', 'defects'},
#   '39462507': {'translation'},
#   '39463436': {'learning'},
#   '39458115': {'associated conditions', 'kidney replacement'},
#   'ppr928507': {'gfrp'},
#   '39467068': {'imaging techniques'},
#   '39231245': {'wildfires'},
#   '39467248': {'behavior', 'regeneration'},
#   '39443652': {'gpt'},
#   '39236595': {'human', 'learning'},
#   '39458126': {'defect', 'depression'},
#   'ppr708649': {'learning'},
#   '38383444': {'learning'},
#   '38404757': {'learning'},
#   '39463441': {'behaviors'},
#   '39465281': {'coney'},
#   '38705894': {'gpt', 'translations'},
#   'ppr931392': {'learning'},
#   '38384782': {'habituation'},
#   '38844634': {'learning', 'short-term memory'},
#   '39453782': {'symbiosis'},
#   '39190934': {'behaviours'},
#   '37651693': {'sos-1', 'sos-2'},
#   '39459095': {'breakdown'},
#   '38883237': {'learning'},
#   'ppr919104': {'learning'},
#   '39464530': {'learning'},
#   '39455708': {'asphalt', 'c2f', 'learning'},
#   'ppr717891': {'learning', 'python'},
#   'ppr919062': {'cylinder', 'hemolysis'},
#   '39462159': {'turkey'},
#   '39466981': {'atoms', 'electron'},
#   '39460214': {'android', 'fp1'},
#   '39465288': {'radical', 'visions'},
#   '39464843': {'contraception'},
#   'ppr931421': {'indo', 'taxes'},
#   '39465909': {'giving birth', 'preterm birth'},
#   'ppr555083': {'rare diseases'},
#   '38530460': {'curb'},
#   '38780006': {'behavior'},
#   '39462723': {'trauma'},
#   '39463753': {'learning', 'uptake'},
#   '37682624': {'learning'},
#   '39463407': {'memory'},
#   '39465739': {'learning', 'pneumoperitoneum'},
#   '38782856': {'learning'},
#   'ppr931514': {'chip', 'defect', 'radio'},
#   '39466289': {'learning', 'xxx'},
#   '38924666': {'behavior', 'behaviors'},
#   'ppr931406': {'learning', 'vision'},
#   '39460217': {'fps', 'learning', 'struck'},
#   '39460123': {'vision'},
#   '39363135': {'ssi1', 'ssi2'},
#   '39460153': {'behaviour'},
#   '39298030': {'erosion'},
#   'ppr931407': {'gpt'},
#   '39463146': {'mp2', 'polymerization', 'radical'},
#   'ppr928995': {'simp'},
#   '38398742': {'learning'},
#   '39459096': {'memory'},
#   'ppr924008': {'harvesters'},
#   '39463487': {'sbs'},
#   '39384676': {'behavior'},
#   'ppr929967': {'host organisms'},
#   '38221560': {'behavior'},
#   '39313074': {'lnp'},
#   '39460183': {'defects'},
#   '38311265': {'seal'},
#   '39462765': {'behaviors'},
#   '39466288': {'xxx'},
#   '39462035': {'pls'},
#   '39461254': {'turkey'},
#   'ppr898533': {'learning', 'memory', 'sma', 'smas'},
#   '38145962': {'growth factors'},
#   '39466108': {'cervical spine instability'},
#   '38410500': {'flutter'},
#   '38232221': {'scapholunate advanced collapse'},
#   '39462469': {'adc'},
#   '39465179': {'python'},
#   '38537727': {'seal'},
#   '39466303': {'cancer'},
#   '38839351': {'coronary artery bypass', 'graft failure', 'stenosis'},
#   '39465290': {'visions'},
#   '37723373': {'behavior', 'behaviors', 'learning'},
#   '39463917': {'acl', 'mcl', 'mpfl'},
#   '39172419': {'behavior', 'behaviors'},
#   '39462670': {'learning'},
#   '38391073': {'behaviors'},
#   '39466137': {'memory'},
#   '38971542': {'scb'},
#   '38393335': {'e9'},
#   '39459225': {'biosensors'},
#   '39465595': {'memory'},
#   '39250366': {'learning'},
#   'ppr718383': {'behaviour', 'transport'},
#   '39464331': {'congenital malformation', 'surgical resection'},
#   '39377908': {'behavior'},
#   '39460088': {'learning', 'rover'},
#   '39365531': {'andes', 'eruptions', 'icp'},
#   'ppr927693': {'photons'},
#   '39460131': {'vsg'},
#   '39207507': {'behaviors', 'hbm', 'ps2', 'ps3', 'ps5', 'pv1'},
#   'ppr909159': {'apa', 'psych'},
#   '39455887': {'whale'},
#   '39463451': {'python', 'transport'},
#   '39467262': {'harvesters'},
#   'ppr706306': {'light scattering'},
#   '39463749': {'learning'},
#   'ppr931456': {'cfa', 'mdc', 'vas'},
#   'ppr704269': {'behaviors'},
#   '39459112': {'spa'},
#   '39459831': {'composite'},
#   '38405276': {'behavior'},
#   '38183663': {'learning'},
#   '39197186': {'learning'},
#   '39250856': {'behavior'},
#   '39390326': {'torsion'},
#   '39464900': {'giving birth',
#    'preterm delivery',
#    'small-for-gestational-age'},
#   '39302414': {'rec'},
#   '38400500': {'learning'},
#   '39467180': {'cms', 'coronary artery bypass'},
#   '39461993': {'eys'},
#   '39045714': {'mdp', 'soft tissue lesions', 'uptake'},
#   '39466778': {'athletes', 'cond'},
#   '38404501': {'memory'},
#   '38315623': {'learning'},
#   '39457273': {'sfs'},
#   '39457980': {'total hip arthroplasty'},
#   '39462646': {'trauma'},
#   'ppr915698': {'behavior', 'pso'},
#   '39466589': {'cognition', 'memory'},
#   'ppr931204': {'interaction prediction'},
#   '39463197': {'learning'},
#   '39466092': {'learning'},
#   '38391086': {'memory'},
#   '38331366': {'graft failure', 'osteoarthritis'},
#   '39434846': {'preterm birth'},
#   '39032864': {'total hip arthroplasty'},
#   '37480290': {'tastes'},
#   '39464988': {'defects', 'lack of interest'},
#   '39465294': {'osc'},
#   '38420171': {'hallucination', 'lsd'},
#   '39453780': {'visual illusions'},
#   'ppr905361': {'lands', 'memory'},
#   '39460238': {' pros'},
#   '39455805': {'behaviour', 'translation'},
#   '39455752': {'learning', 'long-term memory'},
#   '39352527': {'rotator cuff tears'},
#   '39460057': {'light absorption'},
#   '39460051': {'lcr'},
#   '39311982': {'trauma'},
#   '39466366': {'learning'},
#   '39459746': {'asphalt', 'behavior'},
#   '38392367': {'learning'},
#   '39461169': {'sma'},
#   '39466101': {'chronic pain'},
#   '39462697': {'anorectal malformations',
#    'hydroureteronephrosis',
#    'septal defects'},
#   '39458105': {'adiposity', 'ageing', 'deaths', 'obese'},
#   '39423115': {'gpl', 'python'},
#   '39466090': {'learning'},
#   '39466290': {'xxx'},
#   '38861448': {'learning'},
#   '39014250': {'jama'},
#   '39416113': {'torque'},
#   'ppr712262': {'cheetah'},
#   '39069570': {'pod1'},
#   '39374921': {'behavior', 'behaviors'},
#   '39455785': {'learning'},
#   '38597913': {'medical procedure', 'translation'},
#   'ppr472628': {'memory'},
#   '39460085': {'short-term memory'},
#   '39460136': {'frozen shoulder', 'learning'},
#   '39460103': {'defect', 'defects', 'inversion'},
#   '39460197': {'defect', 'defects'},
#   '39465889': {'behavior'},
#   '39462218': {'behavior', 'behaviors', 'memory'},
#   '38963746': {'gan'},
#   '38252566': {'incoherence', 'singular'},
#   '39467165': {'behaviors', 'twisting'},
#   '39463854': {'physical disabilities'},
#   '38835192': {'behaviour'},
#   '39459715': {'behavior', 'feature extraction', 'learning', 'translation'},
#   '39466856': {'feature extraction'},
#   '39460041': {'behavior', 'defect', 'detection of light'},
#   '39453348': {'fear of pain', 'trauma'},
#   '38753490': {'molecular entities'},
#   'ppr930006': {'rsa'},
#   '39460215': {'coyote'},
#   '38425587': {'trauma'},
#   '39462305': {'rare disease', 'rare diseases'},
#   '39464796': {'learning'},
#   '38435706': {'memory'},
#   'ppr868669': {'erosion'},
#   '39453552': {'asthmatic', 'behavior', 'learning', 'mimesis', 'mof'},
#   'ppr930102': {'hood'},
#   '39458066': {'adl', 'lbp', 'translation'},
#   '39466457': {'reflux'},
#   '39460016': {'drl', 'learning'},
#   'ppr832637': {'boson'},
#   'ppr900531': {'nance'},
#   '38366371': {'postoperative complications', 'trigger thumb'},
#   '39464785': {'apn'},
#   '39461265': {'transport'},
#   '39466983': {'osteoarthritis'},
#   '39461309': {'vision'},
#   '39401935': {'actinide', 'actinides'},
#   'ppr799223': {'behaviour'},
#   '39459826': {'lime'},
#   '39464058': {'gpl', 'learning'},
#   'ppr931370': {'lema'},
#   '38145338': {'learning'},
#   '39460160': {'learning'},
#   '39465345': {'behaviour', 'transport'},
#   '39460245': {'radio'},
#   '39357689': {'memory'},
#   '39459688': {'behavior'},
#   '39462664': {'feature extraction', 'short-term memory'},
#   '39136105': {'electron', 'transport'},
#   'ppr931140': {'epithelial-mesenchymal transition', 'sim'},
#   '39462082': {'learning'},
#   '39459198': {'learning'},
#   '39465038': {'behaviors'},
#   '38397650': {'learning'},
#   '39448717': {'swimming'},
#   '39463940': {'learning'},
#   '39109600': {'learning', 'mlip'},
#   '38126743': {'ischaemia'},
#   '39260204': {'at a p'},
#   '39461118': {'bicuspid aortic valve', 'thrombotic'},
#   '38405609': {'interactions prediction', 'learning'},
#   '39463017': {'turkey'},
#   '39462873': {'composite'},
#   '39460249': {'radio'},
#   '39459603': {'amputation', 'trauma'},
#   '39095637': {'spam'},
#   '39465428': {'adc'},
#   '39120991': {'learning', 'visual fatigue'},
#   '39463014': {'behaviors', 'cfi', 'nfi'},
#   '39465230': {'aids', 'learning'},
#   '39207566': {'total hip arthroplasty'},
#   '39460235': {'asphalt', 'learning'},
#   '39463684': {'tobacco'},
#   'ppr320515': {'peach'},
#   '39401841': {'kidney replacement'},
#   '39465091': {'sensitization'},
#   '39234937': {'behavior'},
#   'ppr919220': {'plm'},
#   '38384363': {'spam'},
#   '38406474': {'learning'},
#   '39465306': {'memory', 'smoother'},
#   '39459781': {'behavior'},
#   '38400360': {'learning'},
#   '39231869': {'behaviors'},
#   '38990677': {'behavior'},
#   '39465547': {'eating behaviour', 'obese'},
#   '39463283': {'behaviour', 'behaviours'},
#   '39467096': {'learning'},
#   '38405981': {'python'},
#   '39463077': {'radio'},
#   '39459753': {'asphalt', 'behavior'},
#   '39460155': {'learning'},
#   '38703196': {'learning'},
#   '38857142': {'behavior', 'cannula'},
#   '39453801': {'learning'},
#   '39463602': {'hyperplasia', 'postoperative complications'},
#   '38395914': {'uptake'},
#   'ppr729768': {'recombination'},
#   'ppr925798': {'learning'},
#   '39464846': {'snap'},
#   'ppr931521': {'cmd'},
#   '39466165': {'athletes', 'torque'},
#   '39455601': {'eruptions', 'gamma', 'kiama'},
#   '38261075': {'trauma'},
#   '39467167': {'mage'},
#   '39465477': {'behavior', 'behaviors'},
#   '39459134': {'display technology'},
#   'ppr874144': {'torque'},
#   '39464205': {'meniscus'},
#   '39292579': {'learning'},
#   '39455875': {'memory'},
# ...
#   '39465036': {'trauma'},
#   '39459983': {'ams'},
#   '39466614': {'coffee'},
#   '39460248': {'learning'},
#   '39464306': {'transport'},
#   '39465648': {'fcs', 'quantum dot', 'transport'},
#   '39459149': {'cnc'},
#   'ppr899253': {'feature extraction'},
#   '39462758': {'memory'},
#   'ppr917491': {'fgd'},
#   '39361205': {'behavior'},
#   '39460122': {'adc'},
#   '39463844': {'degenerations'},
#   '39465192': {'learning'},
#   '39466802': {'torque'},
#   '39466423': {'behaviour', 'learning', 'scraping'},
#   'ppr931465': {'aar', 'feature extraction'},
#   '39459130': {'honeycomb'},
#   '39465533': {'learning'},
#   '39466999': {'vip'},
#   'ppr729197': {'waters'},
#   'ppr725206': {'learning', 'sca'},
#   '39461811': {'incest'},
#   '39462418': {'malo', 'transposition'},
#   '39460204': {'gan', 'learning', 'vif'},
#   '38582224': {'hss'},
#   '39457389': {'cellular homeostasis'},
#   '39461071': {'hoods'},
#   '39459099': {'quantum dots', 'quantum-dot'},
#   'ppr715893': {'learning'},
#   '39463080': {'short-term memory'},
#   '39416135': {'learning', 'orthrus'},
#   '38969956': {'behavior', 'fsi'},
#   '39466097': {'learning'},
#   '39466012': {'behavior'},
#   '39088713': {'bone regeneration',
#    'defect',
#    'defects',
#    'mastication',
#    'regeneration',
#    'stump',
#    'stumps'},
#   '39463335': {'trauma'},
#   'ppr898585': {'learning'},
#   '39461072': {'behavior'},
#   '39460102': {'ris'},
#   '39459429': {'bile leak', 'postoperative complications'},
#   '39464850': {'behaviour', 'behaviours'},
#   '37658256': {'behavior'},
#   '37916486': {'infarct', 'rubber', 'svv'},
#   'ppr729611': {'pci', 'ssv', 'u50'},
#   '39463032': {'behavior'},
#   '39461035': {'retrognathia'},
#   '39458956': {'behavior', 'learning'},
#   'ppr872573': {'turkey'},
#   '39458099': {'chronic pain'},
#   '39459148': {'chip', 'electron'},
#   '39459798': {'behavior', 'behaviors'},
#   '39460112': {'amd', 'memory', 'rice', 'vhdl'},
#   '39458239': {'composite', 'rsa'},
#   '39459709': {'behavior'},
#   '39465588': {'strabismus', 'xxx'},
#   '38405777': {'interaction predictions', 'learning'},
#   '39465034': {'behaviors'},
#   '16686795': {'sesame'},
#   'ppr721162': {'cdd', 'csv', 'versed'},
#   '39463755': {'learning'},
#   'ppr839515': {'defects'},
#   'ppr931507': {'panama'},
#   '39301949': {'ans'},
#   'ppr720980': {'learning'},
#   '39029584': {'trauma'},
#   '39463302': {'compulsion'},
#   '39459728': {'pores'},
#   'ppr670794': {'congestion', 'stc'},
#   '39462702': {'hemorrhage',
#    'hemorrhagic shock',
#    'hepatic artery pseudoaneurysm'},
#   '39461556': {'learning'},
#   '39466209': {'behavior'},
#   'ppr776308': {'learning'},
#   'ppr927626': {'learning'},
#   '39460022': {'short-term memory'},
#   '39463655': {'bone necrosis', 'heat generation'},
#   '39453898': {'behaviours'},
#   '39466011': {'behavior', 'behaviors'},
#   '39459987': {'inversion', 'venous engorgement'},
#   '39463468': {'delta', 'reproduction'},
#   '39464386': {'tobacco'},
#   '39465106': {'learning'},
#   '39466869': {'itr'},
#   'ppr931221': {'memory'},
#   '38308947': {'behavior', 'learning'},
#   '39463290': {'nbsp'},
#   'ppr931386': {'vhr'},
#   'ppr730579': {'behavior', 'learning'},
#   'ppr925042': {'asphalt', 'learning', 'python'},
#   '38406409': {'learning'},
#   '38829759': {'learning'},
#   'ppr919031': {'psychiatric diagnosis'},
#   '38406452': {'learning'},
#   '39404795': {'scrna-seq', 'single-cell sequencing'},
#   '39465070': {'hormone replacement therapies', 'tasmania'},
#   '39149838': {'atoms', 'electron'},
#   '39463459': {'behavior'},
#   '39466159': {'breakdowns', 'learning'},
#   'ppr922393': {'learning'},
#   '37730933': {'learning'},
#   '37890120': {'cancer'},
#   '39044009': {'nfp'},
#   '38390351': {'deaths'},
#   '39464874': {'trauma'},
#   '39466486': {'tectonic'},
#   '39462988': {'clare'},
#   '39265275': {'learning'},
#   'ppr914044': {'-dc'},
#   '39457276': {'haemoglobin'},
#   'ppr718136': {'wildfire', 'wildfires'},
#   '37604961': {'android'},
#   'ppr767199': {'learning', 'sev'},
#   '39466356': {'gpt', 'translation', 'translations'},
#   '38385144': {'mental impairments'},
#   '39460073': {'learning'},
#   '39467183': {'behavior'},
#   '38382881': {'learning', 'v(+)', 'v(0)'},
#   '39467198': {'rhode', 'trauma'},
#   'ppr917073': {'behaviours', 'learning', 'learnings'},
#   '39458746': {'composite', 'delamination'},
#   '39460089': {'c2f', 'feature extraction'},
#   '39460207': {'memory'},
#   'ppr931424': {'sex determination'},
#   '37902255': {'chronic low back pain'},
#   '39466426': {'xxx'},
#   '39459400': {'trauma'},
#   '39462735': {'learning', 'uptake'},
#   'ppr721681': {'aids', 'translation'},
#   '39462636': {'learning'},
#   '39457323': {'learning'},
#   '39368049': {'acp'},
#   '39190958': {'behavior', 'behaviors'},
#   '39455673': {'learning'},
#   '39459240': {'atoms'},
#   '38644742': {'critically ill'},
#   '39088409': {'mlp', 'mlps'},
#   '38767797': {'cardiogenic shock', 'ischemia'},
#   '39459985': {'learning', 'memory'},
#   '39285084': {'behavior'},
#   '39459300': {'recombination'},
#   '38320103': {'learning'}},
#  'found_in_ml_not_in_dict': {'38379451': {'interoception'},
#   '38499952': {'covid-19'},
#   '32321880': {'diffuse disease', 'focal disease'},
#   '32321881': {'access', 'vascular access dysfunction'},
#   '37845422': {'behavioral'},
#   '38384368': {'cyberchondria'},
#   '38384774': {'behavioural'},
#   '37830345': {'covid-19'},
#   '34677678': {'adolescent idiopathic scoliosis', 'scoliosis'},
#   '37979209': {'animal', 'behavioral', 'organization'},
#   '37488465': {'neurological impairment'},
#   '37566336': {'behavioural'},
#   '37126798': {'developmental delays', 'opioid'},
#   '38363774': {'covid-19', 'covid-19 infection'},
#   '37429984': {'behavioral'},
#   '37352928': {'sugar', 'sugars'},
#   '37801067': {'spinal cord injury'},
#   '38375445': {'covid-19'},
#   '38031278': {'-19'},
#   '38856964': {'covid-19', 'covid-19 infection'},
#   '37798596': {'behavioral'},
#   '38380781': {'tim'},
#   '38328875': {'behavioral'},
#   '38414019': {'organization'},
#   '38414221': {'beach'},
#   '38406253': {'tree'},
#   '38392985': {'complex'},
#   '38389694': {'-19'},
#   '38410658': {'root canals'},
#   '38415087': {'covid-19'},
#   '38409309': {'behavioral'},
#   '38410717': {'copd'},
#   '38384977': {'women'},
#   '38419764': {'anthocephalus macrophyllus', 'tree', 'wood formation'},
#   '38419004': {'spinal cord injuries', 'spinal cord injury'},
#   '38394087': {'covid-19'},
#   '38400133': {'covid-19'},
#   '38407654': {'behavioral', 'organization'},
#   '38407815': {'men', 'women'},
#   '38397663': {'behavioral'},
#   'ppr806756': {'covid-19'},
#   'ppr830543': {'tree'},
#   'ppr832317': {'covid-19'},
#   '39034600': {'birth injuries'},
#   '38426146': {'bacteria'},
#   '38438108': {'distal femoral fracture'},
#   '38300851': {'cyclooxygenase', 'herg', 'ion channels'},
#   '37913868': {'adolescent idiopathic scoliosis',
#    'idiopathic scoliosis',
#    'scoliosis'},
#   '38950877': {'acl',
#    'acl injury',
#    'anterior cruciate ligament',
#    'anterior cruciate ligament injury',
#    'injury'},
#   '39225238': {'-19', 'covid-19'},
#   '39183429': {'hernias', 'obturator hernia', 'oh'},
#   '38944670': {'women'},
#   '39174679': {'dysphonia'},
#   '37916522': {'ligament'},
#   '39016260': {'adolescent idiopathic scoliosis',
#    'idiopathic scoliosis',
#    'neuromuscular scoliosis',
#    'scoliosis'},
#   '38420628': {'behavioural'},
#   '39459711': {'msp', 'sap'},
#   '39460340': {'covid-19'},
#   '39242408': {'glottic insufficiency'},
#   '39235158': {'nucleic acid'},
#   '39241458': {'adhd'},
#   '38640045': {'goniochromatism'},
#   '38637929': {'cd8'},
#   '38823498': {'behavioral'},
#   '38810535': {'covid-19'},
#   '38814287': {'neo', 'pouch', 'reanastomosis', 'rep'},
#   'ppr307692': {'women'},
#   'ppr870124': {'bird'},
#   'ppr896976': {'injury'},
#   'ppr895846': {'plant'},
#   'ppr843877': {'covid-19'},
#   'ppr839850': {'animal'},
#   'ppr853356': {'pd'},
#   '38197327': {'coarctation of aorta',
#    'coarctation of the aorta',
#    'foramen',
#    'mitral valve',
#    'tricuspid valve'},
#   'ppr928747': {'-19'},
#   'ppr931402': {'covid-19'},
#   'ppr931416': {'chinese netizens'},
#   'ppr931356': {'mangroves'},
#   'ppr931094': {'microbiota', 'piglets', 'sugars'},
#   'ppr910737': {'plant'},
#   'ppr931314': {'brain injury'},
#   'ppr931345': {'transportation'},
#   'ppr906459': {'grapevine', 'grapevines'},
#   'ppr930100': {'animal'},
#   'ppr930526': {'binding'},
#   'ppr929963': {'interoception'},
#   'ppr931477': {'transportation'},
#   'ppr931495': {'transportation'},
#   'ppr931448': {'covid-19'},
#   '38546346': {'organization'},
#   '37655558': {'covid-19'},
#   'ppr719909': {'tai', 'traumatic brain injury'},
#   'ppr715881': {'covid-19'},
#   'ppr728381': {'neuropsychiatric disorders', 'theta rhythms'},
#   'ppr729897': {'cataract'},
#   'ppr729938': {'women'},
#   'ppr729940': {'ed'},
#   'ppr725482': {'breast cancer', 'cancer', 'tumor'},
#   'ppr728943': {'assays'},
#   'ppr719065': {'women'},
#   'ppr722251': {'covid-19'},
#   'ppr712261': {'fungal', 'fungi'},
#   '37639503': {'parkinson'},
#   '39107656': {'phenolic', 'phenolic compounds'},
#   '39117802': {'amino-acid'},
#   '37612451': {'transportation', 'women'},
#   '37620747': {'binding'},
#   '38562284': {'brain injury', 'traumatic brain injury'},
#   '38751311': {'-19'},
#   '38767547': {'pe'},
#   '38761371': {'interpersonal violence',
#    'intimate partner violence',
#    'violence'},
#   '39462480': {'alkyne',
#    'benzene',
#    'boron',
#    'carbonyl',
#    'cobalt',
#    'conjugation',
#    'fluorene',
#    'homopolymers',
#    'synthesis'},
#   '39462214': {'peri-implant diseases'},
#   'ppr900859': {'covid-19'},
#   '39448769': {'tree', 'trees'},
#   '38622860': {'lat'},
#   '39462181': {'-19', 'covid-19'},
#   '39462168': {'women'},
#   '39462304': {'mentally ill', 'neurophysiological dysfunctions', 'women'},
#   '39462399': {'organization'},
#   '39462417': {'malocclusion'},
#   '39448686': {'behavioral', 'organization'},
#   '39459470': {'malocclusion'},
#   '39459836': {'cvd'},
#   '39460106': {'lumens'},
#   '30405682': {'cleft', 'cleft lip'},
#   '38780550': {'covid-19'},
#   '39462332': {'men', 'women'},
#   '39461980': {'oyster'},
#   '39461763': {'dural sinus malformations',
#    'fistula',
#    'neurovascular malformation',
#    'vein of galen malformations'},
#   '39462149': {'-19', 'covid-19'},
#   '39462284': {'ballet'},
#   '39462286': {'avascular necrosis', 'necrosis', 'talus', 'ttr'},
#   '39467281': {'geriatric syndrome', 'women'},
#   '39459533': {'hyperalgesia'},
#   '39459550': {'animal'},
#   '39462053': {'amino acid', 'amino acids'},
#   '39460054': {'grass'},
#   '39459243': {'plant', 'soda'},
#   '39467272': {'foot injuries'},
#   '39459756': {'carbide'},
#   '39459424': {'adolescent idiopathic scoliosis',
#    'idiopathic scoliosis',
#    'scoliosis'},
#   '39467163': {'intimate partner violence', 'men', 'women'},
#   '39459369': {'women'},
#   '39459971': {'plant', 'virus', 'viruses'},
#   '39460082': {'transportation'},
#   '39455593': {'brain injury', 'concussion', 'src'},
#   '39457287': {'organization'},
#   '39455613': {'plant', 'teak', 'trees'},
#   '39457291': {'-19'},
#   '39457292': {'covid-19'},
#   '39457296': {'-19', 'covid-19'},
#   '39457332': {'psychological distress'},
#   '39457334': {'development disabilities', 'developmental delays'},
#   '39457338': {'-19'},
#   '39457339': {'covid-19'},
#   '39455631': {'gold'},
#   '39457308': {'transportation'},
#   '39457261': {'autonomy'},
#   '39457315': {'covid-19'},
#   '39457316': {'women'},
#   '39457269': {'alcohol'},
#   '39457272': {'covid-19'},
#   '39457322': {'locomotive syndrome', 'ls'},
#   '39461233': {'burnout', 'psychological distress'},
#   '39461373': {'misophonia', 'panic'},
#   '39464444': {'coal mine'},
#   '39464526': {'acute brain injuries'},
#   '39464948': {'men', 'women'},
#   '39465405': {'addictive disorders', 'igd', 'internet gaming disorder'},
#   '39463141': {'covid-19'},
#   '39458016': {'women'},
#   '39458448': {'eating psychopathology', 'ed', 'eds', 'psychopathology'},
#   '39464166': {'amino acid', 'amino acids', 'amino-acid'},
#   '39464228': {'pilonidal sinus', 'pns'},
#   '39464445': {'monochalcogenide'},
#   '39464994': {'covid-19'},
#   '39465058': {'head injuries', 'hi'},
#   '39465061': {'attachment', 'lat', 'women'},
#   '39465503': {'gfp'},
#   '39465925': {'abpp'},
#   '39462485': {'behavioral'},
#   '39463275': {'animal'},
#   '39459146': {'antibodies'},
#   '39464296': {'plant'},
#   '39464987': {'women'},
#   '39465064': {'woman'},
#   '39465209': {'ace'},
#   '39465279': {'women'},
#   '39465516': {'behavioral'},
#   '39464038': {'microbiota', 'microorganisms'},
#   '39464385': {'chalcogenide'},
#   '39464552': {'-19'},
#   '39464657': {'opioid'},
#   '39464553': {'men', 'women'},
#   '39462799': {'tia'},
#   '39462800': {'covid-19', 'organization'},
#   '39463303': {'mentally ill'},
#   '39458824': {'plant'},
#   '39461034': {'-19'},
#   '39461402': {'men', 'women'},
#   '39464189': {'circadian syndrome'},
#   '39464563': {'psychological distress', 'women'},
#   '39464873': {'organization'},
#   '39465540': {'fracture'},
#   '39465740': {'fracture'},
#   '39462812': {'women'},
#   '39463307': {'covid-19'},
#   '39461160': {'women'},
#   '39462674': {'bacteria'},
#   '39463327': {'diarrhea'},
#   '39458163': {'covid-19', 'covid-19 pneumonia', 'pneumonia'},
#   '39459189': {'amino acid', 'amino acids', 'sugar', 'sugars'},
#   '39465659': {'dvt'},
#   '39465656': {'organosilica'},
#   '39466741': {'radiocarbon'},
#   '39463457': {'primus'},
#   '39465667': {'burnout'},
#   '39465668': {'aortic root disease'},
#   '39466879': {'hypothermia'},
#   '39463095': {'women'},
#   '39463333': {'-19', 'covid-19'},
#   '39461176': {'microplastics'},
#   '39461295': {'binding'},
#   '39464501': {'women'},
#   '39466151': {'organization'},
#   '39462562': {'locomotive syndrome', 'sarcopenia', 'vitamin d', 'women'},
#   '39462961': {'fracture'},
#   '39462965': {'chronic shoulder diseases'},
#   '39463352': {'women'},
#   '39463462': {'-19'},
#   '39458183': {'anterior', 'ligament'},
#   '39465869': {'ls'},
#   '39465950': {'men', 'women'},
#   '39466062': {'-19'},
#   '39466127': {'covid-19'},
#   '39466163': {'men'},
#   '39466514': {'covid-19'},
#   '39462717': {'-19', '19', 'covid-19'},
#   '39464816': {'sarcopenia'},
#   '39464813': {'sarcopenia'},
#   '39466037': {'metabolic syndrome', 'vitamin c'},
#   '39466452': {'women'},
#   '39466730': {'transportation'},
#   '39466771': {'organization'},
#   '39463863': {'noncommunicable diseases'},
#   '39462576': {'brachial plexus injury'},
#   '39463120': {'muscle tension dysphonia'},
#   '38676438': {'covid-19'},
#   '39464921': {'covid-19'},
#   '39466233': {'adsorption'},
#   '39466278': {'idiopathic scoliosis', 'is', 'scoliosis'},
#   '39466425': {'heat', 'heat illness'},
#   '39466944': {'women'},
#   '39458771': {'polymers'},
#   '39461469': {'hallux'},
#   '39463888': {'covid-19', 'covid-19 infection'},
#   '39463499': {'hemorrhoids'},
#   '39463629': {'hypothermia'},
#   '39458541': {'sugar'},
#   '39462750': {'cas12a', 'cas9', 'microorganisms'},
#   '39462756': {'cyst', 'cysts'},
#   '39463250': {'behavioural'},
#   '39459878': {'virus'},
#   '39462187': {'sarcopenia'},
#   '39462413': {'men', 'women'},
#   '39432589': {'nasal septal deviation', 'tinnitus'},
#   '39441053': {'chronic lateral ankle instability'},
#   '39443600': {'x-ray'},
#   '39425729': {'malocclusion', 'malocclusions'},
#   '39459399': {'cpak'},
#   '39460341': {'covid-19'},
#   '39459353': {'circulation', 'nt-probnp'},
#   '39460174': {'transportation'},
#   '39462070': {'tree'},
#   '39400242': {'injury'},
#   '39416101': {'organization'},
#   '39416032': {'paralysis'},
#   '39459601': {'hh'},
#   '39331537': {'covid-19'},
#   '39342442': {'adhd'},
#   '39342542': {'women'},
#   '39324524': {'women'},
#   '39331126': {'genitourinary disorders'},
#   '39330831': {'organization'},
#   '39347614': {'amphibian'},
#   '39354099': {'acl',
#    'acl injuries',
#    'acl injury',
#    'acl) tears',
#    'anterior',
#    'anterior cruciate ligament',
#    'ligament'},
#   '39305795': {'behavioral'},
#   '39315553': {'ligament'},
#   '39305543': {'women'},
#   '39304180': {'women'},
#   '39303434': {'psychopathology'},
#   '39304578': {'firearm', 'violence'},
#   '39320985': {'organization'},
#   '39318151': {'adhd'},
#   '39297503': {'-19', 'covid-19'},
#   '39152666': {'grey wolves'},
#   '39140653': {'covid-19'},
#   '38979920': {'organization'},
#   '38979941': {'tubercle'},
#   '37449467': {'carbohydrate'},
#   '38889850': {'men', 'women'},
#   '39376182': {'women'},
#   '39282921': {'adhd', 'women'},
#   '39289144': {'organization'}}}
